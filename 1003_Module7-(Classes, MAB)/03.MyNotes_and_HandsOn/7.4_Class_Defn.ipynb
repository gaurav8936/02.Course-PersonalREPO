# %% [markdown]
# # Using the Class Definition

# %%
class Drone:
    
    power_system = 'battery'

# %%
# looks like a variable assignment
# but this is a class attribute as it is inside the class

# %%
class Drone:
    
    power_system = "battery"
    
    
    # define a method
    def fly(self):
        
        return "The drone is flying"

# %%
d = Drone()

print(d.fly())
# Out:
# The drone is flying

# %% [markdown]
# ---

# %% [markdown]
# ### SELF

# %%
# means this specific instance that the class Drone is called for

# %%
class Drone:
    
    power_system = "battery"
    
    
    # define a method
    # use the self attribute to access power_system
    
    def fly(self):
        
        return "The drone is flying with a ", self.power_system
#        return "This is ", self.power_system

# %%
d = Drone()

print(d.fly())
# Out:
# ('The drone is flying with a ', 'battery')

# %%
d1 = Drone()
d2 = Drone()
d1.power_system = "dream"

print(d1.fly())
# only updates attribute for d1


print(d2.fly())
# Out:
# ('The drone is flying with a ', 'dream')
# ('The drone is flying with a ', 'battery')

# %% [markdown]
# ---

# %% [markdown]
# ### taking in a parameter

# %%
class Drone:
    
    power_system = "battery"
    
    
    # define a method
    # use the self attribute to access power_system
    
    def fly(self):
        
        return "The " + self.power_system + " - powered drone is flying at an altitude of " + str(self.altitude)

# creae a new method to ascend
    
    def ascend(self, change):
        self.altitude += change
    

# this is the functionality we want
d = Drone()
d.altitude = 0
d.fly()
d.ascend(100)
d.fly()
# Out:
# 'The battery - powered drone is flying at an altitude of 100'

# %%
# that the return method just printed the last output

# %%
class Drone:
    
    power_system = "battery"
    
    
    # define a method
    # use the self attribute to access power_system
    
    def fly(self):
        
        # return "The " + self.power_system + " - powered drone is flying at an altitude of " + str(self.altitude)
        print("The " + self.power_system + " - powered drone is flying at an \
        altitude of " + str(self.altitude))

# creae a new method to ascend
    
    def ascend(self, change):
        self.altitude += change
    

# this is the functionality we want
d = Drone()
d.altitude = 0
d.fly()
d.ascend(100)
d.fly()
# Out:
# The battery - powered drone is flying at an         altitude of 0
# The battery - powered drone is flying at an         altitude of 100

# %% [markdown]
# ---

# %%
# my interpretation
# why +- change was needed

class Drone:
    
    power_system = "battery"
    
    
    # define a method
    # use the self attribute to access power_system
    
    def fly(self):
        
        # return "The " + self.power_system + " - powered drone is flying at an altitude of " + str(self.altitude)
        print("The " + self.power_system + " - powered drone is flying at an \
        altitude of " + str(self.altitude))

# creae a new method to ascend
    
    #def ascend(self, change):
    def ascend(self, altitude):
        
        # self.altitude += change
        self.altitude += altitude
    

# this is the functionality we want
d = Drone()
d.altitude = 0
d.fly()
d.ascend(100)
d.fly()
# Out:
# The battery - powered drone is flying at an         altitude of 0
# The battery - powered drone is flying at an         altitude of 100

# %% [markdown]
# ---

# %% [markdown]
# ---

# %% [markdown]
# # 7.5.1 Binding Methods

# %% [markdown]
# ![image.png](attachment:9cc3fbc5-8a3a-49e3-b3fe-5684da8907c3.png)

# %%
# d.ascend -- this binds the method ascend to the object d


# self ? dont fully understand

# %% [markdown]
# ![image.png](attachment:de9cc3ac-e7b3-4f29-b592-17bb0b36ad32.png)

# %% [markdown]
# ![image.png](attachment:3b3fefb4-139b-4c7d-a99a-0f0617a1b8eb.png)
