# %%
import sys
import string

scores = {"a": 1, "c": 3, "b": 3, "e": 1, "d": 2, "g": 2,
          "f": 4, "i": 1, "h": 4, "k": 5, "j": 8, "m": 3,
          "l": 1, "o": 1, "n": 1, "q": 10, "p": 3, "s": 1,
          "r": 1, "u": 1, "t": 1, "w": 4, "v": 4, "y": 4,
          "x": 8, "z": 10}

# # Get the Scrabble rack from the command line.
# if len(sys.argv) < 2:
#     print("no rack error.")
#     exit(1)

# # rack = sys.argv[1]
# # rack_low = rack.lower()
rack_low = 'h?a*'

def run_scrabble(rack):
    # this is the main function inside the file scrabble.py


# Turn the words in the sowpods.txt file into a Python list.
with open("sowpods.txt","r") as infile:
    raw_input = infile.readlines()[0:1]
    data = [datum.strip('\n') for datum in raw_input]
    print(data)

# Find all of the valid sowpods words that can be made
# up of the letters in the rack.
valid_words = []


########### Renamed function (can_make_word to can_spell) ############
def can_spell(word):
    rack_letters = list(rack_low)
    #print(rack_letters)
    for letter in word_low:
        if letter in rack_letters:
            rack_letters.remove(letter)
        elif '*' in rack_letters:
            rack_letters.remove('*') 
        elif '?' in rack_letters:
            rack_letters.remove('?')
        else:
            return False
        print(rack_letters)
    return True


########### Alternate matching format ############
# def can_spell(word, rack):
#     """Determine if a word can be spelled with the given rack."""
#     letter_bank = list(rack)
#     for letter in word:
#         if letter not in letter_bank:
#             return False
#         letter_bank.remove(letter)
#     return True

##################################################

for word in data:
    word_low = word.lower()
    if can_spell(word_low):
        # Get the Scrabble scores for each word.
        total = 0
        for letter in word_low:
            total = total + scores[letter]
        valid_words.append([total, word_low])

valid_words.sort(reverse = True)
for entry in valid_words:
    score = entry[0]
    word_low = entry[1]
    print((score, word_low))

print("Total number of words:", len(valid_words))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [2], in <cell line: 63>()
#      48     return True
#      51 ########### Alternate matching format ############
#      52 # def can_spell(word, rack):
#      53 #     """Determine if a word can be spelled with the given rack."""
#    (...)
#      60
#      61 ##################################################
# ---> 63 for word in data:
#      64     word_low = word.lower()
#      65     if can_spell(word_low):
#      66         # Get the Scrabble scores for each word.
#
# NameError: name 'data' is not defined
