# %%
import wordscore
import sys
import argparse

def run_scrabble(rack):
    
    """
    This is a modified version of the traditional scrabble game. The user plays the game
    from the command promt by running run_scrabble and provides the 'rack' as the input.
    The rack is the selection of between 2-7 words and special characters (* or ? only)
    
    The highlights of the game are
    
    1. Allow anywhere from 2-7 character tiles (letters A-Z, upper or lower case)
    2. Do not restrict the number of same tiles (e.g., a user is allowed to input ZZZZZQQ).
    3. There can be a total of only two wild cards in any user input 
       that is, one of each character: one `*` and one `?`). 
       Only use the `*` and `?` as wildcard characters. 
    4. A wildcard character can take any value A-Z. 
    5. Wildcard characters are scored as 0 points, just like in the real Scrabble game. 
       A word that just consists of two wildcards can be made, should be outputted and 
       scored as 0 points.  
    """
    
    ################ COMMAND LINE ARGS ###################################    
    
    # parser = argparse.ArgumentParser()
    # parser.add_argument('rack', nargs='?')
    # args = parser.parse_args()
    # if len(sys.argv) == 1:
    #     print("Please supply some letters. Ex: 'python scrabble.py RSTLNEI'")
    #     exit()
    # rack = args.rack.lower()
    
    # rack = sys.argv[1]
    # print(rack)
    # rack = str(rackin)
    
    # rack = str(sys.argv).lower()
    #renamed argv to 'rack' just to make it easier for me to read
    
    ############### INITIALIZATION ################################
    
    # converts the input rack to lower case
    rack_low = rack.lower() 
    
    
    rack_letters = list(rack_low) 
    # converts the rack to a list of letters
    
    valid_words = [] 
    # An empty list that will eventually hold all valid words from the scrabble dictionary sowpods.txt
    
    valid_rack = True
    # A boolean condition the evaluates the contents of the rack as valid or not
    
    clean_word = []
    # this removes the special characters from the rack
    # may not be really useful -- as the word is already formed
    
    clean_rack = []
    # this removes the special characters from the rack
   
    ################ VALIDATIONS ###################################
    if (rack_low.count('?') > 1 or  rack_low.count('*')) > 1:
        return ("You have entered more than 2 special characters")
        valid_rack = False
        
        # checks the condition for only 1 of the special characters is allowed
        # ie the user cannot enter two * or two ?
        # the user can enter one * and one ?
    
    
    elif len(rack_low) > 7 or len(rack_low) < 2:
        return ("You have entered more than 7 characters or less than 2")
        valid_rack = False
        
        # checks the number of letters in the rack for a minimum of 2 and maximum of 7

    ######################################################################
    
    elif all(x.isalpha() or x in ('?', '*') for x in rack_low):
        valid_rack = True
        pass
    
         # checks if the contains only alphabets or special characters (* ?)
    
    else:
        return ('You have entered non-permitted characters. Please enter only alphabets and/or special characters * and ?')

        valid_rack = False
        
         # this condition needs rework
         # would 
    
    ######################################################################

    #    Deprecated code: Replaced with condition above (would like to make this work
    #    but condition is not tight enough

    #     elif all(x.isalpha() == False and x not in ('?', '*') for x in rack_low):
    #         valid_rack = False
    #         return ('You have entered non-permitted characters. Please enter only alphabets and/or special characters * and ?')


    #         # checks if the contains only alphabets or special characters (* ?)

    #     else:
    #         valid_rack = True

    #         # this condition needs rework
        
    ######################################################################    
        
    
    if valid_rack:

        # reads the scrabble reference dictionary and creates a data list
        # after stripping the line breaks
        
        with open("sowpods.txt","r") as infile:
            raw_input = infile.readlines()#[0:1000]
            data = [datum.strip('\n') for datum in raw_input]
        
        # this is the matching algorithm that iterates through each word in the
        # scrabble dictionary (data) and checks whether the letters exists in the 
        # user input (rack). This also accounts for the two special characters (*, ?)
        # and by a process of elimination is able to implicitly substitute them for 
        # other alphabets
        
        for word in data:
            word_low = word.lower()
            temp_rack_letters = rack_letters.copy() 
            
            ############# INSERTION ON 10/3 ################
            
            candidate = True
            
            ############# INSERTION ON 10/3 ################
            
            # Iterate each letter in the word and check if the letter is in the
            # Scrabble rack. If used once in the rack, remove the letter from the rack.
            # If there's no letter in the rack, skip the letter.
                
            for letter in word_low:
                if letter in temp_rack_letters :
                    temp_rack_letters .remove(letter)
                elif '*' in temp_rack_letters :
                    temp_rack_letters .remove('*') 
                elif '?' in temp_rack_letters :
                    temp_rack_letters .remove('?')
                else:
                    candidate = False
                    #break 
            
                #print('word_low', word_low)
            ####################### WILDCARD ZERO-ORIGINAL ###################
            
            # else:
            #     valid_words.append([score_word(word_low), word_low.upper()])
        
            ####################### WILDCARD ZERO-REWORK ########################
        
            if candidate == True:
#            else:
#                clean_word = ''.join([i for i in word_low if i.isalpha()])
                # removes the special characters from the rack 
                # print(clean_rack)
                # this is really not that helpful -- as it is already the fully formed word
                
                clean_rack = [letter for letter in rack_low if letter.isalpha()]
                print('clean_rack', clean_rack)

                clean_word = [letter for letter in word_low if letter in clean_rack]
                # this seems to work -- matches only letter in word_low to that of the clean rack
                print('clean_word', clean_word)
           
            ####################### FIXING DEDUPLICATE FN - LETTER REPETITIONS - ZZZZEE ########################
        
        
                # clean_word_deduplicate = set(clean_word) & set(clean_rack)
                # print('clean_word_deduplicate', clean_word_deduplicate)
        
                # deduplicate the widlcard (case of '?a' and double counting of cases like 'aa')
            
            
            ####################### Trying out new solution for deduplication (set was only returning 1 for ZZZZEE ######
                
                clean_word_deduplicate = []
                
                if len(clean_rack) < len(clean_word):
                    for i in clean_rack:
                        if (i in clean_word):
                            clean_word_deduplicate.append(i)
                else:
                    for i in clean_word:
                        if (i in clean_rack):
                            clean_word_deduplicate.append(i)
            
                print('clean_word_deduplicate NEW', clean_word_deduplicate)
        
            ####################### SCORING WILDCARD ZERO-REWORK ########################
        
                #valid_words.append([wordscore.score_word(clean_word), word_low.upper()])
                # changing the code to take the new clean_word_deduplicate
                
                valid_words.append([wordscore.score_word(clean_word_deduplicate), word_low.upper()])
                
                # returns the scores for the words in the clean_rack
                # by using clean_word and word_low, they are both derived from word_low
                # so the basis is the same
                print('valid_words', valid_words)
                
        
            ######################################################################
    
    else:
        valid_rack = False 
    
    ################ with SORTED #######################
    valid_words_sorted = sorted(valid_words,key=lambda x:(-x[0],x[1]))
    valid_words_sorted_tuples = []
    valid_words_sorted_tuples = [tuple(l) for l in valid_words_sorted]
    # this converts list content to one that is required by the course - a list of tuples
    
    return valid_words_sorted_tuples, len(valid_words)
    #print(valid_words_sorted_tuples, len(valid_words))

# %%
run_scrabble('QU*ZZ')
# Out:
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'z', 'z']
# clean_word_deduplicate NEW ['u', 'z', 'z']
# valid_words [[21, 'BUZZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'z']
# clean_word_deduplicate NEW ['u', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'z', 'z']
# clean_word_deduplicate NEW ['u', 'z', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'z']
# clean_word_deduplicate NEW ['u', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'z', 'z']
# clean_word_deduplicate NEW ['u', 'z', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['q']
# clean_word_deduplicate NEW ['q']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['q', 'u']
# clean_word_deduplicate NEW ['q', 'u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['q', 'u', 'z']
# clean_word_deduplicate NEW ['q', 'u', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'q']
# clean_word_deduplicate NEW ['u', 'q']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u', 'z', 'z']
# clean_word_deduplicate NEW ['u', 'z', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['u']
# clean_word_deduplicate NEW ['u']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU'], [1, 'YU']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['z']
# clean_word_deduplicate NEW ['z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU'], [1, 'YU'], [10, 'ZA']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['z', 'z']
# clean_word_deduplicate NEW ['z', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU'], [1, 'YU'], [10, 'ZA'], [20, 'ZIZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['z']
# clean_word_deduplicate NEW ['z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU'], [1, 'YU'], [10, 'ZA'], [20, 'ZIZ'], [10, 'ZO']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['z', 'u', 'z']
# clean_word_deduplicate NEW ['z', 'u', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU'], [1, 'YU'], [10, 'ZA'], [20, 'ZIZ'], [10, 'ZO'], [21, 'ZUZ']]
# clean_rack ['q', 'u', 'z', 'z']
# clean_word ['z', 'z', 'z']
# clean_word_deduplicate NEW ['z', 'z', 'z']
# valid_words [[21, 'BUZZ'], [11, 'CUZ'], [21, 'FUZZ'], [1, 'GU'], [11, 'LUZ'], [1, 'MU'], [21, 'MUZZ'], [1, 'NU'], [1, 'OU'], [10, 'QI'], [11, 'QUA'], [21, 'QUIZ'], [11, 'SUQ'], [21, 'TUZZ'], [1, 'UG'], [1, 'UH'], [1, 'UM'], [1, 'UN'], [1, 'UP'], [1, 'UR'], [1, 'US'], [1, 'UT'], [1, 'XU'], [1, 'YU'], [10, 'ZA'], [20, 'ZIZ'], [10, 'ZO'], [21, 'ZUZ'], [30, 'ZZZ']]
# ([(30, 'ZZZ'),
#   (21, 'BUZZ'),
#   (21, 'FUZZ'),
#   (21, 'MUZZ'),
#   (21, 'QUIZ'),
#   (21, 'TUZZ'),
#   (21, 'ZUZ'),
#   (20, 'ZIZ'),
#   (11, 'CUZ'),
#   (11, 'LUZ'),
#   (11, 'QUA'),
#   (11, 'SUQ'),
#   (10, 'QI'),
#   (10, 'ZA'),
#   (10, 'ZO'),
#   (1, 'GU'),
#   (1, 'MU'),
#   (1, 'NU'),
#   (1, 'OU'),
#   (1, 'UG'),
#   (1, 'UH'),
#   (1, 'UM'),
#   (1, 'UN'),
#   (1, 'UP'),
#   (1, 'UR'),
#   (1, 'US'),
#   (1, 'UT'),
#   (1, 'XU'),
#   (1, 'YU')],
#  29)
