# %% [markdown]
# # Sorting out basic design issues

# %% [markdown]
# ## Final Design Version before Cleaning

# %%
import numpy as np
import random
from collections import Counter

class User:
    def __init__(self):
        self.probability2 = random.uniform(0, 1)

    def show_ad(self):
        return  np.random.choice((True, False), p = [self.probability2, 1-self.probability2])

class Auction:
    
    def __init__(self, users, bidders):
        self.users = users
        self.bidders = bidders
        self.auction_history = []
        self.balances = {id(bidder): 0 for bidder in bidders} ########### NEW LINE
        print("*"*100, '\n')
        print('Beginning balances : ',self.balances, '\n','-'*100)
        
        
    def execute_round(self):
        
        ##### if the -ve balance of ALL bidders is < -1000, then break
        
        all_invalid_bidders = any(x > -1000 for x in self.balances.values())
        
        while not all_invalid_bidders:
            print("no bidders are qualifed as all balances are below -1000")
            break
        
        else:
            # print('starting balances2: ', self.balances2, '\n','-'*100)
            bids_dict = {}
            bids_list = []
            bids_list_raw = []

            # 1. SELECT USER (from the pool of users) ----------------------------------

            chosen_user = random.randint(0, len(self.users)-1)
            print('Selected User: ', id(chosen_user), '\n','-'*100) 

            # 2. COLLECT BIDS (send to all bidders) --------------------------------------------
            for bidder in self.bidders:
                #if self.balances[bidder] > -1000:
                #balances = {bidder: 0 for bidder in bidders} ########### NEW LINE
                if self.balances[id(bidder)] > -1000:
                    bids_dict[bidder] = bidder.bid(chosen_user)
                    bidding_round = bidder.bidding_round

                    self.auction_history.append((id(bids_dict[bidder]), bids_dict[bidder])) #bidder
                    highest_bid = 0
                    winning_price = 0
                else:
                    print("Bidder ", id(bidder), "balance is less than -1000. Cannot continue bid" )
     #               #raise Exception("Bidder's balance is less than -1000. Cannot continue bid")
                    continue

            print("Current bidding Round: ", bidding_round, '\n','-'*100)

            # 3. DETERMINE WINNING BID --------------------------------------------
            for bidder, bid_value in bids_dict.items():

                bids_list_raw.append((bidder, bid_value))
                ## only needed to track a human readable bidder id
                bids_list.append((id(bidder), bid_value))


    #        print('bids list', bids_list, '\n','-'*100)

            ###### SORT THE Bids List based on price ##########################################
            sorted_list = sorted(bids_list, key=lambda t:t[1])
            print('Sorted bids list', sorted_list, '\n','-'*100 )

            #------------- for analysis - creating a copy with id(bidder) --------------
            sorted_list_raw = sorted(bids_list_raw, key=lambda t:t[1])
    #        print('sorted bids list RAW', sorted_list_raw, '\n','-'*100 )


            ####### Select second highest price ###############################################
            if len(sorted_list) > 1:
                winning_price = (sorted_list_raw)[-2][1]
                winning_bidder = (sorted_list_raw)[-1][0]
            else:
                winning_price = (sorted_list_raw)[0][-1]
                winning_bidder = (sorted_list_raw)[0][0]

    #        print('Winning Price: ', winning_price, '\n','-'*100)
    #        print('winning bidder', winning_bidder, '\n','-'*100)

            ######## Determine if there are more than 1 bidders with same price ######################

            multiple_winning_bidders = [tup for tup in sorted_list_raw if tup[1] == winning_price]

            if len(multiple_winning_bidders)>1:
                #print('List of biders that submitted similar bids: ' , multiple_winning_bidders, '\n','-'*100)
                randindex = random.randint(0, len(multiple_winning_bidders)-1)
                winning_bidder = multiple_winning_bidders[randindex][0]
                print('Winning bidder from list of similar priced bids: ', winning_bidder, '\n','-'*100)
            else: 
                pass
                #winning_bidder = multiple_winning_bidders[0][0]

            print('Winning Bidder (FINAL): ', id(winning_bidder), '\n','-'*100)
            print('Winning Price (FINAL): ', winning_price, '\n','-'*100)

            ############################################################################################
            # 4. Validate USER CLICK after SHOW AD  --------------------------------------------
            ad_result = self.users[chosen_user].show_ad()
            print('User Clicked on Ad?: ', ad_result,'\n','-'*100)

            # 5.NOTIFY BIDDER & UPDATE BALANCES --------------------------------------------

            print("Bidding Outcomes", '\n','-'*100)
            for bidder in self.bidders:
                if bidder == winning_bidder and ad_result == True:
                    print(id(bidder), "bidder == winning_bidder and ad_result == True:")
                    self.balances[id(bidder)] -= winning_price
                    self.balances[id(bidder)] += 1
                    # balances[bidder] -= winning_price
                    # balances[bidder] += 1                

                    bidder.notify(True, winning_price, ad_result)

                elif bidder == winning_bidder and ad_result == False:
                    print(id(bidder), "bidder == winning_bidder and ad_result == False")
                    self.balances[id(bidder)] -= winning_price
                    # balances[bidder] -= winning_price

                    bidder.notify(True, winning_price, ad_result)

                else:
                    print(id(bidder), "Did not win bid - only notify")
                    bidder.notify(False, winning_price, None)
            print('-'*100, '\n','balances at end of bidding round', self.balances,'\n','-'*100)
                # print('balances at end of bidding round', balances,'\n','-'*100)
        
class Bidder:
    
    #### maintain account balance here as well?

    # BIDDER CREATION -------------- initiated by GAME runner / Developer ------------------------
    
    def __init__(self, num_users, num_rounds):

        self.num_users = num_users
        self.num_rounds = num_rounds
        self.bidding_round = 0

        self.bid_y_n = True
        self.bid_participate = {i: 0 for i in range(num_users)} #whether bidder bids or not (USER: BID COUNT)
        self.bid_wins_no_click = {i: 0 for i in range(num_users)} # if bidder wins
        self.bid_win_user_clicks = {i: 0 for i in range(num_users)} # if user clicks
        self.bid_lost = {i: 0 for i in range(num_users)}
        
        #Transaction records
        self.bid_participate_history = [] # maintains bidderid, userid, bidding round, bid price
        self.bid_win_history = [] # won bid
        self.bid_win_user_click_history = [] # won bid and user clicked
        self.bid_lost_history = [] # lost bid, but know the user and price
        self.bid_price = 0
        
        ########### New tables
        self.bid_win_click_no = []
        self.bid_win_click_yes = []
        self.bid_lost_list = []
        self.bid_360 = []
        
        ############
        #? Winning bid price / user (because you get notified of winning bids) -- 
        ###### you know the user and winning bid (just not the click result)
        
    # SUBMIT BID  ------------ initiated by auction ------------------------------------
    
    def bid(self, user_id):
        self.bidding_round += 1
        #self.bid_participate = 0
        self.user_id = user_id
        default_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        # bid_price = self.default_bid_price + (self.bidding_round)*0.1
        #self.bid_price = default_bid_price
        self.bid_price = self.bid_strategy(user_id)
        print('bid price from STRATEGY', self.bid_price, '\n','-'*100 )
        #bid_price = 0.5
        self.bid_participate[self.user_id] = (self.bid_participate).get(self.user_id, 0)+1
        self.bid_participate_history.append([id(self), self.user_id, self.bidding_round, self.bid_price])
        return self.bid_price
    
#    def bid_strategy(self):
        
        #self.bid_360.extend(self.bid_win_history, self.bid_lost_history)
        # self.bid_360 = [item for sublst in zip(self.bid_win_history,  self.bid_lost_history) for item in sublst]

        # NOTIFIED OF BID OUTCOME ------------ initiated by auction ------------------------------------
    
    def notify(self, auction_winner, price, clicked):
        bid_y_n_won = 0
        self.auction_winner = auction_winner
        self.price = price
        self.clicked = clicked
        
        if auction_winner == True and clicked == True:
            self.bid_win_user_clicks[self.user_id] = (self.bid_win_user_clicks).get(self.user_id, 0)+1
            #self.bid_win_user_click_history.append([self.user_id, self.bidding_round])
            
            self.bid_win_click_yes.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

        elif auction_winner == True and clicked == False:
            #self.bid_participate_history.append([self.user_id, bid_y_n_won+1])
            self.bid_wins_no_click[self.user_id] = (self.bid_wins_no_click).get(self.user_id, 0)+1
            # self.bid_win_history.append([self.user_id, bid_y_n_won+1])

#            self.bid_win_history.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
            
            self.bid_win_click_no.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
        
        else:
            self.bid_lost[self.user_id] = (self.bid_lost).get(self.user_id, 0)+1

#            self.bid_lost_history.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])

            self.bid_lost_list.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

            self.bid_360.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
    
    def bid_strategy(self, user_id):

        self.base_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        trx_master = [x for x in self.bid_360]
        strategy_list = ['A', 'B', 'C', 'D']
        strategy = random.choice(strategy_list)

        #strategy = 'A'
        
        for item in trx_master:
        
        ########## Observe: Start Slow for the first 10 rounds  #############
        
            if item[1] < 2:
                self.bid_price = 0.01
            
        ########## Next 40 rounds, match max price + 10%  #############
        
            
            elif item[1] > 2 and item[1] < 4:
                self.bid_price = max(self.bid_360, key=lambda x: x[6])[6]*1.10
                
            
            elif strategy == 'A':
                self.bid_price = self.strategy_a()
            
            elif strategy == 'B':
                self.bid_price = self.strategy_b()
                
            elif strategy == 'C':
                self.bid_price = self.strategy_c()
                
            elif strategy == 'D':
                self.bid_price = self.strategy_d()
            
            
            else:
                raise Exception("This does not work")
                #self.bid_price = base_bid_price
            
        ########### Review past 10 losses where loss > 10% to winning bid #########
        
        return self.bid_price
        

    def strategy_a(self):
            
        # bprice = 20
        # return bprice
        
        ########### Setting min bid above average difference of loss for prior 10 bids #######
        ########## review past 10 bids (where you lost) where loss % was greater than 10%
        ########### then adjust you next bid to in increase by that amount

         # filter last 10 losses  
        a = [x for x in self.bid_360[-10:] if x[0] == 'BLOS' and (x[6]-x[5]) > (.1*x[5])]

        # calculated the average percentage loss (> 10%)
        avg_loss_10percent = ((sum(i[6] for i in a) - sum(i[5] for i in a))/(max(1, len(a))))

        #adjust bid price
        self.bid_price = self.base_bid_price + avg_loss_10percent    
        
        return self.bid_price
        
    def strategy_b(self):
        
#       ########### Focus on most successful user #############
        
        a = [x for x in self.bid_360[-100:] if x[0] == 'BWCY']
        #print(a)
        b = (Counter([x[3] for x in a]))
        #print(b)
        # filter for success > 5 times
        c = { k: v for k, v in b.items() if v >= 5 }
        # get max user (most successful thus far)
        d = max(c, key=c.get, default=0) # get user with max wins
        self.bid_price = self.base_bid_price*2
        return self.bid_price
    
    def strategy_c(self):
        
        ################ Find Max winning bid in past 10 and raise 20% ###
        
        a = [x for x in self.bid_360[-10:] if x[0] == 'BLOS']
        self.bid_price = max(a, key=lambda x: x[6])[6]*1.20
        
        return self.bid_price
    
    def strategy_d(self):
            
        # Monitor if balance goes < -500
        # then scale back on the bids by 10% of the base price
        # Conserve cash and wait for other random strategies A, B or C to try again

        # sum all bids that were won, but user not clicked (ie BWCN)
        a = [x for x in self.bid_360 if x[0] == 'BWCN'] 

        # calculate cost of bids in BWCN
        b = (sum(i[6] for i in a))

        
        # sum of all bids where user clicked (ie BWCY)
        c = [x for x in self.bid_360 if x[0] == 'BWCY']
        # sum of total cost
        d = (sum(i[6] for i in c) )

        # earnings till date (ie $1 for every BWCY)
        e = len(c)
        f = e * 1


        current_balance = (b + d -f)
        
        if current_balance < -500:
            self.bid_price = 0.01
        return self.base_bid_price    
        
        

        

        
        ########## Aggresive based on win-loss ratio #####
        
        
        ######## Click Ratio < relative percentage of bidders, then > 20%
        
        
        ####### Strategy in case balance drops below < -500
        
        ####### Conserving Cash strategy

# %%
#b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
b1, b2, b3, b4, b5, b6, b7, b8, b9, b10 = Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()for i in range(10)], [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10])
#auction = Auction( [User(), User()], [b1, b2, b3])
auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# Out:
# ****************************************************************************************************
#
# Beginning balances :  {140246947789168: 0, 140246128082032: 0, 140246128082368: 0, 140246946941488: 0, 140246128053744: 0, 140247468446384: 0, 140246128142848: 0, 140246128142800: 0, 140246128142992: 0, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621168
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  1
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246947789168, 0), (140246128082032, 0), (140246128082368, 0), (140246946941488, 0), (140246128053744, 0), (140247468446384, 0), (140246128142848, 0), (140246128142800, 0), (140246128142992, 0), (140246128144096, 0)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a629d0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 bidder == winning_bidder and ad_result == False
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0, 140246128082032: 0, 140246128082368: 0, 140246946941488: 0, 140246128053744: 0, 140247468446384: 0, 140246128142848: 0, 140246128142800: 0, 140246128142992: 0, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------

# %%
bal = auction.balances
bal
# Out:
# {140246947789168: -1566.4706051235294,
#  140246128082032: -1043.1396111197823,
#  140246128082368: -1039.5900151805877,
#  140246946941488: -1096.3780843467305,
#  140246128053744: -1378.290328157206,
#  140247468446384: -1906.0334838697172,
#  140246128142848: -801.0717233258098,
#  140246128142800: -2194.597562246474,
#  140246128142992: -1413.0259501837834,
#  140246128144096: -1381.4406680550462}

# %%
[auction.execute_round() for i in range(100)]
# Out:
# Selected User:  140247459621424
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  2
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246947789168, 0.01), (140246128082032, 0.01), (140246128082368, 0.01), (140246946941488, 0.01), (140246128053744, 0.01), (140247468446384, 0.01), (140246128142848, 0.01), (140246128142800, 0.01), (140246128142992, 0.01), (140246128144096, 0.01)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a53dc0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128082368
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.01
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 bidder == winning_bidder and ad_result == True:
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: 0, 140246128142848: 0, 140246128142800: 0, 140246128142992: 0, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621360
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07833
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04266
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03566
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00334
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08313
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04737
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00063
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00042
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  3
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128144096, 0.00042), (140246128142992, 0.00063), (140246128053744, 0.00334), (140246946941488, 0.012), (140246128142848, 0.012), (140246128082368, 0.03566), (140246128082032, 0.04266), (140246128142800, 0.04737), (140246947789168, 0.07833), (140247468446384, 0.08313)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140247468446384
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.07833
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 bidder == winning_bidder and ad_result == False
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0, 140246128142992: 0, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621168
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.086163
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  4
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246947789168, 0.086163), (140246128082032, 0.086163), (140246128082368, 0.086163), (140246946941488, 0.086163), (140246128053744, 0.086163), (140247468446384, 0.086163), (140246128142848, 0.086163), (140246128142800, 0.086163), (140246128142992, 0.086163), (140246128144096, 0.086163)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a62a90>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142992
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.086163
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 bidder == winning_bidder and ad_result == True:
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0, 140246128142992: 0.913837, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621168
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1033956
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03404
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.075195
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01393
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02904
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07855
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08707000000000001
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.027395
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01041
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1033956
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  5
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142992, 0.01041), (140246946941488, 0.01393), (140246128142800, 0.027395), (140246128053744, 0.02904), (140246128082032, 0.03404), (140246128082368, 0.075195), (140247468446384, 0.07855), (140246128142848, 0.08707000000000001), (140246947789168, 0.1033956), (140246128144096, 0.1033956)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8dc980f970>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246947789168
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.1033956
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 bidder == winning_bidder and ad_result == True:
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.8966044, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0, 140246128142992: 0.913837, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621424
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09717780000000001
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.018535
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09637
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0821278
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00516
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0698828
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.12407472
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.12407472
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.108915
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  6
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140247468446384, 0.00516), (140246128082368, 0.018535), (140246947789168, 0.05995), (140246128142848, 0.0698828), (140246128053744, 0.0821278), (140246946941488, 0.09637), (140246128082032, 0.09717780000000001), (140246128144096, 0.108915), (140246128142800, 0.12407472), (140246128142992, 0.12407472)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a629d0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.12407472
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 bidder == winning_bidder and ad_result == True:
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.8966044, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0.87592528, 140246128142992: 0.913837, 140246128144096: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621136
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.148889664
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0258
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00784
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.017205
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09969917333333334
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.148889664
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05753
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.12407472
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09528779999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.148889664
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  7
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128082368, 0.00784), (140246946941488, 0.017205), (140246128082032, 0.0258), (140246128142848, 0.05753), (140246128142992, 0.09528779999999999), (140246128053744, 0.09969917333333334), (140246128142800, 0.12407472), (140246947789168, 0.148889664), (140247468446384, 0.148889664), (140246128144096, 0.148889664)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a62ee0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128144096
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.148889664
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 bidder == winning_bidder and ad_result == True:
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.8966044, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0.87592528, 140246128142992: 0.913837, 140246128144096: 0.851110336}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621360
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1786675968
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08823
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05423
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.026365
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0451
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.004375
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.027505
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.016255
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01192
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.148889664
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  8
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140247468446384, 0.004375), (140246128142992, 0.01192), (140246128142800, 0.016255), (140246946941488, 0.026365), (140246128142848, 0.027505), (140246128053744, 0.0451), (140246128082368, 0.05423), (140246128082032, 0.08823), (140246128144096, 0.148889664), (140246947789168, 0.1786675968)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246947789168
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.148889664
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 bidder == winning_bidder and ad_result == False
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.7477147359999999, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0.87592528, 140246128142992: 0.913837, 140246128144096: 0.851110336}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621232
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.016545
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06654436960000001
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09285892960000001
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1786675968
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.10835453493333336
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1786675968
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0076
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1786675968
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.136109282
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09460985999999999
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  9
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142848, 0.0076), (140246947789168, 0.016545), (140246128082032, 0.06654436960000001), (140246128082368, 0.09285892960000001), (140246128144096, 0.09460985999999999), (140246128053744, 0.10835453493333336), (140246128142992, 0.136109282), (140246946941488, 0.1786675968), (140247468446384, 0.1786675968), (140246128142800, 0.1786675968)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a629d0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.1786675968
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 bidder == winning_bidder and ad_result == False
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.7477147359999999, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0.6972576832, 140246128142992: 0.913837, 140246128144096: 0.851110336}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621264
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.21440111616
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.21440111616
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03501
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09697
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05845
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08578
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.21440111616
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.024955
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08681808856
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07547748559999999
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  10
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142800, 0.024955), (140246128082368, 0.03501), (140246128053744, 0.05845), (140246128144096, 0.07547748559999999), (140247468446384, 0.08578), (140246128142992, 0.08681808856), (140246946941488, 0.09697), (140246947789168, 0.21440111616), (140246128082032, 0.21440111616), (140246128142848, 0.21440111616)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8dc980f970>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246947789168
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.21440111616
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 bidder == winning_bidder and ad_result == False
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.5333136198399999, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 0.6972576832, 140246128142992: 0.913837, 140246128144096: 0.851110336}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621424
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08841
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01899
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03057
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11705346069333335
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.13137026467047622
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.12416902504000002
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03691
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.257281339392
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.049995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07168
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  11
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128082032, 0.01899), (140246128082368, 0.03057), (140246128142848, 0.03691), (140246128142992, 0.049995), (140246128144096, 0.07168), (140246947789168, 0.08841), (140246946941488, 0.11705346069333335), (140247468446384, 0.12416902504000002), (140246128053744, 0.13137026467047622), (140246128142800, 0.257281339392)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.13137026467047622
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 bidder == winning_bidder and ad_result == True:
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.5333136198399999, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0, 140246128142800: 1.565887418529524, 140246128142992: 0.913837, 140246128144096: 0.851110336}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621392
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.21440111616
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06219
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.14249496200380954
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.049155
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.257281339392
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0644
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.257281339392
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.005475
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.009305
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08876827040609525
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  12
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142800, 0.005475), (140246128142992, 0.009305), (140246946941488, 0.049155), (140246128082032, 0.06219), (140247468446384, 0.0644), (140246128144096, 0.08876827040609525), (140246128082368, 0.14249496200380954), (140246947789168, 0.21440111616), (140246128053744, 0.257281339392), (140246128142848, 0.257281339392)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a62a00>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142848
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.257281339392
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == True:
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.5333136198399999, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0.7427186606080001, 140246128142800: 1.565887418529524, 140246128142992: 0.913837, 140246128144096: 0.851110336}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621424
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08600195117561905
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.13888333490780952
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.30873760727039995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.040215
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01658
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.14680048791040004
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.10096924421006805
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02905
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01667
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.30873760727039995
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  13
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128053744, 0.01658), (140246128142992, 0.01667), (140246128142800, 0.02905), (140246946941488, 0.040215), (140246947789168, 0.08600195117561905), (140246128142848, 0.10096924421006805), (140246128082032, 0.13888333490780952), (140247468446384, 0.14680048791040004), (140246128082368, 0.30873760727039995), (140246128144096, 0.30873760727039995)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a62ee0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128144096
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.30873760727039995
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 bidder == winning_bidder and ad_result == True:
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: 0.5333136198399999, 140246128082032: 0, 140246128082368: 0.99, 140246946941488: 0, 140246128053744: 0, 140247468446384: -0.07833, 140246128142848: 0.7427186606080001, 140246128142800: 1.565887418529524, 140246128142992: 0.913837, 140246128144096: 1.5423727287296}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621136
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06608
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.3704851287244799
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.3704851287244799
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06621
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04093
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.177154093152
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1444697246472583
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02855
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.3704851287244799
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.30873760727039995
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  14
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142800, 0.02855), (140246128053744, 0.04093), (140246947789168, 0.06608), (140246946941488, 0.06621), (140246128142848, 0.1444697246472583), (140247468446384, 0.177154093152), (140246128144096, 0.30873760727039995), (140246128082032, 0.3704851287244799), (140246128082368, 0.3704851287244799), (140246128142992, 0.3704851287244799)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7f8d98a62a90>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142992
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.3704851287244799
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 Did not win bid - only notify
# 140246128142800 Did not win bid - only notify
# 140246128142992 bidder == winning_bidder and ad_result == False
# 140246128144096 Did not win bid - only notify
# ...
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == True:
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: -1566.4706051235294, 140246128082032: -1043.1396111197823, 140246128082368: -1039.5900151805877, 140246946941488: -1096.3780843467305, 140246128053744: -1378.290328157206, 140247468446384: -1906.0334838697172, 140246128142848: -521.2394638517824, 140246128142800: -2194.597562246474, 140246128142992: -1413.0259501837834, 140246128144096: -1381.4406680550462}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621200
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246947789168 balance is less than -1000. Cannot continue bid
# Bidder  140246128082032 balance is less than -1000. Cannot continue bid
# Bidder  140246128082368 balance is less than -1000. Cannot continue bid
# Bidder  140246946941488 balance is less than -1000. Cannot continue bid
# Bidder  140246128053744 balance is less than -1000. Cannot continue bid
# Bidder  140247468446384 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.013625
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246128142800 balance is less than -1000. Cannot continue bid
# Bidder  140246128142992 balance is less than -1000. Cannot continue bid
# Bidder  140246128144096 balance is less than -1000. Cannot continue bid
# Current bidding Round:  97
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142848, 0.013625)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142848
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.013625
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == False
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: -1566.4706051235294, 140246128082032: -1043.1396111197823, 140246128082368: -1039.5900151805877, 140246946941488: -1096.3780843467305, 140246128053744: -1378.290328157206, 140247468446384: -1906.0334838697172, 140246128142848: -521.2530888517824, 140246128142800: -2194.597562246474, 140246128142992: -1413.0259501837834, 140246128144096: -1381.4406680550462}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621264
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246947789168 balance is less than -1000. Cannot continue bid
# Bidder  140246128082032 balance is less than -1000. Cannot continue bid
# Bidder  140246128082368 balance is less than -1000. Cannot continue bid
# Bidder  140246946941488 balance is less than -1000. Cannot continue bid
# Bidder  140246128053744 balance is less than -1000. Cannot continue bid
# Bidder  140247468446384 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.05337
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246128142800 balance is less than -1000. Cannot continue bid
# Bidder  140246128142992 balance is less than -1000. Cannot continue bid
# Bidder  140246128144096 balance is less than -1000. Cannot continue bid
# Current bidding Round:  98
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142848, 0.05337)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142848
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.05337
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == False
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: -1566.4706051235294, 140246128082032: -1043.1396111197823, 140246128082368: -1039.5900151805877, 140246946941488: -1096.3780843467305, 140246128053744: -1378.290328157206, 140247468446384: -1906.0334838697172, 140246128142848: -521.3064588517824, 140246128142800: -2194.597562246474, 140246128142992: -1413.0259501837834, 140246128144096: -1381.4406680550462}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621360
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246947789168 balance is less than -1000. Cannot continue bid
# Bidder  140246128082032 balance is less than -1000. Cannot continue bid
# Bidder  140246128082368 balance is less than -1000. Cannot continue bid
# Bidder  140246946941488 balance is less than -1000. Cannot continue bid
# Bidder  140246128053744 balance is less than -1000. Cannot continue bid
# Bidder  140247468446384 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 281.7571844740275
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246128142800 balance is less than -1000. Cannot continue bid
# Bidder  140246128142992 balance is less than -1000. Cannot continue bid
# Bidder  140246128144096 balance is less than -1000. Cannot continue bid
# Current bidding Round:  99
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142848, 281.7571844740275)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142848
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  281.7571844740275
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == False
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: -1566.4706051235294, 140246128082032: -1043.1396111197823, 140246128082368: -1039.5900151805877, 140246946941488: -1096.3780843467305, 140246128053744: -1378.290328157206, 140247468446384: -1906.0334838697172, 140246128142848: -803.0636433258098, 140246128142800: -2194.597562246474, 140246128142992: -1413.0259501837834, 140246128144096: -1381.4406680550462}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621168
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246947789168 balance is less than -1000. Cannot continue bid
# Bidder  140246128082032 balance is less than -1000. Cannot continue bid
# Bidder  140246128082368 balance is less than -1000. Cannot continue bid
# Bidder  140246946941488 balance is less than -1000. Cannot continue bid
# Bidder  140246128053744 balance is less than -1000. Cannot continue bid
# Bidder  140247468446384 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.00487
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246128142800 balance is less than -1000. Cannot continue bid
# Bidder  140246128142992 balance is less than -1000. Cannot continue bid
# Bidder  140246128144096 balance is less than -1000. Cannot continue bid
# Current bidding Round:  100
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142848, 0.00487)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142848
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.00487
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == True:
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: -1566.4706051235294, 140246128082032: -1043.1396111197823, 140246128082368: -1039.5900151805877, 140246946941488: -1096.3780843467305, 140246128053744: -1378.290328157206, 140247468446384: -1906.0334838697172, 140246128142848: -802.0685133258098, 140246128142800: -2194.597562246474, 140246128142992: -1413.0259501837834, 140246128144096: -1381.4406680550462}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140247459621136
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246947789168 balance is less than -1000. Cannot continue bid
# Bidder  140246128082032 balance is less than -1000. Cannot continue bid
# Bidder  140246128082368 balance is less than -1000. Cannot continue bid
# Bidder  140246946941488 balance is less than -1000. Cannot continue bid
# Bidder  140246128053744 balance is less than -1000. Cannot continue bid
# Bidder  140247468446384 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.00321
#  ----------------------------------------------------------------------------------------------------
# Bidder  140246128142800 balance is less than -1000. Cannot continue bid
# Bidder  140246128142992 balance is less than -1000. Cannot continue bid
# Bidder  140246128144096 balance is less than -1000. Cannot continue bid
# Current bidding Round:  101
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140246128142848, 0.00321)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140246128142848
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.00321
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140246947789168 Did not win bid - only notify
# 140246128082032 Did not win bid - only notify
# 140246128082368 Did not win bid - only notify
# 140246946941488 Did not win bid - only notify
# 140246128053744 Did not win bid - only notify
# 140247468446384 Did not win bid - only notify
# 140246128142848 bidder == winning_bidder and ad_result == True:
# 140246128142800 Did not win bid - only notify
# 140246128142992 Did not win bid - only notify
# 140246128144096 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140246947789168: -1566.4706051235294, 140246128082032: -1043.1396111197823, 140246128082368: -1039.5900151805877, 140246946941488: -1096.3780843467305, 140246128053744: -1378.290328157206, 140247468446384: -1906.0334838697172, 140246128142848: -801.0717233258098, 140246128142800: -2194.597562246474, 140246128142992: -1413.0259501837834, 140246128144096: -1381.4406680550462}
#  ----------------------------------------------------------------------------------------------------
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Consolidate Metrics: All Bidders

# %% [markdown]
# ## Overall

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)

BWCY = (len(b1.bid_win_click_yes), len(b2.bid_win_click_yes), \
      len(b3.bid_win_click_yes), len(b4.bid_win_click_yes),  len(b5.bid_win_click_yes), len(b6.bid_win_click_yes), \
      len(b7.bid_win_click_yes), len(b8.bid_win_click_yes), len(b9.bid_win_click_yes), len(b10.bid_win_click_yes))

sum(BWCY)
print('BWCY - Bid Win - Click YES: Count', sum(BWCY))

BWCN = (len(b1.bid_win_click_no),len(b2.bid_win_click_no),len(b3.bid_win_click_no)\
     ,len(b4.bid_win_click_no),len(b5.bid_win_click_no),len(b6.bid_win_click_no),len(b7.bid_win_click_no),\
    len(b8.bid_win_click_no),len(b9.bid_win_click_no),len(b10.bid_win_click_no))

sum(BWCN)

print('BWCN - Bid Win - Click NO: Count',sum(BWCN))

# GENERAL CLICK RATIO

print('Overall Click Ratio ', sum(BWCY) / (sum(BWCY)+sum(BWCN)) )

# BLOS = NOT RELEVANT
# print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))

# print('Balances', auction.balances)
# Out:
# Bidding Rounds 76
# BWCY - Bid Win - Click YES: Count 42
# BWCN - Bid Win - Click NO: Count 52
# Overall Click Ratio  0.44680851063829785

# %% [markdown]
# # Bid Refining - Filters

# %% [markdown]
# ## Observe first 10 rounds

# %%
trx_master = [x for x in self.bid_360]

for item in trx_master:

    if item[1] < 10:
        self.bid_price = 0.01
    else:
        self.bid_price = base_bid_price

# trx_master = [x for x in b1.bid_360]

# for item in trx_master:
#     if item[1] < 10:
#         print('hey')
#     else:
#         print('hey no')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 trx_master = [x for x in self.bid_360]
#       3 for item in trx_master:
#       5     if item[1] < 10:
#
# NameError: name 'self' is not defined

# %%
a = [x for x in b1.bid_360[-100:] if 0 < x[1] < 50]

for item in a:
    if item[1] < 10:
        print('hey')
    else:
        print('hey no')

# b = filter(lambda x: x[1] < 10, a)
# print(b)
# Out:
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no

# %% [markdown]
# ## Loss by > 10%

# %%
# lost the bid by a price > 10%

# filter last 10 bids for those you have lost 
a = [x for x in b1.bid_360[-10:] if x[0] == 'BLOS' and (x[6]-x[5]) > (.1*x[5])]
#print(a)

# calculated the average percentage loss (> 10%)
b = ((sum(i[6] for i in a) - sum(i[5] for i in a))/(max(1, len(a))))

print(b)

# then set bid_price = 

# [0]Category, [1]self.bidding_round, [2]id(self), [3]self.user_id, 
# [4]self.auction_winner, [5]#self.bid_price, [6]self.winning price, [7]self.clicked
# Out:
# 0.03324855583759785

# %% [markdown]
# ## Most successful user

# %%
# lost the bid by a price > 10%
from collections import Counter

a = [x for x in b1.bid_360[-1000:] if x[0] == 'BWCY']
#print(a)
b = (Counter([x[3] for x in a]))
c = { k: v for k, v in b.items() if v >= 3 }
#print(b)
d = max(c, key=c.get, default = 0) # get user with max wins
print(d)
#print(c)

#print(max(b, key=b.get))

# then set bid_price = 

# [0]Category, [1]self.bidding_round, [2]id(self), [3]self.user_id, 
# [4]self.auction_winner, [5]#self.bid_price, [6]self.winning price, [7]self.clicked
# Out:
# 0

# %% [markdown]
# ## Wait certain rounds, then accelerate

# %%
#a = [x for x in b1.bid_360[-100:] if x[0] == 'BWCN'] # < ]
a = [x for x in b1.bid_360[-100:] if 100 < x[1] < 200] #'BWCN'] # < ]
print(a)
     # then take default bid probability
# Out:
# [['BLOS', 101, 140568245737168, 6, False, 0.04786, 0.08659, None]]

# %% [markdown]
# ## Match Max and go over 10%

# %% [markdown]
# ---

# %%
b1.bid_360 # Category,self.bidding_round, id(self), self.user_id, self.auction_winner,
           #self.bid_price, self.winning price, self.clicked
#[x for x in b1.bid_360]    

a = [x for x in b1.bid_360[-10:] if x[0] == 'BLOS']

# a  = [x for x in b1.bid_360]
# a = [trx_master[-10:] if x[0] == 'BLOS']
#print(trx_master)
a

b = max(a, key=lambda x: x[6])[6]*1.20
print(b)
# Out:
# 0.012

# %% [markdown]
# ## Monitor balance and go convervative

# %%
# Monitor if balance goes < -500
# then scale back on the bids by 10% of the base price

# filter last 10 bids for those you have lost 
a = [x for x in b1.bid_360 if x[0] == 'BWCN'] 
#print(a)

# calculate current balance
b = (sum(i[6] for i in a))# - sum(i[5] for i in a))/(max(1, len(a))))
print(b)

c = [x for x in b1.bid_360 if x[0] == 'BWCY']
d = (sum(i[6] for i in c) )
print(d)
      
e = len(c)

f = e * 1


balance = (b + d -f)
print(balance)
# then set bid_price =
# Out:
# 1755.6575161955327
# 45.451559031805296
# 1797.109075227338

# %% [markdown]
# ## By Bidder

# %% [markdown]
# ### for b1

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b1.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b1.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 76
# BWCY - Bid Win - Click YES: Count 1
# BWCN - Bid Win - Click NO: Count 4
# BLOS - Bid LOST: Count 89
# Balances {140247470807600: -1290.4954813598738, 140247470807504: -1169.945474204086, 140247470807552: -1045.1914497593625, 140247470807696: -1158.3749250143646, 140247470807648: -1971.2838021829293, 140247470807360: -1235.8687140930142, 140247470808464: -1015.4259847324158, 140247470805440: -1142.4693441632548, 140247470805104: -2040.7236071369248, 140247470805344: -2327.4981049483868}

# %% [markdown]
# ## for b2

# %%
# Summary Counts
print('Bidding Rounds', b2.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b2.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b2.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b2.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 71
# BWCY - Bid Win - Click YES: Count 5
# BWCN - Bid Win - Click NO: Count 6
# BLOS - Bid LOST: Count 83
# Balances {140247470807600: -1290.4954813598738, 140247470807504: -1169.945474204086, 140247470807552: -1045.1914497593625, 140247470807696: -1158.3749250143646, 140247470807648: -1971.2838021829293, 140247470807360: -1235.8687140930142, 140247470808464: -1015.4259847324158, 140247470805440: -1142.4693441632548, 140247470805104: -2040.7236071369248, 140247470805344: -2327.4981049483868}

# %% [markdown]
# ## for b3

# %%
# Summary Counts
print('Bidding Rounds', b3.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b3.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b3.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b3.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 101
# BWCY - Bid Win - Click YES: Count 5
# BWCN - Bid Win - Click NO: Count 10
# BLOS - Bid LOST: Count 86
# Balances {140588383663200: -1147.6122670914983, 140588388722480: -1234.6556190166716, 140588388723152: -683.9171783816711, 140588388722912: -1103.359507689096, 140588388721088: -1428.327987930117, 140588388722816: -1782.5122671418005, 140588388720848: -1279.3556726191655, 140588388722864: -1182.55272084212, 140588388721616: -454.9901072078393, 140588388720944: -1439.5127313027533}

# %% [markdown]
# ---

# %% [markdown]
# # User Info

# %%
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Wins User Clicked', {k: v for k, v in sorted(b1.bid_win_user_clicks.items(), key=lambda item: item[0])})
print('BWCN - Bid Wins User NO Clicked', {k: v for k, v in sorted(b1.bid_wins_no_click.items(), key=lambda item: item[0])})
print('BLOS - Bids Lost', {k: v for k, v in sorted(b1.bid_lost.items(), key=lambda item: item[0])})
# Out:
# Bidding Rounds 89
# BWCY - Bid Wins User Clicked {0: 0, 2: 1, 3: 1, 6: 1}
# BWCN - Bid Wins User NO Clicked {0: 3, 1: 2, 5: 1, 8: 1, 9: 3}
# BLOS - Bids Lost {0: 9, 1: 12, 2: 5, 3: 7, 4: 9, 5: 5, 6: 5, 7: 9, 8: 21, 9: 6}

# %%
b1.bid_360
# Out:
# [['BLOS', 1, 140631870820752, 0, False, 0, 0, None],
#  ['BLOS', 2, 140631870820752, 9, False, 0.01, 0.01, None],
#  ['BLOS', 3, 140631870820752, 8, False, 0.01, 0.01, None],
#  ['BLOS', 4, 140631870820752, 5, False, 0.01, 0.01, None],
#  ['BLOS', 5, 140631870820752, 2, False, 0.01, 0.01, None],
#  ['BLOS', 6, 140631870820752, 9, False, 0.01, 0.01, None],
#  ['BLOS', 7, 140631870820752, 4, False, 0.01, 0.01, None],
#  ['BLOS', 8, 140631870820752, 8, False, 0.01, 0.01, None],
#  ['BWCY', 9, 140631870820752, 8, True, 0.01, 0.01, True],
#  ['BLOS', 10, 140631870820752, 4, False, 0.01, 0.01, None],
#  ['BLOS', 11, 140631870820752, 5, False, 0.01896, 0.03877, None],
#  ['BLOS', 12, 140631870820752, 3, False, 0.041105, 0.042475, None],
#  ['BLOS', 13, 140631870820752, 2, False, 0.0097, 0.040555, None],
#  ['BLOS', 14, 140631870820752, 2, False, 0.046645, 0.046645, None],
#  ['BLOS', 15, 140631870820752, 0, False, 0.01983, 0.03821, None],
#  ['BLOS', 16, 140631870820752, 1, False, 0.03321, 0.036455, None],
#  ['BLOS', 17, 140631870820752, 7, False, 0.00988, 0.03952, None],
#  ['BLOS', 18, 140631870820752, 8, False, 0.038435, 0.042535, None],
#  ['BLOS', 19, 140631870820752, 1, False, 0.022965, 0.048445, None],
#  ['BLOS', 20, 140631870820752, 3, False, 0.006995, 0.043925, None],
#  ['BWCY', 21, 140631870820752, 7, True, 0.04959, 0.04738, True],
#  ['BLOS', 22, 140631870820752, 7, False, 0.017535, 0.045295, None],
#  ['BLOS', 23, 140631870820752, 1, False, 0.015345, 0.048455, None],
#  ['BLOS', 24, 140631870820752, 3, False, 0.033075, 0.033075, None],
#  ['BLOS', 25, 140631870820752, 9, False, 0.0058, 0.04161, None],
#  ['BWCN', 26, 140631870820752, 4, True, 0.048065, 0.035795, False],
#  ['BLOS', 27, 140631870820752, 5, False, 0.015855, 0.039235, None],
#  ['BLOS', 28, 140631870820752, 1, False, 0.003695, 0.045595, None],
#  ['BLOS', 29, 140631870820752, 5, False, 0.03561, 0.045365, None],
#  ['BLOS', 30, 140631870820752, 2, False, 0.015785, 0.046795, None],
#  ['BLOS', 31, 140631870820752, 7, False, 0.036415, 0.04302, None],
#  ['BLOS', 32, 140631870820752, 1, False, 0.0, 0.04056, None],
#  ['BLOS', 33, 140631870820752, 2, False, 0.022045, 0.04689, None],
#  ['BLOS', 34, 140631870820752, 6, False, 0.039665, 0.043735, None],
#  ['BLOS', 35, 140631870820752, 2, False, 0.04704, 0.04704, None],
#  ['BLOS', 36, 140631870820752, 3, False, 0.04083, 0.04083, None],
#  ['BLOS', 37, 140631870820752, 6, False, 0.027345, 0.038255, None],
#  ['BLOS', 38, 140631870820752, 7, False, 0.02786, 0.03504, None],
#  ['BLOS', 39, 140631870820752, 4, False, 0.02487, 0.030495, None],
#  ['BLOS', 40, 140631870820752, 8, False, 0.00835, 0.037835, None],
#  ['BLOS', 41, 140631870820752, 6, False, 0.03997, 0.03997, None],
#  ['BLOS', 42, 140631870820752, 1, False, 0.00561, 0.04833, None],
#  ['BLOS', 43, 140631870820752, 8, False, 0.031725, 0.03816, None],
#  ['BLOS', 44, 140631870820752, 0, False, 0.03084, 0.03084, None],
#  ['BLOS', 45, 140631870820752, 1, False, 0.019955, 0.04591, None],
#  ['BLOS', 46, 140631870820752, 2, False, 0.040995, 0.040995, None],
#  ['BLOS', 47, 140631870820752, 2, False, 0.03211, 0.048735, None],
#  ['BLOS', 48, 140631870820752, 6, False, 0.03678, 0.03678, None],
#  ['BLOS', 49, 140631870820752, 0, False, 0.01763, 0.02804, None],
#  ['BLOS', 50, 140631870820752, 7, False, 0.018755, 0.037695, None],
#  ['BLOS', 51, 140631870820752, 4, False, 0.01707, 0.048805, None],
#  ['BLOS', 52, 140631870820752, 4, False, 0.040965, 0.040965, None],
#  ['BLOS', 53, 140631870820752, 6, False, 0.026145, 0.0327, None],
#  ['BLOS', 54, 140631870820752, 1, False, 0.01395, 0.041265, None],
#  ['BLOS', 55, 140631870820752, 3, False, 0.03821, 0.040735, None],
#  ['BLOS', 56, 140631870820752, 2, False, 0.00741, 0.044025, None],
#  ['BLOS', 57, 140631870820752, 8, False, 0.02825, 0.046675, None],
#  ['BLOS', 58, 140631870820752, 9, False, 0.00863, 0.03161, None],
#  ['BLOS', 59, 140631870820752, 0, False, 0.04528, 0.04528, None],
#  ['BLOS', 60, 140631870820752, 3, False, 0.001155, 0.049005, None],
#  ['BLOS', 61, 140631870820752, 0, False, 0.03805, 0.042475, None],
#  ['BLOS', 62, 140631870820752, 7, False, 0.002445, 0.043905, None],
#  ['BLOS', 63, 140631870820752, 7, False, 0.01518, 0.04628, None],
#  ['BLOS', 64, 140631870820752, 9, False, 0.00249, 0.02598, None],
#  ['BLOS', 65, 140631870820752, 0, False, 0.047125, 0.047125, None],
#  ['BLOS', 66, 140631870820752, 8, False, 0.041315, 0.0421, None],
#  ['BLOS', 67, 140631870820752, 1, False, 0.024325, 0.0415, None],
#  ['BLOS', 68, 140631870820752, 1, False, 0.045485, 0.04681, None],
#  ['BLOS', 69, 140631870820752, 9, False, 0.00484, 0.029125, None],
#  ['BLOS', 70, 140631870820752, 4, False, 0.02698, 0.039305, None],
#  ['BLOS', 71, 140631870820752, 7, False, 0.022765, 0.03278, None],
#  ['BLOS', 72, 140631870820752, 9, False, 0.02809, 0.042055, None],
#  ['BLOS', 73, 140631870820752, 1, False, 0.03697, 0.039095, None],
#  ['BLOS', 74, 140631870820752, 8, False, 0.018255, 0.04132, None],
#  ['BLOS', 75, 140631870820752, 7, False, 0.048055, 0.04861, None],
#  ['BLOS', 76, 140631870820752, 4, False, 0.017635, 0.03882, None],
#  ['BLOS', 77, 140631870820752, 9, False, 0.023885, 0.04133, None],
#  ['BLOS', 78, 140631870820752, 5, False, 0.02152, 0.02251, None],
#  ['BLOS', 79, 140631870820752, 4, False, 0.030765, 0.042225, None],
#  ['BWCN', 80, 140631870820752, 0, True, 0.04809, 0.045155, False],
#  ['BLOS', 81, 140631870820752, 1, False, 0.00418, 0.039945, None],
#  ['BLOS', 82, 140631870820752, 0, False, 0.01313, 0.04534, None],
#  ['BLOS', 83, 140631870820752, 3, False, 0.025475, 0.04261, None],
#  ['BLOS', 84, 140631870820752, 4, False, 0.004045, 0.04833, None],
#  ['BLOS', 85, 140631870820752, 2, False, 0.00216, 0.03944, None],
#  ['BLOS', 86, 140631870820752, 5, False, 0.005895, 0.02997, None],
#  ['BLOS', 87, 140631870820752, 3, False, 0.0271, 0.045415, None],
#  ['BLOS', 88, 140631870820752, 9, False, 0.01474, 0.041375, None],
#  ['BLOS', 89, 140631870820752, 8, False, 0.01232, 0.038675, None],
#  ['BLOS', 90, 140631870820752, 1, False, 0.046505, 0.047055, None],
#  ['BLOS', 91, 140631870820752, 2, False, 0.03436, 0.045, None],
#  ['BLOS', 92, 140631870820752, 7, False, 0.01829, 0.042975, None],
#  ['BLOS', 93, 140631870820752, 0, False, 0.015045, 0.03291, None],
#  ['BLOS', 94, 140631870820752, 0, False, 0.022885, 0.025455, None],
#  ['BLOS', 95, 140631870820752, 9, False, 0.02818, 0.039505, None],
#  ['BLOS', 96, 140631870820752, 7, False, 0.00412, 0.04968, None],
#  ['BWCN', 97, 140631870820752, 5, True, 0.03057, 0.02764, False],
#  ['BWCY', 98, 140631870820752, 6, True, 0.047955, 0.042475, True],
#  ['BLOS', 99, 140631870820752, 9, False, 0.02994, 0.04769, None],
#  ['BLOS', 100, 140631870820752, 3, False, 0.006925, 0.035735, None],
#  ['BLOS', 101, 140631870820752, 6, False, 0.03492, 0.038685, None]]
