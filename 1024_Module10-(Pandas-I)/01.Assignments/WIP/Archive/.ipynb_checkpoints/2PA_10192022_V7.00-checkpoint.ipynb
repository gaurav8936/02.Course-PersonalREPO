# %% [markdown]
# # Sorting out basic design issues

# %% [markdown]
# ## Start Focus on Bidder Side - Make bidding decisions

# %%
import numpy as np
import random

class User:
    def __init__(self):
        self.probability2 = random.uniform(0, 1)

    def show_ad(self):
        return  np.random.choice((True, False), p = [self.probability2, 1-self.probability2])

class Auction:
    
    auction_history = [] # for the auction exchange only
    balances = {}
    
    def __init__(self, users, bidders):
        self.users = users
        self.bidders = bidders
        
        self.balances = {id(bidder): 0 for bidder in bidders} ########### NEW LINE
        print("*"*100, '\n')
        print('Beginning balances : ',self.balances, '\n','-'*100)
        
        
    def execute_round(self):
        
        ##### if the -ve balance of ALL bidders is < -1000, then break
        
        all_invalid_bidders = any(x > -1000 for x in self.balances.values())
        
        while not all_invalid_bidders:
            print("no bidders are qualifed as all balances are below -1000")
            break
        
        else:
            # print('starting balances2: ', self.balances2, '\n','-'*100)
            bids_dict = {}
            bids_list = []
            bids_list_raw = []

            # 1. SELECT USER (from the pool of users) ----------------------------------

            chosen_user = random.randint(0, len(self.users)-1)
            print('Selected User: ', id(chosen_user), '\n','-'*100) 

            # 2. COLLECT BIDS (send to all bidders) --------------------------------------------
            for bidder in self.bidders:
                #if self.balances[bidder] > -1000:
                #balances = {bidder: 0 for bidder in bidders} ########### NEW LINE
                if self.balances[id(bidder)] > -1000:
                    bids_dict[bidder] = bidder.bid(chosen_user)
                    bidding_round = bidder.bidding_round

                    self.auction_history.append((id(bids_dict[bidder]), bids_dict[bidder])) #bidder
                    highest_bid = 0
                    winning_price = 0
                else:
                    print("Bidder ", id(bidder), "balance is less than -1000. Cannot continue bid" )
     #               #raise Exception("Bidder's balance is less than -1000. Cannot continue bid")
                    continue

            print("Current bidding Round: ", bidding_round, '\n','-'*100)

            # 3. DETERMINE WINNING BID --------------------------------------------
            for bidder, bid_value in bids_dict.items():

                bids_list_raw.append((bidder, bid_value))
                ## only needed to track a human readable bidder id
                bids_list.append((id(bidder), bid_value))


    #        print('bids list', bids_list, '\n','-'*100)

            ###### SORT THE Bids List based on price ##########################################
            sorted_list = sorted(bids_list, key=lambda t:t[1])
            print('Sorted bids list', sorted_list, '\n','-'*100 )

            #------------- for analysis - creating a copy with id(bidder) --------------
            sorted_list_raw = sorted(bids_list_raw, key=lambda t:t[1])
    #        print('sorted bids list RAW', sorted_list_raw, '\n','-'*100 )


            ####### Select second highest price ###############################################
            if len(sorted_list) > 1:
                winning_price = (sorted_list_raw)[-2][1]
                winning_bidder = (sorted_list_raw)[-1][0]
            else:
                winning_price = (sorted_list_raw)[0][-1]
                winning_bidder = (sorted_list_raw)[0][0]

    #        print('Winning Price: ', winning_price, '\n','-'*100)
    #        print('winning bidder', winning_bidder, '\n','-'*100)

            ######## Determine if there are more than 1 bidders with same price ######################

            multiple_winning_bidders = [tup for tup in sorted_list_raw if tup[1] == winning_price]

            if len(multiple_winning_bidders)>1:
                print('List of biders that submitted similar bids: ' , multiple_winning_bidders, '\n','-'*100)
                randindex = random.randint(0, len(multiple_winning_bidders)-1)
                winning_bidder = multiple_winning_bidders[randindex][0]
                print('Winning bidder from list of similar priced bids: ', winning_bidder, '\n','-'*100)
            else: 
                pass
                #winning_bidder = multiple_winning_bidders[0][0]

            print('Winning Bidder (FINAL): ', id(winning_bidder), '\n','-'*100)
            print('Winning Price (FINAL): ', winning_price, '\n','-'*100)

            ############################################################################################
            # 4. Validate USER CLICK after SHOW AD  --------------------------------------------
            ad_result = self.users[chosen_user].show_ad()
            print('User Clicked on Ad?: ', ad_result,'\n','-'*100)

            # 5.NOTIFY BIDDER & UPDATE BALANCES --------------------------------------------

            print("Bidding Outcomes", '\n','-'*100)
            for bidder in self.bidders:
                if bidder == winning_bidder and ad_result == True:
                    print(id(bidder), "bidder == winning_bidder and ad_result == True:")
                    self.balances[id(bidder)] -= winning_price
                    self.balances[id(bidder)] += 1
                    # balances[bidder] -= winning_price
                    # balances[bidder] += 1                

                    bidder.notify(True, winning_price, ad_result)

                elif bidder == winning_bidder and ad_result == False:
                    print(id(bidder), "bidder == winning_bidder and ad_result == False")
                    self.balances[id(bidder)] -= winning_price
                    # balances[bidder] -= winning_price

                    bidder.notify(True, winning_price, ad_result)

                else:
                    print(id(bidder), "Did not win bid - only notify")
                    bidder.notify(False, winning_price, None)
            print('-'*100, '\n','balances at end of bidding round', self.balances,'\n','-'*100)
                # print('balances at end of bidding round', balances,'\n','-'*100)
        
class Bidder:
    
    #### maintain account balance here as well?

    # BIDDER CREATION -------------- initiated by GAME runner / Developer ------------------------
    
    def __init__(self, num_users, num_rounds):

        self.num_users = num_users
        self.num_rounds = num_rounds
        self.bidding_round = 0

        self.bid_y_n = True
        self.bid_participate = {i: 0 for i in range(num_users)} #whether bidder bids or not (USER: BID COUNT)
        self.bid_wins = {i: 0 for i in range(num_users)} # if bidder wins
        #print('bid wins', self.bid_wins)
        self.bid_win_user_clicks = {i: 0 for i in range(num_users)} # if user clicks
        self.bid_lost = {i: 0 for i in range(num_users)}
        
        #Transaction records
        self.bid_participate_history = [] # maintains bidderid, userid, bidding round, bid price
        self.bid_win_history = [] # won bid
        self.bid_win_user_click_history = [] # won bid and user clicked
        self.bid_lost_history = [] # lost bid, but know the user and price
        self.bid_360 = []
        
        ############
        #? Winning bid price / user (because you get notified of winning bids) -- 
        ###### you know the user and winning bid (just not the click result)
        
    # SUBMIT BID  ------------ initiated by auction ------------------------------------
    
    def bid(self, user_id):
        self.bidding_round += 1
        #self.bid_participate = 0
        self.user_id = user_id
        default_bid_price = random.randint(1000, 10000)/2000 #random.uniform(0, 1)
        # bid_price = self.default_bid_price + (self.bidding_round)*0.1
        bid_price = default_bid_price
        #bid_price = 0.5
        self.bid_participate[self.user_id] = (self.bid_participate).get(self.user_id, 0)+1
        self.bid_participate_history.append([id(self), self.user_id, self.bidding_round, bid_price])
        return bid_price
    
#    def bid_strategy(self):
        
        #self.bid_360.extend(self.bid_win_history, self.bid_lost_history)
        self.bid_360 = [item for sublst in zip(self.bid_win_history,  self.bid_lost_history) for item in sublst]

        # NOTIFIED OF BID OUTCOME ------------ initiated by auction ------------------------------------
    
    def notify(self, auction_winner, price, clicked):
        bid_y_n_won = 0
        self.auction_winner = auction_winner
        self.price = price
        self.clicked = clicked
        if auction_winner:
            #self.bid_participate_history.append([self.user_id, bid_y_n_won+1])
            self.bid_wins[self.user_id] = (self.bid_wins).get(self.user_id, 0)+1
            # self.bid_win_history.append([self.user_id, bid_y_n_won+1])
            self.bid_win_history.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
            self.bid_360.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
            
            if clicked:
                self.bid_win_user_clicks[self.user_id] = (self.bid_win_user_clicks).get(self.user_id, 0)+1
                #self.bid_win_user_click_history.append([self.user_id, self.bidding_round])
                self.bid_360.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
        else:
            self.bid_lost[self.user_id] = (self.bid_lost).get(self.user_id, 0)+1
            self.bid_lost_history.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
            self.bid_360.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
            # NOTIFICATION: bidder.notify(False, winning_price, None)
            pass

# %%
b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()for i in range(10)], [b1, b2, b3])
#auction = Auction( [User(), User()], [b1, b2, b3])

auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# Out:
# ****************************************************************************************************
#
# Beginning balances :  {140530668556544: 0, 140530668557264: 0, 140530668556736: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460816
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  1
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.381), (140530668556736, 2.9655), (140530668557264, 4.3435)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.9655
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == True:
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: 0, 140530668557264: -1.9655, 140530668556736: 0}
#  ----------------------------------------------------------------------------------------------------

# %%
print('Bidding Rounds', b1.bidding_round)
#print('Bid Participate', b1.bid_participate)
print('Bid Participate Sorted', {k: v for k, v in sorted(b1.bid_participate.items(), key=lambda item: item[0])})
#print('Bid Wins', b1.bid_wins)
print('Bidding Wins Sorted', {k: v for k, v in sorted(b1.bid_wins.items(), key=lambda item: item[0])})
#print('User Clicks', b1.bid_win_user_clicks)
print('User Clicks Sorted', {k: v for k, v in sorted(b1.bid_win_user_clicks.items(), key=lambda item: item[0])})
#print('Bids Lost', b1.bid_lost)
print('Bids Lost Sorted', {k: v for k, v in sorted(b1.bid_lost.items(), key=lambda item: item[0])})
# Out:
# Bidding Rounds 1
# Bid Participate Sorted {0: 0, 3: 1}
# Bidding Wins Sorted {0: 0}
# User Clicks Sorted {0: 0}
# Bids Lost Sorted {0: 0, 3: 1}

# %%
print('occurances', len(b1.bid_win_history))
b1.bid_win_history # 1.bidding_round, 2. User_id, 3. auction_winner 4.self.price  5. self.clicked
# Out:
# occurances 33
# [[6, 9, True, 3.7275, True],
#  [7, 0, True, 2.712, True],
#  [8, 2, True, 1.7535, False],
#  [10, 4, True, 2.238, False],
#  [11, 4, True, 1.9865, False],
#  [16, 5, True, 1.349, False],
#  [17, 7, True, 2.454, True],
#  [18, 4, True, 2.1415, False],
#  [21, 5, True, 2.9295, False],
#  [22, 1, True, 2.594, True],
#  [24, 7, True, 1.8325, True],
#  [28, 6, True, 1.7615, False],
#  [30, 2, True, 2.6315, True],
#  [33, 9, True, 2.873, True],
#  [35, 7, True, 3.132, False],
#  [37, 9, True, 2.321, True],
#  [43, 0, True, 2.1715, False],
#  [46, 6, True, 2.2, False],
#  [50, 8, True, 2.334, True],
#  [58, 1, True, 1.1555, True],
#  [66, 4, True, 1.458, True],
#  [67, 9, True, 3.776, True],
#  [69, 9, True, 3.371, False],
#  [70, 9, True, 1.3085, True],
#  [74, 1, True, 2.9275, True],
#  [75, 7, True, 3.205, False],
#  [77, 8, True, 4.1945, False],
#  [79, 9, True, 2.6285, True],
#  [87, 4, True, 3.207, True],
#  [90, 1, True, 4.3235, True],
#  [91, 5, True, 1.4765, True],
#  [96, 0, True, 2.71, False],
#  [98, 6, True, 1.146, False]]

# %%
print('occurances',len(b1.bid_lost_history))
b1.bid_lost_history # 1.bidding_round, 2. User_id, 3. auction_winner 4.self.price  5. self.clicked
# Out:
# occurances 68
# [[1, 3, False, 1.8325, None],
#  [2, 6, False, 2.824, None],
#  [3, 0, False, 0.5945, None],
#  [4, 5, False, 4.0945, None],
#  [5, 9, False, 2.4755, None],
#  [9, 0, False, 2.334, None],
#  [12, 2, False, 3.994, None],
#  [13, 2, False, 1.414, None],
#  [14, 3, False, 1.8345, None],
#  [15, 9, False, 2.5525, None],
#  [19, 7, False, 0.781, None],
#  [20, 3, False, 4.336, None],
#  [23, 5, False, 2.5105, None],
#  [25, 0, False, 3.963, None],
#  [26, 4, False, 1.314, None],
#  [27, 0, False, 3.138, None],
#  [29, 3, False, 1.2195, None],
#  [31, 1, False, 4.071, None],
#  [32, 2, False, 3.6065, None],
#  [34, 2, False, 4.9265, None],
#  [36, 8, False, 3.472, None],
#  [38, 5, False, 1.01, None],
#  [39, 1, False, 2.565, None],
#  [40, 2, False, 1.533, None],
#  [41, 7, False, 3.3875, None],
#  [42, 5, False, 0.689, None],
#  [44, 7, False, 2.981, None],
#  [45, 9, False, 1.155, None],
#  [47, 6, False, 2.597, None],
#  [48, 4, False, 1.1725, None],
#  [49, 6, False, 2.751, None],
#  [51, 7, False, 3.863, None],
#  [52, 1, False, 2.3065, None],
#  [53, 5, False, 2.3585, None],
#  [54, 8, False, 0.7755, None],
#  [55, 9, False, 4.0885, None],
#  [56, 2, False, 3.2605, None],
#  [57, 2, False, 3.642, None],
#  [59, 9, False, 3.039, None],
#  [60, 6, False, 2.8535, None],
#  [61, 0, False, 3.237, None],
#  [62, 3, False, 1.427, None],
#  [63, 4, False, 2.8745, None],
#  [64, 7, False, 3.7155, None],
#  [65, 3, False, 4.1695, None],
#  [68, 1, False, 2.079, None],
#  [71, 0, False, 2.802, None],
#  [72, 4, False, 0.8125, None],
#  [73, 9, False, 1.6815, None],
#  [76, 6, False, 4.1315, None],
#  [78, 8, False, 2.813, None],
#  [80, 1, False, 3.1195, None],
#  [81, 6, False, 3.7475, None],
#  [82, 2, False, 1.802, None],
#  [83, 5, False, 2.7045, None],
#  [84, 3, False, 2.254, None],
#  [85, 3, False, 1.8005, None],
#  [86, 6, False, 3.803, None],
#  [88, 3, False, 3.967, None],
#  [89, 9, False, 0.6105, None],
#  [92, 3, False, 3.2885, None],
#  [93, 8, False, 1.616, None],
#  [94, 0, False, 2.8975, None],
#  [95, 0, False, 1.614, None],
#  [97, 4, False, 2.73, None],
#  [99, 4, False, 1.241, None],
#  [100, 3, False, 2.2335, None],
#  [101, 2, False, 4.6035, None]]

# %%
print('occurances',len(b1.bid_360))
b1.bid_360 # 1.bidding_round, 2. User_id, 3. auction_winner 4.self.price  5. self.clicked
# Out:
# occurances 113
# [[1, 4, False, 2.9655, None],
#  [2, 6, False, 3.6945, None],
#  [3, 7, False, 2.492, None],
#  [4, 3, False, 4.2265, None],
#  [5, 4, True, 2.495, False],
#  [6, 3, False, 3.1185, None],
#  [7, 9, False, 1.8935, None],
#  [8, 2, True, 3.0755, False],
#  [9, 5, False, 3.5685, None],
#  [10, 8, True, 3.4185, False],
#  [11, 7, False, 2.233, None],
#  [12, 6, False, 4.06, None],
#  [13, 4, True, 0.5675, True],
#  [13, 4, True, 0.5675, True],
#  [14, 9, False, 1.4195, None],
#  [15, 0, False, 1.1215, None],
#  [16, 9, False, 3.2795, None],
#  [17, 3, False, 1.4605, None],
#  [18, 1, True, 3.0735, False],
#  [19, 3, False, 3.278, None],
#  [20, 4, False, 2.068, None],
#  [21, 8, True, 2.522, False],
#  [22, 6, False, 2.0365, None],
#  [23, 6, False, 3.9735, None],
#  [24, 3, False, 3.902, None],
#  [25, 9, False, 3.1925, None],
#  [26, 6, True, 3.6315, True],
#  [26, 6, True, 3.6315, True],
#  [27, 0, True, 3.978, False],
#  [28, 0, False, 1.176, None],
#  [29, 5, False, 4.051, None],
#  [30, 2, False, 4.3255, None],
#  [31, 2, False, 3.367, None],
#  [32, 3, False, 1.871, None],
#  [33, 9, False, 3.428, None],
#  [34, 7, False, 1.059, None],
#  [35, 3, True, 3.195, False],
#  [36, 3, True, 2.2275, False],
#  [37, 8, False, 3.9965, None],
#  [38, 2, False, 3.648, None],
#  [39, 8, True, 3.053, True],
#  [39, 8, True, 3.053, True],
#  [40, 6, True, 2.6665, False],
#  [41, 6, False, 2.7965, None],
#  [42, 7, False, 1.7945, None],
#  [43, 9, True, 1.5635, False],
#  [44, 6, False, 3.5545, None],
#  [45, 8, True, 1.138, True],
#  [45, 8, True, 1.138, True],
#  [46, 8, True, 1.485, False],
#  [47, 8, False, 2.0635, None],
#  [48, 1, True, 3.2955, False],
#  [49, 7, False, 3.48, None],
#  [50, 8, False, 4.383, None],
#  [51, 7, True, 1.9465, True],
#  [51, 7, True, 1.9465, True],
#  [52, 4, True, 2.412, True],
#  [52, 4, True, 2.412, True],
#  [53, 7, True, 4.014, True],
#  [53, 7, True, 4.014, True],
#  [54, 7, False, 1.736, None],
#  [55, 8, False, 1.2305, None],
#  [56, 8, False, 2.5465, None],
#  [57, 1, False, 3.0005, None],
#  [58, 8, False, 2.787, None],
#  [59, 8, True, 2.199, False],
#  [60, 3, True, 2.2635, False],
#  [61, 5, False, 3.8575, None],
#  [62, 8, True, 4.079, False],
#  [63, 9, False, 1.947, None],
#  [64, 7, True, 2.1545, True],
#  [64, 7, True, 2.1545, True],
#  [65, 5, False, 3.8165, None],
#  [66, 1, False, 4.5155, None],
#  [67, 1, False, 2.779, None],
#  [68, 5, False, 4.6595, None],
#  [69, 1, False, 3.5395, None],
#  [70, 5, False, 2.17, None],
#  [71, 9, True, 2.1015, False],
#  [72, 0, False, 1.0505, None],
#  [73, 9, True, 1.7585, False],
#  [74, 2, False, 2.1155, None],
#  [75, 8, False, 3.3685, None],
#  [76, 8, True, 0.7435, False],
#  [77, 8, False, 2.4215, None],
#  [78, 0, True, 0.768, True],
#  [78, 0, True, 0.768, True],
#  [79, 2, True, 3.143, True],
#  [79, 2, True, 3.143, True],
#  [80, 4, False, 3.057, None],
#  [81, 0, False, 2.77, None],
#  [82, 4, False, 4.402, None],
#  [83, 9, False, 2.4605, None],
#  [84, 8, False, 2.871, None],
#  [85, 8, True, 3.2715, True],
#  [85, 8, True, 3.2715, True],
#  [86, 8, True, 3.2235, False],
#  [87, 4, False, 1.1325, None],
#  [88, 3, False, 3.663, None],
#  [89, 4, True, 1.0075, False],
#  [90, 1, False, 2.6935, None],
#  [91, 4, False, 2.335, None],
#  [92, 0, True, 4.3695, False],
#  [93, 8, False, 2.7495, None],
#  [94, 6, False, 4.6815, None],
#  [95, 9, True, 1.473, False],
#  [96, 8, False, 2.107, None],
#  [97, 4, False, 2.1035, None],
#  [98, 2, True, 2.615, True],
#  [98, 2, True, 2.615, True],
#  [99, 3, False, 3.781, None],
#  [100, 9, False, 1.158, None],
#  [101, 8, False, 2.0535, None]]

# %%
[auction.execute_round() for i in range(100)]
# Out:
# Selected User:  140530390460880
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  2
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.169), (140530668556736, 3.6945), (140530668557264, 4.4815)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.6945
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: 0, 140530668557264: -5.66, 140530668556736: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460912
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  3
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.492), (140530668556736, 2.492), (140530668557264, 4.878)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.492
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: 0, 140530668557264: -8.152000000000001, 140530668556736: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  4
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 1.0925), (140530668556544, 4.2265), (140530668557264, 4.26)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  4.2265
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: 0, 140530668557264: -12.3785, 140530668556736: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460816
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  5
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 1.213), (140530668557264, 2.495), (140530668556544, 4.7195)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.495
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -2.495, 140530668557264: -12.3785, 140530668556736: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  6
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 1.177), (140530668556544, 3.1185), (140530668556736, 3.204)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.1185
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -2.495, 140530668557264: -12.3785, 140530668556736: -3.1185}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  7
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 1.1105), (140530668556544, 1.8935), (140530668557264, 3.124)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.8935
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -2.495, 140530668557264: -14.272, 140530668556736: -3.1185}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460752
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  8
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 2.8485), (140530668556736, 3.0755), (140530668556544, 3.772)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.0755
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -5.5705, 140530668557264: -14.272, 140530668556736: -3.1185}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460848
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  9
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.006), (140530668557264, 3.5685), (140530668556736, 3.656)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.5685
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == True:
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -5.5705, 140530668557264: -14.272, 140530668556736: -5.686999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460944
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  10
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.943), (140530668556736, 3.4185), (140530668556544, 3.522)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.4185
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.989, 140530668557264: -14.272, 140530668556736: -5.686999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460912
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  11
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 0.853), (140530668557264, 2.233), (140530668556736, 4.7475)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.233
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == True:
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.989, 140530668557264: -14.272, 140530668556736: -6.92}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460880
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  12
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 3.802), (140530668556736, 4.06), (140530668557264, 4.873)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  4.06
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.989, 140530668557264: -18.332, 140530668556736: -6.92}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460816
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  13
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.554), (140530668556736, 0.5675), (140530668556544, 1.278)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.5675
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == True:
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.556500000000002, 140530668557264: -18.332, 140530668556736: -6.92}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  14
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.815), (140530668556544, 1.4195), (140530668556736, 4.1505)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.4195
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.556500000000002, 140530668557264: -18.332, 140530668556736: -8.3395}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460688
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  15
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 0.6845), (140530668556544, 1.1215), (140530668557264, 1.8915)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.1215
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.556500000000002, 140530668557264: -19.453500000000002, 140530668556736: -8.3395}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  16
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 3.2795), (140530668557264, 3.2795), (140530668556736, 3.3345)]
#  ----------------------------------------------------------------------------------------------------
# List of biders that submitted similar bids:  [(<__main__.Bidder object at 0x7fcfd8945100>, 3.2795), (<__main__.Bidder object at 0x7fcfd89453d0>, 3.2795)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fcfd89453d0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.2795
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.556500000000002, 140530668557264: -22.733, 140530668556736: -8.3395}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  17
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.449), (140530668557264, 1.4605), (140530668556736, 1.4855)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.4605
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -8.556500000000002, 140530668557264: -22.733, 140530668556736: -9.799999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460720
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  18
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 2.072), (140530668557264, 3.0735), (140530668556544, 4.7165)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.0735
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -11.630000000000003, 140530668557264: -22.733, 140530668556736: -9.799999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  19
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 3.095), (140530668556544, 3.278), (140530668557264, 3.76)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.278
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -11.630000000000003, 140530668557264: -26.011, 140530668556736: -9.799999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460816
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  20
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.842), (140530668556736, 2.068), (140530668557264, 4.261)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.068
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == True:
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -11.630000000000003, 140530668557264: -27.079, 140530668556736: -9.799999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460944
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  21
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.575), (140530668556736, 2.522), (140530668556544, 3.5785)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.522
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -14.152000000000003, 140530668557264: -27.079, 140530668556736: -9.799999999999999}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460880
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  22
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 1.6215), (140530668556544, 2.0365), (140530668556736, 4.673)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.0365
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -14.152000000000003, 140530668557264: -27.079, 140530668556736: -11.8365}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460880
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  23
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 1.8565), (140530668556544, 3.9735), (140530668557264, 4.7925)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.9735
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -14.152000000000003, 140530668557264: -31.052500000000002, 140530668556736: -11.8365}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  24
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 2.963), (140530668557264, 3.902), (140530668556736, 4.868)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.902
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -14.152000000000003, 140530668557264: -31.052500000000002, 140530668556736: -15.738499999999998}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  25
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 0.5365), (140530668557264, 3.1925), (140530668556736, 4.264)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.1925
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -14.152000000000003, 140530668557264: -31.052500000000002, 140530668556736: -18.930999999999997}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460880
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  26
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 2.2045), (140530668556736, 3.6315), (140530668556544, 4.627)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.6315
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == True:
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -16.783500000000004, 140530668557264: -31.052500000000002, 140530668556736: -18.930999999999997}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460688
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  27
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 3.0325), (140530668557264, 3.978), (140530668556544, 4.4655)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.978
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -31.052500000000002, 140530668556736: -18.930999999999997}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460688
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  28
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.022), (140530668556736, 1.176), (140530668557264, 2.049)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.176
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -32.228500000000004, 140530668556736: -18.930999999999997}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460848
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  29
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 3.4235), (140530668557264, 4.051), (140530668556736, 4.605)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  4.051
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -32.228500000000004, 140530668556736: -22.982}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460752
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  30
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 2.935), (140530668556544, 4.3255), (140530668556736, 4.6985)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  4.3255
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -32.228500000000004, 140530668556736: -27.307499999999997}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460752
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  31
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 3.291), (140530668557264, 3.367), (140530668556736, 3.8485)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.367
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == True:
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -32.228500000000004, 140530668556736: -29.6745}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  32
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.9025), (140530668556544, 1.871), (140530668556736, 2.845)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.871
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -32.228500000000004, 140530668556736: -31.545499999999997}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  33
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 0.8975), (140530668557264, 3.428), (140530668556736, 4.11)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.428
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -20.761500000000005, 140530668557264: -32.228500000000004, 140530668556736: -34.973499999999994}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460912
# ...
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -65.47099999999999, 140530668557264: -86.1785, 140530668556736: -69.72449999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460688
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  92
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 2.1445), (140530668557264, 4.3695), (140530668556544, 4.499)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  4.3695
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -69.84049999999999, 140530668557264: -86.1785, 140530668556736: -69.72449999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460944
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  93
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556736, 0.8885), (140530668556544, 2.7495), (140530668557264, 3.9335)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.7495
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == True:
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -69.84049999999999, 140530668557264: -87.928, 140530668556736: -69.72449999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460880
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  94
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.6895), (140530668556544, 4.6815), (140530668556736, 4.998)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  4.6815
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -69.84049999999999, 140530668557264: -87.928, 140530668556736: -74.40599999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  95
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 0.501), (140530668556736, 1.473), (140530668556544, 4.594)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.473
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == False
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -71.31349999999999, 140530668557264: -87.928, 140530668556736: -74.40599999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460944
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  96
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.686), (140530668556736, 2.107), (140530668557264, 3.361)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.107
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == True:
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -71.31349999999999, 140530668557264: -89.035, 140530668556736: -74.40599999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460816
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  97
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.822), (140530668556736, 2.1035), (140530668557264, 3.5665)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.1035
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == True:
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -71.31349999999999, 140530668557264: -90.1385, 140530668556736: -74.40599999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460752
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  98
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 1.3195), (140530668556736, 2.615), (140530668556544, 2.747)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556544
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.615
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 bidder == winning_bidder and ad_result == True:
# 140530668557264 Did not win bid - only notify
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -72.92849999999999, 140530668557264: -90.1385, 140530668556736: -74.40599999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460784
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  99
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 3.187), (140530668556736, 3.781), (140530668557264, 4.2655)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668557264
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  3.781
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 bidder == winning_bidder and ad_result == False
# 140530668556736 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -72.92849999999999, 140530668557264: -93.9195, 140530668556736: -74.40599999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460976
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  100
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668556544, 1.0335), (140530668557264, 1.158), (140530668556736, 2.2245)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1.158
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -72.92849999999999, 140530668557264: -93.9195, 140530668556736: -75.56399999999996}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140530390460944
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  101
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140530668557264, 1.77), (140530668556544, 2.0535), (140530668556736, 3.0885)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140530668556736
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2.0535
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140530668556544 Did not win bid - only notify
# 140530668557264 Did not win bid - only notify
# 140530668556736 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140530668556544: -72.92849999999999, 140530668557264: -93.9195, 140530668556736: -77.61749999999996}
#  ----------------------------------------------------------------------------------------------------
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
auction.balances
# Out:
# {140276743991200: -1000.3605,
#  140276743990432: -1000.5714999999998,
#  140276743982816: -1000.3000000000001}

# %%
b1.bidding_round
# Out:
# 101

# %%
b1.bid_participate_history #bidderid, userid, bidding round, bid price
# Out:
# [[140467995445472, 5, 1, 2.633]]

# %%
b2.bid_participate_history #bidderid, userid, bidding round, bid price

# %%
b3.bid_participate_history #bidderid, userid, bidding round, bid price

# %%
[auction.execute_round() for i in range(10)]

# %%
b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()], [b1, b2, b3])
auction.execute_round()

# %%
print('b1 bid is: ', b1.bid(0x7fb6581c8ca0))
print('b2 bid is: ', b2.bid(0x7fb6581c8ca0))
print('b3 bid is: ', b3.bid(0x7fb6581c8ca0))

# %%
u1 = User()
id(u1)

# %%
user_wins = {i: 0 for i in range(10)}
user_wins

# %%
bids_list = [(1,2), (7,8), (5,6),(3,4) ]

# %%
sorted_list = sorted(bids_list, key=lambda t:t[1])
sorted_list
# Out:
# [(1, 2), (3, 4), (5, 6), (7, 8)]

# %%
winning_price = (sorted_list)[-2][1]
winning_price
# Out:
# 6

# %%
winning_bid = (sorted_list)[-1][0]
winning_bid
# Out:
# 7

# %%
list2 = [(1,2)]
sorted_list = sorted(list2, key=lambda t:t[1])
sorted_list
# Out:
# [(1, 2)]

# %%
winning_price = (sorted_list)[0][-1]

# %%
winning_price
# Out:
# 2

# %%
winning_bid = (sorted_list)[0][0]
winning_bid
# Out:
# 1
