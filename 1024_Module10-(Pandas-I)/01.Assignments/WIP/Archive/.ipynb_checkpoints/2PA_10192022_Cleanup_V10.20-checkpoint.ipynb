# %% [markdown]
# # Sorting out basic design issues

# %% [markdown]
# ## Final Design Version before Cleaning

# %%
import numpy as np
import random
from collections import Counter

class User:
    def __init__(self):
        self.probability2 = random.uniform(0, 1)

    def show_ad(self):
        return  np.random.choice((True, False), p = [self.probability2, 1-self.probability2])

class Auction:
    
    def __init__(self, users, bidders):
        self.users = users
        self.bidders = bidders
        self.auction_history = []
        self.balances = {id(bidder): 0 for bidder in bidders} ########### NEW LINE
        print("*"*100, '\n')
        print('Beginning balances : ',self.balances, '\n','-'*100)
        
        
    def execute_round(self):
        
        ##### if the -ve balance of ALL bidders is < -1000, then break
        
        all_invalid_bidders = any(x > -1000 for x in self.balances.values())
        
        while not all_invalid_bidders:
            print("no bidders are qualifed as all balances are below -1000")
            break
        
        else:
            # print('starting balances2: ', self.balances2, '\n','-'*100)
            bids_dict = {}
            bids_list = []
            bids_list_raw = []

            # 1. SELECT USER (from the pool of users) ----------------------------------

            chosen_user = random.randint(0, len(self.users)-1)
            print('Selected User: ', id(chosen_user), '\n','-'*100) 

            # 2. COLLECT BIDS (send to all bidders) --------------------------------------------
            for bidder in self.bidders:
                #if self.balances[bidder] > -1000:
                #balances = {bidder: 0 for bidder in bidders} ########### NEW LINE
                if self.balances[id(bidder)] > -1000:
                    bids_dict[bidder] = bidder.bid(chosen_user)
                    bidding_round = bidder.bidding_round

                    self.auction_history.append((id(bids_dict[bidder]), bids_dict[bidder])) #bidder
                    highest_bid = 0
                    winning_price = 0
                else:
                    print("Bidder ", id(bidder), "balance is less than -1000. Cannot continue bid" )
     #               #raise Exception("Bidder's balance is less than -1000. Cannot continue bid")
                    continue

            print("Current bidding Round: ", bidding_round, '\n','-'*100)

            # 3. DETERMINE WINNING BID --------------------------------------------
            for bidder, bid_value in bids_dict.items():

                bids_list_raw.append((bidder, bid_value))
                ## only needed to track a human readable bidder id
                bids_list.append((id(bidder), bid_value))


    #        print('bids list', bids_list, '\n','-'*100)

            ###### SORT THE Bids List based on price ##########################################
            sorted_list = sorted(bids_list, key=lambda t:t[1])
            print('Sorted bids list', sorted_list, '\n','-'*100 )

            #------------- for analysis - creating a copy with id(bidder) --------------
            sorted_list_raw = sorted(bids_list_raw, key=lambda t:t[1])
    #        print('sorted bids list RAW', sorted_list_raw, '\n','-'*100 )


            ####### Select second highest price ###############################################
            if len(sorted_list) > 1:
                winning_price = (sorted_list_raw)[-2][1]
                winning_bidder = (sorted_list_raw)[-1][0]
            else:
                winning_price = (sorted_list_raw)[0][-1]
                winning_bidder = (sorted_list_raw)[0][0]

    #        print('Winning Price: ', winning_price, '\n','-'*100)
    #        print('winning bidder', winning_bidder, '\n','-'*100)

            ######## Determine if there are more than 1 bidders with same price ######################

            multiple_winning_bidders = [tup for tup in sorted_list_raw if tup[1] == winning_price]

            if len(multiple_winning_bidders)>1:
                #print('List of biders that submitted similar bids: ' , multiple_winning_bidders, '\n','-'*100)
                randindex = random.randint(0, len(multiple_winning_bidders)-1)
                winning_bidder = multiple_winning_bidders[randindex][0]
                print('Winning bidder from list of similar priced bids: ', winning_bidder, '\n','-'*100)
            else: 
                pass
                #winning_bidder = multiple_winning_bidders[0][0]

            print('Winning Bidder (FINAL): ', id(winning_bidder), '\n','-'*100)
            print('Winning Price (FINAL): ', winning_price, '\n','-'*100)

            ############################################################################################
            # 4. Validate USER CLICK after SHOW AD  --------------------------------------------
            ad_result = self.users[chosen_user].show_ad()
            print('User Clicked on Ad?: ', ad_result,'\n','-'*100)

            # 5.NOTIFY BIDDER & UPDATE BALANCES --------------------------------------------

            print("Bidding Outcomes", '\n','-'*100)
            for bidder in self.bidders:
                if bidder == winning_bidder and ad_result == True:
                    print(id(bidder), "bidder == winning_bidder and ad_result == True:")
                    self.balances[id(bidder)] -= winning_price
                    self.balances[id(bidder)] += 1
                    # balances[bidder] -= winning_price
                    # balances[bidder] += 1                

                    bidder.notify(True, winning_price, ad_result)

                elif bidder == winning_bidder and ad_result == False:
                    print(id(bidder), "bidder == winning_bidder and ad_result == False")
                    self.balances[id(bidder)] -= winning_price
                    # balances[bidder] -= winning_price

                    bidder.notify(True, winning_price, ad_result)

                else:
                    print(id(bidder), "Did not win bid - only notify")
                    bidder.notify(False, winning_price, None)
            print('-'*100, '\n','balances at end of bidding round', self.balances,'\n','-'*100)
                # print('balances at end of bidding round', balances,'\n','-'*100)
        
class Bidder:
    
    """
    This is the bidder class where we track bidding details, patterns and history. 
    In addition to the required functions, there are five other functions that have been 
    created to model bidding strategies -- listed below
    """
    
    # BIDDER CREATION -------------- initiated by GAME runner / Developer ------------------------
    
    def __init__(self, num_users, num_rounds):
        
        ########### initializing basic attributes ###########
        self.num_users = num_users
        self.num_rounds = num_rounds
        self.bidding_round = 0
        self.bid_price = 0

        ########### Basic tracking metrics - dictionaries ###########
        self.bid_participate = {i: 0 for i in range(num_users)} #whether bidder bids or not (USER: BID COUNT)
        self.bid_wins_no_click = {i: 0 for i in range(num_users)} # if bidder wins
        self.bid_win_user_clicks = {i: 0 for i in range(num_users)} # if user clicks
        self.bid_lost = {i: 0 for i in range(num_users)}

        
        ########### Historical transaction tracking for trend analysis ###########
        self.bid_win_click_no = []
        self.bid_win_click_yes = []
        self.bid_lost_list = []
        self.bid_360 = []
        
    ############ SUBMIT BID  ########### initiated by auction #########################################
    ###################################################################################################
    
    def bid(self, user_id):
        """
        Function to set teh default (aka base) bid price
        The bid price is called from a separate function that determines the bid strategy
        """
        
        
        self.bidding_round += 1
        self.user_id = user_id
        #default_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        self.bid_price = self.bid_strategy(user_id)
        print('bid price from STRATEGY', self.bid_price, '\n','-'*100 )
        return self.bid_price
    
        # NOTIFIED OF BID OUTCOME ------------ initiated by auction ------------------------------------
    
    def notify(self, auction_winner, price, clicked):
        bid_y_n_won = 0
        self.auction_winner = auction_winner
        self.price = price
        self.clicked = clicked
        
        if auction_winner == True and clicked == True:
            self.bid_win_user_clicks[self.user_id] = (self.bid_win_user_clicks).get(self.user_id, 0)+1
            
            self.bid_win_click_yes.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

        elif auction_winner == True and clicked == False:
            self.bid_wins_no_click[self.user_id] = (self.bid_wins_no_click).get(self.user_id, 0)+1

            self.bid_win_click_no.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
        
        else:
            self.bid_lost[self.user_id] = (self.bid_lost).get(self.user_id, 0)+1

            self.bid_lost_list.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

            self.bid_360.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
    
    def bid_strategy(self, user_id):

        """
        This function controls the strategy and changes this with what it learns from the bidding process
        There are two basic - default strategies that will be followed for the first 50 rounds which are
        (1) start slow and observe bidding behavior for first 10 rounds
        (2) go aggressive and match max price of past rounds and in crease base bid by 10%
        After the first 50 rounds, the strategy revolves through 4 models (A, B, C & D) aso detailed below
        """
        
        self.base_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        trx_master = [x for x in self.bid_360]
        strategy_list = ['A', 'B', 'C', 'D']
        strategy = random.choice(strategy_list)
        
        for item in trx_master:
        
        ########## Observe: Start Slow for the first 10 rounds  #############
        
            if item[1] < 2:
                self.bid_price = 0.01
            
        ########## Next 40 rounds, match max price + 10%  #############
        
            
            elif item[1] > 2 and item[1] < 4:
                self.bid_price = max(self.bid_360, key=lambda x: x[6])[6]*1.10
        
        ########## Rounds 50+ Learn, Optimize, Mitigate Losses and Win  #############
            
            elif strategy == 'A':
                self.bid_price = self.strategy_a()
            
            elif strategy == 'B':
                self.bid_price = self.strategy_b()
                
            elif strategy == 'C':
                self.bid_price = self.strategy_c()
                
            elif strategy == 'D':
                self.bid_price = self.strategy_d()
            
            else:
                self.bid_price = self.base_bid_price
            
        
        return self.bid_price
        

    def strategy_a(self):
            
        """
        Setting min bid above average difference of loss for prior 10 bids  was greater than 10%
        then adjust you next bid to in increase by that amount
        """

        # filter last 10 losses  
        a = [x for x in self.bid_360[-10:] if x[0] == 'BLOS' and (x[6]-x[5]) > (.1*x[5])]

        # calculated the average percentage loss (> 10%)
        avg_loss_10percent = ((sum(i[6] for i in a) - sum(i[5] for i in a))/(max(1, len(a))))

        #adjust bid price
        self.bid_price = self.base_bid_price + avg_loss_10percent    
        
        return self.bid_price
        
    def strategy_b(self):
        
        """
        Focus on most successful user --- ie where bidder has worn atleast 5 times for same user
        For this user, double the base bid price to increase odds of winning again
        """
        
        a = [x for x in self.bid_360[-100:] if x[0] == 'BWCY']
        #print(a)
        b = (Counter([x[3] for x in a]))
        #print(b)
        # filter for success > 5 times
        c = { k: v for k, v in b.items() if v >= 5 }
        # get max user (most successful thus far)
        d = max(c, key=c.get, default=0) # get user with max wins
        self.bid_price = self.base_bid_price*2
        return self.bid_price
    
    def strategy_c(self):
        
        """
        Find Max winning bid in past 10 bids and increase your base bid by 20%
        """

        a = [x for x in self.bid_360[-10:] if x[0] == 'BLOS']
        self.bid_price = max(a, key=lambda x: x[6])[6]*1.20
        return self.bid_price
    
    def strategy_d(self):
            
        """
        Monitor if balance goes < -500 then scale back on the bids by 10% of the base price
        Conserve cash and wait for other random strategies A, B or C to try again
        """

        # sum all bids that were won, but user not clicked (ie BWCN)
        a = [x for x in self.bid_360 if x[0] == 'BWCN'] 

        # calculate cost of bids in BWCN
        b = (sum(i[6] for i in a))
        
        # sum of all bids where user clicked (ie BWCY)
        c = [x for x in self.bid_360 if x[0] == 'BWCY']
        # sum of total cost
        d = (sum(i[6] for i in c) )

        # earnings till date (ie $1 for every BWCY)
        e = len(c)
        f = e * 1

        current_balance = (b + d -f)
        
        if current_balance < -500:
            self.bid_price = 0.01
        return self.base_bid_price

# %%
#b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
b1, b2, b3, b4, b5, b6, b7, b8, b9, b10 = Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()for i in range(10)], [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10])
#auction = Auction( [User(), User()], [b1, b2, b3])
auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# Out:
# ****************************************************************************************************
#
# Beginning balances :  {140609583389232: 0, 140609583389472: 0, 140609583388704: 0, 140609583389088: 0, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: 0, 140608778463648: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920400
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  1
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389232, 0), (140609583389472, 0), (140609583388704, 0), (140609583389088, 0), (140609583389568, 0), (140609583390528, 0), (140609583390240, 0), (140609583390048, 0), (140609583389136, 0), (140608778463648, 0)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe238451b20>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389472
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 bidder == winning_bidder and ad_result == False
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0, 140609583389472: 0, 140609583388704: 0, 140609583389088: 0, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: 0, 140608778463648: 0}
#  ----------------------------------------------------------------------------------------------------

# %%
bal = auction.balances
bal
# Out:
# {140369076672688: 0,
#  140369076672928: 0,
#  140369076672592: 0,
#  140369076672544: 0,
#  140369076672736: 0,
#  140369076672640: 0,
#  140369076672784: 0,
#  140369076672832: 0,
#  140369076672880: 1,
#  140369076672976: 0}

# %%
[auction.execute_round() for i in range(100)]
# Out:
# Selected User:  140609578920432
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  2
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389232, 0.01), (140609583389472, 0.01), (140609583388704, 0.01), (140609583389088, 0.01), (140609583389568, 0.01), (140609583390528, 0.01), (140609583390240, 0.01), (140609583390048, 0.01), (140609583389136, 0.01), (140608778463648, 0.01)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe2384519a0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389088
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.01
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 bidder == winning_bidder and ad_result == True:
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0, 140609583389472: 0, 140609583388704: 0, 140609583389088: 0.99, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: 0, 140608778463648: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920304
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0418
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.032255
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.029995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00951
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012965
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.042495
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  3
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583390528, 0.00951), (140609583389232, 0.012), (140609583389472, 0.012), (140609583390048, 0.012), (140608778463648, 0.012), (140609583390240, 0.012965), (140609583389568, 0.029995), (140609583389088, 0.032255), (140609583388704, 0.0418), (140609583389136, 0.042495)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.0418
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 bidder == winning_bidder and ad_result == False
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0, 140609583389472: 0, 140609583388704: 0, 140609583389088: 0.99, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: -0.0418, 140608778463648: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920304
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04598
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  4
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389232, 0.04598), (140609583389472, 0.04598), (140609583388704, 0.04598), (140609583389088, 0.04598), (140609583389568, 0.04598), (140609583390528, 0.04598), (140609583390240, 0.04598), (140609583390048, 0.04598), (140609583389136, 0.04598), (140608778463648, 0.04598)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe2084ae9a0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140608778463648
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.04598
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 bidder == winning_bidder and ad_result == False
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0, 140609583389472: 0, 140609583388704: 0, 140609583389088: 0.99, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: -0.0418, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920432
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.010225
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01887
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07307
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.055175999999999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01554
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00294
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05101499999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.055175999999999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.008645
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.050159999999999996
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  5
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583390528, 0.00294), (140609583389136, 0.008645), (140609583389232, 0.010225), (140609583389568, 0.01554), (140609583389472, 0.01887), (140608778463648, 0.050159999999999996), (140609583390240, 0.05101499999999999), (140609583389088, 0.055175999999999996), (140609583390048, 0.055175999999999996), (140609583388704, 0.07307)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe2384519a0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389088
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.055175999999999996
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 bidder == winning_bidder and ad_result == True:
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: -0.0418, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920304
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09689
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.013865
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0662112
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.055175999999999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.008025
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06870799999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0662112
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.065525
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00654
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.049315
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  6
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389136, 0.00654), (140609583389568, 0.008025), (140609583389472, 0.013865), (140608778463648, 0.049315), (140609583389088, 0.055175999999999996), (140609583390048, 0.065525), (140609583388704, 0.0662112), (140609583390240, 0.0662112), (140609583390528, 0.06870799999999999), (140609583389232, 0.09689)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389232
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.06870799999999999
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 bidder == winning_bidder and ad_result == True:
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0.931292, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0, 140609583390048: 0, 140609583389136: -0.0418, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920432
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.031375
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03893
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.013055
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02804
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08244959999999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.034425
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08244959999999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.043574999999999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03421
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0397
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  7
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583388704, 0.013055), (140609583389088, 0.02804), (140609583389232, 0.031375), (140609583389136, 0.03421), (140609583390528, 0.034425), (140609583389472, 0.03893), (140608778463648, 0.0397), (140609583390048, 0.043574999999999996), (140609583389568, 0.08244959999999998), (140609583390240, 0.08244959999999998)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe238451e20>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583390240
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.08244959999999998
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 bidder == winning_bidder and ad_result == True:
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0.931292, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: 0, 140609583390240: 0.9175504, 140609583390048: 0, 140609583389136: -0.0418, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920208
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.042421866666666655
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.006995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0259
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01267
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.039904666666666665
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09893951999999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03003
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06549229999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00296
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09893951999999998
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  8
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389136, 0.00296), (140609583389472, 0.006995), (140609583389088, 0.01267), (140609583388704, 0.0259), (140609583390240, 0.03003), (140609583389568, 0.039904666666666665), (140609583389232, 0.042421866666666655), (140609583390048, 0.06549229999999999), (140609583390528, 0.09893951999999998), (140608778463648, 0.09893951999999998)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe238451f40>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583390528
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.09893951999999998
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 bidder == winning_bidder and ad_result == False
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0.931292, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: -0.09893951999999998, 140609583390240: 0.9175504, 140609583390048: 0, 140609583389136: -0.0418, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920464
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05304
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01809
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08690705999999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.033625
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.007025
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04438
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04854
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02579
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.056112533333333325
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  9
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389568, 0.007025), (140609583389472, 0.01809), (140609583390048, 0.02579), (140609583389088, 0.033625), (140609583390528, 0.04438), (140609583390240, 0.04854), (140609583389232, 0.05304), (140608778463648, 0.056112533333333325), (140609583388704, 0.08690705999999997), (140609583389136, 0.11872742399999997)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.08690705999999997
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 bidder == winning_bidder and ad_result == False
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0.931292, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: -0.09893951999999998, 140609583390240: 0.9175504, 140609583390048: 0, 140609583389136: -0.12870705999999996, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920496
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.011835
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08588003
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01099
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08044
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01594
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09292941499999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0361
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.002065
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07950428166666665
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  10
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389136, 0.002065), (140609583388704, 0.01099), (140609583389232, 0.011835), (140609583389568, 0.01594), (140609583390240, 0.0361), (140608778463648, 0.07950428166666665), (140609583389088, 0.08044), (140609583389472, 0.08588003), (140609583390528, 0.09292941499999999), (140609583390048, 0.11872742399999997)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583390048
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.09292941499999999
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 bidder == winning_bidder and ad_result == False
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 0.931292, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: -0.09893951999999998, 140609583390240: 0.9175504, 140609583390048: -0.09292941499999999, 140609583389136: -0.12870705999999996, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920304
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02496
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03197
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.008065
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.055349414999999985
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00232
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05149
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  11
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389136, 0.00232), (140609583389088, 0.008065), (140609583389472, 0.02496), (140609583388704, 0.03197), (140608778463648, 0.05149), (140609583390528, 0.055349414999999985), (140609583389232, 0.11872742399999997), (140609583389568, 0.11872742399999997), (140609583390240, 0.11872742399999997), (140609583390048, 0.11872742399999997)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe238451a30>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389232
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.11872742399999997
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 bidder == winning_bidder and ad_result == True:
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 1.812564576, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: -0.09893951999999998, 140609583390240: 0.9175504, 140609583390048: -0.09292941499999999, 140609583389136: -0.12870705999999996, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920368
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02975
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06360680057142855
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09281273974999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.14247290879999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.013795
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.14247290879999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08783024874999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08369471999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08998832649999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03719
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  12
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389568, 0.013795), (140609583389232, 0.02975), (140608778463648, 0.03719), (140609583389472, 0.06360680057142855), (140609583390048, 0.08369471999999999), (140609583390240, 0.08783024874999998), (140609583389136, 0.08998832649999997), (140609583388704, 0.09281273974999997), (140609583389088, 0.14247290879999996), (140609583390528, 0.14247290879999996)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe238451f40>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583390528
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.14247290879999996
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 bidder == winning_bidder and ad_result == False
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 1.812564576, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: -0.24141242879999994, 140609583390240: 0.9175504, 140609583390048: -0.09292941499999999, 140609583389136: -0.12870705999999996, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920400
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01385
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03634
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09750322560999997
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05268
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02709
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.14247290879999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0479
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.011875
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.17096749055999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09221751325714286
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  13
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583390048, 0.011875), (140609583389232, 0.01385), (140609583389568, 0.02709), (140609583389472, 0.03634), (140609583390240, 0.0479), (140609583389088, 0.05268), (140608778463648, 0.09221751325714286), (140609583388704, 0.09750322560999997), (140609583390528, 0.14247290879999996), (140609583389136, 0.17096749055999996)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.14247290879999996
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 bidder == winning_bidder and ad_result == False
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: 1.812564576, 140609583389472: 0, 140609583388704: 0, 140609583389088: 1.9348239999999999, 140609583389568: 0, 140609583390528: -0.24141242879999994, 140609583390240: 0.9175504, 140609583390048: -0.09292941499999999, 140609583389136: -0.27117996879999995, 140608778463648: -0.04598}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920240
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.17096749055999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06096
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00439
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.17096749055999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05922
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06317641724999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.003665
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.10290799551999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.17096749055999996
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01896
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  14
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583390240, 0.003665), (140609583388704, 0.00439), (140608778463648, 0.01896), (140609583389568, 0.05922), (140609583389472, 0.06096), (140609583390528, 0.06317641724999998), (140609583390048, 0.10290799551999996), (140609583389232, 0.17096749055999996), (140609583389088, 0.17096749055999996), (140609583389136, 0.17096749055999996)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe2384519d0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.17096749055999996
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 bidder == winning_bidder and ad_result == False
# 140608778463648 Did not win bid - only notify
# ...
# bid price from STRATEGY 0.02749
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583390528 balance is less than -1000. Cannot continue bid
# Bidder  140609583390240 balance is less than -1000. Cannot continue bid
# Bidder  140609583390048 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.027625
#  ----------------------------------------------------------------------------------------------------
# Bidder  140608778463648 balance is less than -1000. Cannot continue bid
# Current bidding Round:  85
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389568, 0.02749), (140609583389136, 0.027625), (140609583389232, 0.07988)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389232
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.027625
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 bidder == winning_bidder and ad_result == True:
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: -919.1559416794712, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -822.7586450089708, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -494.6725818445218, 140608778463648: -1229.9684893382973}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920272
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05337
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583389472 balance is less than -1000. Cannot continue bid
# Bidder  140609583388704 balance is less than -1000. Cannot continue bid
# Bidder  140609583389088 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.014445
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583390528 balance is less than -1000. Cannot continue bid
# Bidder  140609583390240 balance is less than -1000. Cannot continue bid
# Bidder  140609583390048 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 2240.465865843389
#  ----------------------------------------------------------------------------------------------------
# Bidder  140608778463648 balance is less than -1000. Cannot continue bid
# Current bidding Round:  86
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389568, 0.014445), (140609583389232, 0.05337), (140609583389136, 2240.465865843389)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.05337
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 bidder == winning_bidder and ad_result == True:
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: -919.1559416794712, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -822.7586450089708, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -493.7259518445218, 140608778463648: -1229.9684893382973}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920400
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 945.2301432724232
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583389472 balance is less than -1000. Cannot continue bid
# Bidder  140609583388704 balance is less than -1000. Cannot continue bid
# Bidder  140609583389088 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 2240.465865843389
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583390528 balance is less than -1000. Cannot continue bid
# Bidder  140609583390240 balance is less than -1000. Cannot continue bid
# Bidder  140609583390048 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.07731
#  ----------------------------------------------------------------------------------------------------
# Bidder  140608778463648 balance is less than -1000. Cannot continue bid
# Current bidding Round:  87
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389136, 0.07731), (140609583389232, 945.2301432724232), (140609583389568, 2240.465865843389)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389568
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  945.2301432724232
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 bidder == winning_bidder and ad_result == True:
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: -919.1559416794712, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -1766.9887882813941, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -493.7259518445218, 140608778463648: -1229.9684893382973}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920240
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 2240.465865843389
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583389472 balance is less than -1000. Cannot continue bid
# Bidder  140609583388704 balance is less than -1000. Cannot continue bid
# Bidder  140609583389088 balance is less than -1000. Cannot continue bid
# Bidder  140609583389568 balance is less than -1000. Cannot continue bid
# Bidder  140609583390528 balance is less than -1000. Cannot continue bid
# Bidder  140609583390240 balance is less than -1000. Cannot continue bid
# Bidder  140609583390048 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 2240.465865843389
#  ----------------------------------------------------------------------------------------------------
# Bidder  140608778463648 balance is less than -1000. Cannot continue bid
# Current bidding Round:  88
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389232, 2240.465865843389), (140609583389136, 2240.465865843389)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7fe238451a30>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389232
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2240.465865843389
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 bidder == winning_bidder and ad_result == True:
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 Did not win bid - only notify
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: -3158.6218075228603, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -1766.9887882813941, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -493.7259518445218, 140608778463648: -1229.9684893382973}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140609578920240
#  ----------------------------------------------------------------------------------------------------
# Bidder  140609583389232 balance is less than -1000. Cannot continue bid
# Bidder  140609583389472 balance is less than -1000. Cannot continue bid
# Bidder  140609583388704 balance is less than -1000. Cannot continue bid
# Bidder  140609583389088 balance is less than -1000. Cannot continue bid
# Bidder  140609583389568 balance is less than -1000. Cannot continue bid
# Bidder  140609583390528 balance is less than -1000. Cannot continue bid
# Bidder  140609583390240 balance is less than -1000. Cannot continue bid
# Bidder  140609583390048 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 1159.0481006005882
#  ----------------------------------------------------------------------------------------------------
# Bidder  140608778463648 balance is less than -1000. Cannot continue bid
# Current bidding Round:  89
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140609583389136, 1159.0481006005882)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140609583389136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1159.0481006005882
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140609583389232 Did not win bid - only notify
# 140609583389472 Did not win bid - only notify
# 140609583388704 Did not win bid - only notify
# 140609583389088 Did not win bid - only notify
# 140609583389568 Did not win bid - only notify
# 140609583390528 Did not win bid - only notify
# 140609583390240 Did not win bid - only notify
# 140609583390048 Did not win bid - only notify
# 140609583389136 bidder == winning_bidder and ad_result == True:
# 140608778463648 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140609583389232: -3158.6218075228603, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -1766.9887882813941, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -1651.77405244511, 140608778463648: -1229.9684893382973}
#  ----------------------------------------------------------------------------------------------------
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Consolidate Metrics: All Bidders

# %% [markdown]
# ## Overall

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)

BWCY = (len(b1.bid_win_click_yes), len(b2.bid_win_click_yes), \
      len(b3.bid_win_click_yes), len(b4.bid_win_click_yes),  len(b5.bid_win_click_yes), len(b6.bid_win_click_yes), \
      len(b7.bid_win_click_yes), len(b8.bid_win_click_yes), len(b9.bid_win_click_yes), len(b10.bid_win_click_yes))

sum(BWCY)
print('BWCY - Bid Win - Click YES: Count', sum(BWCY))

BWCN = (len(b1.bid_win_click_no),len(b2.bid_win_click_no),len(b3.bid_win_click_no)\
     ,len(b4.bid_win_click_no),len(b5.bid_win_click_no),len(b6.bid_win_click_no),len(b7.bid_win_click_no),\
    len(b8.bid_win_click_no),len(b9.bid_win_click_no),len(b10.bid_win_click_no))

sum(BWCN)

print('BWCN - Bid Win - Click NO: Count',sum(BWCN))

# GENERAL CLICK RATIO

print('Overall Click Ratio ', sum(BWCY) / (sum(BWCY)+sum(BWCN)) )

# BLOS = NOT RELEVANT
# print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))

# print('Balances', auction.balances)
# Out:
# Bidding Rounds 80
# BWCY - Bid Win - Click YES: Count 32
# BWCN - Bid Win - Click NO: Count 69
# Overall Click Ratio  0.31683168316831684

# %% [markdown]
# # Bid Refining - Filters

# %% [markdown]
# ## Observe first 10 rounds

# %%
trx_master = [x for x in self.bid_360]

for item in trx_master:

    if item[1] < 10:
        self.bid_price = 0.01
    else:
        self.bid_price = base_bid_price

# trx_master = [x for x in b1.bid_360]

# for item in trx_master:
#     if item[1] < 10:
#         print('hey')
#     else:
#         print('hey no')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 trx_master = [x for x in self.bid_360]
#       3 for item in trx_master:
#       5     if item[1] < 10:
#
# NameError: name 'self' is not defined

# %%
a = [x for x in b1.bid_360[-100:] if 0 < x[1] < 50]

for item in a:
    if item[1] < 10:
        print('hey')
    else:
        print('hey no')

# b = filter(lambda x: x[1] < 10, a)
# print(b)
# Out:
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no

# %% [markdown]
# ## Loss by > 10%

# %%
# lost the bid by a price > 10%

# filter last 10 bids for those you have lost 
a = [x for x in b1.bid_360[-10:] if x[0] == 'BLOS' and (x[6]-x[5]) > (.1*x[5])]
#print(a)

# calculated the average percentage loss (> 10%)
b = ((sum(i[6] for i in a) - sum(i[5] for i in a))/(max(1, len(a))))

print(b)

# then set bid_price = 

# [0]Category, [1]self.bidding_round, [2]id(self), [3]self.user_id, 
# [4]self.auction_winner, [5]#self.bid_price, [6]self.winning price, [7]self.clicked
# Out:
# 0.03324855583759785

# %% [markdown]
# ## Most successful user

# %%
# lost the bid by a price > 10%
from collections import Counter

a = [x for x in b1.bid_360[-1000:] if x[0] == 'BWCY']
#print(a)
b = (Counter([x[3] for x in a]))
c = { k: v for k, v in b.items() if v >= 3 }
#print(b)
d = max(c, key=c.get, default = 0) # get user with max wins
print(d)
#print(c)

#print(max(b, key=b.get))

# then set bid_price = 

# [0]Category, [1]self.bidding_round, [2]id(self), [3]self.user_id, 
# [4]self.auction_winner, [5]#self.bid_price, [6]self.winning price, [7]self.clicked
# Out:
# 0

# %% [markdown]
# ## Wait certain rounds, then accelerate

# %%
#a = [x for x in b1.bid_360[-100:] if x[0] == 'BWCN'] # < ]
a = [x for x in b1.bid_360[-100:] if 100 < x[1] < 200] #'BWCN'] # < ]
print(a)
     # then take default bid probability
# Out:
# [['BLOS', 101, 140568245737168, 6, False, 0.04786, 0.08659, None]]

# %% [markdown]
# ## Match Max and go over 10%

# %% [markdown]
# ---

# %%
b1.bid_360 # Category,self.bidding_round, id(self), self.user_id, self.auction_winner,
           #self.bid_price, self.winning price, self.clicked
#[x for x in b1.bid_360]    

a = [x for x in b1.bid_360[-10:] if x[0] == 'BLOS']

# a  = [x for x in b1.bid_360]
# a = [trx_master[-10:] if x[0] == 'BLOS']
#print(trx_master)
a

b = max(a, key=lambda x: x[6])[6]*1.20
print(b)
# Out:
# 0.012

# %% [markdown]
# ## Monitor balance and go convervative

# %%
# Monitor if balance goes < -500
# then scale back on the bids by 10% of the base price

# filter last 10 bids for those you have lost 
a = [x for x in b1.bid_360 if x[0] == 'BWCN'] 
#print(a)

# calculate current balance
b = (sum(i[6] for i in a))# - sum(i[5] for i in a))/(max(1, len(a))))
print(b)

c = [x for x in b1.bid_360 if x[0] == 'BWCY']
d = (sum(i[6] for i in c) )
print(d)
      
e = len(c)

f = e * 1


balance = (b + d -f)
print(balance)
# then set bid_price =
# Out:
# 1755.6575161955327
# 45.451559031805296
# 1797.109075227338

# %% [markdown]
# ---

# %% [markdown]
# ## By Bidder

# %% [markdown]
# ### for b1

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b1.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b1.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 88
# BWCY - Bid Win - Click YES: Count 8
# BWCN - Bid Win - Click NO: Count 1
# BLOS - Bid LOST: Count 80
# Balances {140609583389232: -3158.6218075228603, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -1766.9887882813941, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -1651.77405244511, 140608778463648: -1229.9684893382973}

# %% [markdown]
# ## for b2

# %%
# Summary Counts
print('Bidding Rounds', b2.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b2.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b2.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b2.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 80
# BWCY - Bid Win - Click YES: Count 4
# BWCN - Bid Win - Click NO: Count 7
# BLOS - Bid LOST: Count 78
# Balances {140609583389232: -3158.6218075228603, 140609583389472: -2036.9503334695264, 140609583388704: -1298.4005622498923, 140609583389088: -2422.3687593379536, 140609583389568: -1766.9887882813941, 140609583390528: -1248.6460170059604, 140609583390240: -1242.9306891310805, 140609583390048: -1558.7446566452027, 140609583389136: -1651.77405244511, 140608778463648: -1229.9684893382973}

# %% [markdown]
# ## for b3

# %%
# Summary Counts
print('Bidding Rounds', b3.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b3.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b3.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b3.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 101
# BWCY - Bid Win - Click YES: Count 5
# BWCN - Bid Win - Click NO: Count 10
# BLOS - Bid LOST: Count 86
# Balances {140588383663200: -1147.6122670914983, 140588388722480: -1234.6556190166716, 140588388723152: -683.9171783816711, 140588388722912: -1103.359507689096, 140588388721088: -1428.327987930117, 140588388722816: -1782.5122671418005, 140588388720848: -1279.3556726191655, 140588388722864: -1182.55272084212, 140588388721616: -454.9901072078393, 140588388720944: -1439.5127313027533}

# %% [markdown]
# ---

# %% [markdown]
# # User Info

# %%
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Wins User Clicked', {k: v for k, v in sorted(b1.bid_win_user_clicks.items(), key=lambda item: item[0])})
print('BWCN - Bid Wins User NO Clicked', {k: v for k, v in sorted(b1.bid_wins_no_click.items(), key=lambda item: item[0])})
print('BLOS - Bids Lost', {k: v for k, v in sorted(b1.bid_lost.items(), key=lambda item: item[0])})
# Out:
# Bidding Rounds 89
# BWCY - Bid Wins User Clicked {0: 0, 2: 1, 3: 1, 6: 1}
# BWCN - Bid Wins User NO Clicked {0: 3, 1: 2, 5: 1, 8: 1, 9: 3}
# BLOS - Bids Lost {0: 9, 1: 12, 2: 5, 3: 7, 4: 9, 5: 5, 6: 5, 7: 9, 8: 21, 9: 6}

# %%
b1.bid_360
# Out:
# [['BWCY', 1, 140369076362160, 6, True, 0, 0, True],
#  ['BLOS', 2, 140369076362160, 1, False, 0.01, 0.01, None],
#  ['BLOS', 3, 140369076362160, 4, False, 0.01263, 0.034125, None],
#  ['BLOS',
#   4,
#   140369076362160,
#   5,
#   False,
#   0.03753750000000001,
#   0.03753750000000001,
#   None],
#  ['BWCY', 5, 140369076362160, 6, True, 0.08493, 0.07898, True],
#  ['BLOS', 6, 140369076362160, 9, False, 0.08328, 0.08328, None],
#  ['BLOS', 7, 140369076362160, 3, False, 0.00955, 0.09477599999999999, None],
#  ['BLOS',
#   8,
#   140369076362160,
#   3,
#   False,
#   0.05403549999999999,
#   0.11373119999999998,
#   None],
#  ['BLOS', 9, 140369076362160, 9, False, 0.03343, 0.13647743999999998, None],
#  ['BLOS',
#   10,
#   140369076362160,
#   6,
#   False,
#   0.07888103499999997,
#   0.13647743999999998,
#   None],
#  ['BLOS', 11, 140369076362160, 7, False, 0.0823, 0.08351, None],
#  ['BLOS',
#   12,
#   140369076362160,
#   9,
#   False,
#   0.16377292799999996,
#   0.16377292799999996,
#   None],
#  ['BLOS', 13, 140369076362160, 5, False, 0.035025, 0.10744785828571427, None],
#  ['BLOS', 14, 140369076362160, 7, False, 0.012155, 0.19652751359999995, None],
#  ['BWCY',
#   15,
#   140369076362160,
#   9,
#   True,
#   0.23583301631999992,
#   0.23583301631999992,
#   True],
#  ['BLOS', 16, 140369076362160, 5, False, 0.0995, 0.2829996195839999, None],
#  ['BWCY',
#   17,
#   140369076362160,
#   9,
#   True,
#   0.33959954350079985,
#   0.2829996195839999,
#   True],
#  ['BLOS', 18, 140369076362160, 5, False, 0.0529, 0.33959954350079985, None],
#  ['BLOS', 19, 140369076362160, 8, False, 0.04078, 0.177893292993736, None],
#  ['BLOS', 20, 140369076362160, 8, False, 0.044085, 0.4075194522009598, None],
#  ['BLOS', 21, 140369076362160, 3, False, 0.06743, 0.4075194522009598, None],
#  ['BLOS',
#   22,
#   140369076362160,
#   9,
#   False,
#   0.48902334264115177,
#   0.48902334264115177,
#   None],
#  ['BLOS', 23, 140369076362160, 4, False, 0.048865, 0.09918, None],
#  ['BLOS', 24, 140369076362160, 0, False, 0.042935, 0.5868280111693821, None],
#  ['BLOS', 25, 140369076362160, 3, False, 0.05247, 0.2871282300523307, None],
#  ['BLOS',
#   26,
#   140369076362160,
#   8,
#   False,
#   0.28030282521277106,
#   0.7041936134032585,
#   None],
#  ['BLOS',
#   27,
#   140369076362160,
#   6,
#   False,
#   0.33738672128858194,
#   0.33738672128858194,
#   None],
#  ['BWCY',
#   28,
#   140369076362160,
#   8,
#   True,
#   0.8450323360839102,
#   0.8450323360839102,
#   True],
#  ['BWCY',
#   29,
#   140369076362160,
#   9,
#   True,
#   0.8450323360839102,
#   0.4308563816466299,
#   True],
#  ['BLOS', 30, 140369076362160, 6, False, 0.01588, 1.0140388033006922, None],
#  ['BLOS', 31, 140369076362160, 9, False, 0.08751, 1.2168465639608306, None],
#  ['BLOS', 32, 140369076362160, 0, False, 0.01939, 1.4602158767529967, None],
#  ['BLOS',
#   33,
#   140369076362160,
#   2,
#   False,
#   1.752259052103596,
#   1.752259052103596,
#   None],
#  ['BLOS', 34, 140369076362160, 1, False, 0.02704, 2.102710862524315, None],
#  ['BLOS', 35, 140369076362160, 3, False, 0.04197, 2.523253035029178, None],
#  ['BLOS',
#   36,
#   140369076362160,
#   9,
#   False,
#   3.027903642035014,
#   3.027903642035014,
#   None],
#  ['BLOS',
#   37,
#   140369076362160,
#   9,
#   False,
#   1.6278150283136026,
#   3.6334843704420163,
#   None],
#  ['BWCY',
#   38,
#   140369076362160,
#   8,
#   True,
#   1.7347807472827375,
#   1.6467699316658286,
#   True],
#  ['BLOS',
#   39,
#   140369076362160,
#   1,
#   False,
#   1.7344307472827376,
#   4.36018124453042,
#   None],
#  ['BLOS',
#   40,
#   140369076362160,
#   9,
#   False,
#   1.8325649972777298,
#   5.2322174934365036,
#   None],
#  ['BLOS', 41, 140369076362160, 9, False, 0.05966, 6.278660992123804, None],
#  ['BLOS',
#   42,
#   140369076362160,
#   5,
#   False,
#   2.9008704431378805,
#   7.534393190548564,
#   None],
#  ['BLOS',
#   43,
#   140369076362160,
#   4,
#   False,
#   9.041271828658276,
#   9.041271828658276,
#   None],
#  ['BWCN',
#   44,
#   140369076362160,
#   1,
#   True,
#   10.84952619438993,
#   10.84952619438993,
#   False],
#  ['BLOS',
#   45,
#   140369076362160,
#   3,
#   False,
#   10.84952619438993,
#   10.84952619438993,
#   None],
#  ['BLOS',
#   46,
#   140369076362160,
#   3,
#   False,
#   3.8195892150138713,
#   5.353344202047788,
#   None],
#  ['BLOS', 47, 140369076362160, 8, False, 0.020365, 13.019431433267917, None],
#  ['BWCY',
#   48,
#   140369076362160,
#   8,
#   True,
#   15.623317719921499,
#   15.623317719921499,
#   True],
#  ['BLOS',
#   49,
#   140369076362160,
#   5,
#   False,
#   15.623317719921499,
#   18.747981263905796,
#   None],
#  ['BWCN',
#   50,
#   140369076362160,
#   1,
#   True,
#   22.497577516686956,
#   8.965171318023883,
#   False],
#  ['BLOS', 51, 140369076362160, 5, False, 0.024125, 22.497577516686956, None],
#  ['BWCY', 52, 140369076362160, 8, True, 8.984712045676753, 0.09363, True],
#  ['BLOS',
#   53,
#   140369076362160,
#   0,
#   False,
#   26.997093020024348,
#   26.997093020024348,
#   None],
#  ['BLOS',
#   54,
#   140369076362160,
#   7,
#   False,
#   10.056439370243272,
#   32.396511624029216,
#   None],
#  ['BWCN',
#   55,
#   140369076362160,
#   3,
#   True,
#   38.87581394883506,
#   38.87581394883506,
#   False],
#  ['BLOS',
#   56,
#   140369076362160,
#   7,
#   False,
#   38.87581394883506,
#   38.87581394883506,
#   None],
#  ['BLOS',
#   57,
#   140369076362160,
#   4,
#   False,
#   15.27388368693128,
#   46.65097673860207,
#   None],
#  ['BWCY',
#   58,
#   140369076362160,
#   7,
#   True,
#   55.98117208632248,
#   55.98117208632248,
#   True],
#  ['BLOS', 59, 140369076362160, 8, False, 0.06991, 0.06991, None],
#  ['BLOS', 60, 140369076362160, 1, False, 0.06469, 67.17740650358698, None],
#  ['BLOS',
#   61,
#   140369076362160,
#   5,
#   False,
#   80.61288780430438,
#   80.61288780430438,
#   None],
#  ['BLOS', 62, 140369076362160, 8, False, 0.00744, 36.87436817646857, None],
#  ['BLOS', 63, 140369076362160, 1, False, 0.01344, 96.73546536516525, None],
#  ['BLOS', 64, 140369076362160, 7, False, 0.05499, 96.73546536516525, None],
#  ['BLOS', 65, 140369076362160, 0, False, 0.04679, 116.0825584381983, None],
#  ['BWCY',
#   66,
#   140369076362160,
#   4,
#   True,
#   139.29907012583797,
#   139.29907012583797,
#   True],
#  ['BLOS',
#   67,
#   140369076362160,
#   2,
#   False,
#   139.29907012583797,
#   167.15888415100557,
#   None],
#  ['BLOS', 68, 140369076362160, 4, False, 0.02824, 200.59066098120667, None],
#  ['BLOS', 69, 140369076362160, 7, False, 0.06822, 240.708793177448, None],
#  ['BWCY',
#   70,
#   140369076362160,
#   9,
#   True,
#   288.85055181293757,
#   288.85055181293757,
#   True],
#  ['BLOS', 71, 140369076362160, 8, False, 0.040025, 346.62066217552507, None],
#  ['BLOS',
#   72,
#   140369076362160,
#   4,
#   False,
#   145.2782803380431,
#   149.39575412541703,
#   None],
#  ['BLOS',
#   73,
#   140369076362160,
#   8,
#   False,
#   160.732859218268,
#   415.9447946106301,
#   None],
#  ['BLOS', 74, 140369076362160, 6, False, 0.01422, 499.1337535327561, None],
#  ['BLOS', 75, 140369076362160, 7, False, 0.03593, 598.9605042393073, None],
#  ['BLOS', 76, 140369076362160, 5, False, 0.01012, 258.14983916714436, None],
#  ['BLOS',
#   77,
#   140369076362160,
#   7,
#   False,
#   718.7526050871687,
#   718.7526050871687,
#   None],
#  ['BLOS', 78, 140369076362160, 7, False, 0.00961, 862.5031261046024, None],
#  ['BLOS', 79, 140369076362160, 1, False, 0.010095, 1035.003751325523, None],
#  ['BLOS', 80, 140369076362160, 0, False, 0.02637, 1242.0045015906273, None],
#  ['BLOS', 81, 140369076362160, 2, False, 0.04419, 1490.4054019087528, None],
#  ['BWCN',
#   82,
#   140369076362160,
#   0,
#   True,
#   1788.4864822905033,
#   1788.4864822905033,
#   False],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   846.038986532926,
#   None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.03834, None],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   659.7842865121158,
#   None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.06816, None],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   835.3846609884102,
#   None],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   858.6934641686585,
#   None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.00449, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.07542, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.023095, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.09559, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.07723, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.04626, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.03117, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.07364, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.033815, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.00795, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.002225, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.005705, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.024925, None]]
