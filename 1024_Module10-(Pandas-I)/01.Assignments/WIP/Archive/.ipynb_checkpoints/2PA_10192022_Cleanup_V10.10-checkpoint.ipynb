# %% [markdown]
# # Sorting out basic design issues

# %% [markdown]
# ## Final Design Version before Cleaning

# %%
import numpy as np
import random
from collections import Counter

class User:
    def __init__(self):
        self.probability2 = random.uniform(0, 1)

    def show_ad(self):
        return  np.random.choice((True, False), p = [self.probability2, 1-self.probability2])

class Auction:
    
    def __init__(self, users, bidders):
        self.users = users
        self.bidders = bidders
        self.auction_history = []
        self.balances = {id(bidder): 0 for bidder in bidders} ########### NEW LINE
        print("*"*100, '\n')
        print('Beginning balances : ',self.balances, '\n','-'*100)
        
        
    def execute_round(self):
        
        ##### if the -ve balance of ALL bidders is < -1000, then break
        
        all_invalid_bidders = any(x > -1000 for x in self.balances.values())
        
        while not all_invalid_bidders:
            print("no bidders are qualifed as all balances are below -1000")
            break
        
        else:
            # print('starting balances2: ', self.balances2, '\n','-'*100)
            bids_dict = {}
            bids_list = []
            bids_list_raw = []

            # 1. SELECT USER (from the pool of users) ----------------------------------

            chosen_user = random.randint(0, len(self.users)-1)
            print('Selected User: ', id(chosen_user), '\n','-'*100) 

            # 2. COLLECT BIDS (send to all bidders) --------------------------------------------
            for bidder in self.bidders:
                #if self.balances[bidder] > -1000:
                #balances = {bidder: 0 for bidder in bidders} ########### NEW LINE
                if self.balances[id(bidder)] > -1000:
                    bids_dict[bidder] = bidder.bid(chosen_user)
                    bidding_round = bidder.bidding_round

                    self.auction_history.append((id(bids_dict[bidder]), bids_dict[bidder])) #bidder
                    highest_bid = 0
                    winning_price = 0
                else:
                    print("Bidder ", id(bidder), "balance is less than -1000. Cannot continue bid" )
     #               #raise Exception("Bidder's balance is less than -1000. Cannot continue bid")
                    continue

            print("Current bidding Round: ", bidding_round, '\n','-'*100)

            # 3. DETERMINE WINNING BID --------------------------------------------
            for bidder, bid_value in bids_dict.items():

                bids_list_raw.append((bidder, bid_value))
                ## only needed to track a human readable bidder id
                bids_list.append((id(bidder), bid_value))


    #        print('bids list', bids_list, '\n','-'*100)

            ###### SORT THE Bids List based on price ##########################################
            sorted_list = sorted(bids_list, key=lambda t:t[1])
            print('Sorted bids list', sorted_list, '\n','-'*100 )

            #------------- for analysis - creating a copy with id(bidder) --------------
            sorted_list_raw = sorted(bids_list_raw, key=lambda t:t[1])
    #        print('sorted bids list RAW', sorted_list_raw, '\n','-'*100 )


            ####### Select second highest price ###############################################
            if len(sorted_list) > 1:
                winning_price = (sorted_list_raw)[-2][1]
                winning_bidder = (sorted_list_raw)[-1][0]
            else:
                winning_price = (sorted_list_raw)[0][-1]
                winning_bidder = (sorted_list_raw)[0][0]

    #        print('Winning Price: ', winning_price, '\n','-'*100)
    #        print('winning bidder', winning_bidder, '\n','-'*100)

            ######## Determine if there are more than 1 bidders with same price ######################

            multiple_winning_bidders = [tup for tup in sorted_list_raw if tup[1] == winning_price]

            if len(multiple_winning_bidders)>1:
                #print('List of biders that submitted similar bids: ' , multiple_winning_bidders, '\n','-'*100)
                randindex = random.randint(0, len(multiple_winning_bidders)-1)
                winning_bidder = multiple_winning_bidders[randindex][0]
                print('Winning bidder from list of similar priced bids: ', winning_bidder, '\n','-'*100)
            else: 
                pass
                #winning_bidder = multiple_winning_bidders[0][0]

            print('Winning Bidder (FINAL): ', id(winning_bidder), '\n','-'*100)
            print('Winning Price (FINAL): ', winning_price, '\n','-'*100)

            ############################################################################################
            # 4. Validate USER CLICK after SHOW AD  --------------------------------------------
            ad_result = self.users[chosen_user].show_ad()
            print('User Clicked on Ad?: ', ad_result,'\n','-'*100)

            # 5.NOTIFY BIDDER & UPDATE BALANCES --------------------------------------------

            print("Bidding Outcomes", '\n','-'*100)
            for bidder in self.bidders:
                if bidder == winning_bidder and ad_result == True:
                    print(id(bidder), "bidder == winning_bidder and ad_result == True:")
                    self.balances[id(bidder)] -= winning_price
                    self.balances[id(bidder)] += 1
                    # balances[bidder] -= winning_price
                    # balances[bidder] += 1                

                    bidder.notify(True, winning_price, ad_result)

                elif bidder == winning_bidder and ad_result == False:
                    print(id(bidder), "bidder == winning_bidder and ad_result == False")
                    self.balances[id(bidder)] -= winning_price
                    # balances[bidder] -= winning_price

                    bidder.notify(True, winning_price, ad_result)

                else:
                    print(id(bidder), "Did not win bid - only notify")
                    bidder.notify(False, winning_price, None)
            print('-'*100, '\n','balances at end of bidding round', self.balances,'\n','-'*100)
                # print('balances at end of bidding round', balances,'\n','-'*100)
        
class Bidder:
    
    """
    This is the bidder class where we track bidding details, patterns and history. 
    In addition to the required functions, there are five other functions that have been 
    created to model bidding strategies -- listed below
    """
    
    # BIDDER CREATION -------------- initiated by GAME runner / Developer ------------------------
    
    def __init__(self, num_users, num_rounds):

        self.num_users = num_users
        self.num_rounds = num_rounds
        self.bidding_round = 0

        self.bid_y_n = True
        self.bid_participate = {i: 0 for i in range(num_users)} #whether bidder bids or not (USER: BID COUNT)
        self.bid_wins_no_click = {i: 0 for i in range(num_users)} # if bidder wins
        self.bid_win_user_clicks = {i: 0 for i in range(num_users)} # if user clicks
        self.bid_lost = {i: 0 for i in range(num_users)}
        
        #Transaction records
        # self.bid_win_history = [] # won bid
        # self.bid_win_user_click_history = [] # won bid and user clicked
        # self.bid_lost_history = [] # lost bid, but know the user and price
        self.bid_price = 0
        
        ########### New tables
        self.bid_win_click_no = []
        self.bid_win_click_yes = []
        self.bid_lost_list = []
        self.bid_360 = []
        
        ############
        #? Winning bid price / user (because you get notified of winning bids) -- 
        ###### you know the user and winning bid (just not the click result)
        
    # SUBMIT BID  ------------ initiated by auction ------------------------------------
    
    def bid(self, user_id):
        self.bidding_round += 1
        self.user_id = user_id
        default_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        self.bid_price = self.bid_strategy(user_id)
        print('bid price from STRATEGY', self.bid_price, '\n','-'*100 )
        return self.bid_price
    
        # NOTIFIED OF BID OUTCOME ------------ initiated by auction ------------------------------------
    
    def notify(self, auction_winner, price, clicked):
        bid_y_n_won = 0
        self.auction_winner = auction_winner
        self.price = price
        self.clicked = clicked
        
        if auction_winner == True and clicked == True:
            self.bid_win_user_clicks[self.user_id] = (self.bid_win_user_clicks).get(self.user_id, 0)+1
            
            self.bid_win_click_yes.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

        elif auction_winner == True and clicked == False:
            self.bid_wins_no_click[self.user_id] = (self.bid_wins_no_click).get(self.user_id, 0)+1

            self.bid_win_click_no.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
        
        else:
            self.bid_lost[self.user_id] = (self.bid_lost).get(self.user_id, 0)+1

            self.bid_lost_list.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

            self.bid_360.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
    
    def bid_strategy(self, user_id):

        """
        This function controls the strategy and changes this with what it learns from the bidding process
        There are two basic - default strategies that will be followed for the first 50 rounds which are
        (1) start slow and observe bidding behavior for first 10 rounds
        (2) go aggressive and match max price of past rounds and in crease base bid by 10%
        After the first 50 rounds, the strategy revolves through 4 models (A, B, C & D) aso detailed below
        """
        
        self.base_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        trx_master = [x for x in self.bid_360]
        strategy_list = ['A', 'B', 'C', 'D']
        strategy = random.choice(strategy_list)
        
        for item in trx_master:
        
        ########## Observe: Start Slow for the first 10 rounds  #############
        
            if item[1] < 2:
                self.bid_price = 0.01
            
        ########## Next 40 rounds, match max price + 10%  #############
        
            
            elif item[1] > 2 and item[1] < 4:
                self.bid_price = max(self.bid_360, key=lambda x: x[6])[6]*1.10
        
        ########## Rounds 50+ Learn, Optimize, Mitigate Losses and Win  #############
            
            elif strategy == 'A':
                self.bid_price = self.strategy_a()
            
            elif strategy == 'B':
                self.bid_price = self.strategy_b()
                
            elif strategy == 'C':
                self.bid_price = self.strategy_c()
                
            elif strategy == 'D':
                self.bid_price = self.strategy_d()
            
            else:
                self.bid_price = self.base_bid_price
            
        
        return self.bid_price
        

    def strategy_a(self):
            
        """
        Setting min bid above average difference of loss for prior 10 bids  was greater than 10%
        then adjust you next bid to in increase by that amount
        """

        # filter last 10 losses  
        a = [x for x in self.bid_360[-10:] if x[0] == 'BLOS' and (x[6]-x[5]) > (.1*x[5])]

        # calculated the average percentage loss (> 10%)
        avg_loss_10percent = ((sum(i[6] for i in a) - sum(i[5] for i in a))/(max(1, len(a))))

        #adjust bid price
        self.bid_price = self.base_bid_price + avg_loss_10percent    
        
        return self.bid_price
        
    def strategy_b(self):
        
        """
        Focus on most successful user --- ie where bidder has worn atleast 5 times for same user
        For this user, double the base bid price to increase odds of winning again
        """
        
        a = [x for x in self.bid_360[-100:] if x[0] == 'BWCY']
        #print(a)
        b = (Counter([x[3] for x in a]))
        #print(b)
        # filter for success > 5 times
        c = { k: v for k, v in b.items() if v >= 5 }
        # get max user (most successful thus far)
        d = max(c, key=c.get, default=0) # get user with max wins
        self.bid_price = self.base_bid_price*2
        return self.bid_price
    
    def strategy_c(self):
        
        """
        Find Max winning bid in past 10 bids and increase your base bid by 20%
        """

        a = [x for x in self.bid_360[-10:] if x[0] == 'BLOS']
        self.bid_price = max(a, key=lambda x: x[6])[6]*1.20
        return self.bid_price
    
    def strategy_d(self):
            
        """
        Monitor if balance goes < -500 then scale back on the bids by 10% of the base price
        Conserve cash and wait for other random strategies A, B or C to try again
        """

        # sum all bids that were won, but user not clicked (ie BWCN)
        a = [x for x in self.bid_360 if x[0] == 'BWCN'] 

        # calculate cost of bids in BWCN
        b = (sum(i[6] for i in a))
        
        # sum of all bids where user clicked (ie BWCY)
        c = [x for x in self.bid_360 if x[0] == 'BWCY']
        # sum of total cost
        d = (sum(i[6] for i in c) )

        # earnings till date (ie $1 for every BWCY)
        e = len(c)
        f = e * 1

        current_balance = (b + d -f)
        
        if current_balance < -500:
            self.bid_price = 0.01
        return self.base_bid_price

# %%
#b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
b1, b2, b3, b4, b5, b6, b7, b8, b9, b10 = Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()for i in range(10)], [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10])
#auction = Auction( [User(), User()], [b1, b2, b3])
auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# Out:
# ****************************************************************************************************
#
# Beginning balances :  {140671326044464: 0, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 0, 140671326047632: 0, 140671326048016: 0, 140671326048208: 0, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512592
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  1
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326044464, 0), (140671326045520, 0), (140671326047344, 0), (140671326045184, 0), (140671326047392, 0), (140671326047632, 0), (140671326048016, 0), (140671326048208, 0), (140671326044800, 0), (140671326045136, 0)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4ca0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326047392
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 bidder == winning_bidder and ad_result == True:
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: 0, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1, 140671326047632: 0, 140671326048016: 0, 140671326048208: 0, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------

# %%
bal = auction.balances
bal
# Out:
# {140369076672688: 0,
#  140369076672928: 0,
#  140369076672592: 0,
#  140369076672544: 0,
#  140369076672736: 0,
#  140369076672640: 0,
#  140369076672784: 0,
#  140369076672832: 0,
#  140369076672880: 1,
#  140369076672976: 0}

# %%
[auction.execute_round() for i in range(100)]
# Out:
# Selected User:  140672124512624
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  2
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326044464, 0.01), (140671326045520, 0.01), (140671326047344, 0.01), (140671326045184, 0.01), (140671326047392, 0.01), (140671326047632, 0.01), (140671326048016, 0.01), (140671326048208, 0.01), (140671326044800, 0.01), (140671326045136, 0.01)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4130>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326044464
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.01
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 bidder == winning_bidder and ad_result == False
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1, 140671326047632: 0, 140671326048016: 0, 140671326048208: 0, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512720
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01278
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04658
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.035285
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01098
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04381
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.07172
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.006605
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.028805
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  3
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326044800, 0.006605), (140671326047392, 0.01098), (140671326047344, 0.012), (140671326048016, 0.012), (140671326044464, 0.01278), (140671326045136, 0.028805), (140671326045184, 0.035285), (140671326047632, 0.04381), (140671326045520, 0.04658), (140671326048208, 0.07172)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326048208
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.04658
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 bidder == winning_bidder and ad_result == True:
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1, 140671326047632: 0, 140671326048016: 0, 140671326048208: 0.95342, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512752
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  4
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326044464, 0.051238000000000006), (140671326045520, 0.051238000000000006), (140671326047344, 0.051238000000000006), (140671326045184, 0.051238000000000006), (140671326047392, 0.051238000000000006), (140671326047632, 0.051238000000000006), (140671326048016, 0.051238000000000006), (140671326048208, 0.051238000000000006), (140671326044800, 0.051238000000000006), (140671326045136, 0.051238000000000006)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4d90>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326047632
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.051238000000000006
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 bidder == winning_bidder and ad_result == False
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1, 140671326047632: -0.051238000000000006, 140671326048016: 0, 140671326048208: 0.95342, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512592
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0614856
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.012555
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0614856
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09787
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08544
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09915
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09039
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0614856
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02921
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  5
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326045520, 0.012555), (140671326045136, 0.02921), (140671326044464, 0.0614856), (140671326047344, 0.0614856), (140671326044800, 0.0614856), (140671326047392, 0.06995), (140671326047632, 0.08544), (140671326048208, 0.09039), (140671326045184, 0.09787), (140671326048016, 0.09915)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326048016
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.09787
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 bidder == winning_bidder and ad_result == True:
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.95342, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512592
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05374
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09583
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00975
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.040615000000000005
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11744399999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11744399999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.011775
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.01535
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.11744399999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.028055
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  6
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326047344, 0.00975), (140671326048016, 0.011775), (140671326048208, 0.01535), (140671326045136, 0.028055), (140671326045184, 0.040615000000000005), (140671326044464, 0.05374), (140671326045520, 0.09583), (140671326047392, 0.11744399999999999), (140671326047632, 0.11744399999999999), (140671326044800, 0.11744399999999999)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4ca0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326047392
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.11744399999999999
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 bidder == winning_bidder and ad_result == False
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 0.882556, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.95342, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512784
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00525
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0746
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08736279999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1409328
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03133
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02489
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0909095
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1409328
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1409328
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.036485
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  7
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326044464, 0.00525), (140671326047632, 0.02489), (140671326047392, 0.03133), (140671326045136, 0.036485), (140671326045520, 0.0746), (140671326047344, 0.08736279999999999), (140671326048016, 0.0909095), (140671326045184, 0.1409328), (140671326048208, 0.1409328), (140671326044800, 0.1409328)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4fd0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326048208
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.1409328
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 bidder == winning_bidder and ad_result == False
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 0.882556, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.8124872000000001, 140671326044800: 0, 140671326045136: 0}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512720
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.16911936
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08045893333333332
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0609
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.083167
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1024726
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0782064
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06667909999999999
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.032975
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02411
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.16911936
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  8
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326044800, 0.02411), (140671326048208, 0.032975), (140671326047344, 0.0609), (140671326048016, 0.06667909999999999), (140671326047632, 0.0782064), (140671326045520, 0.08045893333333332), (140671326045184, 0.083167), (140671326047392, 0.1024726), (140671326044464, 0.16911936), (140671326045136, 0.16911936)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b43d0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326045136
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.16911936
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 bidder == winning_bidder and ad_result == True:
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0, 140671326047344: 0, 140671326045184: 0, 140671326047392: 0.882556, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.8124872000000001, 140671326044800: 0, 140671326045136: 0.83088064}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512560
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06406
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.202943232
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.202943232
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08444545333333334
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02794
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.10197858666666666
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08186814
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.16182417999999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.202943232
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.05526
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  9
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326047392, 0.02794), (140671326045136, 0.05526), (140671326044464, 0.06406), (140671326048016, 0.08186814), (140671326045184, 0.08444545333333334), (140671326047632, 0.10197858666666666), (140671326048208, 0.16182417999999998), (140671326045520, 0.202943232), (140671326047344, 0.202943232), (140671326044800, 0.202943232)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4550>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326045520
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.202943232
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 bidder == winning_bidder and ad_result == True:
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0.797056768, 140671326047344: 0, 140671326045184: 0, 140671326047392: 0.882556, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.8124872000000001, 140671326044800: 0, 140671326045136: 0.83088064}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512528
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.24353187839999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09199055666666664
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0192
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00426
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.24353187839999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08580260133333334
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.035225
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09360413733333334
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.24353187839999998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09972600639999997
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  10
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326045184, 0.00426), (140671326047344, 0.0192), (140671326048016, 0.035225), (140671326047632, 0.08580260133333334), (140671326045520, 0.09199055666666664), (140671326048208, 0.09360413733333334), (140671326045136, 0.09972600639999997), (140671326044464, 0.24353187839999998), (140671326047392, 0.24353187839999998), (140671326044800, 0.24353187839999998)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4ca0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326047392
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.24353187839999998
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 bidder == winning_bidder and ad_result == True:
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0.797056768, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1.6390241215999999, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.8124872000000001, 140671326044800: 0, 140671326045136: 0.83088064}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512816
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.29223825408
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.011795
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03567
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.1198142034133333
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.03781
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.29223825408
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.08612
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.29223825408
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.09379
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.29223825408
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  11
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326045520, 0.011795), (140671326047344, 0.03567), (140671326047392, 0.03781), (140671326048016, 0.08612), (140671326044800, 0.09379), (140671326045184, 0.1198142034133333), (140671326044464, 0.29223825408), (140671326047632, 0.29223825408), (140671326048208, 0.29223825408), (140671326045136, 0.29223825408)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4fd0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326048208
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.29223825408
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 bidder == winning_bidder and ad_result == False
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0.797056768, 140671326047344: 0, 140671326045184: 0, 140671326047392: 1.6390241215999999, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.5202489459200001, 140671326044800: 0, 140671326045136: 0.83088064}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512752
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06225
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.350685904896
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.350685904896
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.00894
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.350685904896
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.049575
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.001745
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04333
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02924
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.139438484
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  12
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326048016, 0.001745), (140671326045184, 0.00894), (140671326044800, 0.02924), (140671326048208, 0.04333), (140671326047632, 0.049575), (140671326044464, 0.06225), (140671326045136, 0.139438484), (140671326045520, 0.350685904896), (140671326047344, 0.350685904896), (140671326047392, 0.350685904896)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4ca0>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326047392
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.350685904896
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 bidder == winning_bidder and ad_result == True:
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.01, 140671326045520: 0.797056768, 140671326047344: 0, 140671326045184: 0, 140671326047392: 2.288338216704, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.5202489459200001, 140671326044800: 0, 140671326045136: 0.83088064}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512784
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.42082308587519995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.42082308587519995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.0341
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.18938585323276189
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.350685904896
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.13952009788266667
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.16372921117199998
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04444
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.42082308587519995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.13540833212800002
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  13
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326047344, 0.0341), (140671326048208, 0.04444), (140671326045136, 0.13540833212800002), (140671326047632, 0.13952009788266667), (140671326048016, 0.16372921117199998), (140671326045184, 0.18938585323276189), (140671326047392, 0.350685904896), (140671326044464, 0.42082308587519995), (140671326045520, 0.42082308587519995), (140671326044800, 0.42082308587519995)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4130>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326044464
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.42082308587519995
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 bidder == winning_bidder and ad_result == False
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -0.43082308587519996, 140671326045520: 0.797056768, 140671326047344: 0, 140671326045184: 0, 140671326047392: 2.288338216704, 140671326047632: -0.051238000000000006, 140671326048016: 0.90213, 140671326048208: 0.5202489459200001, 140671326044800: 0, 140671326045136: 0.83088064}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512592
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.13688806737919995
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.14437613374666664
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.5049877030502399
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.5049877030502399
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.06918
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.020535
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.02694
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.2215490239729778
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.197856979744
#  ----------------------------------------------------------------------------------------------------
# bid price from STRATEGY 0.04931
#  ----------------------------------------------------------------------------------------------------
# Current bidding Round:  14
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326047632, 0.020535), (140671326048016, 0.02694), (140671326045136, 0.04931), (140671326047392, 0.06918), (140671326044464, 0.13688806737919995), (140671326045520, 0.14437613374666664), (140671326044800, 0.197856979744), (140671326048208, 0.2215490239729778), (140671326047344, 0.5049877030502399), (140671326045184, 0.5049877030502399)]
#  ----------------------------------------------------------------------------------------------------
# Winning bidder from list of similar priced bids:  <__main__.Bidder object at 0x7ff0986b4c70>
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326047344
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.5049877030502399
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# ...
# Selected User:  140672124512816
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326044464 balance is less than -1000. Cannot continue bid
# Bidder  140671326045520 balance is less than -1000. Cannot continue bid
# Bidder  140671326047344 balance is less than -1000. Cannot continue bid
# Bidder  140671326045184 balance is less than -1000. Cannot continue bid
# Bidder  140671326047392 balance is less than -1000. Cannot continue bid
# Bidder  140671326047632 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.04086
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326048208 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.048735
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326045136 balance is less than -1000. Cannot continue bid
# Current bidding Round:  85
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326048016, 0.04086), (140671326044800, 0.048735)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326044800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.04086
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 bidder == winning_bidder and ad_result == True:
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -1868.2168574044706, 140671326045520: -1853.3499175074014, 140671326047344: -1750.9073594318656, 140671326045184: -2189.83579645587, 140671326047392: -1871.6285499587016, 140671326047632: -1160.297805580702, 140671326048016: -204.17815293046021, 140671326048208: -2724.2755561780205, 140671326044800: -784.0853191421915, 140671326045136: -1475.9311244559844}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512752
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326044464 balance is less than -1000. Cannot continue bid
# Bidder  140671326045520 balance is less than -1000. Cannot continue bid
# Bidder  140671326047344 balance is less than -1000. Cannot continue bid
# Bidder  140671326045184 balance is less than -1000. Cannot continue bid
# Bidder  140671326047392 balance is less than -1000. Cannot continue bid
# Bidder  140671326047632 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.048965
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326048208 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 2659.496156319648
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326045136 balance is less than -1000. Cannot continue bid
# Current bidding Round:  86
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326048016, 0.048965), (140671326044800, 2659.496156319648)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326044800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.048965
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 bidder == winning_bidder and ad_result == True:
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -1868.2168574044706, 140671326045520: -1853.3499175074014, 140671326047344: -1750.9073594318656, 140671326045184: -2189.83579645587, 140671326047392: -1871.6285499587016, 140671326047632: -1160.297805580702, 140671326048016: -204.17815293046021, 140671326048208: -2724.2755561780205, 140671326044800: -783.1342841421914, 140671326045136: -1475.9311244559844}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512656
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326044464 balance is less than -1000. Cannot continue bid
# Bidder  140671326045520 balance is less than -1000. Cannot continue bid
# Bidder  140671326047344 balance is less than -1000. Cannot continue bid
# Bidder  140671326045184 balance is less than -1000. Cannot continue bid
# Bidder  140671326047392 balance is less than -1000. Cannot continue bid
# Bidder  140671326047632 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 0.005055
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326048208 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 1063.312595763775
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326045136 balance is less than -1000. Cannot continue bid
# Current bidding Round:  87
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326048016, 0.005055), (140671326044800, 1063.312595763775)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326044800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  0.005055
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  False
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 bidder == winning_bidder and ad_result == False
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -1868.2168574044706, 140671326045520: -1853.3499175074014, 140671326047344: -1750.9073594318656, 140671326045184: -2189.83579645587, 140671326047392: -1871.6285499587016, 140671326047632: -1160.297805580702, 140671326048016: -204.17815293046021, 140671326048208: -2724.2755561780205, 140671326044800: -783.1393391421914, 140671326045136: -1475.9311244559844}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512752
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326044464 balance is less than -1000. Cannot continue bid
# Bidder  140671326045520 balance is less than -1000. Cannot continue bid
# Bidder  140671326047344 balance is less than -1000. Cannot continue bid
# Bidder  140671326045184 balance is less than -1000. Cannot continue bid
# Bidder  140671326047392 balance is less than -1000. Cannot continue bid
# Bidder  140671326047632 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 1385.2993309143194
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326048208 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 2659.496156319648
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326045136 balance is less than -1000. Cannot continue bid
# Current bidding Round:  88
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326048016, 1385.2993309143194), (140671326044800, 2659.496156319648)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326044800
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  1385.2993309143194
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 Did not win bid - only notify
# 140671326048208 Did not win bid - only notify
# 140671326044800 bidder == winning_bidder and ad_result == True:
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -1868.2168574044706, 140671326045520: -1853.3499175074014, 140671326047344: -1750.9073594318656, 140671326045184: -2189.83579645587, 140671326047392: -1871.6285499587016, 140671326047632: -1160.297805580702, 140671326048016: -204.17815293046021, 140671326048208: -2724.2755561780205, 140671326044800: -2167.438670056511, 140671326045136: -1475.9311244559844}
#  ----------------------------------------------------------------------------------------------------
# Selected User:  140672124512752
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326044464 balance is less than -1000. Cannot continue bid
# Bidder  140671326045520 balance is less than -1000. Cannot continue bid
# Bidder  140671326047344 balance is less than -1000. Cannot continue bid
# Bidder  140671326045184 balance is less than -1000. Cannot continue bid
# Bidder  140671326047392 balance is less than -1000. Cannot continue bid
# Bidder  140671326047632 balance is less than -1000. Cannot continue bid
# bid price from STRATEGY 2659.496156319648
#  ----------------------------------------------------------------------------------------------------
# Bidder  140671326048208 balance is less than -1000. Cannot continue bid
# Bidder  140671326044800 balance is less than -1000. Cannot continue bid
# Bidder  140671326045136 balance is less than -1000. Cannot continue bid
# Current bidding Round:  89
#  ----------------------------------------------------------------------------------------------------
# Sorted bids list [(140671326048016, 2659.496156319648)]
#  ----------------------------------------------------------------------------------------------------
# Winning Bidder (FINAL):  140671326048016
#  ----------------------------------------------------------------------------------------------------
# Winning Price (FINAL):  2659.496156319648
#  ----------------------------------------------------------------------------------------------------
# User Clicked on Ad?:  True
#  ----------------------------------------------------------------------------------------------------
# Bidding Outcomes
#  ----------------------------------------------------------------------------------------------------
# 140671326044464 Did not win bid - only notify
# 140671326045520 Did not win bid - only notify
# 140671326047344 Did not win bid - only notify
# 140671326045184 Did not win bid - only notify
# 140671326047392 Did not win bid - only notify
# 140671326047632 Did not win bid - only notify
# 140671326048016 bidder == winning_bidder and ad_result == True:
# 140671326048208 Did not win bid - only notify
# 140671326044800 Did not win bid - only notify
# 140671326045136 Did not win bid - only notify
# ----------------------------------------------------------------------------------------------------
#  balances at end of bidding round {140671326044464: -1868.2168574044706, 140671326045520: -1853.3499175074014, 140671326047344: -1750.9073594318656, 140671326045184: -2189.83579645587, 140671326047392: -1871.6285499587016, 140671326047632: -1160.297805580702, 140671326048016: -2862.6743092501083, 140671326048208: -2724.2755561780205, 140671326044800: -2167.438670056511, 140671326045136: -1475.9311244559844}
#  ----------------------------------------------------------------------------------------------------
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# no bidders are qualifed as all balances are below -1000
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # Consolidate Metrics: All Bidders

# %% [markdown]
# ## Overall

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)

BWCY = (len(b1.bid_win_click_yes), len(b2.bid_win_click_yes), \
      len(b3.bid_win_click_yes), len(b4.bid_win_click_yes),  len(b5.bid_win_click_yes), len(b6.bid_win_click_yes), \
      len(b7.bid_win_click_yes), len(b8.bid_win_click_yes), len(b9.bid_win_click_yes), len(b10.bid_win_click_yes))

sum(BWCY)
print('BWCY - Bid Win - Click YES: Count', sum(BWCY))

BWCN = (len(b1.bid_win_click_no),len(b2.bid_win_click_no),len(b3.bid_win_click_no)\
     ,len(b4.bid_win_click_no),len(b5.bid_win_click_no),len(b6.bid_win_click_no),len(b7.bid_win_click_no),\
    len(b8.bid_win_click_no),len(b9.bid_win_click_no),len(b10.bid_win_click_no))

sum(BWCN)

print('BWCN - Bid Win - Click NO: Count',sum(BWCN))

# GENERAL CLICK RATIO

print('Overall Click Ratio ', sum(BWCY) / (sum(BWCY)+sum(BWCN)) )

# BLOS = NOT RELEVANT
# print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))

# print('Balances', auction.balances)
# Out:
# Bidding Rounds 78
# BWCY - Bid Win - Click YES: Count 61
# BWCN - Bid Win - Click NO: Count 28
# Overall Click Ratio  0.6853932584269663

# %% [markdown]
# # Bid Refining - Filters

# %% [markdown]
# ## Observe first 10 rounds

# %%
trx_master = [x for x in self.bid_360]

for item in trx_master:

    if item[1] < 10:
        self.bid_price = 0.01
    else:
        self.bid_price = base_bid_price

# trx_master = [x for x in b1.bid_360]

# for item in trx_master:
#     if item[1] < 10:
#         print('hey')
#     else:
#         print('hey no')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 trx_master = [x for x in self.bid_360]
#       3 for item in trx_master:
#       5     if item[1] < 10:
#
# NameError: name 'self' is not defined

# %%
a = [x for x in b1.bid_360[-100:] if 0 < x[1] < 50]

for item in a:
    if item[1] < 10:
        print('hey')
    else:
        print('hey no')

# b = filter(lambda x: x[1] < 10, a)
# print(b)
# Out:
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no
# hey no

# %% [markdown]
# ## Loss by > 10%

# %%
# lost the bid by a price > 10%

# filter last 10 bids for those you have lost 
a = [x for x in b1.bid_360[-10:] if x[0] == 'BLOS' and (x[6]-x[5]) > (.1*x[5])]
#print(a)

# calculated the average percentage loss (> 10%)
b = ((sum(i[6] for i in a) - sum(i[5] for i in a))/(max(1, len(a))))

print(b)

# then set bid_price = 

# [0]Category, [1]self.bidding_round, [2]id(self), [3]self.user_id, 
# [4]self.auction_winner, [5]#self.bid_price, [6]self.winning price, [7]self.clicked
# Out:
# 0.03324855583759785

# %% [markdown]
# ## Most successful user

# %%
# lost the bid by a price > 10%
from collections import Counter

a = [x for x in b1.bid_360[-1000:] if x[0] == 'BWCY']
#print(a)
b = (Counter([x[3] for x in a]))
c = { k: v for k, v in b.items() if v >= 3 }
#print(b)
d = max(c, key=c.get, default = 0) # get user with max wins
print(d)
#print(c)

#print(max(b, key=b.get))

# then set bid_price = 

# [0]Category, [1]self.bidding_round, [2]id(self), [3]self.user_id, 
# [4]self.auction_winner, [5]#self.bid_price, [6]self.winning price, [7]self.clicked
# Out:
# 0

# %% [markdown]
# ## Wait certain rounds, then accelerate

# %%
#a = [x for x in b1.bid_360[-100:] if x[0] == 'BWCN'] # < ]
a = [x for x in b1.bid_360[-100:] if 100 < x[1] < 200] #'BWCN'] # < ]
print(a)
     # then take default bid probability
# Out:
# [['BLOS', 101, 140568245737168, 6, False, 0.04786, 0.08659, None]]

# %% [markdown]
# ## Match Max and go over 10%

# %% [markdown]
# ---

# %%
b1.bid_360 # Category,self.bidding_round, id(self), self.user_id, self.auction_winner,
           #self.bid_price, self.winning price, self.clicked
#[x for x in b1.bid_360]    

a = [x for x in b1.bid_360[-10:] if x[0] == 'BLOS']

# a  = [x for x in b1.bid_360]
# a = [trx_master[-10:] if x[0] == 'BLOS']
#print(trx_master)
a

b = max(a, key=lambda x: x[6])[6]*1.20
print(b)
# Out:
# 0.012

# %% [markdown]
# ## Monitor balance and go convervative

# %%
# Monitor if balance goes < -500
# then scale back on the bids by 10% of the base price

# filter last 10 bids for those you have lost 
a = [x for x in b1.bid_360 if x[0] == 'BWCN'] 
#print(a)

# calculate current balance
b = (sum(i[6] for i in a))# - sum(i[5] for i in a))/(max(1, len(a))))
print(b)

c = [x for x in b1.bid_360 if x[0] == 'BWCY']
d = (sum(i[6] for i in c) )
print(d)
      
e = len(c)

f = e * 1


balance = (b + d -f)
print(balance)
# then set bid_price =
# Out:
# 1755.6575161955327
# 45.451559031805296
# 1797.109075227338

# %% [markdown]
# ---

# %% [markdown]
# ## By Bidder

# %% [markdown]
# ### for b1

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b1.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b1.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 78
# BWCY - Bid Win - Click YES: Count 3
# BWCN - Bid Win - Click NO: Count 2
# BLOS - Bid LOST: Count 84
# Balances {140671326044464: -1868.2168574044706, 140671326045520: -1853.3499175074014, 140671326047344: -1750.9073594318656, 140671326045184: -2189.83579645587, 140671326047392: -1871.6285499587016, 140671326047632: -1160.297805580702, 140671326048016: -2862.6743092501083, 140671326048208: -2724.2755561780205, 140671326044800: -2167.438670056511, 140671326045136: -1475.9311244559844}

# %% [markdown]
# ## for b2

# %%
# Summary Counts
print('Bidding Rounds', b2.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b2.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b2.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b2.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 76
# BWCY - Bid Win - Click YES: Count 4
# BWCN - Bid Win - Click NO: Count 5
# BLOS - Bid LOST: Count 92
# Balances {140670794265600: -1004.5329159716475, 140670794268096: -1425.0147488511693, 140670794267904: -1370.2512419906266, 140670794266800: -1468.564036552157, 140670794265696: -1540.2391246863885, 140670794268480: -973.910464073819, 140670794265984: -1790.3038791398367, 140671326102192: -971.5295267093967, 140671326105552: -1436.1346724874247, 140671326105024: -1756.6369392268828}

# %% [markdown]
# ## for b3

# %%
# Summary Counts
print('Bidding Rounds', b3.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b3.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b3.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b3.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 101
# BWCY - Bid Win - Click YES: Count 5
# BWCN - Bid Win - Click NO: Count 10
# BLOS - Bid LOST: Count 86
# Balances {140588383663200: -1147.6122670914983, 140588388722480: -1234.6556190166716, 140588388723152: -683.9171783816711, 140588388722912: -1103.359507689096, 140588388721088: -1428.327987930117, 140588388722816: -1782.5122671418005, 140588388720848: -1279.3556726191655, 140588388722864: -1182.55272084212, 140588388721616: -454.9901072078393, 140588388720944: -1439.5127313027533}

# %% [markdown]
# ---

# %% [markdown]
# # User Info

# %%
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Wins User Clicked', {k: v for k, v in sorted(b1.bid_win_user_clicks.items(), key=lambda item: item[0])})
print('BWCN - Bid Wins User NO Clicked', {k: v for k, v in sorted(b1.bid_wins_no_click.items(), key=lambda item: item[0])})
print('BLOS - Bids Lost', {k: v for k, v in sorted(b1.bid_lost.items(), key=lambda item: item[0])})
# Out:
# Bidding Rounds 89
# BWCY - Bid Wins User Clicked {0: 0, 2: 1, 3: 1, 6: 1}
# BWCN - Bid Wins User NO Clicked {0: 3, 1: 2, 5: 1, 8: 1, 9: 3}
# BLOS - Bids Lost {0: 9, 1: 12, 2: 5, 3: 7, 4: 9, 5: 5, 6: 5, 7: 9, 8: 21, 9: 6}

# %%
b1.bid_360
# Out:
# [['BWCY', 1, 140369076362160, 6, True, 0, 0, True],
#  ['BLOS', 2, 140369076362160, 1, False, 0.01, 0.01, None],
#  ['BLOS', 3, 140369076362160, 4, False, 0.01263, 0.034125, None],
#  ['BLOS',
#   4,
#   140369076362160,
#   5,
#   False,
#   0.03753750000000001,
#   0.03753750000000001,
#   None],
#  ['BWCY', 5, 140369076362160, 6, True, 0.08493, 0.07898, True],
#  ['BLOS', 6, 140369076362160, 9, False, 0.08328, 0.08328, None],
#  ['BLOS', 7, 140369076362160, 3, False, 0.00955, 0.09477599999999999, None],
#  ['BLOS',
#   8,
#   140369076362160,
#   3,
#   False,
#   0.05403549999999999,
#   0.11373119999999998,
#   None],
#  ['BLOS', 9, 140369076362160, 9, False, 0.03343, 0.13647743999999998, None],
#  ['BLOS',
#   10,
#   140369076362160,
#   6,
#   False,
#   0.07888103499999997,
#   0.13647743999999998,
#   None],
#  ['BLOS', 11, 140369076362160, 7, False, 0.0823, 0.08351, None],
#  ['BLOS',
#   12,
#   140369076362160,
#   9,
#   False,
#   0.16377292799999996,
#   0.16377292799999996,
#   None],
#  ['BLOS', 13, 140369076362160, 5, False, 0.035025, 0.10744785828571427, None],
#  ['BLOS', 14, 140369076362160, 7, False, 0.012155, 0.19652751359999995, None],
#  ['BWCY',
#   15,
#   140369076362160,
#   9,
#   True,
#   0.23583301631999992,
#   0.23583301631999992,
#   True],
#  ['BLOS', 16, 140369076362160, 5, False, 0.0995, 0.2829996195839999, None],
#  ['BWCY',
#   17,
#   140369076362160,
#   9,
#   True,
#   0.33959954350079985,
#   0.2829996195839999,
#   True],
#  ['BLOS', 18, 140369076362160, 5, False, 0.0529, 0.33959954350079985, None],
#  ['BLOS', 19, 140369076362160, 8, False, 0.04078, 0.177893292993736, None],
#  ['BLOS', 20, 140369076362160, 8, False, 0.044085, 0.4075194522009598, None],
#  ['BLOS', 21, 140369076362160, 3, False, 0.06743, 0.4075194522009598, None],
#  ['BLOS',
#   22,
#   140369076362160,
#   9,
#   False,
#   0.48902334264115177,
#   0.48902334264115177,
#   None],
#  ['BLOS', 23, 140369076362160, 4, False, 0.048865, 0.09918, None],
#  ['BLOS', 24, 140369076362160, 0, False, 0.042935, 0.5868280111693821, None],
#  ['BLOS', 25, 140369076362160, 3, False, 0.05247, 0.2871282300523307, None],
#  ['BLOS',
#   26,
#   140369076362160,
#   8,
#   False,
#   0.28030282521277106,
#   0.7041936134032585,
#   None],
#  ['BLOS',
#   27,
#   140369076362160,
#   6,
#   False,
#   0.33738672128858194,
#   0.33738672128858194,
#   None],
#  ['BWCY',
#   28,
#   140369076362160,
#   8,
#   True,
#   0.8450323360839102,
#   0.8450323360839102,
#   True],
#  ['BWCY',
#   29,
#   140369076362160,
#   9,
#   True,
#   0.8450323360839102,
#   0.4308563816466299,
#   True],
#  ['BLOS', 30, 140369076362160, 6, False, 0.01588, 1.0140388033006922, None],
#  ['BLOS', 31, 140369076362160, 9, False, 0.08751, 1.2168465639608306, None],
#  ['BLOS', 32, 140369076362160, 0, False, 0.01939, 1.4602158767529967, None],
#  ['BLOS',
#   33,
#   140369076362160,
#   2,
#   False,
#   1.752259052103596,
#   1.752259052103596,
#   None],
#  ['BLOS', 34, 140369076362160, 1, False, 0.02704, 2.102710862524315, None],
#  ['BLOS', 35, 140369076362160, 3, False, 0.04197, 2.523253035029178, None],
#  ['BLOS',
#   36,
#   140369076362160,
#   9,
#   False,
#   3.027903642035014,
#   3.027903642035014,
#   None],
#  ['BLOS',
#   37,
#   140369076362160,
#   9,
#   False,
#   1.6278150283136026,
#   3.6334843704420163,
#   None],
#  ['BWCY',
#   38,
#   140369076362160,
#   8,
#   True,
#   1.7347807472827375,
#   1.6467699316658286,
#   True],
#  ['BLOS',
#   39,
#   140369076362160,
#   1,
#   False,
#   1.7344307472827376,
#   4.36018124453042,
#   None],
#  ['BLOS',
#   40,
#   140369076362160,
#   9,
#   False,
#   1.8325649972777298,
#   5.2322174934365036,
#   None],
#  ['BLOS', 41, 140369076362160, 9, False, 0.05966, 6.278660992123804, None],
#  ['BLOS',
#   42,
#   140369076362160,
#   5,
#   False,
#   2.9008704431378805,
#   7.534393190548564,
#   None],
#  ['BLOS',
#   43,
#   140369076362160,
#   4,
#   False,
#   9.041271828658276,
#   9.041271828658276,
#   None],
#  ['BWCN',
#   44,
#   140369076362160,
#   1,
#   True,
#   10.84952619438993,
#   10.84952619438993,
#   False],
#  ['BLOS',
#   45,
#   140369076362160,
#   3,
#   False,
#   10.84952619438993,
#   10.84952619438993,
#   None],
#  ['BLOS',
#   46,
#   140369076362160,
#   3,
#   False,
#   3.8195892150138713,
#   5.353344202047788,
#   None],
#  ['BLOS', 47, 140369076362160, 8, False, 0.020365, 13.019431433267917, None],
#  ['BWCY',
#   48,
#   140369076362160,
#   8,
#   True,
#   15.623317719921499,
#   15.623317719921499,
#   True],
#  ['BLOS',
#   49,
#   140369076362160,
#   5,
#   False,
#   15.623317719921499,
#   18.747981263905796,
#   None],
#  ['BWCN',
#   50,
#   140369076362160,
#   1,
#   True,
#   22.497577516686956,
#   8.965171318023883,
#   False],
#  ['BLOS', 51, 140369076362160, 5, False, 0.024125, 22.497577516686956, None],
#  ['BWCY', 52, 140369076362160, 8, True, 8.984712045676753, 0.09363, True],
#  ['BLOS',
#   53,
#   140369076362160,
#   0,
#   False,
#   26.997093020024348,
#   26.997093020024348,
#   None],
#  ['BLOS',
#   54,
#   140369076362160,
#   7,
#   False,
#   10.056439370243272,
#   32.396511624029216,
#   None],
#  ['BWCN',
#   55,
#   140369076362160,
#   3,
#   True,
#   38.87581394883506,
#   38.87581394883506,
#   False],
#  ['BLOS',
#   56,
#   140369076362160,
#   7,
#   False,
#   38.87581394883506,
#   38.87581394883506,
#   None],
#  ['BLOS',
#   57,
#   140369076362160,
#   4,
#   False,
#   15.27388368693128,
#   46.65097673860207,
#   None],
#  ['BWCY',
#   58,
#   140369076362160,
#   7,
#   True,
#   55.98117208632248,
#   55.98117208632248,
#   True],
#  ['BLOS', 59, 140369076362160, 8, False, 0.06991, 0.06991, None],
#  ['BLOS', 60, 140369076362160, 1, False, 0.06469, 67.17740650358698, None],
#  ['BLOS',
#   61,
#   140369076362160,
#   5,
#   False,
#   80.61288780430438,
#   80.61288780430438,
#   None],
#  ['BLOS', 62, 140369076362160, 8, False, 0.00744, 36.87436817646857, None],
#  ['BLOS', 63, 140369076362160, 1, False, 0.01344, 96.73546536516525, None],
#  ['BLOS', 64, 140369076362160, 7, False, 0.05499, 96.73546536516525, None],
#  ['BLOS', 65, 140369076362160, 0, False, 0.04679, 116.0825584381983, None],
#  ['BWCY',
#   66,
#   140369076362160,
#   4,
#   True,
#   139.29907012583797,
#   139.29907012583797,
#   True],
#  ['BLOS',
#   67,
#   140369076362160,
#   2,
#   False,
#   139.29907012583797,
#   167.15888415100557,
#   None],
#  ['BLOS', 68, 140369076362160, 4, False, 0.02824, 200.59066098120667, None],
#  ['BLOS', 69, 140369076362160, 7, False, 0.06822, 240.708793177448, None],
#  ['BWCY',
#   70,
#   140369076362160,
#   9,
#   True,
#   288.85055181293757,
#   288.85055181293757,
#   True],
#  ['BLOS', 71, 140369076362160, 8, False, 0.040025, 346.62066217552507, None],
#  ['BLOS',
#   72,
#   140369076362160,
#   4,
#   False,
#   145.2782803380431,
#   149.39575412541703,
#   None],
#  ['BLOS',
#   73,
#   140369076362160,
#   8,
#   False,
#   160.732859218268,
#   415.9447946106301,
#   None],
#  ['BLOS', 74, 140369076362160, 6, False, 0.01422, 499.1337535327561, None],
#  ['BLOS', 75, 140369076362160, 7, False, 0.03593, 598.9605042393073, None],
#  ['BLOS', 76, 140369076362160, 5, False, 0.01012, 258.14983916714436, None],
#  ['BLOS',
#   77,
#   140369076362160,
#   7,
#   False,
#   718.7526050871687,
#   718.7526050871687,
#   None],
#  ['BLOS', 78, 140369076362160, 7, False, 0.00961, 862.5031261046024, None],
#  ['BLOS', 79, 140369076362160, 1, False, 0.010095, 1035.003751325523, None],
#  ['BLOS', 80, 140369076362160, 0, False, 0.02637, 1242.0045015906273, None],
#  ['BLOS', 81, 140369076362160, 2, False, 0.04419, 1490.4054019087528, None],
#  ['BWCN',
#   82,
#   140369076362160,
#   0,
#   True,
#   1788.4864822905033,
#   1788.4864822905033,
#   False],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   846.038986532926,
#   None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.03834, None],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   659.7842865121158,
#   None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.06816, None],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   835.3846609884102,
#   None],
#  ['BLOS',
#   82,
#   140369076362160,
#   0,
#   False,
#   1788.4864822905033,
#   858.6934641686585,
#   None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.00449, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.07542, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.023095, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.09559, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.07723, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.04626, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.03117, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.07364, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.033815, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.00795, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.002225, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.005705, None],
#  ['BLOS', 82, 140369076362160, 0, False, 1788.4864822905033, 0.024925, None]]
