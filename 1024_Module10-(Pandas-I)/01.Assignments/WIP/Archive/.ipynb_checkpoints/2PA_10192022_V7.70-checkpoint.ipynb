# %% [markdown]
# # Sorting out basic design issues

# %% [markdown]
# ## Running the model for 10 bidders and 10 users

# %%
import numpy as np
import random

class User:
    def __init__(self):
        self.probability = random.uniform(0, 1)

    def show_ad(self):
        return  np.random.choice((True, False), p = [self.probability, 1-self.probability])

class Auction:
    
    auction_history = [] # for the auction exchange only
    balances = {}
    
    def __init__(self, users, bidders):
        self.users = users
        self.bidders = bidders
        print(self.bidders)
        
        self.balances = {id(bidder): 0 for bidder in bidders} ########### NEW LINE
#!!        print("*"*100, '\n')
#!!        print('Beginning balances : ',self.balances, '\n','-'*100)
        
        
    def execute_round(self):
        
        ##### if the -ve balance of ALL bidders is < -1000, then break
        
        all_invalid_bidders = any(x > -1000 for x in self.balances.values())
        
        while not all_invalid_bidders:
            print("no bidders are qualifed as all balances are below -1000")
            break
        
        else:
            # print('starting balances2: ', self.balances2, '\n','-'*100)
            bids_dict = {}
            bids_list = []
            bids_list_raw = []

            # 1. SELECT USER (from the pool of users) ----------------------------------

            chosen_user = random.randint(0, len(self.users)-1)
#!!            print('Selected User: ', id(chosen_user), '\n','-'*100) 

            # 2. COLLECT BIDS (send to all bidders) --------------------------------------------
            for bidder in self.bidders:
                #if self.balances[bidder] > -1000:
                #balances = {bidder: 0 for bidder in bidders} ########### NEW LINE
                if self.balances[id(bidder)] > -1000:
                    bids_dict[bidder] = bidder.bid(chosen_user)
                    bidding_round = bidder.bidding_round

                    self.auction_history.append((id(bids_dict[bidder]), bids_dict[bidder])) #bidder
                    highest_bid = 0
                    winning_price = 0
                else:
#!!                    print("Bidder ", id(bidder), "balance is less than -1000. Cannot continue bid" )
     #               #raise Exception("Bidder's balance is less than -1000. Cannot continue bid")
                    continue

#!!            print("Current bidding Round: ", bidding_round, '\n','-'*100)

            # 3. DETERMINE WINNING BID --------------------------------------------
            for bidder, bid_value in bids_dict.items():

                bids_list_raw.append((bidder, bid_value))
                ## only needed to track a human readable bidder id
                bids_list.append((id(bidder), bid_value))


    #        print('bids list', bids_list, '\n','-'*100)

            ###### SORT THE Bids List based on price ##########################################
            sorted_list = sorted(bids_list, key=lambda t:t[1])
#!!            print('Sorted bids list', sorted_list, '\n','-'*100 )

            #------------- for analysis - creating a copy with id(bidder) --------------
            sorted_list_raw = sorted(bids_list_raw, key=lambda t:t[1])
    #        print('sorted bids list RAW', sorted_list_raw, '\n','-'*100 )


            ####### Select second highest price ###############################################
            if len(sorted_list) > 1:
                winning_price = (sorted_list_raw)[-2][1]
                winning_bidder = (sorted_list_raw)[-1][0]
            else:
                winning_price = (sorted_list_raw)[0][-1]
                winning_bidder = (sorted_list_raw)[0][0]

    #        print('Winning Price: ', winning_price, '\n','-'*100)
    #        print('winning bidder', winning_bidder, '\n','-'*100)

            ######## Determine if there are more than 1 bidders with same price ######################

            multiple_winning_bidders = [tup for tup in sorted_list_raw if tup[1] == winning_price]

            if len(multiple_winning_bidders)>1:
#!                print('List of biders that submitted similar bids: ' , multiple_winning_bidders, '\n','-'*100)
                randindex = random.randint(0, len(multiple_winning_bidders)-1)
                winning_bidder = multiple_winning_bidders[randindex][0]
#!                print('Winning bidder from list of similar priced bids: ', winning_bidder, '\n','-'*100)
            else: 
                pass
                #winning_bidder = multiple_winning_bidders[0][0]

#!!           print('Winning Bidder (FINAL): ', id(winning_bidder), '\n','-'*100)
#!!            print('Winning Price (FINAL): ', winning_price, '\n','-'*100)

            ############################################################################################
            # 4. Validate USER CLICK after SHOW AD  --------------------------------------------
            ad_result = self.users[chosen_user].show_ad()
#!!            print('User Clicked on Ad?: ', ad_result,'\n','-'*100)

            # 5.NOTIFY BIDDER & UPDATE BALANCES --------------------------------------------

#!!            print("Bidding Outcomes", '\n','-'*100)
            for bidder in self.bidders:
                if bidder == winning_bidder and ad_result == True:
#!!                    print(id(bidder), "bidder == winning_bidder and ad_result == True:")
                    self.balances[id(bidder)] -= winning_price
                    self.balances[id(bidder)] += 1
                    # balances[bidder] -= winning_price
                    # balances[bidder] += 1                

                    bidder.notify(True, winning_price, ad_result)

                elif bidder == winning_bidder and ad_result == False:
#!!                    print(id(bidder), "bidder == winning_bidder and ad_result == False")
                    self.balances[id(bidder)] -= winning_price
                    # balances[bidder] -= winning_price

                    bidder.notify(True, winning_price, ad_result)

                else:
#!!                    print(id(bidder), "Did not win bid - only notify")
                    bidder.notify(False, winning_price, None)
#!!            print('-'*100, '\n','balances at end of bidding round', self.balances,'\n','-'*100)
                # print('balances at end of bidding round', balances,'\n','-'*100)
        
class Bidder:
    
    #### maintain account balance here as well?

    # BIDDER CREATION -------------- initiated by GAME runner / Developer ------------------------
    
    def __init__(self, num_users, num_rounds):

        self.num_users = num_users
        self.num_rounds = num_rounds
        self.bidding_round = 0

        self.bid_y_n = True
        self.bid_participate = {i: 0 for i in range(num_users)} #whether bidder bids or not (USER: BID COUNT)
        self.bid_wins_no_click = {i: 0 for i in range(num_users)} # if bidder wins
        self.bid_win_user_clicks = {i: 0 for i in range(num_users)} # if user clicks
        self.bid_lost = {i: 0 for i in range(num_users)}
        
        #Transaction records
        self.bid_participate_history = [] # maintains bidderid, userid, bidding round, bid price
        self.bid_win_history = [] # won bid
        self.bid_win_user_click_history = [] # won bid and user clicked
        self.bid_lost_history = [] # lost bid, but know the user and price
        self.bid_price = 0
        
        ########### New tables
        self.bid_win_click_no = []
        self.bid_win_click_yes = []
        self.bid_lost_list = []
        self.bid_360 = []
        
        ############# bid strategy
#        self.bid_strategy(user_id)
#        self.user_id = user_id
        
        
    # SUBMIT BID  ------------ initiated by auction ------------------------------------
    

    
    def bid(self, user_id):
        self.bidding_round += 1
        #self.bid_participate = 0
        self.user_id = user_id
        #self.bid_strategy()
        #default_bid_price = random.randint(0, 10000)/200000 #random.uniform(0, 1)
        #self.bid_price = default_bid_price
        #self.bid_price = bid_strategy(self.user_id)
#        print(bid_strategy(self.user_id))
        
#        print(self.bid_strategy)
        bid_price = self.bid_strategy(user_id)
        print(bid_price)
#        bid_price = 0.5
        self.bid_participate[self.user_id] = (self.bid_participate).get(self.user_id, 0)+1
        self.bid_participate_history.append([id(self), self.user_id, self.bidding_round, self.bid_price])
        return self.bid_price
    

        
        #self.bid_360.extend(self.bid_win_history, self.bid_lost_history)
        # self.bid_360 = [item for sublst in zip(self.bid_win_history,  self.bid_lost_history) for item in sublst]

        # NOTIFIED OF BID OUTCOME ------------ initiated by auction ------------------------------------
    
    def notify(self, auction_winner, price, clicked):
        bid_y_n_won = 0
        self.auction_winner = auction_winner
        self.price = price
        self.clicked = clicked
        
        if auction_winner == True and clicked == True:
            self.bid_win_user_clicks[self.user_id] = (self.bid_win_user_clicks).get(self.user_id, 0)+1
            #self.bid_win_user_click_history.append([self.user_id, self.bidding_round])
            
            self.bid_win_click_yes.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCY', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

        elif auction_winner == True and clicked == False:
            #self.bid_participate_history.append([self.user_id, bid_y_n_won+1])
            self.bid_wins_no_click[self.user_id] = (self.bid_wins_no_click).get(self.user_id, 0)+1
            # self.bid_win_history.append([self.user_id, bid_y_n_won+1])

#            self.bid_win_history.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])
            
            self.bid_win_click_no.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
            
            self.bid_360.append(['BWCN', self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
        
        else:
            self.bid_lost[self.user_id] = (self.bid_lost).get(self.user_id, 0)+1

#            self.bid_lost_history.append([self.bidding_round, self.user_id, self.auction_winner,self.price, self.clicked])

            self.bid_lost_list.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])

            self.bid_360.append(['BLOS',self.bidding_round, id(self), self.user_id, self.auction_winner,self.bid_price, self.price, self.clicked])
    

    def bid_strategy(self, user_id):
#        bidder = self.bidder
        # self.user_id = user_id
        # self.bid_price = bid_price
        if user_id ==0: #and self.bidder == 'b1':
            bid_price = 0.5
        else: 
            bid_price = 1
        return bid_price
#        print(self.bid_360)

# %%
#b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
b1, b2, b3, b4, b5, b6, b7, b8, b9, b10 = Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()for i in range(10)], [b1, b2, b3, b4, b5, b6, b7, b8, b9, b10])
#auction = Auction( [User(), User()], [b1, b2, b3])

auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# auction.execute_round()
# Out:
# [<__main__.Bidder object at 0x7fd710f63ca0>, <__main__.Bidder object at 0x7fd710f63fd0>, <__main__.Bidder object at 0x7fd710f63fa0>, <__main__.Bidder object at 0x7fd710f63d60>, <__main__.Bidder object at 0x7fd710f63eb0>, <__main__.Bidder object at 0x7fd710f63a60>, <__main__.Bidder object at 0x7fd710f63c10>, <__main__.Bidder object at 0x7fd710f639a0>, <__main__.Bidder object at 0x7fd710f63730>, <__main__.Bidder object at 0x7fd710f638b0>]
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5
# 0.5

# %%
b2.bid_strategy(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [92], in <cell line: 1>()
# ----> 1 b2.bid_strategy(0)
#
# Input In [90], in Bidder.bid_strategy(self, user_id)
#     242 def bid_strategy(self, user_id):
#     243     # self.user_id = user_id
#     244     # self.bid_price = bid_price
# --> 245     if user_id ==0 and bidder == 'b1':
#     246         bid_price = 0.5
#     247     else:
#
# NameError: name 'bidder' is not defined

# %%
b1.bid_strategy(1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 1>()
# ----> 1 b1.bid_strategy(1)
#
# TypeError: 'int' object is not callable

# %% [markdown]
# ### for b1

# %%
# Summary Counts
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b1.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b1.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b1.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 10001
# BWCY - Bid Win - Click YES: Count 644
# BWCN - Bid Win - Click NO: Count 394
# BLOS - Bid LOST: Count 8963
# Balances {140651191949152: 601.6143099999995, 140651191948624: 594.1921000000002, 140651191948768: 518.4661300000006, 140651191948528: 620.6862250000005, 140651191948816: 541.1730200000002, 140651191948336: 611.4100000000004, 140651191947664: 594.4631899999997, 140651191947808: 555.3326999999994, 140651191947568: 553.2597699999995, 140651191951024: 527.8950800000005}

# %% [markdown]
# ## for b2

# %%
# Summary Counts
print('Bidding Rounds', b2.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b2.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b2.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b2.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 10001
# BWCY - Bid Win - Click YES: Count 636
# BWCN - Bid Win - Click NO: Count 390
# BLOS - Bid LOST: Count 8975
# Balances {140651191949152: 601.6143099999995, 140651191948624: 594.1921000000002, 140651191948768: 518.4661300000006, 140651191948528: 620.6862250000005, 140651191948816: 541.1730200000002, 140651191948336: 611.4100000000004, 140651191947664: 594.4631899999997, 140651191947808: 555.3326999999994, 140651191947568: 553.2597699999995, 140651191951024: 527.8950800000005}

# %% [markdown]
# ## for b3

# %%
# Summary Counts
print('Bidding Rounds', b3.bidding_round)
print('BWCY - Bid Win - Click YES: Count', len(b3.bid_win_click_yes))
print('BWCN - Bid Win - Click NO: Count',len(b3.bid_win_click_no))
print('BLOS - Bid LOST: Count',len(b3.bid_lost_list))
print('Balances', auction.balances)
# Out:
# Bidding Rounds 10001
# BWCY - Bid Win - Click YES: Count 556
# BWCN - Bid Win - Click NO: Count 364
# BLOS - Bid LOST: Count 9081
# Balances {140651191949152: 601.6143099999995, 140651191948624: 594.1921000000002, 140651191948768: 518.4661300000006, 140651191948528: 620.6862250000005, 140651191948816: 541.1730200000002, 140651191948336: 611.4100000000004, 140651191947664: 594.4631899999997, 140651191947808: 555.3326999999994, 140651191947568: 553.2597699999995, 140651191951024: 527.8950800000005}

# %% [markdown]
# ---

# %%
print('Bidding Rounds', b1.bidding_round)
print('BWCY - Bid Wins User Clicked', {k: v for k, v in sorted(b1.bid_win_user_clicks.items(), key=lambda item: item[0])})
print('BWCN - Bid Wins User NO Clicked', {k: v for k, v in sorted(b1.bid_wins_no_click.items(), key=lambda item: item[0])})
print('BLOS - Bids Lost', {k: v for k, v in sorted(b1.bid_lost.items(), key=lambda item: item[0])})
# Out:
# Bidding Rounds 10001
# BWCY - Bid Wins User Clicked {0: 81, 1: 57, 2: 19, 3: 47, 4: 83, 5: 88, 6: 24, 7: 94, 8: 79, 9: 72}
# BWCN - Bid Wins User NO Clicked {0: 14, 1: 50, 2: 77, 3: 68, 4: 36, 5: 11, 6: 67, 7: 14, 8: 20, 9: 37}
# BLOS - Bids Lost {0: 906, 1: 893, 2: 931, 3: 878, 4: 843, 5: 916, 6: 930, 7: 893, 8: 861, 9: 912}

# %%
print('Bid 360: BWCY, BWCN, BLOS: Count', len(b1.bid_360))
b1.bid_360 # 1.Type 2.Round, 3. User, 4. Won Auction? 5.Bid Price 5.Winning Price(2ndBest)  6. User Clicked?
# Out:
# Bid 360: BWCY, BWCN, BLOS: Count 101
# [['BLOS', 1, 140640859184336, 2, False, 1.785, 1.785, None],
#  ['BLOS', 2, 140640859184336, 0, False, 0.955, 1.9225, None],
#  ['BLOS', 3, 140640859184336, 8, False, 0.2925, 1.443, None],
#  ['BWCY', 4, 140640859184336, 5, True, 2.0, 1.957, True],
#  ['BLOS', 5, 140640859184336, 9, False, 1.209, 1.209, None],
#  ['BLOS', 6, 140640859184336, 3, False, 1.071, 1.438, None],
#  ['BLOS', 7, 140640859184336, 0, False, 1.6205, 1.7375, None],
#  ['BLOS', 8, 140640859184336, 1, False, 0.842, 1.7755, None],
#  ['BLOS', 9, 140640859184336, 3, False, 0.6445, 1.77, None],
#  ['BWCN', 10, 140640859184336, 4, True, 1.96, 1.86, False],
#  ['BLOS', 11, 140640859184336, 7, False, 1.8015, 1.8015, None],
#  ['BLOS', 12, 140640859184336, 2, False, 0.02, 1.2885, None],
#  ['BLOS', 13, 140640859184336, 3, False, 1.3895, 1.9205, None],
#  ['BLOS', 14, 140640859184336, 9, False, 0.245, 1.371, None],
#  ['BLOS', 15, 140640859184336, 3, False, 0.863, 1.7935, None],
#  ['BLOS', 16, 140640859184336, 6, False, 1.033, 1.738, None],
#  ['BLOS', 17, 140640859184336, 6, False, 0.0465, 1.437, None],
#  ['BLOS', 18, 140640859184336, 2, False, 1.5845, 1.7005, None],
#  ['BLOS', 19, 140640859184336, 1, False, 0.357, 1.2595, None],
#  ['BLOS', 20, 140640859184336, 3, False, 0.76, 1.5475, None],
#  ['BLOS', 21, 140640859184336, 8, False, 0.0955, 1.8145, None],
#  ['BLOS', 22, 140640859184336, 0, False, 0.605, 1.386, None],
#  ['BLOS', 23, 140640859184336, 2, False, 0.867, 1.8125, None],
#  ['BLOS', 24, 140640859184336, 7, False, 1.1115, 1.504, None],
#  ['BLOS', 25, 140640859184336, 0, False, 0.3385, 1.608, None],
#  ['BLOS', 26, 140640859184336, 7, False, 1.322, 1.826, None],
#  ['BLOS', 27, 140640859184336, 8, False, 1.9345, 1.9345, None],
#  ['BWCN', 28, 140640859184336, 9, True, 1.9935, 1.9515, False],
#  ['BWCN', 29, 140640859184336, 4, True, 1.922, 1.7545, False],
#  ['BLOS', 30, 140640859184336, 3, False, 1.8925, 1.8925, None],
#  ['BLOS', 31, 140640859184336, 3, False, 1.5615, 1.7985, None],
#  ['BLOS', 32, 140640859184336, 2, False, 0.237, 1.683, None],
#  ['BLOS', 33, 140640859184336, 1, False, 0.9045, 1.6365, None],
#  ['BLOS', 34, 140640859184336, 4, False, 1.47, 1.711, None],
#  ['BLOS', 35, 140640859184336, 9, False, 0.15, 1.3755, None],
#  ['BWCY', 36, 140640859184336, 2, True, 1.991, 1.9435, True],
#  ['BLOS', 37, 140640859184336, 2, False, 1.858, 1.888, None],
#  ['BLOS', 38, 140640859184336, 9, False, 1.1925, 1.4825, None],
#  ['BLOS', 39, 140640859184336, 2, False, 0.4025, 1.4795, None],
#  ['BLOS', 40, 140640859184336, 0, False, 1.6455, 1.6455, None],
#  ['BLOS', 41, 140640859184336, 0, False, 1.2775, 1.2775, None],
#  ['BLOS', 42, 140640859184336, 3, False, 1.2885, 1.61, None],
#  ['BLOS', 43, 140640859184336, 7, False, 0.995, 1.675, None],
#  ['BLOS', 44, 140640859184336, 4, False, 1.0895, 1.0895, None],
#  ['BWCN', 45, 140640859184336, 3, True, 1.6675, 1.6415, False],
#  ['BWCY', 46, 140640859184336, 8, True, 1.9315, 1.7885, True],
#  ['BLOS', 47, 140640859184336, 5, False, 1.4245, 1.596, None],
#  ['BWCN', 48, 140640859184336, 5, True, 1.81, 1.454, False],
#  ['BLOS', 49, 140640859184336, 2, False, 0.618, 1.688, None],
#  ['BLOS', 50, 140640859184336, 6, False, 0.09, 1.7565, None],
#  ['BLOS', 51, 140640859184336, 2, False, 0.897, 1.842, None],
#  ['BLOS', 52, 140640859184336, 9, False, 1.224, 1.6455, None],
#  ['BLOS', 53, 140640859184336, 9, False, 0.3505, 1.409, None],
#  ['BLOS', 54, 140640859184336, 4, False, 1.0845, 1.7305, None],
#  ['BLOS', 55, 140640859184336, 4, False, 1.129, 1.5015, None],
#  ['BLOS', 56, 140640859184336, 4, False, 0.33, 1.5435, None],
#  ['BLOS', 57, 140640859184336, 6, False, 1.6115, 1.732, None],
#  ['BWCN', 58, 140640859184336, 5, True, 1.8115, 1.58, False],
#  ['BLOS', 59, 140640859184336, 6, False, 1.6695, 1.7125, None],
#  ['BLOS', 60, 140640859184336, 6, False, 0.067, 1.766, None],
#  ['BWCY', 61, 140640859184336, 6, True, 1.4265, 1.299, True],
#  ['BLOS', 62, 140640859184336, 7, False, 1.0005, 1.639, None],
#  ['BLOS', 63, 140640859184336, 2, False, 0.1665, 1.7075, None],
#  ['BLOS', 64, 140640859184336, 0, False, 1.087, 1.6575, None],
#  ['BLOS', 65, 140640859184336, 7, False, 0.023, 1.7805, None],
#  ['BLOS', 66, 140640859184336, 9, False, 1.727, 1.774, None],
#  ['BLOS', 67, 140640859184336, 5, False, 1.4475, 1.799, None],
#  ['BLOS', 68, 140640859184336, 7, False, 1.8435, 1.8435, None],
#  ['BWCN', 69, 140640859184336, 6, True, 1.9165, 1.7285, False],
#  ['BLOS', 70, 140640859184336, 8, False, 1.5175, 1.924, None],
#  ['BLOS', 71, 140640859184336, 2, False, 1.84, 1.84, None],
#  ['BLOS', 72, 140640859184336, 2, False, 1.745, 1.745, None],
#  ['BLOS', 73, 140640859184336, 9, False, 1.8355, 1.9665, None],
#  ['BLOS', 74, 140640859184336, 4, False, 1.0455, 1.343, None],
#  ['BLOS', 75, 140640859184336, 4, False, 1.123, 1.8185, None],
#  ['BLOS', 76, 140640859184336, 7, False, 0.8035, 1.476, None],
#  ['BLOS', 77, 140640859184336, 1, False, 1.467, 1.663, None],
#  ['BLOS', 78, 140640859184336, 4, False, 0.6645, 1.033, None],
#  ['BLOS', 79, 140640859184336, 0, False, 1.0975, 1.705, None],
#  ['BLOS', 80, 140640859184336, 4, False, 1.149, 1.921, None],
#  ['BLOS', 81, 140640859184336, 2, False, 0.941, 1.8105, None],
#  ['BLOS', 82, 140640859184336, 8, False, 0.1495, 1.773, None],
#  ['BLOS', 83, 140640859184336, 3, False, 0.0155, 1.3445, None],
#  ['BLOS', 84, 140640859184336, 0, False, 0.2775, 1.437, None],
#  ['BLOS', 85, 140640859184336, 0, False, 1.3115, 1.702, None],
#  ['BLOS', 86, 140640859184336, 5, False, 0.051, 1.567, None],
#  ['BLOS', 87, 140640859184336, 9, False, 1.1285, 1.5995, None],
#  ['BLOS', 88, 140640859184336, 7, False, 1.7055, 1.7685, None],
#  ['BLOS', 89, 140640859184336, 0, False, 1.631, 1.631, None],
#  ['BLOS', 90, 140640859184336, 6, False, 0.48, 1.9215, None],
#  ['BLOS', 91, 140640859184336, 0, False, 1.6785, 1.6785, None],
#  ['BLOS', 92, 140640859184336, 6, False, 1.451, 1.8905, None],
#  ['BLOS', 93, 140640859184336, 0, False, 1.6415, 1.6775, None],
#  ['BWCY', 94, 140640859184336, 7, True, 1.808, 1.537, True],
#  ['BWCN', 95, 140640859184336, 0, True, 1.9635, 1.8255, False],
#  ['BLOS', 96, 140640859184336, 6, False, 0.021, 1.587, None],
#  ['BLOS', 97, 140640859184336, 4, False, 1.1695, 1.376, None],
#  ['BLOS', 98, 140640859184336, 0, False, 1.3195, 1.493, None],
#  ['BLOS', 99, 140640859184336, 2, False, 1.8685, 1.8685, None],
#  ['BLOS', 100, 140640859184336, 5, False, 1.345, 1.7915, None],
#  ['BLOS', 101, 140640859184336, 5, False, 1.3295, 1.9525, None]]

# %%
print('Bid Win - Click YES: Count', len(b1.bid_win_click_yes))
b1.bid_win_click_yes # 1.Type 2.Round, 3. User, 4. Won Auction? 5.Bid Price 5.Winning Price (2ndBest)  6. User Clicked?
# Out:
# Bid Win - Click YES: Count 204
# [['BWCY', 4, 2, True, 1.6975, 1.272, True],
#  ['BWCY', 6, 6, True, 1.158, 0.9215, True],
#  ['BWCY', 7, 1, True, 0.7445, 0.6935, True],
#  ['BWCY', 9, 9, True, 1.5925, 1.4045, True],
#  ['BWCY', 11, 6, True, 1.5975, 1.423, True],
#  ['BWCY', 13, 3, True, 1.578, 0.973, True],
#  ['BWCY', 22, 4, True, 1.0825, 0.634, True],
#  ['BWCY', 26, 3, True, 1.9285, 1.804, True],
#  ['BWCY', 27, 0, True, 1.9975, 0.5955, True],
#  ['BWCY', 31, 2, True, 1.631, 1.3035, True],
#  ['BWCY', 32, 3, True, 1.8485, 1.6655, True],
#  ['BWCY', 43, 3, True, 1.9755, 1.327, True],
#  ['BWCY', 51, 2, True, 1.2145, 0.6145, True],
#  ['BWCY', 69, 2, True, 1.6395, 1.5325, True],
#  ['BWCY', 71, 3, True, 1.4885, 0.79, True],
#  ['BWCY', 87, 6, True, 1.385, 1.1165, True],
#  ['BWCY', 89, 9, True, 1.8345, 0.952, True],
#  ['BWCY', 91, 7, True, 1.9775, 0.6355, True],
#  ['BWCY', 95, 6, True, 1.431, 0.539, True],
#  ['BWCY', 103, 3, True, 1.517, 1.5115, True],
#  ['BWCY', 107, 7, True, 1.926, 1.528, True],
#  ['BWCY', 115, 2, True, 1.725, 1.401, True],
#  ['BWCY', 117, 9, True, 1.5445, 0.9695, True],
#  ['BWCY', 120, 3, True, 1.6805, 1.5635, True],
#  ['BWCY', 122, 7, True, 1.5515, 0.236, True],
#  ['BWCY', 123, 3, True, 1.6585, 0.8875, True],
#  ['BWCY', 125, 9, True, 1.921, 1.137, True],
#  ['BWCY', 128, 2, True, 1.8325, 1.7305, True],
#  ['BWCY', 132, 6, True, 0.584, 0.218, True],
#  ['BWCY', 136, 6, True, 1.066, 0.708, True],
#  ['BWCY', 141, 9, True, 1.9845, 1.716, True],
#  ['BWCY', 144, 3, True, 0.26, 0.076, True],
#  ['BWCY', 154, 9, True, 1.8365, 0.2215, True],
#  ['BWCY', 162, 1, True, 1.28, 1.134, True],
#  ['BWCY', 175, 1, True, 1.9495, 1.8425, True],
#  ['BWCY', 177, 9, True, 1.4215, 0.9145, True],
#  ['BWCY', 181, 8, True, 0.5925, 0.578, True],
#  ['BWCY', 182, 6, True, 1.7825, 0.7635, True],
#  ['BWCY', 188, 9, True, 1.4525, 1.3175, True],
#  ['BWCY', 201, 8, True, 1.079, 0.5795, True],
#  ['BWCY', 203, 6, True, 1.69, 0.666, True],
#  ['BWCY', 204, 3, True, 1.2365, 0.8605, True],
#  ['BWCY', 205, 6, True, 1.0615, 0.898, True],
#  ['BWCY', 206, 6, True, 1.8895, 1.6755, True],
#  ['BWCY', 207, 6, True, 0.867, 0.7825, True],
#  ['BWCY', 221, 6, True, 1.803, 1.4895, True],
#  ['BWCY', 228, 1, True, 1.6855, 1.356, True],
#  ['BWCY', 230, 3, True, 1.804, 0.7285, True],
#  ['BWCY', 231, 3, True, 1.8525, 1.577, True],
#  ['BWCY', 236, 6, True, 1.3335, 0.336, True],
#  ['BWCY', 240, 9, True, 1.539, 0.222, True],
#  ['BWCY', 256, 1, True, 1.2385, 0.7995, True],
#  ['BWCY', 257, 7, True, 1.9345, 0.8645, True],
#  ['BWCY', 274, 6, True, 0.353, 0.2035, True],
#  ['BWCY', 280, 8, True, 1.43, 1.226, True],
#  ['BWCY', 284, 4, True, 1.827, 1.7855, True],
#  ['BWCY', 290, 1, True, 1.862, 0.351, True],
#  ['BWCY', 295, 4, True, 1.1025, 0.884, True],
#  ['BWCY', 300, 0, True, 1.8475, 1.3215, True],
#  ['BWCY', 301, 7, True, 0.8145, 0.355, True],
#  ['BWCY', 306, 7, True, 1.423, 0.901, True],
#  ['BWCY', 323, 9, True, 1.271, 0.9765, True],
#  ['BWCY', 324, 8, True, 0.197, 0.0575, True],
#  ['BWCY', 334, 7, True, 0.8225, 0.331, True],
#  ['BWCY', 336, 3, True, 1.023, 0.1595, True],
#  ['BWCY', 338, 2, True, 1.0715, 0.3315, True],
#  ['BWCY', 340, 6, True, 1.881, 1.556, True],
#  ['BWCY', 343, 7, True, 1.154, 1.025, True],
#  ['BWCY', 344, 6, True, 1.645, 0.68, True],
#  ['BWCY', 346, 3, True, 1.938, 1.227, True],
#  ['BWCY', 348, 6, True, 1.785, 1.7165, True],
#  ['BWCY', 350, 1, True, 1.393, 0.919, True],
#  ['BWCY', 355, 2, True, 1.8585, 0.449, True],
#  ['BWCY', 364, 6, True, 1.249, 0.609, True],
#  ['BWCY', 370, 7, True, 1.195, 0.1435, True],
#  ['BWCY', 371, 0, True, 1.508, 0.514, True],
#  ['BWCY', 377, 7, True, 1.6065, 1.232, True],
#  ['BWCY', 387, 2, True, 1.927, 1.616, True],
#  ['BWCY', 390, 1, True, 1.59, 0.4285, True],
#  ['BWCY', 393, 4, True, 1.7945, 0.7325, True],
#  ['BWCY', 404, 9, True, 1.8195, 0.251, True],
#  ['BWCY', 405, 1, True, 1.204, 0.954, True],
#  ['BWCY', 409, 8, True, 1.7595, 1.5375, True],
#  ['BWCY', 410, 1, True, 1.922, 1.9145, True],
#  ['BWCY', 412, 3, True, 1.808, 1.338, True],
#  ['BWCY', 414, 6, True, 1.9975, 1.484, True],
#  ['BWCY', 417, 2, True, 1.6655, 0.9975, True],
#  ['BWCY', 422, 2, True, 1.892, 1.6345, True],
#  ['BWCY', 428, 2, True, 0.592, 0.529, True],
#  ['BWCY', 435, 7, True, 1.5035, 1.1445, True],
#  ['BWCY', 439, 1, True, 1.115, 0.9635, True],
#  ['BWCY', 445, 9, True, 1.101, 0.726, True],
#  ['BWCY', 448, 9, True, 1.515, 1.2355, True],
#  ['BWCY', 451, 7, True, 1.479, 1.3675, True],
#  ['BWCY', 459, 1, True, 1.7685, 1.532, True],
#  ['BWCY', 464, 2, True, 1.126, 1.0975, True],
#  ['BWCY', 465, 3, True, 1.9305, 0.728, True],
#  ['BWCY', 468, 2, True, 0.5075, 0.282, True],
#  ['BWCY', 470, 3, True, 1.2875, 1.2745, True],
#  ['BWCY', 484, 6, True, 1.58, 1.0495, True],
#  ['BWCY', 489, 8, True, 1.6855, 1.2845, True],
#  ['BWCY', 491, 3, True, 1.44, 0.8195, True],
#  ['BWCY', 493, 2, True, 1.4785, 1.2325, True],
#  ['BWCY', 494, 3, True, 1.3655, 0.897, True],
#  ['BWCY', 505, 3, True, 1.876, 0.9945, True],
#  ['BWCY', 512, 7, True, 1.4675, 1.4355, True],
#  ['BWCY', 516, 2, True, 1.647, 1.5595, True],
#  ['BWCY', 517, 1, True, 1.7945, 1.5735, True],
#  ['BWCY', 526, 9, True, 0.554, 0.3175, True],
#  ['BWCY', 535, 5, True, 1.7355, 0.8545, True],
#  ['BWCY', 540, 3, True, 1.8905, 0.569, True],
#  ['BWCY', 543, 1, True, 1.9025, 0.685, True],
#  ['BWCY', 549, 3, True, 1.466, 1.1795, True],
#  ['BWCY', 558, 9, True, 0.683, 0.614, True],
#  ['BWCY', 561, 3, True, 0.9575, 0.3625, True],
#  ['BWCY', 564, 8, True, 1.961, 1.556, True],
#  ['BWCY', 567, 2, True, 1.4765, 1.4435, True],
#  ['BWCY', 572, 8, True, 1.8895, 1.3695, True],
#  ['BWCY', 580, 6, True, 1.399, 0.5905, True],
#  ['BWCY', 581, 5, True, 1.832, 0.715, True],
#  ['BWCY', 597, 7, True, 1.4675, 0.6905, True],
#  ['BWCY', 598, 9, True, 1.979, 0.7835, True],
#  ['BWCY', 601, 1, True, 1.73, 1.07, True],
#  ['BWCY', 602, 3, True, 0.907, 0.3795, True],
#  ['BWCY', 604, 2, True, 1.637, 1.3105, True],
#  ['BWCY', 608, 2, True, 1.9695, 1.958, True],
#  ['BWCY', 609, 3, True, 0.7395, 0.4865, True],
#  ['BWCY', 620, 4, True, 1.6245, 1.2235, True],
#  ['BWCY', 622, 2, True, 0.6185, 0.2375, True],
#  ['BWCY', 631, 2, True, 1.97, 1.936, True],
#  ['BWCY', 634, 2, True, 1.846, 0.724, True],
#  ['BWCY', 639, 2, True, 0.95, 0.94, True],
#  ['BWCY', 642, 6, True, 1.76, 1.5635, True],
#  ['BWCY', 645, 6, True, 1.094, 0.818, True],
#  ['BWCY', 650, 3, True, 0.3075, 0.127, True],
#  ['BWCY', 652, 6, True, 1.087, 0.5935, True],
#  ['BWCY', 655, 6, True, 1.918, 1.4515, True],
#  ['BWCY', 664, 2, True, 1.9955, 1.0995, True],
#  ['BWCY', 674, 2, True, 1.4885, 0.4945, True],
#  ['BWCY', 675, 8, True, 1.423, 0.738, True],
#  ['BWCY', 677, 1, True, 1.9455, 1.7245, True],
#  ['BWCY', 678, 2, True, 1.736, 0.454, True],
#  ['BWCY', 694, 2, True, 1.8765, 1.632, True],
#  ['BWCY', 719, 8, True, 0.581, 0.497, True],
#  ['BWCY', 731, 1, True, 1.514, 0.5005, True],
#  ['BWCY', 733, 6, True, 1.315, 0.8755, True],
#  ['BWCY', 741, 7, True, 1.8875, 1.1655, True],
#  ['BWCY', 743, 3, True, 0.943, 0.7065, True],
#  ['BWCY', 744, 5, True, 1.9725, 1.5075, True],
#  ['BWCY', 751, 6, True, 1.9915, 1.252, True],
#  ['BWCY', 754, 6, True, 1.8035, 1.3595, True],
#  ['BWCY', 755, 9, True, 1.9105, 1.141, True],
#  ['BWCY', 759, 8, True, 0.8685, 0.32, True],
#  ['BWCY', 765, 8, True, 1.6715, 1.167, True],
#  ['BWCY', 778, 3, True, 0.792, 0.578, True],
#  ['BWCY', 788, 1, True, 1.9735, 0.773, True],
#  ['BWCY', 792, 1, True, 1.301, 1.2025, True],
#  ['BWCY', 793, 8, True, 1.5035, 1.4685, True],
#  ['BWCY', 799, 6, True, 1.796, 1.502, True],
#  ['BWCY', 805, 9, True, 1.672, 1.5435, True],
#  ['BWCY', 810, 6, True, 1.238, 1.2145, True],
#  ['BWCY', 816, 3, True, 1.062, 0.8135, True],
#  ['BWCY', 822, 9, True, 1.418, 1.352, True],
#  ['BWCY', 835, 6, True, 1.0445, 0.587, True],
#  ['BWCY', 842, 1, True, 1.6735, 0.7315, True],
#  ['BWCY', 845, 7, True, 1.9415, 1.032, True],
#  ['BWCY', 854, 7, True, 1.6845, 0.3965, True],
#  ['BWCY', 855, 6, True, 1.4835, 1.2475, True],
#  ['BWCY', 858, 2, True, 1.923, 1.779, True],
#  ['BWCY', 860, 3, True, 1.822, 0.708, True],
#  ['BWCY', 868, 3, True, 1.748, 1.3725, True],
#  ['BWCY', 870, 9, True, 1.1455, 0.8245, True],
#  ['BWCY', 874, 3, True, 1.7835, 1.6465, True],
#  ['BWCY', 875, 1, True, 0.511, 0.376, True],
#  ['BWCY', 876, 2, True, 1.9875, 1.863, True],
#  ['BWCY', 884, 9, True, 0.986, 0.3425, True],
#  ['BWCY', 890, 9, True, 1.9935, 1.8, True],
#  ['BWCY', 893, 9, True, 1.532, 1.054, True],
#  ['BWCY', 895, 9, True, 1.0575, 0.8155, True],
#  ['BWCY', 903, 9, True, 1.15, 0.8475, True],
#  ['BWCY', 905, 1, True, 1.751, 1.5355, True],
#  ['BWCY', 907, 3, True, 1.2365, 0.736, True],
#  ['BWCY', 914, 9, True, 1.9585, 1.2385, True],
#  ['BWCY', 916, 9, True, 1.819, 0.7345, True],
#  ['BWCY', 920, 9, True, 1.286, 0.985, True],
#  ['BWCY', 930, 7, True, 1.5435, 0.3435, True],
#  ['BWCY', 935, 9, True, 1.338, 0.874, True],
#  ['BWCY', 940, 6, True, 1.4595, 1.412, True],
#  ['BWCY', 941, 7, True, 1.2915, 1.2615, True],
#  ['BWCY', 945, 4, True, 1.9855, 1.856, True],
#  ['BWCY', 950, 8, True, 0.897, 0.5, True],
#  ['BWCY', 952, 3, True, 1.049, 0.657, True],
#  ['BWCY', 953, 3, True, 1.951, 0.6805, True],
#  ['BWCY', 956, 1, True, 1.3575, 0.9605, True],
#  ['BWCY', 957, 1, True, 1.7495, 1.6965, True],
#  ['BWCY', 964, 8, True, 1.246, 0.516, True],
#  ['BWCY', 965, 2, True, 1.5455, 0.621, True],
#  ['BWCY', 970, 2, True, 1.2225, 0.895, True],
#  ['BWCY', 973, 9, True, 1.9835, 1.337, True],
#  ['BWCY', 974, 9, True, 1.8755, 1.8085, True],
#  ['BWCY', 977, 7, True, 0.439, 0.4375, True],
#  ['BWCY', 984, 9, True, 0.41, 0.346, True],
#  ['BWCY', 986, 3, True, 1.963, 1.611, True],
#  ['BWCY', 989, 9, True, 1.737, 1.012, True]]

# %%
print('Bid Win - Click NO: Count',len(b1.bid_win_click_no))
b1.bid_win_click_no # 1.Type 2.Round, 3. User, 4. Won Auction? 5.Bid Price 5.Winning Price (2ndBest)  6. User Clicked?
# Out:
# Bid Win - Click NO: Count 138
# [['BWCN', 1, 0, True, 1.4435, 1.213, False],
#  ['BWCN', 12, 0, True, 0.895, 0.8095, False],
#  ['BWCN', 19, 4, True, 1.614, 1.6085, False],
#  ['BWCN', 25, 8, True, 1.783, 1.0885, False],
#  ['BWCN', 29, 0, True, 1.5705, 1.306, False],
#  ['BWCN', 35, 5, True, 1.1455, 1.129, False],
#  ['BWCN', 40, 0, True, 1.1875, 0.984, False],
#  ['BWCN', 42, 4, True, 1.679, 1.5035, False],
#  ['BWCN', 46, 4, True, 1.744, 1.3535, False],
#  ['BWCN', 47, 8, True, 1.7755, 1.567, False],
#  ['BWCN', 58, 0, True, 1.438, 1.271, False],
#  ['BWCN', 60, 0, True, 1.645, 0.473, False],
#  ['BWCN', 62, 1, True, 1.6865, 1.4775, False],
#  ['BWCN', 67, 4, True, 1.775, 1.6105, False],
#  ['BWCN', 78, 0, True, 1.5785, 0.8825, False],
#  ['BWCN', 90, 7, True, 1.88, 1.425, False],
#  ['BWCN', 110, 9, True, 1.55, 1.512, False],
#  ['BWCN', 111, 5, True, 1.817, 0.666, False],
#  ['BWCN', 116, 3, True, 0.7625, 0.4175, False],
#  ['BWCN', 124, 0, True, 1.957, 0.637, False],
#  ['BWCN', 127, 7, True, 1.946, 1.072, False],
#  ['BWCN', 129, 4, True, 0.936, 0.84, False],
#  ['BWCN', 137, 1, True, 1.9565, 1.787, False],
#  ['BWCN', 143, 5, True, 1.698, 1.5515, False],
#  ['BWCN', 148, 7, True, 1.5015, 1.5005, False],
#  ['BWCN', 156, 4, True, 1.686, 1.549, False],
#  ['BWCN', 158, 0, True, 0.9105, 0.884, False],
#  ['BWCN', 161, 5, True, 1.351, 0.8735, False],
#  ['BWCN', 167, 5, True, 1.8625, 0.3575, False],
#  ['BWCN', 172, 1, True, 1.218, 0.7405, False],
#  ['BWCN', 186, 5, True, 0.538, 0.4915, False],
#  ['BWCN', 194, 1, True, 1.9645, 1.2025, False],
#  ['BWCN', 199, 0, True, 1.9465, 1.406, False],
#  ['BWCN', 213, 1, True, 1.869, 1.8025, False],
#  ['BWCN', 214, 0, True, 1.189, 0.7995, False],
#  ['BWCN', 220, 5, True, 1.3345, 0.445, False],
#  ['BWCN', 222, 4, True, 1.0985, 0.858, False],
#  ['BWCN', 223, 0, True, 1.5265, 1.236, False],
#  ['BWCN', 229, 4, True, 1.1465, 0.6545, False],
#  ['BWCN', 241, 0, True, 1.3175, 1.0325, False],
#  ['BWCN', 246, 2, True, 1.111, 1.0685, False],
#  ['BWCN', 247, 0, True, 1.984, 1.569, False],
#  ['BWCN', 252, 0, True, 1.7575, 0.7265, False],
#  ['BWCN', 254, 5, True, 1.934, 1.5915, False],
#  ['BWCN', 265, 4, True, 1.8625, 0.2125, False],
#  ['BWCN', 288, 7, True, 0.879, 0.836, False],
#  ['BWCN', 292, 0, True, 1.5705, 1.184, False],
#  ['BWCN', 294, 4, True, 1.3435, 1.088, False],
#  ['BWCN', 303, 0, True, 1.9445, 1.894, False],
#  ['BWCN', 313, 7, True, 1.3805, 0.826, False],
#  ['BWCN', 316, 7, True, 1.838, 1.049, False],
#  ['BWCN', 326, 0, True, 1.103, 0.6865, False],
#  ['BWCN', 328, 4, True, 1.796, 1.36, False],
#  ['BWCN', 332, 4, True, 1.7795, 0.2385, False],
#  ['BWCN', 333, 0, True, 1.78, 1.572, False],
#  ['BWCN', 349, 0, True, 1.9815, 1.965, False],
#  ['BWCN', 353, 5, True, 1.491, 1.424, False],
#  ['BWCN', 354, 8, True, 1.8305, 1.198, False],
#  ['BWCN', 362, 4, True, 1.5655, 1.3455, False],
#  ['BWCN', 367, 5, True, 1.643, 0.7105, False],
#  ['BWCN', 372, 5, True, 1.8295, 0.39, False],
#  ['BWCN', 384, 2, True, 1.626, 1.48, False],
#  ['BWCN', 392, 0, True, 1.9385, 1.851, False],
#  ['BWCN', 418, 2, True, 1.2855, 0.7815, False],
#  ['BWCN', 425, 7, True, 1.8135, 0.2775, False],
#  ['BWCN', 426, 9, True, 1.4015, 0.744, False],
#  ['BWCN', 431, 1, True, 1.798, 0.789, False],
#  ['BWCN', 453, 8, True, 1.2775, 0.983, False],
#  ['BWCN', 463, 8, True, 1.742, 1.435, False],
#  ['BWCN', 467, 8, True, 1.841, 1.727, False],
#  ['BWCN', 479, 0, True, 1.6025, 0.2685, False],
#  ['BWCN', 495, 0, True, 1.679, 1.0975, False],
#  ['BWCN', 496, 5, True, 1.372, 1.128, False],
#  ['BWCN', 501, 0, True, 1.638, 0.9955, False],
#  ['BWCN', 503, 5, True, 1.0485, 0.4905, False],
#  ['BWCN', 508, 2, True, 1.501, 1.008, False],
#  ['BWCN', 522, 4, True, 1.766, 1.173, False],
#  ['BWCN', 536, 2, True, 1.681, 0.9725, False],
#  ['BWCN', 542, 0, True, 1.5125, 1.0775, False],
#  ['BWCN', 544, 8, True, 1.9795, 1.9145, False],
#  ['BWCN', 551, 4, True, 1.9875, 1.649, False],
#  ['BWCN', 565, 4, True, 0.662, 0.5755, False],
#  ['BWCN', 568, 1, True, 1.5965, 1.4295, False],
#  ['BWCN', 582, 5, True, 1.3205, 0.3625, False],
#  ['BWCN', 586, 7, True, 0.9905, 0.7065, False],
#  ['BWCN', 587, 4, True, 1.7085, 0.987, False],
#  ['BWCN', 590, 1, True, 1.915, 0.959, False],
#  ['BWCN', 613, 0, True, 1.6945, 0.5315, False],
#  ['BWCN', 615, 0, True, 1.899, 1.655, False],
#  ['BWCN', 617, 5, True, 1.2515, 0.591, False],
#  ['BWCN', 626, 7, True, 1.206, 1.046, False],
#  ['BWCN', 643, 0, True, 1.88, 1.7405, False],
#  ['BWCN', 644, 7, True, 1.1215, 0.1765, False],
#  ['BWCN', 661, 5, True, 1.5, 0.494, False],
#  ['BWCN', 671, 0, True, 1.935, 1.5315, False],
#  ['BWCN', 682, 5, True, 1.594, 0.699, False],
#  ['BWCN', 684, 5, True, 1.4485, 1.1185, False],
#  ['BWCN', 700, 1, True, 1.765, 1.5625, False],
#  ['BWCN', 707, 8, True, 1.8765, 1.5235, False],
#  ['BWCN', 716, 1, True, 1.7295, 1.5245, False],
#  ['BWCN', 720, 7, True, 1.111, 0.7465, False],
#  ['BWCN', 727, 7, True, 0.7915, 0.6605, False],
#  ['BWCN', 736, 8, True, 1.4925, 1.359, False],
#  ['BWCN', 745, 8, True, 1.9615, 0.996, False],
#  ['BWCN', 753, 4, True, 1.523, 0.9945, False],
#  ['BWCN', 772, 5, True, 1.549, 0.8755, False],
#  ['BWCN', 777, 0, True, 1.3805, 0.3485, False],
#  ['BWCN', 779, 1, True, 1.1255, 1.0865, False],
#  ['BWCN', 786, 0, True, 1.0755, 1.064, False],
#  ['BWCN', 789, 4, True, 1.0655, 0.284, False],
#  ['BWCN', 803, 1, True, 0.4425, 0.2875, False],
#  ['BWCN', 806, 8, True, 1.62, 0.604, False],
#  ['BWCN', 812, 4, True, 1.5705, 0.5115, False],
#  ['BWCN', 819, 5, True, 1.385, 1.356, False],
#  ['BWCN', 820, 4, True, 1.686, 1.118, False],
#  ['BWCN', 827, 0, True, 1.7265, 0.7175, False],
#  ['BWCN', 849, 5, True, 1.6745, 1.1725, False],
#  ['BWCN', 853, 0, True, 1.9615, 1.7775, False],
#  ['BWCN', 862, 0, True, 1.098, 0.9785, False],
#  ['BWCN', 863, 5, True, 1.973, 1.752, False],
#  ['BWCN', 864, 4, True, 1.9785, 1.9555, False],
#  ['BWCN', 866, 0, True, 1.8145, 0.9005, False],
#  ['BWCN', 867, 0, True, 1.903, 1.811, False],
#  ['BWCN', 869, 5, True, 1.9165, 0.564, False],
#  ['BWCN', 885, 8, True, 1.93, 1.217, False],
#  ['BWCN', 894, 5, True, 1.609, 0.5675, False],
#  ['BWCN', 896, 1, True, 1.521, 1.1595, False],
#  ['BWCN', 915, 5, True, 1.339, 0.2585, False],
#  ['BWCN', 922, 7, True, 1.779, 0.5425, False],
#  ['BWCN', 939, 0, True, 0.556, 0.54, False],
#  ['BWCN', 943, 5, True, 1.6955, 1.649, False],
#  ['BWCN', 944, 7, True, 1.8935, 0.624, False],
#  ['BWCN', 948, 0, True, 1.7225, 1.3875, False],
#  ['BWCN', 960, 7, True, 1.4255, 1.4005, False],
#  ['BWCN', 969, 5, True, 1.0125, 0.416, False],
#  ['BWCN', 983, 3, True, 1.037, 0.748, False],
#  ['BWCN', 994, 4, True, 1.9225, 0.66, False],
#  ['BWCN', 998, 5, True, 1.1335, 0.929, False]]

# %%
print('Bid LOST: Count',len(b1.bid_lost_list))
b1.bid_lost_list # 1.Type 2.Round, 3. User, 4. Won Auction? 5.Bid Price 5.Winning Price (2ndBest)  6. User Clicked?
# Out:
# Bid LOST: Count 659
# [['BLOS', 2, 6, False, 0.2685, 0.455, None],
#  ['BLOS', 3, 5, False, 0.216, 0.939, None],
#  ['BLOS', 5, 5, False, 0.6715, 0.778, None],
#  ['BLOS', 8, 7, False, 0.2325, 1.3285, None],
#  ['BLOS', 10, 5, False, 1.1915, 1.1915, None],
#  ['BLOS', 14, 6, False, 1.4175, 1.817, None],
#  ['BLOS', 15, 1, False, 0.732, 0.732, None],
#  ['BLOS', 16, 9, False, 0.8075, 0.856, None],
#  ['BLOS', 17, 2, False, 1.2895, 1.2895, None],
#  ['BLOS', 18, 9, False, 1.048, 1.8545, None],
#  ['BLOS', 20, 5, False, 1.3075, 1.3075, None],
#  ['BLOS', 21, 4, False, 0.7705, 0.7705, None],
#  ['BLOS', 23, 3, False, 0.5865, 1.1155, None],
#  ['BLOS', 24, 8, False, 0.0605, 0.189, None],
#  ['BLOS', 28, 4, False, 1.0505, 1.0505, None],
#  ['BLOS', 30, 1, False, 0.5545, 0.6545, None],
#  ['BLOS', 33, 3, False, 0.1905, 1.726, None],
#  ['BLOS', 34, 3, False, 1.791, 1.791, None],
#  ['BLOS', 36, 7, False, 0.063, 0.063, None],
#  ['BLOS', 37, 7, False, 1.717, 1.717, None],
#  ['BLOS', 38, 1, False, 0.7875, 0.7875, None],
#  ['BLOS', 39, 2, False, 1.0335, 1.0335, None],
#  ['BLOS', 41, 6, False, 0.282, 1.2085, None],
#  ['BLOS', 44, 8, False, 0.107, 1.0545, None],
#  ['BLOS', 45, 2, False, 1.272, 1.272, None],
#  ['BLOS', 48, 3, False, 0.5045, 1.3265, None],
#  ['BLOS', 49, 2, False, 0.2155, 0.246, None],
#  ['BLOS', 50, 2, False, 1.209, 1.209, None],
#  ['BLOS', 52, 6, False, 0.1045, 0.5535, None],
#  ['BLOS', 53, 3, False, 0.9255, 0.9255, None],
#  ['BLOS', 54, 6, False, 1.912, 1.912, None],
#  ['BLOS', 55, 5, False, 0.5965, 0.5965, None],
#  ['BLOS', 56, 2, False, 1.102, 1.3805, None],
#  ['BLOS', 57, 7, False, 1.6435, 1.7905, None],
#  ['BLOS', 59, 5, False, 0.479, 0.491, None],
#  ['BLOS', 61, 6, False, 1.0295, 1.401, None],
#  ['BLOS', 63, 7, False, 0.2365, 0.2365, None],
#  ['BLOS', 64, 3, False, 0.505, 0.505, None],
#  ['BLOS', 65, 5, False, 1.041, 1.041, None],
#  ['BLOS', 66, 5, False, 0.117, 1.823, None],
#  ['BLOS', 68, 9, False, 0.8705, 1.295, None],
#  ['BLOS', 70, 2, False, 1.1925, 1.6425, None],
#  ['BLOS', 72, 4, False, 0.732, 1.023, None],
#  ['BLOS', 73, 8, False, 0.709, 0.709, None],
#  ['BLOS', 74, 4, False, 0.22, 0.4, None],
#  ['BLOS', 75, 6, False, 0.169, 0.353, None],
#  ['BLOS', 76, 5, False, 1.1865, 1.6685, None],
#  ['BLOS', 77, 3, False, 1.541, 1.541, None],
#  ['BLOS', 79, 7, False, 1.4875, 1.4875, None],
#  ['BLOS', 80, 9, False, 0.1015, 1.2775, None],
#  ['BLOS', 81, 7, False, 0.331, 0.678, None],
#  ['BLOS', 82, 1, False, 0.5395, 0.5395, None],
#  ['BLOS', 83, 9, False, 0.366, 0.8575, None],
#  ['BLOS', 84, 9, False, 0.976, 1.306, None],
#  ['BLOS', 85, 1, False, 0.9775, 0.9775, None],
#  ['BLOS', 86, 1, False, 1.5135, 1.5135, None],
#  ['BLOS', 88, 3, False, 0.5365, 0.5365, None],
#  ['BLOS', 92, 1, False, 0.004, 0.846, None],
#  ['BLOS', 93, 3, False, 0.8935, 1.0215, None],
#  ['BLOS', 94, 2, False, 0.357, 1.2085, None],
#  ['BLOS', 96, 7, False, 1.362, 1.362, None],
#  ['BLOS', 97, 2, False, 0.264, 0.9005, None],
#  ['BLOS', 98, 1, False, 0.8415, 1.8375, None],
#  ['BLOS', 99, 4, False, 1.1205, 1.64, None],
#  ['BLOS', 100, 1, False, 0.731, 0.731, None],
#  ['BLOS', 101, 4, False, 1.5085, 1.5085, None],
#  ['BLOS', 102, 0, False, 1.0375, 1.0375, None],
#  ['BLOS', 104, 8, False, 0.184, 1.116, None],
#  ['BLOS', 105, 2, False, 0.2165, 0.926, None],
#  ['BLOS', 106, 5, False, 1.2775, 1.2775, None],
#  ['BLOS', 108, 3, False, 0.6745, 0.6745, None],
#  ['BLOS', 109, 9, False, 0.0275, 0.188, None],
#  ['BLOS', 112, 0, False, 0.409, 0.409, None],
#  ['BLOS', 113, 2, False, 0.9, 0.9, None],
#  ['BLOS', 114, 2, False, 0.698, 1.1165, None],
#  ['BLOS', 118, 8, False, 0.2355, 0.6365, None],
#  ['BLOS', 119, 7, False, 0.645, 1.3115, None],
#  ['BLOS', 121, 7, False, 0.422, 0.5615, None],
#  ['BLOS', 126, 4, False, 0.0485, 0.8755, None],
#  ['BLOS', 130, 7, False, 1.197, 1.197, None],
#  ['BLOS', 131, 5, False, 0.2685, 0.2685, None],
#  ['BLOS', 133, 3, False, 1.4095, 1.7115, None],
#  ['BLOS', 134, 6, False, 1.1545, 1.2785, None],
#  ['BLOS', 135, 8, False, 1.1325, 1.1935, None],
#  ['BLOS', 138, 8, False, 0.1905, 1.1285, None],
#  ['BLOS', 139, 5, False, 1.4975, 1.4975, None],
#  ['BLOS', 140, 6, False, 0.732, 1.312, None],
#  ['BLOS', 142, 2, False, 1.0435, 1.0435, None],
#  ['BLOS', 145, 9, False, 1.1305, 1.649, None],
#  ['BLOS', 146, 3, False, 1.1945, 1.1945, None],
#  ['BLOS', 147, 4, False, 0.7345, 0.8355, None],
#  ['BLOS', 149, 2, False, 0.468, 0.468, None],
#  ['BLOS', 150, 7, False, 1.4485, 1.4485, None],
#  ['BLOS', 151, 6, False, 0.029, 1.0, None],
#  ['BLOS', 152, 6, False, 1.526, 1.526, None],
#  ['BLOS', 153, 6, False, 0.728, 0.728, None],
#  ['BLOS', 155, 7, False, 0.8615, 0.8615, None],
#  ['BLOS', 157, 4, False, 1.277, 1.277, None],
#  ['BLOS', 159, 7, False, 1.5675, 1.5675, None],
#  ['BLOS', 160, 0, False, 0.607, 0.607, None],
#  ['BLOS', 163, 9, False, 1.0685, 1.0685, None],
#  ['BLOS', 164, 7, False, 1.5775, 1.5775, None],
#  ['BLOS', 165, 3, False, 0.0745, 0.7915, None],
#  ['BLOS', 166, 2, False, 0.348, 0.7765, None],
#  ['BLOS', 168, 4, False, 1.887, 1.887, None],
#  ['BLOS', 169, 1, False, 0.607, 0.607, None],
#  ['BLOS', 170, 0, False, 0.4745, 1.3865, None],
#  ['BLOS', 171, 8, False, 0.693, 0.864, None],
#  ['BLOS', 173, 4, False, 1.7895, 1.7895, None],
#  ['BLOS', 174, 2, False, 1.4585, 1.4585, None],
#  ['BLOS', 176, 9, False, 1.209, 1.209, None],
#  ['BLOS', 178, 2, False, 0.4005, 0.744, None],
#  ['BLOS', 179, 5, False, 0.031, 0.976, None],
#  ['BLOS', 180, 4, False, 0.338, 0.363, None],
#  ['BLOS', 183, 1, False, 1.013, 1.013, None],
#  ['BLOS', 184, 6, False, 1.1325, 1.1325, None],
#  ['BLOS', 185, 0, False, 0.4225, 0.7435, None],
#  ['BLOS', 187, 7, False, 1.799, 1.799, None],
#  ['BLOS', 189, 5, False, 1.1095, 1.1095, None],
#  ['BLOS', 190, 4, False, 0.0655, 0.0655, None],
#  ['BLOS', 191, 9, False, 1.209, 1.296, None],
#  ['BLOS', 192, 0, False, 0.8585, 0.8585, None],
#  ['BLOS', 193, 7, False, 1.183, 1.183, None],
#  ['BLOS', 195, 7, False, 0.244, 1.305, None],
#  ['BLOS', 196, 6, False, 1.0135, 1.0135, None],
#  ['BLOS', 197, 2, False, 0.5045, 1.0315, None],
#  ['BLOS', 198, 2, False, 1.3875, 1.3875, None],
#  ['BLOS', 200, 8, False, 1.133, 1.7485, None],
#  ['BLOS', 202, 0, False, 0.64, 1.0235, None],
#  ['BLOS', 208, 1, False, 1.0165, 1.0165, None],
#  ['BLOS', 209, 4, False, 0.3895, 1.078, None],
#  ['BLOS', 210, 2, False, 0.9275, 1.7965, None],
#  ['BLOS', 211, 1, False, 0.689, 0.689, None],
#  ['BLOS', 212, 4, False, 1.7165, 1.7165, None],
#  ['BLOS', 215, 2, False, 1.8955, 1.8955, None],
#  ['BLOS', 216, 8, False, 1.303, 1.4365, None],
#  ['BLOS', 217, 8, False, 1.227, 1.418, None],
#  ['BLOS', 218, 1, False, 1.5815, 1.5815, None],
#  ['BLOS', 219, 6, False, 1.0495, 1.0495, None],
#  ['BLOS', 224, 9, False, 1.408, 1.408, None],
#  ['BLOS', 225, 1, False, 0.498, 0.498, None],
#  ['BLOS', 226, 3, False, 1.0845, 1.0845, None],
#  ['BLOS', 227, 2, False, 0.5235, 0.5235, None],
#  ['BLOS', 232, 7, False, 0.929, 1.1635, None],
#  ['BLOS', 233, 4, False, 1.8045, 1.8045, None],
#  ['BLOS', 234, 4, False, 1.809, 1.809, None],
#  ['BLOS', 235, 9, False, 0.8705, 0.8705, None],
#  ['BLOS', 237, 3, False, 0.0395, 1.359, None],
#  ['BLOS', 238, 9, False, 0.999, 0.999, None],
#  ['BLOS', 239, 8, False, 1.3865, 1.3865, None],
#  ['BLOS', 242, 5, False, 1.3085, 1.428, None],
#  ['BLOS', 243, 0, False, 0.826, 0.826, None],
#  ['BLOS', 244, 6, False, 0.5275, 0.5275, None],
#  ['BLOS', 245, 4, False, 0.719, 0.719, None],
#  ['BLOS', 248, 6, False, 0.98, 0.98, None],
#  ['BLOS', 249, 0, False, 1.1015, 1.1015, None],
#  ['BLOS', 250, 6, False, 0.4645, 1.0515, None],
#  ['BLOS', 251, 9, False, 0.9225, 0.9225, None],
#  ['BLOS', 253, 7, False, 0.0835, 0.3535, None],
#  ['BLOS', 255, 6, False, 1.4735, 1.4735, None],
#  ['BLOS', 258, 8, False, 1.327, 1.327, None],
#  ['BLOS', 259, 6, False, 1.398, 1.398, None],
#  ['BLOS', 260, 7, False, 0.0525, 1.493, None],
#  ['BLOS', 261, 7, False, 0.543, 0.543, None],
#  ['BLOS', 262, 8, False, 0.743, 0.8625, None],
#  ['BLOS', 263, 1, False, 1.366, 1.366, None],
#  ['BLOS', 264, 1, False, 0.3885, 1.454, None],
#  ['BLOS', 266, 9, False, 0.431, 1.6795, None],
#  ['BLOS', 267, 4, False, 1.4015, 1.4015, None],
#  ['BLOS', 268, 6, False, 0.1575, 0.1575, None],
#  ['BLOS', 269, 8, False, 0.526, 0.887, None],
#  ['BLOS', 270, 8, False, 0.321, 0.321, None],
#  ['BLOS', 271, 9, False, 1.1425, 1.1425, None],
#  ['BLOS', 272, 9, False, 1.2985, 1.2985, None],
#  ['BLOS', 273, 8, False, 0.0385, 0.1785, None],
#  ['BLOS', 275, 9, False, 1.694, 1.694, None],
#  ['BLOS', 276, 1, False, 1.2405, 1.2405, None],
#  ['BLOS', 277, 5, False, 0.8755, 0.8755, None],
#  ['BLOS', 278, 2, False, 1.291, 1.479, None],
#  ['BLOS', 279, 0, False, 0.234, 0.3195, None],
#  ['BLOS', 281, 9, False, 0.0025, 1.769, None],
#  ['BLOS', 282, 1, False, 0.016, 0.0415, None],
#  ['BLOS', 283, 5, False, 0.579, 1.5305, None],
#  ['BLOS', 285, 6, False, 1.4315, 1.6075, None],
#  ['BLOS', 286, 6, False, 0.3125, 0.799, None],
#  ['BLOS', 287, 1, False, 0.6915, 0.6915, None],
#  ['BLOS', 289, 0, False, 0.524, 0.6785, None],
#  ['BLOS', 291, 3, False, 0.5925, 1.8665, None],
#  ['BLOS', 293, 4, False, 1.3005, 1.3855, None],
#  ['BLOS', 296, 8, False, 0.179, 0.525, None],
#  ['BLOS', 297, 1, False, 0.4575, 0.4575, None],
#  ['BLOS', 298, 9, False, 0.137, 1.431, None],
#  ['BLOS', 299, 9, False, 1.612, 1.612, None],
#  ['BLOS', 302, 3, False, 0.8315, 0.8315, None],
#  ['BLOS', 304, 5, False, 0.0225, 0.191, None],
#  ['BLOS', 305, 1, False, 0.8215, 0.984, None],
#  ['BLOS', 307, 1, False, 0.394, 0.9855, None],
#  ['BLOS', 308, 6, False, 1.2495, 1.2495, None],
#  ['BLOS', 309, 1, False, 0.0185, 0.2035, None],
#  ['BLOS', 310, 1, False, 1.5475, 1.5475, None],
#  ['BLOS', 311, 0, False, 0.563, 0.563, None],
#  ['BLOS', 312, 7, False, 1.869, 1.869, None],
#  ['BLOS', 314, 5, False, 1.551, 1.551, None],
#  ['BLOS', 315, 7, False, 1.1175, 1.1175, None],
#  ['BLOS', 317, 1, False, 1.155, 1.4045, None],
#  ['BLOS', 318, 2, False, 1.069, 1.069, None],
#  ['BLOS', 319, 0, False, 0.813, 0.8355, None],
#  ['BLOS', 320, 2, False, 0.395, 0.549, None],
#  ['BLOS', 321, 8, False, 0.74, 0.74, None],
#  ['BLOS', 322, 2, False, 0.056, 0.056, None],
#  ['BLOS', 325, 5, False, 0.043, 0.5375, None],
#  ['BLOS', 327, 3, False, 0.8235, 0.838, None],
#  ['BLOS', 329, 0, False, 1.3755, 1.3755, None],
#  ['BLOS', 330, 3, False, 0.9515, 0.9515, None],
#  ['BLOS', 331, 4, False, 1.3925, 1.3925, None],
#  ['BLOS', 335, 8, False, 1.738, 1.738, None],
#  ['BLOS', 337, 6, False, 1.3295, 1.3295, None],
#  ['BLOS', 339, 3, False, 0.467, 1.1215, None],
#  ['BLOS', 341, 9, False, 1.019, 1.019, None],
#  ['BLOS', 342, 3, False, 0.225, 0.6035, None],
#  ['BLOS', 345, 3, False, 0.677, 0.677, None],
#  ['BLOS', 347, 9, False, 0.493, 0.8485, None],
#  ['BLOS', 351, 9, False, 1.343, 1.343, None],
#  ['BLOS', 352, 9, False, 1.408, 1.5245, None],
#  ['BLOS', 356, 0, False, 0.3505, 0.6785, None],
#  ['BLOS', 357, 8, False, 0.6105, 0.6105, None],
#  ['BLOS', 358, 8, False, 0.656, 0.656, None],
#  ['BLOS', 359, 1, False, 0.3035, 0.5245, None],
#  ['BLOS', 360, 0, False, 0.296, 1.364, None],
#  ['BLOS', 361, 8, False, 0.3365, 1.385, None],
#  ['BLOS', 363, 3, False, 0.738, 0.738, None],
#  ['BLOS', 365, 5, False, 0.4485, 0.4485, None],
#  ['BLOS', 366, 0, False, 0.362, 1.773, None],
#  ['BLOS', 368, 4, False, 0.691, 0.803, None],
#  ['BLOS', 369, 6, False, 0.4885, 0.874, None],
#  ['BLOS', 373, 4, False, 1.9275, 1.9275, None],
#  ['BLOS', 374, 9, False, 0.116, 1.5835, None],
#  ['BLOS', 375, 1, False, 0.2125, 0.2125, None],
#  ['BLOS', 376, 2, False, 0.4485, 1.314, None],
#  ['BLOS', 378, 0, False, 0.731, 0.731, None],
#  ['BLOS', 379, 2, False, 0.0755, 0.399, None],
#  ['BLOS', 380, 8, False, 0.0875, 0.3695, None],
#  ['BLOS', 381, 0, False, 0.3165, 0.3165, None],
#  ['BLOS', 382, 6, False, 0.64, 0.913, None],
#  ['BLOS', 383, 1, False, 0.147, 0.949, None],
#  ['BLOS', 385, 2, False, 1.024, 1.4185, None],
#  ['BLOS', 386, 1, False, 0.0815, 0.5145, None],
#  ['BLOS', 388, 8, False, 1.677, 1.677, None],
#  ['BLOS', 389, 0, False, 1.2755, 1.2755, None],
#  ['BLOS', 391, 5, False, 1.4505, 1.4505, None],
#  ['BLOS', 394, 6, False, 0.455, 1.7935, None],
#  ['BLOS', 395, 7, False, 0.416, 0.661, None],
#  ['BLOS', 396, 4, False, 1.342, 1.342, None],
#  ['BLOS', 397, 5, False, 0.602, 0.6445, None],
#  ['BLOS', 398, 1, False, 0.335, 0.579, None],
#  ['BLOS', 399, 0, False, 0.8925, 0.8925, None],
#  ['BLOS', 400, 0, False, 1.355, 1.355, None],
#  ['BLOS', 401, 6, False, 0.404, 0.77, None],
#  ['BLOS', 402, 8, False, 0.091, 0.8655, None],
#  ['BLOS', 403, 2, False, 0.0475, 0.8785, None],
#  ['BLOS', 406, 6, False, 1.1025, 1.3855, None],
#  ['BLOS', 407, 7, False, 0.3145, 0.384, None],
#  ['BLOS', 408, 2, False, 0.198, 1.324, None],
#  ['BLOS', 411, 5, False, 0.1105, 1.1785, None],
#  ['BLOS', 413, 9, False, 0.2335, 0.3775, None],
#  ['BLOS', 415, 0, False, 0.3965, 0.592, None],
#  ['BLOS', 416, 9, False, 0.0505, 0.217, None],
#  ['BLOS', 419, 3, False, 0.572, 0.8865, None],
#  ['BLOS', 420, 9, False, 0.0145, 0.2815, None],
#  ['BLOS', 421, 0, False, 0.1, 0.5075, None],
#  ['BLOS', 423, 1, False, 0.6235, 0.6235, None],
#  ['BLOS', 424, 6, False, 1.241, 1.241, None],
#  ['BLOS', 427, 6, False, 1.249, 1.249, None],
#  ['BLOS', 429, 7, False, 0.818, 0.818, None],
#  ['BLOS', 430, 1, False, 0.082, 0.7515, None],
#  ['BLOS', 432, 7, False, 0.799, 1.2225, None],
#  ['BLOS', 433, 4, False, 0.229, 0.229, None],
#  ['BLOS', 434, 4, False, 1.1865, 1.1865, None],
#  ['BLOS', 436, 5, False, 0.4, 0.621, None],
#  ['BLOS', 437, 0, False, 0.1535, 0.46, None],
#  ['BLOS', 438, 9, False, 1.2305, 1.2305, None],
#  ['BLOS', 440, 2, False, 0.0985, 0.0985, None],
#  ['BLOS', 441, 8, False, 0.474, 0.474, None],
#  ['BLOS', 442, 0, False, 0.869, 0.869, None],
#  ['BLOS', 443, 8, False, 0.951, 1.2685, None],
#  ['BLOS', 444, 5, False, 0.565, 0.591, None],
#  ['BLOS', 446, 2, False, 1.109, 1.109, None],
#  ['BLOS', 447, 3, False, 0.014, 0.8505, None],
#  ['BLOS', 449, 9, False, 0.1935, 0.3855, None],
#  ['BLOS', 450, 8, False, 0.8845, 0.8845, None],
#  ['BLOS', 452, 9, False, 0.786, 0.9805, None],
#  ['BLOS', 454, 7, False, 1.2435, 1.2435, None],
#  ['BLOS', 455, 1, False, 1.0055, 1.0055, None],
#  ['BLOS', 456, 8, False, 0.5595, 0.5595, None],
#  ['BLOS', 457, 1, False, 1.12, 1.12, None],
#  ['BLOS', 458, 0, False, 0.587, 0.8125, None],
#  ['BLOS', 460, 1, False, 1.319, 1.319, None],
#  ['BLOS', 461, 7, False, 0.65, 1.1405, None],
#  ['BLOS', 462, 1, False, 0.813, 1.135, None],
#  ['BLOS', 466, 4, False, 0.285, 1.148, None],
#  ['BLOS', 469, 1, False, 1.3755, 1.483, None],
#  ['BLOS', 471, 8, False, 0.8555, 0.9915, None],
#  ['BLOS', 472, 8, False, 1.272, 1.272, None],
#  ['BLOS', 473, 2, False, 0.7175, 0.7175, None],
#  ['BLOS', 474, 2, False, 1.2115, 1.265, None],
#  ['BLOS', 475, 0, False, 0.081, 0.977, None],
#  ['BLOS', 476, 6, False, 0.1765, 1.3845, None],
#  ['BLOS', 477, 7, False, 1.0345, 1.0345, None],
#  ['BLOS', 478, 4, False, 0.657, 0.657, None],
#  ['BLOS', 480, 9, False, 0.064, 0.299, None],
#  ['BLOS', 481, 8, False, 0.0805, 0.633, None],
#  ['BLOS', 482, 8, False, 1.3705, 1.3705, None],
#  ['BLOS', 483, 3, False, 1.7015, 1.7015, None],
#  ['BLOS', 485, 6, False, 0.2365, 0.9065, None],
#  ['BLOS', 486, 9, False, 0.4135, 1.764, None],
#  ['BLOS', 487, 6, False, 0.0765, 0.162, None],
#  ['BLOS', 488, 7, False, 0.9075, 0.9075, None],
#  ['BLOS', 490, 0, False, 0.9425, 1.7895, None],
#  ['BLOS', 492, 6, False, 0.604, 0.604, None],
#  ['BLOS', 497, 2, False, 0.8455, 0.8455, None],
#  ['BLOS', 498, 7, False, 1.287, 1.287, None],
#  ['BLOS', 499, 7, False, 0.0105, 0.3245, None],
#  ['BLOS', 500, 2, False, 1.5085, 1.5085, None],
#  ['BLOS', 502, 9, False, 0.2205, 0.2205, None],
#  ['BLOS', 504, 5, False, 0.985, 1.288, None],
#  ['BLOS', 506, 2, False, 0.68, 1.6125, None],
#  ['BLOS', 507, 4, False, 0.007, 0.383, None],
#  ['BLOS', 509, 0, False, 1.8355, 1.8355, None],
#  ['BLOS', 510, 1, False, 0.177, 0.395, None],
#  ['BLOS', 511, 5, False, 0.3975, 0.726, None],
#  ['BLOS', 513, 5, False, 0.519, 0.606, None],
#  ['BLOS', 514, 6, False, 1.049, 1.1995, None],
#  ['BLOS', 515, 7, False, 1.6255, 1.6255, None],
#  ['BLOS', 518, 4, False, 0.8, 0.8, None],
#  ['BLOS', 519, 2, False, 0.708, 1.146, None],
#  ['BLOS', 520, 8, False, 1.246, 1.246, None],
#  ['BLOS', 521, 0, False, 0.703, 0.703, None],
#  ['BLOS', 523, 3, False, 0.3965, 0.9705, None],
#  ['BLOS', 524, 9, False, 0.188, 1.2775, None],
#  ['BLOS', 525, 0, False, 0.459, 0.922, None],
#  ['BLOS', 527, 8, False, 0.2605, 0.949, None],
#  ['BLOS', 528, 5, False, 0.8535, 0.8535, None],
#  ['BLOS', 529, 3, False, 0.129, 0.336, None],
#  ['BLOS', 530, 6, False, 0.182, 0.466, None],
#  ['BLOS', 531, 0, False, 0.943, 0.943, None],
#  ['BLOS', 532, 3, False, 0.996, 1.0825, None],
#  ['BLOS', 533, 9, False, 0.06, 0.5595, None],
#  ['BLOS', 534, 5, False, 0.4675, 0.4675, None],
#  ['BLOS', 537, 8, False, 0.9045, 0.9045, None],
#  ['BLOS', 538, 6, False, 0.407, 0.759, None],
#  ['BLOS', 539, 5, False, 0.815, 0.815, None],
#  ['BLOS', 541, 9, False, 1.2425, 1.2425, None],
#  ['BLOS', 545, 0, False, 0.3365, 0.3365, None],
#  ['BLOS', 546, 4, False, 0.691, 1.307, None],
#  ['BLOS', 547, 4, False, 0.0855, 1.4425, None],
#  ['BLOS', 548, 5, False, 1.478, 1.478, None],
#  ['BLOS', 550, 8, False, 0.192, 0.2045, None],
#  ['BLOS', 552, 9, False, 0.756, 1.534, None],
#  ['BLOS', 553, 7, False, 0.9715, 1.737, None],
#  ['BLOS', 554, 9, False, 0.3335, 1.279, None],
#  ['BLOS', 555, 0, False, 0.022, 0.8455, None],
#  ['BLOS', 556, 4, False, 0.103, 1.14, None],
#  ['BLOS', 557, 4, False, 0.6075, 0.6075, None],
#  ['BLOS', 559, 5, False, 0.078, 0.146, None],
#  ['BLOS', 560, 3, False, 0.973, 0.973, None],
#  ['BLOS', 562, 4, False, 0.052, 0.738, None],
#  ['BLOS', 563, 3, False, 0.973, 0.973, None],
#  ['BLOS', 566, 5, False, 1.2165, 1.2165, None],
#  ['BLOS', 569, 1, False, 0.738, 0.738, None],
#  ['BLOS', 570, 8, False, 1.776, 1.776, None],
#  ['BLOS', 571, 3, False, 0.3595, 0.589, None],
#  ['BLOS', 573, 1, False, 0.8915, 0.937, None],
#  ['BLOS', 574, 7, False, 1.041, 1.041, None],
#  ['BLOS', 575, 8, False, 1.624, 1.729, None],
#  ['BLOS', 576, 9, False, 0.504, 0.504, None],
#  ['BLOS', 577, 1, False, 1.112, 1.112, None],
#  ['BLOS', 578, 5, False, 0.988, 1.2605, None],
#  ['BLOS', 579, 3, False, 0.09, 0.09, None],
#  ['BLOS', 583, 3, False, 1.048, 1.048, None],
#  ['BLOS', 584, 9, False, 0.1345, 1.441, None],
#  ['BLOS', 585, 7, False, 0.657, 1.0385, None],
#  ['BLOS', 588, 0, False, 0.2, 0.438, None],
#  ['BLOS', 589, 2, False, 0.2395, 0.898, None],
#  ['BLOS', 591, 5, False, 0.4205, 0.809, None],
#  ['BLOS', 592, 2, False, 1.8525, 1.8525, None],
#  ['BLOS', 593, 4, False, 1.6915, 1.7985, None],
#  ['BLOS', 594, 2, False, 1.016, 1.6745, None],
#  ['BLOS', 595, 0, False, 0.353, 0.353, None],
#  ['BLOS', 596, 6, False, 0.738, 0.7655, None],
#  ['BLOS', 599, 5, False, 0.2275, 0.654, None],
#  ['BLOS', 600, 9, False, 0.738, 0.738, None],
#  ['BLOS', 603, 4, False, 0.7515, 0.7515, None],
#  ['BLOS', 605, 2, False, 0.508, 0.508, None],
#  ['BLOS', 606, 8, False, 1.192, 1.192, None],
#  ['BLOS', 607, 3, False, 1.2105, 1.2105, None],
#  ['BLOS', 610, 8, False, 1.416, 1.416, None],
#  ['BLOS', 611, 8, False, 0.4065, 0.5675, None],
#  ['BLOS', 612, 2, False, 0.9685, 0.9685, None],
#  ['BLOS', 614, 9, False, 0.7155, 0.7155, None],
#  ['BLOS', 616, 1, False, 0.408, 0.925, None],
#  ['BLOS', 618, 5, False, 0.7065, 1.0845, None],
#  ['BLOS', 619, 3, False, 0.3115, 0.4225, None],
#  ['BLOS', 621, 9, False, 0.571, 1.3365, None],
#  ['BLOS', 623, 1, False, 1.8595, 1.8595, None],
#  ['BLOS', 624, 3, False, 0.146, 0.5065, None],
#  ['BLOS', 625, 9, False, 0.679, 0.679, None],
#  ['BLOS', 627, 4, False, 0.976, 1.2475, None],
#  ['BLOS', 628, 2, False, 0.0585, 0.0585, None],
#  ['BLOS', 629, 1, False, 0.2885, 1.2035, None],
#  ['BLOS', 630, 0, False, 1.372, 1.488, None],
#  ['BLOS', 632, 7, False, 1.2945, 1.2945, None],
#  ['BLOS', 633, 8, False, 0.4895, 0.4895, None],
#  ['BLOS', 635, 3, False, 1.106, 1.106, None],
#  ['BLOS', 636, 5, False, 0.036, 1.1735, None],
#  ['BLOS', 637, 3, False, 1.075, 1.2085, None],
#  ['BLOS', 638, 1, False, 1.38, 1.38, None],
#  ['BLOS', 640, 3, False, 1.0265, 1.809, None],
#  ['BLOS', 641, 5, False, 0.8715, 0.8715, None],
#  ['BLOS', 646, 0, False, 0.25, 1.142, None],
#  ['BLOS', 647, 4, False, 0.8045, 0.8045, None],
#  ['BLOS', 648, 8, False, 1.333, 1.333, None],
#  ['BLOS', 649, 4, False, 0.2635, 0.8015, None],
#  ['BLOS', 651, 2, False, 0.2715, 0.3765, None],
#  ['BLOS', 653, 0, False, 0.8865, 0.8865, None],
#  ['BLOS', 654, 6, False, 1.465, 1.465, None],
#  ['BLOS', 656, 0, False, 0.9465, 0.9465, None],
#  ['BLOS', 657, 3, False, 1.0405, 1.0405, None],
#  ['BLOS', 658, 5, False, 0.2355, 0.2355, None],
#  ['BLOS', 659, 8, False, 1.191, 1.191, None],
#  ['BLOS', 660, 9, False, 0.38, 0.38, None],
#  ['BLOS', 662, 2, False, 1.0455, 1.7105, None],
#  ['BLOS', 663, 3, False, 1.895, 1.895, None],
#  ['BLOS', 665, 6, False, 0.017, 0.5075, None],
#  ['BLOS', 666, 2, False, 1.7995, 1.7995, None],
#  ['BLOS', 667, 9, False, 0.278, 0.292, None],
#  ['BLOS', 668, 4, False, 0.006, 0.769, None],
#  ['BLOS', 669, 1, False, 0.1335, 0.67, None],
#  ['BLOS', 670, 3, False, 0.7695, 1.28, None],
#  ['BLOS', 672, 6, False, 0.327, 0.327, None],
#  ['BLOS', 673, 2, False, 0.08, 0.465, None],
#  ['BLOS', 676, 3, False, 1.1965, 1.1965, None],
#  ['BLOS', 679, 0, False, 0.245, 1.1145, None],
#  ['BLOS', 680, 2, False, 0.286, 0.7855, None],
#  ['BLOS', 681, 8, False, 0.148, 0.884, None],
#  ['BLOS', 683, 0, False, 0.6765, 0.699, None],
#  ['BLOS', 685, 2, False, 0.57, 0.57, None],
#  ['BLOS', 686, 7, False, 0.225, 0.2825, None],
#  ['BLOS', 687, 9, False, 1.546, 1.546, None],
#  ['BLOS', 688, 8, False, 1.904, 1.904, None],
#  ['BLOS', 689, 8, False, 0.1805, 1.0625, None],
#  ['BLOS', 690, 4, False, 1.222, 1.222, None],
#  ['BLOS', 691, 2, False, 0.766, 0.766, None],
#  ['BLOS', 692, 2, False, 0.4345, 0.8365, None],
#  ['BLOS', 693, 7, False, 1.676, 1.676, None],
#  ['BLOS', 695, 2, False, 1.125, 1.125, None],
#  ['BLOS', 696, 4, False, 1.4145, 1.4145, None],
#  ['BLOS', 697, 9, False, 0.8235, 0.8235, None],
#  ['BLOS', 698, 0, False, 0.588, 0.588, None],
#  ['BLOS', 699, 5, False, 0.0145, 0.509, None],
#  ['BLOS', 701, 0, False, 1.119, 1.6085, None],
#  ['BLOS', 702, 2, False, 1.07, 1.313, None],
#  ['BLOS', 703, 1, False, 0.393, 0.393, None],
#  ['BLOS', 704, 2, False, 0.853, 1.135, None],
#  ['BLOS', 705, 0, False, 0.742, 1.37, None],
#  ['BLOS', 706, 9, False, 0.973, 1.093, None],
#  ['BLOS', 708, 8, False, 0.0195, 0.3635, None],
#  ['BLOS', 709, 1, False, 0.5975, 0.847, None],
#  ['BLOS', 710, 9, False, 1.5315, 1.5315, None],
#  ['BLOS', 711, 7, False, 0.4735, 0.646, None],
#  ['BLOS', 712, 2, False, 0.1845, 0.1845, None],
#  ['BLOS', 713, 2, False, 0.8575, 0.8575, None],
#  ['BLOS', 714, 5, False, 1.8035, 1.8035, None],
#  ['BLOS', 715, 4, False, 1.2485, 1.2485, None],
#  ['BLOS', 717, 5, False, 0.477, 0.477, None],
#  ['BLOS', 718, 3, False, 0.3375, 1.4765, None],
#  ['BLOS', 721, 4, False, 0.913, 0.913, None],
#  ['BLOS', 722, 4, False, 0.4045, 0.4045, None],
#  ['BLOS', 723, 5, False, 1.43, 1.43, None],
#  ['BLOS', 724, 7, False, 0.974, 1.277, None],
#  ['BLOS', 725, 1, False, 0.22, 0.991, None],
#  ['BLOS', 726, 2, False, 0.966, 1.087, None],
#  ['BLOS', 728, 6, False, 0.0835, 0.779, None],
#  ['BLOS', 729, 4, False, 1.0875, 1.2725, None],
#  ['BLOS', 730, 6, False, 0.9625, 1.068, None],
#  ['BLOS', 732, 5, False, 0.127, 0.7225, None],
#  ['BLOS', 734, 8, False, 0.415, 0.748, None],
#  ['BLOS', 735, 5, False, 0.323, 0.7905, None],
#  ['BLOS', 737, 9, False, 1.0065, 1.0065, None],
#  ['BLOS', 738, 6, False, 1.3915, 1.663, None],
#  ['BLOS', 739, 3, False, 0.0635, 0.74, None],
#  ['BLOS', 740, 4, False, 1.101, 1.101, None],
#  ['BLOS', 742, 4, False, 0.936, 1.1825, None],
#  ['BLOS', 746, 3, False, 0.0225, 0.2115, None],
#  ['BLOS', 747, 4, False, 0.825, 0.8375, None],
#  ['BLOS', 748, 9, False, 0.7755, 0.7755, None],
#  ['BLOS', 749, 3, False, 0.6815, 0.775, None],
#  ['BLOS', 750, 0, False, 1.5545, 1.5545, None],
#  ['BLOS', 752, 2, False, 0.6915, 1.1115, None],
#  ['BLOS', 756, 5, False, 1.43, 1.4395, None],
#  ['BLOS', 757, 8, False, 0.416, 1.296, None],
#  ['BLOS', 758, 9, False, 0.4125, 1.365, None],
#  ['BLOS', 760, 6, False, 1.69, 1.69, None],
#  ['BLOS', 761, 6, False, 0.719, 0.719, None],
#  ['BLOS', 762, 9, False, 0.104, 1.8265, None],
#  ['BLOS', 763, 6, False, 0.2165, 0.2165, None],
#  ['BLOS', 764, 7, False, 0.4295, 0.776, None],
#  ['BLOS', 766, 5, False, 1.67, 1.67, None],
#  ['BLOS', 767, 2, False, 0.535, 0.535, None],
#  ['BLOS', 768, 7, False, 0.8055, 1.51, None],
#  ['BLOS', 769, 8, False, 1.735, 1.735, None],
#  ['BLOS', 770, 2, False, 0.8935, 0.9125, None],
#  ['BLOS', 771, 7, False, 1.876, 1.876, None],
#  ['BLOS', 773, 9, False, 0.9285, 0.9285, None],
#  ['BLOS', 774, 0, False, 0.3155, 1.5365, None],
#  ['BLOS', 775, 8, False, 0.575, 0.575, None],
#  ['BLOS', 776, 5, False, 0.1845, 0.733, None],
#  ['BLOS', 780, 7, False, 1.398, 1.398, None],
#  ['BLOS', 781, 5, False, 0.565, 0.565, None],
#  ['BLOS', 782, 2, False, 1.2275, 1.2275, None],
#  ['BLOS', 783, 5, False, 0.939, 1.2995, None],
#  ['BLOS', 784, 3, False, 0.6825, 0.9475, None],
#  ['BLOS', 785, 9, False, 0.215, 1.316, None],
#  ['BLOS', 787, 2, False, 0.238, 0.238, None],
#  ['BLOS', 790, 6, False, 1.04, 1.04, None],
#  ['BLOS', 791, 1, False, 0.105, 1.036, None],
#  ['BLOS', 794, 7, False, 0.0065, 0.916, None],
#  ['BLOS', 795, 4, False, 1.34, 1.34, None],
#  ['BLOS', 796, 3, False, 0.8475, 0.8475, None],
#  ['BLOS', 797, 2, False, 0.627, 0.627, None],
#  ['BLOS', 798, 5, False, 0.7135, 0.7135, None],
#  ['BLOS', 800, 8, False, 0.888, 1.0105, None],
#  ['BLOS', 801, 0, False, 0.2135, 0.9825, None],
#  ['BLOS', 802, 2, False, 0.6635, 0.6635, None],
#  ['BLOS', 804, 2, False, 0.0425, 0.2465, None],
#  ['BLOS', 807, 4, False, 0.5965, 0.6265, None],
#  ['BLOS', 808, 1, False, 0.79, 0.79, None],
#  ['BLOS', 809, 4, False, 0.4935, 0.9215, None],
#  ['BLOS', 811, 5, False, 0.038, 0.319, None],
#  ['BLOS', 813, 9, False, 0.816, 0.816, None],
#  ['BLOS', 814, 8, False, 0.5625, 0.756, None],
#  ['BLOS', 815, 2, False, 0.676, 1.0665, None],
#  ['BLOS', 817, 1, False, 0.6125, 1.131, None],
#  ['BLOS', 818, 4, False, 1.053, 1.053, None],
#  ['BLOS', 821, 4, False, 0.8615, 0.8615, None],
#  ['BLOS', 823, 7, False, 0.4815, 0.673, None],
#  ['BLOS', 824, 7, False, 0.234, 0.234, None],
#  ['BLOS', 825, 1, False, 0.3625, 0.654, None],
#  ['BLOS', 826, 0, False, 1.0855, 1.0855, None],
#  ['BLOS', 828, 9, False, 0.2025, 0.3925, None],
#  ['BLOS', 829, 6, False, 0.6785, 0.6785, None],
#  ['BLOS', 830, 0, False, 1.4065, 1.4065, None],
#  ['BLOS', 831, 6, False, 0.5055, 0.5055, None],
#  ['BLOS', 832, 8, False, 0.4715, 1.3625, None],
#  ['BLOS', 833, 8, False, 0.8505, 0.8505, None],
#  ['BLOS', 834, 5, False, 1.049, 1.409, None],
#  ['BLOS', 836, 3, False, 0.2925, 0.612, None],
#  ['BLOS', 837, 8, False, 1.2115, 1.2115, None],
#  ['BLOS', 838, 7, False, 1.269, 1.4055, None],
#  ['BLOS', 839, 8, False, 0.9175, 0.9175, None],
#  ['BLOS', 840, 0, False, 0.465, 0.465, None],
#  ['BLOS', 841, 7, False, 0.54, 0.877, None],
#  ['BLOS', 843, 4, False, 1.708, 1.787, None],
#  ['BLOS', 844, 9, False, 1.0625, 1.0625, None],
#  ['BLOS', 846, 8, False, 0.994, 0.994, None],
#  ['BLOS', 847, 3, False, 0.1845, 0.4685, None],
#  ['BLOS', 848, 0, False, 0.778, 0.778, None],
#  ['BLOS', 850, 3, False, 1.792, 1.792, None],
#  ['BLOS', 851, 9, False, 0.8795, 1.477, None],
#  ['BLOS', 852, 2, False, 0.616, 0.616, None],
#  ['BLOS', 856, 7, False, 0.831, 0.831, None],
#  ['BLOS', 857, 4, False, 1.1285, 1.1285, None],
#  ['BLOS', 859, 1, False, 0.273, 0.273, None],
#  ['BLOS', 861, 5, False, 0.0165, 0.525, None],
#  ['BLOS', 865, 3, False, 0.1935, 1.1775, None],
#  ['BLOS', 871, 4, False, 0.014, 1.768, None],
#  ['BLOS', 872, 8, False, 1.2295, 1.2295, None],
#  ['BLOS', 873, 3, False, 0.1875, 0.788, None],
#  ['BLOS', 877, 6, False, 1.1405, 1.395, None],
#  ['BLOS', 878, 1, False, 1.408, 1.4755, None],
#  ['BLOS', 879, 8, False, 1.627, 1.627, None],
#  ['BLOS', 880, 0, False, 0.8165, 0.8165, None],
#  ['BLOS', 881, 3, False, 0.752, 0.752, None],
#  ['BLOS', 882, 8, False, 1.093, 1.093, None],
#  ['BLOS', 883, 4, False, 0.524, 0.695, None],
#  ['BLOS', 886, 3, False, 0.7105, 0.807, None],
#  ['BLOS', 887, 1, False, 0.1225, 0.1225, None],
#  ['BLOS', 888, 3, False, 1.0435, 1.6285, None],
#  ['BLOS', 889, 4, False, 1.09, 1.09, None],
#  ['BLOS', 891, 7, False, 1.0105, 1.0105, None],
#  ['BLOS', 892, 7, False, 0.1275, 0.193, None],
#  ['BLOS', 897, 3, False, 0.309, 0.309, None],
#  ['BLOS', 898, 1, False, 1.367, 1.367, None],
#  ['BLOS', 899, 0, False, 0.085, 0.9315, None],
#  ['BLOS', 900, 5, False, 0.2805, 0.2805, None],
#  ['BLOS', 901, 4, False, 0.3005, 1.378, None],
#  ['BLOS', 902, 1, False, 1.1265, 1.15, None],
#  ['BLOS', 904, 8, False, 1.347, 1.347, None],
#  ['BLOS', 906, 7, False, 1.106, 1.106, None],
#  ['BLOS', 908, 5, False, 0.2945, 0.3095, None],
#  ['BLOS', 909, 6, False, 0.3535, 0.3535, None],
#  ['BLOS', 910, 6, False, 0.3385, 0.467, None],
#  ['BLOS', 911, 2, False, 0.511, 0.511, None],
#  ['BLOS', 912, 6, False, 0.5825, 1.016, None],
#  ['BLOS', 913, 9, False, 0.855, 0.962, None],
#  ['BLOS', 917, 0, False, 0.9725, 0.9725, None],
#  ['BLOS', 918, 7, False, 0.25, 0.578, None],
#  ['BLOS', 919, 6, False, 1.285, 1.458, None],
#  ['BLOS', 921, 0, False, 1.7935, 1.7935, None],
#  ['BLOS', 923, 9, False, 0.828, 0.828, None],
#  ['BLOS', 924, 6, False, 1.1135, 1.1135, None],
#  ['BLOS', 925, 4, False, 0.2325, 0.4935, None],
#  ['BLOS', 926, 4, False, 1.1365, 1.1365, None],
#  ['BLOS', 927, 5, False, 1.336, 1.336, None],
#  ['BLOS', 928, 8, False, 0.594, 0.594, None],
#  ['BLOS', 929, 9, False, 0.247, 0.352, None],
#  ['BLOS', 931, 3, False, 1.6415, 1.664, None],
#  ['BLOS', 932, 5, False, 0.341, 0.341, None],
#  ['BLOS', 933, 0, False, 1.884, 1.884, None],
#  ['BLOS', 934, 7, False, 1.0235, 1.0235, None],
#  ['BLOS', 936, 2, False, 0.1255, 0.5265, None],
#  ['BLOS', 937, 5, False, 0.768, 0.768, None],
#  ['BLOS', 938, 4, False, 0.0805, 0.437, None],
#  ['BLOS', 942, 4, False, 0.9485, 0.9515, None],
#  ['BLOS', 946, 5, False, 1.067, 1.1725, None],
#  ['BLOS', 947, 4, False, 0.201, 0.309, None],
#  ['BLOS', 949, 1, False, 0.325, 0.325, None],
#  ['BLOS', 951, 4, False, 0.469, 0.469, None],
#  ['BLOS', 954, 6, False, 0.254, 1.084, None],
#  ['BLOS', 955, 8, False, 0.726, 0.726, None],
#  ['BLOS', 958, 2, False, 0.408, 0.7265, None],
#  ['BLOS', 959, 6, False, 0.6135, 1.215, None],
#  ['BLOS', 961, 3, False, 0.4375, 0.711, None],
#  ['BLOS', 962, 9, False, 0.886, 0.886, None],
#  ['BLOS', 963, 2, False, 0.4415, 0.4415, None],
#  ['BLOS', 966, 6, False, 0.5415, 1.526, None],
#  ['BLOS', 967, 4, False, 0.2405, 0.989, None],
#  ['BLOS', 968, 6, False, 0.8835, 1.204, None],
#  ['BLOS', 971, 2, False, 0.787, 1.5025, None],
#  ['BLOS', 972, 0, False, 0.4775, 0.4775, None],
#  ['BLOS', 975, 0, False, 0.7695, 0.7695, None],
#  ['BLOS', 976, 3, False, 1.241, 1.241, None],
#  ['BLOS', 978, 2, False, 1.4785, 1.4785, None],
#  ['BLOS', 979, 7, False, 0.7475, 0.7475, None],
#  ['BLOS', 980, 1, False, 1.173, 1.7635, None],
#  ['BLOS', 981, 9, False, 0.713, 0.713, None],
#  ['BLOS', 982, 6, False, 1.0015, 1.0015, None],
#  ['BLOS', 985, 6, False, 0.9325, 0.9325, None],
#  ['BLOS', 987, 0, False, 1.088, 1.088, None],
#  ['BLOS', 988, 6, False, 0.002, 0.3965, None],
#  ['BLOS', 990, 7, False, 0.6905, 0.6905, None],
#  ['BLOS', 991, 7, False, 1.1485, 1.34, None],
#  ['BLOS', 992, 5, False, 1.0215, 1.0215, None],
#  ['BLOS', 993, 5, False, 0.3885, 0.8545, None],
#  ['BLOS', 995, 4, False, 0.2965, 0.8935, None],
#  ['BLOS', 996, 3, False, 0.071, 0.58, None],
#  ['BLOS', 997, 3, False, 1.4955, 1.4955, None],
#  ['BLOS', 999, 4, False, 1.1265, 1.1265, None],
#  ['BLOS', 1000, 7, False, 1.058, 1.7925, None],
#  ['BLOS', 1001, 0, False, 0.033, 0.5675, None]]

# %%
[auction.execute_round() for i in range(10000)]
# Out:
# [None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  ...]

# %%
auction.balances
# Out:
# {140276743991200: -1000.3605,
#  140276743990432: -1000.5714999999998,
#  140276743982816: -1000.3000000000001}

# %%
b1.bidding_round
# Out:
# 101

# %%
b1.bid_participate_history #bidderid, userid, bidding round, bid price
# Out:
# [[140467995445472, 5, 1, 2.633]]

# %%
b2.bid_participate_history #bidderid, userid, bidding round, bid price

# %%
b3.bid_participate_history #bidderid, userid, bidding round, bid price

# %%
[auction.execute_round() for i in range(10)]

# %%
b1, b2, b3 = Bidder(1,10), Bidder(1,10), Bidder(1,10)
auction = Auction( [User()], [b1, b2, b3])
auction.execute_round()

# %%
print('b1 bid is: ', b1.bid(0x7fb6581c8ca0))
print('b2 bid is: ', b2.bid(0x7fb6581c8ca0))
print('b3 bid is: ', b3.bid(0x7fb6581c8ca0))

# %%
u1 = User()
id(u1)

# %%
user_wins = {i: 0 for i in range(10)}
user_wins

# %%
bids_list = [(1,2), (7,8), (5,6),(3,4) ]

# %%
sorted_list = sorted(bids_list, key=lambda t:t[1])
sorted_list
# Out:
# [(1, 2), (3, 4), (5, 6), (7, 8)]

# %%
winning_price = (sorted_list)[-2][1]
winning_price
# Out:
# 6

# %%
winning_bid = (sorted_list)[-1][0]
winning_bid
# Out:
# 7

# %%
list2 = [(1,2)]
sorted_list = sorted(list2, key=lambda t:t[1])
sorted_list
# Out:
# [(1, 2)]

# %%
winning_price = (sorted_list)[0][-1]

# %%
winning_price
# Out:
# 2

# %%
winning_bid = (sorted_list)[0][0]
winning_bid
# Out:
# 1
