# %% [markdown]
# # Sorting DataFrames

# %%
import sys
print(sys.version)
import numpy as np
print(np.__version__)
import pandas as pd
print(pd.__version__)
import matplotlib.pyplot as plt

# %matplotlib inline
# Out:
# 3.9.12 (main, Apr  5 2022, 01:53:17)
# [Clang 12.0.0 ]
# 1.21.5
# 1.4.2

# %% [markdown]
# # retrieve csv file

# %%
gradebook = pd.read_csv('gradebook_v2.csv')
gradebook
# Out:
#   student  midterm  final letter_grade
# 0     Ben     88.0   90.0            B
# 1     May     78.0   87.0            B
# 2     Sue     92.0   64.0            C
# 3   Blake     56.0   90.0            C
# 4     Amy     79.0    NaN            C
# 5   Steve      NaN   84.0            B

# %%
# remember the issue with the index (student was earlier)

# %%
gradebook = pd.read_csv('gradebook_v2.csv', index_col = 0)
gradebook
# Out:
#          midterm  final letter_grade
# student
# Ben         88.0   90.0            B
# May         78.0   87.0            B
# Sue         92.0   64.0            C
# Blake       56.0   90.0            C
# Amy         79.0    NaN            C
# Steve        NaN   84.0            B

# %%
# RECALL WE HAD APPLIED A DIFFERERT METHOD TO MAKE SRUDENT THE INDEX (refer last notebook)

# %% [markdown]
# ---

# %%
gradebook.sort_index()
# Out:
#          midterm  final letter_grade
# student
# Amy         79.0    NaN            C
# Ben         88.0   90.0            B
# Blake       56.0   90.0            C
# May         78.0   87.0            B
# Steve        NaN   84.0            B
# Sue         92.0   64.0            C

# %%
gradebook = gradebook.sort_index()

# %%
gradebook
# Out:
#          midterm  final letter_grade
# student
# Amy         79.0    NaN            C
# Ben         88.0   90.0            B
# Blake       56.0   90.0            C
# May         78.0   87.0            B
# Steve        NaN   84.0            B
# Sue         92.0   64.0            C

# %%
# sorting over variables

# %%
gradebook.sort_values('midterm')
# Out:
#          midterm  final letter_grade
# student
# Blake       56.0   90.0            C
# May         78.0   87.0            B
# Amy         79.0    NaN            C
# Ben         88.0   90.0            B
# Sue         92.0   64.0            C
# Steve        NaN   84.0            B

# %%
#### notice missing values gets moved to the bottom

# %%
gradebook.sort_values('midterm', ascending = False)
# Out:
#          midterm  final letter_grade
# student
# Sue         92.0   64.0            C
# Ben         88.0   90.0            B
# Amy         79.0    NaN            C
# May         78.0   87.0            B
# Blake       56.0   90.0            C
# Steve        NaN   84.0            B

# %%
### this moves the highest to teh top

# %% [markdown]
# ---

# %% [markdown]
# ## sorting by different columns

# %%
gradebook.sort_values(['final', 'midterm'], ascending = False)
# Out:
#          midterm  final letter_grade
# student
# Ben         88.0   90.0            B
# Blake       56.0   90.0            C
# May         78.0   87.0            B
# Steve        NaN   84.0            B
# Sue         92.0   64.0            C
# Amy         79.0    NaN            C

# %%
## sort firstby final and them by midterm
