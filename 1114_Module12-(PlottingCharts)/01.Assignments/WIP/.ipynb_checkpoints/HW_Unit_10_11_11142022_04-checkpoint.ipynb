# %% [markdown]
# ## Week 10 and 11 Assignment - DATASCI200 Introduction to Data Science Programming, UC Berkeley MIDS
#
# Write code in this Jupyter Notebook to solve the following problems. Please upload this **Notebook** with your solutions to your GitHub repository and provide a link in the last question in gradescope.
#
# Assignment due date: 11:59PM PT the night before the Week 12 Live Session. Do **NOT** push/upload the data file.

# %% [markdown]
# ## Objectives
#
# - Explore and glean insights from a real dataset using pandas
# - Practice using pandas for exploratory analysis, information gathering, and discovery
# - Practice cleaning data and answering questions

# %% [markdown]
# ## General Guidelines:
#
# - This is a **real** dataset and so it may contain errors and other pecularities to work through
# - This dataset is ~218mb, which will take some time to load (and probably won't load in Google Sheets or Excel)
# - If you make assumptions, annotate them in your responses
# - While there is one code/markdown cell positioned after each question as a placeholder, some of your code/responses may require multiple cells
# - Double-click the markdown cells that say for example **1a answer here:** to enter your written answers. If you need more cells for your written answers, make them markdown cells (rather than code cells)
# - This homework assignment is not autograded because of the variety of responses one could give.
#   - Please upload this notebook to the autograder page and the TAs will manually grade it.
#   - Ensure that each cell is run and outputs your answer for ease of grading!
#   - Highly suggest to do a `restart & run all` before uploading your code to ensure everything runs and outputs correctly.
#   - Answers without code (or code that runs) will be given 0 points.
# - **This is meant to simulate real world data so you will have to do some external research to determine what some of the answers are!**

# %% [markdown]
# ## Dataset
#
# You are to analyze campaign contributions to the 2016 U.S. presidential primary races made in California. Use the csv file located here: https://drive.google.com/file/d/1Lgg-PwXQ6TQLDowd6XyBxZw5g1NGWPjB/view?usp=sharing. You should download and save this file in the same folder as this notebook is stored.  This file originally came from the U.S. Federal Election Commission (https://www.fec.gov/).
#
# **DO NOT PUSH THIS FILE TO YOUR GITHUB REPO!**
#
# - Best practice is to not have DATA files in your code repo. As shown below, the default load is outside of the folder this notebook is in. If you change the folder where the file is stored please update the first cell!
# - If you do accidentally push the file to your github repo - follow the directions here to fix it: https://docs.google.com/document/d/15Irgb5V5G7pKPWgAerH7FPMpKeQRunbNflaW-hR2hTA/edit?usp=sharing
#
# Documentation for this data can be found here: https://drive.google.com/file/d/11o_SByceenv0NgNMstM-dxC1jL7I9fHL/view?usp=sharing

# %% [markdown]
# ## Data Questions
#
# You are working for a California state-wide election campaign. Your boss wants you to examine historic 2016 election contribution data to see what zipcodes are more supportive of fundraising for your candidate.
#
# Your boss asks you to filter out some of the records:
# - Only use primary 2016 contribution data (more like how your race is).
# - Concentrate on Bernie Sanders as a candidate (most a like your candidate)
#
# The questions your boss wants answered is:
# - Which zipcode (5-digit zipcode) had the highest count of contributions and the most dollar amount?
# - What day(s) of the month do most people donate?

# %% [markdown]
# ## Setup
#
# Run the cell below as it will load the data into a pandas dataframe named `contrib`. Note that a custom date parser is defined to speed up loading. If Python were to guess the date format, it would take even longer to load.

# %%
import pandas as pd
import numpy as np
from datetime import datetime

# These commands below set some options for pandas and to have matplotlib show the charts in the notebook
pd.set_option('display.max_rows', 1000)
pd.options.display.float_format = '{:,.2f}'.format

# Define a date parser to pass to read_csv
d = lambda x: datetime.strptime(x, '%d-%b-%y')

# Load the data
# We have this defaulted to the folder OUTSIDE of your repo - please change it as needed
contrib = pd.read_csv('P00000001-CA.csv', index_col=False, parse_dates=['contb_receipt_dt'], date_parser=d)

# Note - for now, it is okay to ignore the warning about mixed types.
# Out:
# /var/folders/_5/mw87wr4s5p902pvj5xm4sqnw0000gn/T/ipykernel_7984/2050583822.py:14: DtypeWarning: Columns (6,11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   contrib = pd.read_csv('P00000001-CA.csv', index_col=False, parse_dates=['contb_receipt_dt'], date_parser=d)

# %% [markdown]
# ***
# ## 1. Initial Data Checks (50 points)
#
# First we will take a preliminary look at the data to check that it was loaded correctly and contains the info we need.
#
# The questions to answer at the end of this section:
# - Do we have the correct # of columns and rows.
# - Do the records contain data for the questions we want to answer
# - What columns are important?
# - What columns can be dropped?
# - What are the data problems?

# %% [markdown]
# **1a.** Print the *shape* of the data. Does this match the expectation? (2 points)

# %%
# 1a YOUR CODE HERE

# contrib.head(-10)

contrib.shape
# Out:
# (1125659, 18)

# %% [markdown]
# - **1a answer here:**
#
# The shape matches expectations. I used contrib.head(-10) to get a list of the last 10 rows and see that that last row is 1125659 and the count of columns is 18

# %% [markdown]
# **1b.** Print a list of column names. Are all the columns included that are in the documentation? (2 points)

# %%
# 1b YOUR CODE HERE

contrib.columns
# Out:
# Index(['cmte_id', 'cand_id', 'cand_nm', 'contbr_nm', 'contbr_city',
#        'contbr_st', 'contbr_zip', 'contbr_employer', 'contbr_occupation',
#        'contb_receipt_amt', 'contb_receipt_dt', 'receipt_desc', 'memo_cd',
#        'memo_text', 'form_tp', 'file_num', 'tran_id', 'election_tp'],
#       dtype='object')

# %% [markdown]
# - **1b answer here:**
#
# I can't say for sure if the 18 columsns are precisely what was in the documentation as I could not find a single bulk file with the 18 fields. However, I reviewed several files (like those listed below) and reason to believe that the data is complete as it has been blended from multiple sources and the relevant information needed to answer the question is contained.
#
# https://www.fec.gov/data/browse-data/?tab=bulk-data
#
# https://www.fec.gov/campaign-finance-data/candidate-committee-linkage-file-description/
#
# https://www.fec.gov/campaign-finance-data/all-candidates-file-description/
#
# https://www.fec.gov/campaign-finance-data/committee-master-file-description/
#
# https://www.fec.gov/campaign-finance-data/contributions-committees-candidates-file-description/

# %% [markdown]
# **1c** Print out the first five rows of the dataset. How do the columns `cand_id`, `cand_nm` and `contbr_st` look? (3 points)

# %%
# 1c YOUR CODE HERE
contrib.head()
# Out:
#      cmte_id    cand_id                  cand_nm          contbr_nm  \
# 0  C00575795  P00003392  Clinton, Hillary Rodham         AULL, ANNE
# 1  C00575795  P00003392  Clinton, Hillary Rodham  CARROLL, MARYJEAN
# 2  C00575795  P00003392  Clinton, Hillary Rodham   GANDARA, DESIREE
# 3  C00577130  P60007168         Sanders, Bernard          LEE, ALAN
# 4  C00577130  P60007168         Sanders, Bernard   LEONELLI, ODETTE
#
#      contbr_city contbr_st     contbr_zip            contbr_employer  \
# 0       LARKSPUR        CA 949,391,913.00                        NaN
# 1        CAMBRIA        CA 934,284,638.00                        NaN
# 2        FONTANA        CA 923,371,507.00                        NaN
# 3      CAMARILLO        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS
# 4  REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
#
#    contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 0            RETIRED              50.00       2016-04-26          NaN       X
# 1            RETIRED             200.00       2016-04-20          NaN       X
# 2            RETIRED               5.00       2016-04-02          NaN       X
# 3  SOFTWARE ENGINEER              40.00       2016-03-04          NaN     NaN
# 4         PHARMACIST              35.00       2016-03-05          NaN     NaN
#
#                              memo_text form_tp  file_num      tran_id  \
# 0               * HILLARY VICTORY FUND    SA18   1091718     C4768722
# 1               * HILLARY VICTORY FUND    SA18   1091718     C4747242
# 2               * HILLARY VICTORY FUND    SA18   1091718     C4666603
# 3  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKWA097
# 4  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKX3MB3
#
#   election_tp
# 0       P2016
# 1       P2016
# 2       P2016
# 3       P2016
# 4       P2016

# %% [markdown]
# - **1c answer here:**
#
# The 4 fields are cand_id (ie candidate id) which is a alphanumeric type. The cand_nm (ie candidate name) is alphabetic (unless we have a name like X Æ A-Xii, thanks to Elon).
#
# The contbd_st (constribution state) is a 2 digid alphabet (caps) that stands for CA (as this data is limited to california)

# %% [markdown]
# **1d.** Print out the values for the column `election_tp`. In your own words, based on the documentation, what information does the `election_tp` variable contain? Do the values in the column match the documentation? (3 points)

# %%
# 1d YOUR CODE HERE

contrib.election_tp.unique()
# Out:
# array(['P2016', 'G2016', nan, 'P2020'], dtype=object)

# %% [markdown]
# - **1d answer here:**
#
# I see 4 valuesP2016, G2016, P2020 and a nan). I can infer that we have two anomolies here (asusming that P2020 refers to campaign finance data for CY 2020). Also, the nan values have to be fixed as well

# %% [markdown]
# **1e.** Print out the datatypes for all of the columns. What are the datatypes for the `contbr_zip`, `contb_receipt_amt`, `contb_receipt_dt`? (5 points)

# %%
# 1e YOUR CODE HERE

#type(contrib)

contrib.info()

#contrib.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1125659 entries, 0 to 1125658
# Data columns (total 18 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   cmte_id            1125659 non-null  object
#  1   cand_id            1125659 non-null  object
#  2   cand_nm            1125659 non-null  object
#  3   contbr_nm          1125659 non-null  object
#  4   contbr_city        1125633 non-null  object
#  5   contbr_st          1125659 non-null  object
#  6   contbr_zip         1125564 non-null  object
#  7   contbr_employer    967757 non-null   object
#  8   contbr_occupation  1115260 non-null  object
#  9   contb_receipt_amt  1125659 non-null  float64
#  10  contb_receipt_dt   1125659 non-null  datetime64[ns]
#  11  receipt_desc       15045 non-null    object
#  12  memo_cd            144268 non-null   object
#  13  memo_text          501148 non-null   object
#  14  form_tp            1125659 non-null  object
#  15  file_num           1125659 non-null  int64
#  16  tran_id            1125659 non-null  object
#  17  election_tp        1124234 non-null  object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(15)
# memory usage: 154.6+ MB

# %% [markdown]
# - **1e answer here:**
#
# * contbr_zip : object
# * contb_receipt_amt : float64
# * contb_receipt_dt: datetime64[ns]

# %% [markdown]
# **1f.** What columns have the most non-nulls?  Would you recommend to drop any columns based on the number of nulls? (5 points)

# %%
# 1f YOUR CODE HERE
#contrib.info()
#contrib.isnull().sum(axis = 0)

# to get the column with the least non-null values
#contrib.count().idxmin()

# to get the column with the most non-null values
contrib.count().idxmax()
# Out:
# 'cmte_id'

# %% [markdown]
# - **1f answer here:**
#
# I am using multiple queries here -- starting with contrib.info() which gives me the detailed listing (refer 1g). I just validated if I am on the right track with query contrib.count().idxmax()
#
# The max count (for non-null values) is 1125659 and there are a number of columns have the most non-null values. In order they are
# * 0   cmte_id            1125659 non-null  object
# * 1   cand_id            1125659 non-null  object
# * 2   cand_nm            1125659 non-null  object
# * 3   contbr_nm          1125659 non-null  object
# * 5   contbr_st          1125659 non-null  object
# * 9   contb_receipt_amt  1125659 non-null  float64
# * 10  contb_receipt_dt   1125659 non-null  datetime64[ns]
# * 14  form_tp            1125659 non-null  object
# * 15  file_num           1125659 non-null  int64
# * 16  tran_id            1125659 non-null  object
#
# receipt_desc has the least number of non-null values (15045), implying there are 1110614, or ~ 99% of values are null. This is a candidate to be removed
#
# I would also consider the following two columns for removal as well as they don't seem relevant to the basic question and have a ton of null values
#
# Percentage of non-null values:
#
# * memo_cd: 87%
# * memo_text: 55%

# %% [markdown]
# **1g.** A column we know that we want to use is the cand_nm column.  From the documentation each candidate is a unique candidate id also. Check data quality of `cand_id` column to see if it matches `cand_nm` column. Specifically check to ensure our targetted candidate 'Bernard Sanders' always has the same cand_id throughout. Any issues with `cand_nm` matching `cand_id`? (5 points)

# %%
# 1g YOUR CODE HERE
# contrib.loc[contrib['cand_nm'] == 'Sanders, Bernard']

# this gives me a list of all records for Bernie
df1 = contrib.loc[contrib['cand_nm'].str.contains('Sanders, Bernard')]
# df1

# this is a lsit of all bernie records in California

df2 = df1.loc[df1['contbr_st']=='CA']
#df2

# get a list of all candidate ids for bernie in california
df2['cand_id'].unique()
# Out:
# array(['P60007168'], dtype=object)

# %% [markdown]
# - **1g answer here:**
#
# appears that bernie has candidate id of 'P60007168' throughout the CA dataset. No problem

# %% [markdown]
# **1h.** Another area to check is to make sure all of the records are from California. Check the `contbr_st` column - are there any records outside of California based on `contbr_st`? (5 points)

# %%
# 1h YOUR CODE HERE
contrib['contbr_st'].unique()
# Out:
# array(['CA'], dtype=object)

# %% [markdown]
# - **1h answer here:**
#
# it appears that all the records are from california

# %% [markdown]
# **1i.** The next column to check for the analysis is the `tran_id` column. This column could be the primary key so look for duplicates. How many duplicate entries are there? Any pattern for why are there duplicate entries? (5 points)

# %%
# 1i YOUR CODE HERE

# pd.concat(x for _, x in contrib.groupby("tran_id") if len(x) > 1).head(10)

df_dupes = pd.concat(x for _, x in contrib.groupby("tran_id") if len(x) > 1)

len(df_dupes.index)

#df_dupes['cand_nm'].unique()

#df_dupes.head()
# Out:
# 6873

# %% [markdown]
# - **1i answer here:**
#
# * yes, there are several duplicate entries (6873 to be precise)
# * The interesting coincidence is that they seem to occur in 3's!
# * There are others where the duplicates are in 2's where the only variable seems to be where the
# * -- contbr_occupation is 'Information Requested'
#
# * These also are cases where the contributor zip code is incorrect.
#
# * There are other variations but these are the primary ones

# %% [markdown]
# ---

# %% [markdown]
# **1j.** Another column to check is the `contb_receipt_amt` that shows the donation amounts. How many negative donations are included? What do negative donations mean? Please show at least pull a few rows to look at the records with negative donations. Do these records match with the expectation of why a negative donation would happen? (5 points)

# %%
# 1j YOUR CODE HERE

#contrib.info()
# contrib[contrib<0]
#contrib['contb_receipt_amt'] < 0

# contrib2 = contrib[contrib['contb_receipt_amt'] < 0]
# contrib2
#contrib2['memo_text'].unique()
#--------------------------------------------------------------
# ALL NEGATIVE CONTRIBUTIONS
contrib_neg = contrib[contrib['contb_receipt_amt'] < 0]
#contrib[contrib['contb_receipt_amt'] < 0].count()

neg_contributions = contrib_neg['contb_receipt_amt'].count()

print('the total number of negative contributions are :', neg_contributions)

contrib_neg[:10]
# Out:
# the total number of negative contributions are : 11896
#        cmte_id    cand_id                    cand_nm           contbr_nm  \
# 19   C00574624  P60006111  Cruz, Rafael Edward 'Ted'    JOLLIFF, RICHARD
# 23   C00574624  P60006111  Cruz, Rafael Edward 'Ted'    JOLLIFF, RICHARD
# 81   C00574624  P60006111  Cruz, Rafael Edward 'Ted'    JOLLIFF, RICHARD
# 190  C00574624  P60006111  Cruz, Rafael Edward 'Ted'    NOWELL, DIANA L.
# 213  C00574624  P60006111  Cruz, Rafael Edward 'Ted'  LICHTY, ANDREW MR.
# 220  C00574624  P60006111  Cruz, Rafael Edward 'Ted'  LICHTY, ANDREW MR.
# 223  C00574624  P60006111  Cruz, Rafael Edward 'Ted'  LICHTY, ANDREW MR.
# 231  C00574624  P60006111  Cruz, Rafael Edward 'Ted'  LICHTY, ANDREW MR.
# 261  C00574624  P60006111  Cruz, Rafael Edward 'Ted'    NOWELL, DIANA L.
# 307  C00574624  P60006111  Cruz, Rafael Edward 'Ted'  LICHTY, ANDREW MR.
#
#                 contbr_city contbr_st     contbr_zip  \
# 19                    CHICO        CA 959,289,507.00
# 23                    CHICO        CA 959,289,507.00
# 81                    CHICO        CA 959,289,507.00
# 190  RANCHO SANTA MARGARITA        CA 926,884,928.00
# 213               SAN DIEGO        CA 921,096,720.00
# 220               SAN DIEGO        CA 921,096,720.00
# 223               SAN DIEGO        CA 921,096,720.00
# 231               SAN DIEGO        CA 921,096,720.00
# 261  RANCHO SANTA MARGARITA        CA 926,884,928.00
# 307               SAN DIEGO        CA 921,096,720.00
#
#                         contbr_employer     contbr_occupation  \
# 19                        SELF EMPLOYED               RANCHER
# 23                        SELF EMPLOYED               RANCHER
# 81                        SELF EMPLOYED               RANCHER
# 190  CAPISTRAND UNIFIED SCHOOL DISTRICT  LIBRARIAN TECHNICIAN
# 213                       SELF EMPLOYED           REAL ESTATE
# 220                       SELF EMPLOYED           REAL ESTATE
# 223                       SELF EMPLOYED           REAL ESTATE
# 231                       SELF EMPLOYED           REAL ESTATE
# 261  CAPISTRAND UNIFIED SCHOOL DISTRICT  LIBRARIAN TECHNICIAN
# 307                       SELF EMPLOYED           REAL ESTATE
#
#      contb_receipt_amt contb_receipt_dt              receipt_desc memo_cd  \
# 19              -25.00       2016-04-29  REDESIGNATION TO GENERAL       X
# 23             -150.00       2016-04-29  REDESIGNATION TO GENERAL       X
# 81              -60.00       2016-04-14  REDESIGNATION TO GENERAL       X
# 190            -100.00       2016-04-11  REDESIGNATION TO GENERAL       X
# 213             -25.00       2016-04-30  REDESIGNATION TO GENERAL       X
# 220             -25.00       2016-04-30  REDESIGNATION TO GENERAL       X
# 223             -50.00       2016-04-30  REDESIGNATION TO GENERAL       X
# 231             -50.00       2016-04-30  REDESIGNATION TO GENERAL       X
# 261            -150.00       2016-04-11  REDESIGNATION TO GENERAL       X
# 307             -50.00       2016-04-30  REDESIGNATION TO GENERAL       X
#
#                     memo_text form_tp  file_num         tran_id election_tp
# 19   REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826482B       P2016
# 23   REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826483B       P2016
# 81   REDESIGNATION TO GENERAL   SA17A   1077664   SA17A.1827494       P2016
# 190  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1639830B       P2016
# 213  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826888B       P2016
# 220  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826894B       P2016
# 223  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826895B       P2016
# 231  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826886B       P2016
# 261  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1639829B       P2016
# 307  REDESIGNATION TO GENERAL   SA17A   1077664  SA17A.1826889B       P2016

# %% [markdown]
# - **1j answer here:**
#
# NOTE: The question does not specify if the scope is for P2016 only. I have analyzed the full dataset unless the questions specifically states, 2016 primary season
#
# * total number of negative values = 1113763
#
# * total number of positive values = 11896
#
# * sum of counts of negative and positive values = 1125659 (which is the total number of records)
#
# * about 1% of thse records have a +ve contb_receipt_amt value
#
# * it appears that the -ve values are driven by the fact that this is an accounting transaction where these amounnts are moved to a different account. You can see this by the 'receipt_desc' as 'REDESIGNATION TO GENERAL' or other reasons like 'REATTRIBUTION TO SPOUSE'. The full list of these account related charges are shown below
#
# 'REDESIGNATION TO GENERAL', nan, '* HILLARY VICTORY FUND',
#        'REATTRIBUTION TO SPOUSE', 'CHARGED BACK',
#        'REDESIGNATION TO PRESIDENTIAL GENERAL',
#        'TRANSFER FROM RUBIO VICTORY',
#        '2016 SENATE PRIMARY DONOR REDESIGNATION TO GENERAL',
#        'REDESIGNATION FROM PRIMARY',
#        'US CITIZEN REDESIGNATION TO GENERAL',
#        'REDESIGNATION TO CRUZ FOR SENATE',
#        '* REATTRIBUTED TO JOHN CASTOR', 'NSF/RETURNED CHECK',
#        '* REATTRIBUTED TO FRANK DARABONT',
#        'REFUND TO BE ISSUED; REDESIGNATION TO GENERAL',
#        'REFUND TO BE ISSUED; CHARGED BACK',
#        'REATTRIBUTION TO SPOUSE; SEE REDESIGNATION',
#        'CHECK RETURNED BY BANK', 'OVERPAYMENT', '*BEST EFFORTS UPDATE',
#        '* REATTRIBUTED TO CHRISTINE MARSHALL',
#        '* REATTRIBUTED TO CAROL FITZMORRIS',
#        '* REATTRIBUTED TO ERIC UHRANE', '* REATTRIBUTED TO YEU-WEI YEE',
#        '* REATTRIBUTED TO NORAH STONE', '* REATTRIBUTED FROM KIM RIDDER',
#        'INSUFFICIENT FUNDS', 'REDESIGNATION TO PRIMARY',
#        'REATTRIBUTION TO SPOUSE, TERRIE SCHULTZ.',
#        '* HILLARY ACTION FUND', 'VOIDED 9/16/16', '2016 SENATE GENERAL',
#        '* REATTRIBUTION TO SPOUSE, TERRIE SCHULTZ.', 'REISSUED ON 6/21',
#        'CHARGEBACK REVERSAL', 'REATTRIBUTION TO SPOUSE, HARRY HICKS.',
#        'REATTRIBUTION/REDESIGNATION REQUESTED REDESIGNATION TO GENERAL',
#        '* REATTRIBUTED TO ELIZABETH DOYLE',
#        '* REATTRIBUTED TO PRUDENCE MOORE',
#        '* REATTRIBUTED TO AISHA LYNCH',
#        '* REATTRIBUTED TO SHEILA NEWBERRY',
#        '* REATTRIBUTED TO JESSIKA CROIZAT',
#        '* REATTRIBUTED TO JUDITH HAYNIE'], dtype=object)

# %% [markdown]
# ---

# %% [markdown]
# **1k.** One more column to look at is the date of donation column. Are there any dates outside of the primary period (defined as 1 Jan 2014 to 7 June 2016)? Are the dates well-formatted for our analysis? (5 points)

# %%
# 1k YOUR CODE HERE

# contrib['election_tp'].unique()

# 1 first exclose the 2016 general as well as 2020 data
contrib_p2016 = contrib[contrib['election_tp'] == 'P2016']
contrib_p2016

# 2 select records based on the data parameters

# inscope = contrib[(contrib['contb_receipt_dt'] >= '2014-01-01')  & (contrib['contb_receipt_dt'] <= '2016-6-7')]

# inscope

inscope_p2016 = contrib_p2016[(contrib_p2016['contb_receipt_dt'] >= '2014-01-01')  & \
                       (contrib_p2016['contb_receipt_dt'] <= '2016-06-07')]

#inscope_p2016

# 3 count of records in scope
len(inscope_p2016.index)
# 668864
p2016_valid = len(inscope_p2016.index)


# 4 count of records out of scope (from full dataframe)
#len(contrib.index)
# 1125659
contrib_full = len(contrib.index)

# 5 count of records of only the P2016 primary
#len(contrib_p2016.index)
# 810481
p2016_all = len(contrib_p2016.index)

# 6 calculate the invalid records

print("invalid records in 2016 primary onlyis : ", p2016_all - p2016_valid)
#print("invalid records in 2016 primary onlyis : ", p2016_all - p2016_valid)
# I realize that the second comparion (with contrib_full) is not valid and will stick to the printed output as below
# Out:
# invalid records in 2016 primary onlyis :  141617

# %% [markdown]
# - **1k answer here:**
# * first, isolcate the records in the contrib df to only those for the primary campaign 2016. I see the file contains data from 3 cycles ['P2016', 'G2016', nan, 'P2020']. So, we need to exclude the others first.
#
# * the date of the donation is the field 'receipt_dt'
# * as you can see from above, I have taken 5 steps (admittedly this can be done in a single line, but that would be
#   hard to interpret as yet)
# * I first calculate the number of inscope rows (from the already narrowed df of contrib_p2016)
# * I then compare that with the full list of rows in the p2016 section
# * the final answer is 141617 records that are outside the date range

# %% [markdown]
# ---

# %% [markdown]
# **1l.** Finally, answer the initial questions in the cells below (5 points)

# %% [markdown]
# **1l.1** Do we have the correct # of columns and rows.
#
# - **1l.1 answer here:**
#
# Not sure what this exactly means. If by 'correct', you mean 'adequate', the answer is yes we do have the adequate data in order to answer the two questions. Having 407172 records for Bernie is a good enouigh sample size for us to work with. It also shows that Bernie got 36% of all contributions, which is pretty cool.
#
# bernie = len(contrib[contrib['cand_nm'].str.contains('Sanders, Bernard')].index)
# total = len(contrib.index)
# print(bernie/total)

# %% [markdown]
# **1l.2** Do the records contain data for the questions we want to answer?
#
# - **1l.2 answer here:**
#
# The two primary questions are about the most supportive zip code (5 digit) and the days of the month are people most likely to donate. However we have a problem
#
# The zipcode field is not really 5 digits -- it is more like the expanded 9 digit format. Infact, only 2% of the records are 5 digits and the rest are greater than 5. More research needs to be done for the > 5 digit data and clean it, which could be as simply as taking just the first 5 digits and ignoring the rest.
#
# ------------------------ query used ------------------------
# The query I used was
# zip_greater_5 = len(contrib[contrib['contbr_zip'].str.len() > 5].index)
# zip_5 = len(contrib[contrib['contbr_zip'].str.len() == 5].index)
#
# print(zip_5/zip_greater_5)
#
# Coming to the dates, it appears that all records are of length 10, which is good. This means, we don't have records less than 10 or greater than 10. However, further research needs to be done if the order (yyyy-mm-dd) is consistent across all records
#
# ------------------------ query used ------------------------
# date_string = contrib['contb_receipt_dt'].astype('str')
# date_string_10 = date_string.str.len() == 10
# date_string_10.value_counts()
# #type(date_string_10)
# #len(date_string_10)
# date_string_less_10 = date_string.str.len() < 10
# date_string_less_10.value_counts()
# date_string_greater_10 = date_string.str.len() > 10

# %% [markdown]
# **1l.3** What columns are important?
#
# - **1l.3 answer here:**
#
# The two questions are (1) Which zipcode (5-digit zipcode) had the highest count of contributions and the most dollar amount? and (2) What day(s) of the month do most people donate?
#
# to answer these 2 questions, the following 5 fields are most relevant
#
# --- filter first ---
# * cand_nm (filtered for only Bernie)
# * election_to (filtered for only P2016)
#
# --- key data -----
# * contr_zip
# * contb_receipt_amt
# * contb_receipt_dt

# %% [markdown]
# **1l.4** What columns can be dropped?
#
# - **1l.4 answer here:**
#
# The following columns can be dropped
#
# * cmte_id'
# * 'contbr_nm',
# * 'contbr_city',
# * 'contbr_st',
# * 'contbr_employer',
# * 'contbr_occupation',
# * 'form_tp',
# * 'file_num',
# * 'tran_id',
#
# While not entirely relevant to the question, I would like to retain the following fields as they help clarify accounting discrepencies
# * 'receipt_desc',
# * 'memo_cd',
# * 'memo_text',

# %% [markdown]
# **1l.5** What are the data problems?
#
# - **1l.5 answer here:**
#
# There are several data problems, but the primary one being the following
# * -ve receipt amounts
# * duplicate records (which in cases is tired to the -ve receipt amounts as they are accounting transfers / corrections)
#
# Some minor data issues include
# * receipt_desc is NaN
# * memo_cd contains irrelevant / incorrect / Nan
#
# On a side note, I was concerned if the candidate name was missplet in the data, but no. I valided this with the query
#
# * bernie_all = contrib[contrib['cand_nm'].str.contains('Bern')]
# * bernie_all['cand_nm'].unique()

# %% [markdown]
# **1l.6** List any assumptions so far:
#
# - **1l.6 answer here:**
#
# * All the contribtions are from either american citizens or those resident here. Foreign contributions are excluded
# * All contributions were done legally and following campaign contribution guidelines
# * Individual contributions are only done up to the max allowed ($1000 per candidate per election)
# * Contributions are limited to only those for a candidate. Contribution to Super-PACs or political parties is excluded.
# * Fields like receipt_desc have many null values. This is concerning but assumed to be benign
# * Memo_cd in particular has many null or irrelevant values. This is also assumed to be benigh
# * All contributions are in US dollars
# * Tran_id has multiple formats, which perhaps means it originated from multiple places. Assumption here that this value is benign and does not influence the outcome of the analysis

# %% [markdown]
# ***
# ## 2. Data filtering and data quality fixes (30 points)
#
# Now that we have a basic understanding of the data, let's filter out the records we don't need and fix the data.

# %% [markdown]
# **2a.** From the dataset filter out (remove) any election_tp not in the primary election. Print/show the shape of the dataframe after the filtering is complete. (5 points)

# %%
# 2a YOUR CODE HERE

contrib_p2016 = contrib[contrib['election_tp'] == 'P2016']

contrib_shape = contrib_p2016.shape
print('Contribution shape after filtering only for 2016 CA primary is :', contrib_shape)
#print(contrib_p2016.shape())
#contrib_p2016
# Out:
# Contribution shape after filtering only for 2016 CA primary is : (810481, 18)

# %% [markdown]
# ---

# %% [markdown]
# **2b.** From the dataset filter out (remove) any candidate that is not Bernie Sanders. Print/show the shape of the dataframe after the filtering is complete. (5 points)

# %%
# 2b YOUR CODE HERE

## assumption -- I am assuming 2a as sequential to 2b adn beyond. for example, this means that the analysis
## is limited to 2016 primary elections only


# start by confirming all of bernie records
#bernie_all = contrib[contrib['cand_nm'].str.contains('Bern')]

bernie_2016p = contrib_p2016[contrib_p2016['cand_nm'].str.contains('Bern')]

# I chose a .contains('Bern') in order to check if there are records with the name misspelt
#bernie_2016p['cand_nm'].unique()
# the outcome from this confirms there is just one candidate record for 'Sanders, Bernard'
#bernie

# print shape of bernie only records for P2016

print('Shape of Bernie-only data for 2016 CA Primaries is ', bernie_2016p.shape)
# Out:
# Shape of Bernie-only data for 2016 CA Primaries is  (407171, 18)

# %% [markdown]
# **2c.** The `contbr_zip` column is not formatted well for our analysis. Make a new zipcode column that is the five-digit zipcodes. Filter out any records outside of California based on the zipcode. Print/show the shape of the dataframe after the filtering is complete. (10 points).
#
# - You will have to research what the valid 5-digit zipcodes for California are!

# %% [markdown]
# ---

# %%
# 2c YOUR CODE HERE

bernie_2016p['contbr_zip']# > 1000
#new_zip['zip'] = contrib[contrib['contbr_zip']]# == '959,289,507.00']
# Out:
# 3         930,111,214.00
# 4         902,784,310.00
# 5         902,784,310.00
# 6         920,842,849.00
# 8         926,833,846.00
#                ...
# 1121696        914361655
# 1121698        914361655
# 1121703        928313414
# 1121704        928313414
# 1121705        928313414
# Name: contbr_zip, Length: 407171, dtype: object

# %%
type(bernie_2016p['contbr_zip'])
# Out:
# pandas.core.series.Series

# %%
bernie_2016p['contbr_zip'].str[:]
# Out:
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 8          NaN
#           ...
# 1121696    NaN
# 1121698    NaN
# 1121703    NaN
# 1121704    NaN
# 1121705    NaN
# Name: contbr_zip, Length: 407171, dtype: object

# %%
bernie_2016p['temp']  = bernie_2016p['contbr_zip'].str[:]
#bernie_2016p
# Out:
# /var/folders/_5/mw87wr4s5p902pvj5xm4sqnw0000gn/T/ipykernel_7984/2684361181.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bernie_2016p['temp']  = bernie_2016p['contbr_zip'].str[:]

# %%
bernie_2016p['temp']  = bernie_2016p['contbr_zip'].astype(str).str[:5]
#bernie_2016p['temp_num'] = bernie_2016p['temp'].astype(int)
bernie_2016p
# Out:
# /var/folders/_5/mw87wr4s5p902pvj5xm4sqnw0000gn/T/ipykernel_7984/1697485308.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bernie_2016p['temp']  = bernie_2016p['contbr_zip'].astype(str).str[:5]
#            cmte_id    cand_id           cand_nm            contbr_nm  \
# 3        C00577130  P60007168  Sanders, Bernard            LEE, ALAN
# 4        C00577130  P60007168  Sanders, Bernard     LEONELLI, ODETTE
# 5        C00577130  P60007168  Sanders, Bernard     LEONELLI, ODETTE
# 6        C00577130  P60007168  Sanders, Bernard       LEOPARD, PATTI
# 8        C00577130  P60007168  Sanders, Bernard         LEPKE, KELLY
# ...            ...        ...               ...                  ...
# 1121696  C00577130  P60007168  Sanders, Bernard       SIMONE, ARLENE
# 1121698  C00577130  P60007168  Sanders, Bernard       SIMONE, ARLENE
# 1121703  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
# 1121704  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
# 1121705  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
#
#            contbr_city contbr_st     contbr_zip            contbr_employer  \
# 3            CAMARILLO        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS
# 4        REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
# 5        REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
# 6                VISTA        CA 920,842,849.00  ONSITE ENERGY CORPORATION
# 8          WESTMINSTER        CA 926,833,846.00                       NONE
# ...                ...       ...            ...                        ...
# 1121696         ENCINO        CA      914361655     SELF EMPLOYED-EMPLOYED
# 1121698         ENCINO        CA      914361655     SELF EMPLOYED-EMPLOYED
# 1121703      FULLERTON        CA      928313414        CITY OF LOS ANGELES
# 1121704      FULLERTON        CA      928313414        CITY OF LOS ANGELES
# 1121705      FULLERTON        CA      928313414        CITY OF LOS ANGELES
#
#             contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 3           SOFTWARE ENGINEER              40.00       2016-03-04
# 4                  PHARMACIST              35.00       2016-03-05
# 5                  PHARMACIST             100.00       2016-03-06
# 6             PROJECT MANAGER              25.00       2016-03-04
# 8                NOT EMPLOYED              10.00       2016-03-05
# ...                       ...                ...              ...
# 1121696          ENTERTASINER              50.00       2016-04-23
# 1121698          ENTERTASINER             100.00       2016-04-27
# 1121703  MANAGEMENT ASSISTANT              15.00       2016-04-15
# 1121704  MANAGEMENT ASSISTANT              15.00       2016-04-23
# 1121705  MANAGEMENT ASSISTANT              15.00       2016-04-25
#
#         receipt_desc memo_cd                            memo_text form_tp  \
# 3                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 4                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 5                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 6                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 8                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# ...              ...     ...                                  ...     ...
# 1121696          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121698          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121703          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121704          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121705          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
#
#          file_num      tran_id election_tp   temp  zipcode_5
# 3         1077404  VPF7BKWA097       P2016  93011      93011
# 4         1077404  VPF7BKX3MB3       P2016  90278      90278
# 5         1077404  VPF7BKYBXV4       P2016  90278      90278
# 6         1077404  VPF7BKW04C1       P2016  92084      92084
# 8         1077404  VPF7BKX3H59       P2016  92683      92683
# ...           ...          ...         ...    ...        ...
# 1121696   1079445  VPF7BP5TFS6       P2016  91436      91436
# 1121698   1079445  VPF7BP86GH6       P2016  91436      91436
# 1121703   1079445  VPF7BNXXDY5       P2016  92831      92831
# 1121704   1079445  VPF7BP64DH7       P2016  92831      92831
# 1121705   1079445  VPF7BP6KBS4       P2016  92831      92831
#
# [407171 rows x 20 columns]

# %%
# extract first 5 characters from the zip code field

bernie_2016p['temp']  = bernie_2016p['contbr_zip'].astype(str).str[:5]

# convert the new field (temp) to an integer

bernie_2016p['zipcode_5'] = pd.to_numeric(bernie_2016p['temp'], errors='coerce').fillna(0).astype(np.int64)
bernie_2016p
# Out:
# /var/folders/_5/mw87wr4s5p902pvj5xm4sqnw0000gn/T/ipykernel_7984/1571530492.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bernie_2016p['temp']  = bernie_2016p['contbr_zip'].astype(str).str[:5]
# /var/folders/_5/mw87wr4s5p902pvj5xm4sqnw0000gn/T/ipykernel_7984/1571530492.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bernie_2016p['zipcode_5'] = pd.to_numeric(bernie_2016p['temp'], errors='coerce').fillna(0).astype(np.int64)
#            cmte_id    cand_id           cand_nm            contbr_nm  \
# 3        C00577130  P60007168  Sanders, Bernard            LEE, ALAN
# 4        C00577130  P60007168  Sanders, Bernard     LEONELLI, ODETTE
# 5        C00577130  P60007168  Sanders, Bernard     LEONELLI, ODETTE
# 6        C00577130  P60007168  Sanders, Bernard       LEOPARD, PATTI
# 8        C00577130  P60007168  Sanders, Bernard         LEPKE, KELLY
# ...            ...        ...               ...                  ...
# 1121696  C00577130  P60007168  Sanders, Bernard       SIMONE, ARLENE
# 1121698  C00577130  P60007168  Sanders, Bernard       SIMONE, ARLENE
# 1121703  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
# 1121704  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
# 1121705  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
#
#            contbr_city contbr_st     contbr_zip            contbr_employer  \
# 3            CAMARILLO        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS
# 4        REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
# 5        REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
# 6                VISTA        CA 920,842,849.00  ONSITE ENERGY CORPORATION
# 8          WESTMINSTER        CA 926,833,846.00                       NONE
# ...                ...       ...            ...                        ...
# 1121696         ENCINO        CA      914361655     SELF EMPLOYED-EMPLOYED
# 1121698         ENCINO        CA      914361655     SELF EMPLOYED-EMPLOYED
# 1121703      FULLERTON        CA      928313414        CITY OF LOS ANGELES
# 1121704      FULLERTON        CA      928313414        CITY OF LOS ANGELES
# 1121705      FULLERTON        CA      928313414        CITY OF LOS ANGELES
#
#             contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 3           SOFTWARE ENGINEER              40.00       2016-03-04
# 4                  PHARMACIST              35.00       2016-03-05
# 5                  PHARMACIST             100.00       2016-03-06
# 6             PROJECT MANAGER              25.00       2016-03-04
# 8                NOT EMPLOYED              10.00       2016-03-05
# ...                       ...                ...              ...
# 1121696          ENTERTASINER              50.00       2016-04-23
# 1121698          ENTERTASINER             100.00       2016-04-27
# 1121703  MANAGEMENT ASSISTANT              15.00       2016-04-15
# 1121704  MANAGEMENT ASSISTANT              15.00       2016-04-23
# 1121705  MANAGEMENT ASSISTANT              15.00       2016-04-25
#
#         receipt_desc memo_cd                            memo_text form_tp  \
# 3                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 4                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 5                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 6                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 8                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# ...              ...     ...                                  ...     ...
# 1121696          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121698          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121703          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121704          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121705          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
#
#          file_num      tran_id election_tp   temp  zipcode_5
# 3         1077404  VPF7BKWA097       P2016  93011      93011
# 4         1077404  VPF7BKX3MB3       P2016  90278      90278
# 5         1077404  VPF7BKYBXV4       P2016  90278      90278
# 6         1077404  VPF7BKW04C1       P2016  92084      92084
# 8         1077404  VPF7BKX3H59       P2016  92683      92683
# ...           ...          ...         ...    ...        ...
# 1121696   1079445  VPF7BP5TFS6       P2016  91436      91436
# 1121698   1079445  VPF7BP86GH6       P2016  91436      91436
# 1121703   1079445  VPF7BNXXDY5       P2016  92831      92831
# 1121704   1079445  VPF7BP64DH7       P2016  92831      92831
# 1121705   1079445  VPF7BP6KBS4       P2016  92831      92831
#
# [407171 rows x 20 columns]

# %%
bernie_2016p[bernie_2016p['zipcode_5'] < 92000]
# Out:
#            cmte_id    cand_id           cand_nm         contbr_nm  \
# 4        C00577130  P60007168  Sanders, Bernard  LEONELLI, ODETTE
# 5        C00577130  P60007168  Sanders, Bernard  LEONELLI, ODETTE
# 47       C00577130  P60007168  Sanders, Bernard   HAZELTINE, GALE
# 48       C00577130  P60007168  Sanders, Bernard    ORDORICA, LEON
# 63       C00577130  P60007168  Sanders, Bernard   MARTINEZ, JESUS
# ...            ...        ...               ...               ...
# 1121692  C00577130  P60007168  Sanders, Bernard     SIMMONS, TODD
# 1121693  C00577130  P60007168  Sanders, Bernard    SIMONE, ARLENE
# 1121694  C00577130  P60007168  Sanders, Bernard    SIMONE, ARLENE
# 1121696  C00577130  P60007168  Sanders, Bernard    SIMONE, ARLENE
# 1121698  C00577130  P60007168  Sanders, Bernard    SIMONE, ARLENE
#
#               contbr_city contbr_st     contbr_zip           contbr_employer  \
# 4           REDONDO BEACH        CA 902,784,310.00  VERICOR ENTERPRISES INC.
# 5           REDONDO BEACH        CA 902,784,310.00  VERICOR ENTERPRISES INC.
# 47          REDONDO BEACH        CA 902,774,354.00             SELF EMPLOYED
# 48       SANTA FE SPRINGS        CA 906,703,118.00                       DWP
# 63            CHULA VISTA        CA 919,115,130.00                 PIZZA HUT
# ...                   ...       ...            ...                       ...
# 1121692            VENICE        CA      902914520                    INTUIT
# 1121693            ENCINO        CA      914361655    SELF EMPLOYED-EMPLOYED
# 1121694            ENCINO        CA      914361655    SELF EMPLOYED-EMPLOYED
# 1121696            ENCINO        CA      914361655    SELF EMPLOYED-EMPLOYED
# 1121698            ENCINO        CA      914361655    SELF EMPLOYED-EMPLOYED
#
#           contbr_occupation  contb_receipt_amt contb_receipt_dt receipt_desc  \
# 4                PHARMACIST              35.00       2016-03-05          NaN
# 5                PHARMACIST             100.00       2016-03-06          NaN
# 47       PHYSICAL THERAPIST              50.00       2016-03-05          NaN
# 48                  LABORER              27.00       2016-03-06          NaN
# 63          DELIVERY DRIVER              10.00       2016-03-05          NaN
# ...                     ...                ...              ...          ...
# 1121692           MARKETING             100.00       2016-04-06          NaN
# 1121693        ENTERTASINER             100.00       2016-04-02          NaN
# 1121694        ENTERTASINER              25.00       2016-04-13          NaN
# 1121696        ENTERTASINER              50.00       2016-04-23          NaN
# 1121698        ENTERTASINER             100.00       2016-04-27          NaN
#
#         memo_cd                            memo_text form_tp  file_num  \
# 4           NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404
# 5           NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404
# 47          NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404
# 48          NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404
# 63          NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404
# ...         ...                                  ...     ...       ...
# 1121692     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445
# 1121693     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445
# 1121694     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445
# 1121696     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445
# 1121698     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445
#
#              tran_id election_tp   temp  zipcode_5
# 4        VPF7BKX3MB3       P2016  90278      90278
# 5        VPF7BKYBXV4       P2016  90278      90278
# 47       VPF7BKXW2D7       P2016  90277      90277
# 48       VPF7BKYJ6D9       P2016  90670      90670
# 63       VPF7BKWYZE1       P2016  91911      91911
# ...              ...         ...    ...        ...
# 1121692  VPF7BNKE4R3       P2016  90291      90291
# 1121693  VPF7BNFGDQ2       P2016  91436      91436
# 1121694  VPF7BNVB1E2       P2016  91436      91436
# 1121696  VPF7BP5TFS6       P2016  91436      91436
# 1121698  VPF7BP86GH6       P2016  91436      91436
#
# [107221 rows x 20 columns]

# %%
bernie_2016p[bernie_2016p['zipcode_5'] = res]
# Out:
#   Input In [74]
#     bernie_2016p[bernie_2016p['zipcode_5'] = res]
#                                            ^
# SyntaxError: invalid syntax

# %%
bernie_2016p[bernie_2016p['zipcode_5'].isin(res)]
# Out:
# Empty DataFrame
# Columns: [cmte_id, cand_id, cand_nm, contbr_nm, contbr_city, contbr_st, contbr_zip, contbr_employer, contbr_occupation, contb_receipt_amt, contb_receipt_dt, receipt_desc, memo_cd, memo_text, form_tp, file_num, tran_id, election_tp, temp, zipcode_5]
# Index: []

# %%
bernie_2016p[bernie_2016p['zipcode_5'].isin([94110, 94112])]
# Out:
#            cmte_id    cand_id           cand_nm        contbr_nm  \
# 1238     C00577130  P60007168  Sanders, Bernard     MAY, BRIDGET
# 1385     C00577130  P60007168  Sanders, Bernard        NAIR, ANL
# 1386     C00577130  P60007168  Sanders, Bernard        NAIR, ANL
# 1624     C00577130  P60007168  Sanders, Bernard   KETSCHER, MARK
# 2219     C00577130  P60007168  Sanders, Bernard    HUBBERT, LISA
# ...            ...        ...               ...              ...
# 1121131  C00577130  P60007168  Sanders, Bernard    SCHMITT, PETE
# 1121461  C00577130  P60007168  Sanders, Bernard  SCHWANKE, JAMES
# 1121462  C00577130  P60007168  Sanders, Bernard  SCHWANKE, JAMES
# 1121477  C00577130  P60007168  Sanders, Bernard    SLAVIN, NANCY
# 1121587  C00577130  P60007168  Sanders, Bernard     SEAVEY, FRED
#
#            contbr_city contbr_st     contbr_zip  \
# 1238     SAN FRANCISCO        CA 941,103,924.00
# 1385     SAN FRANCISCO        CA 941,104,625.00
# 1386     SAN FRANCISCO        CA 941,104,625.00
# 1624     SAN FRANCISCO        CA 941,106,056.00
# 2219     SAN FRANCISCO        CA 941,102,370.00
# ...                ...       ...            ...
# 1121131  SAN FRANCISCO        CA      941106025
# 1121461  SAN FRANCISCO        CA      941105215
# 1121462  SAN FRANCISCO        CA      941105215
# 1121477  SAN FRANCISCO        CA      941121052
# 1121587  SAN FRANCISCO        CA      941104633
#
#                               contbr_employer      contbr_occupation  \
# 1238                     THERAVANCE BIOPHARMA     ANALYTICAL CHEMIST
# 1385                                     ASCO  SOFTWARE PROFESSIONAL
# 1386                                     ASCO  SOFTWARE PROFESSIONAL
# 1624                          UNITED AIRLINES                  PULOT
# 2219                                SWIRL INC               PRODUCER
# ...                                       ...                    ...
# 1121131                              JBR, INC         REGION MANAGER
# 1121461                         SELF EMPLOYED              PHYSICIAN
# 1121462                         SELF EMPLOYED              PHYSICIAN
# 1121477                                  NONE           NOT EMPLOYED
# 1121587  NATIONAL UNION OF HEALTHCARE WORKERS             RESEARCHER
#
#          contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 1238                 27.00       2016-03-05          NaN     NaN
# 1385                100.00       2016-03-06          NaN     NaN
# 1386                 27.00       2016-03-06          NaN     NaN
# 1624                100.00       2016-03-06          NaN     NaN
# 2219                 10.00       2016-03-06          NaN     NaN
# ...                    ...              ...          ...     ...
# 1121131              50.00       2016-04-30          NaN     NaN
# 1121461             100.00       2016-04-01          NaN     NaN
# 1121462              50.00       2016-04-29          NaN     NaN
# 1121477              25.00       2016-04-08          NaN     NaN
# 1121587             200.00       2016-04-30          NaN     NaN
#
#                                    memo_text form_tp  file_num      tran_id  \
# 1238     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKXQ8T4
# 1385     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BM0KJ12
# 1386     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BM0SF05
# 1624     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKZGBA4
# 2219     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKYBQD2
# ...                                      ...     ...       ...          ...
# 1121131  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BPAQ3P3
# 1121461  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BNDVHR0
# 1121462  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BPA14W0
# 1121477  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BNMZ8S7
# 1121587  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BPB0540
#
#         election_tp   temp  zipcode_5
# 1238          P2016  94110      94110
# 1385          P2016  94110      94110
# 1386          P2016  94110      94110
# 1624          P2016  94110      94110
# 2219          P2016  94110      94110
# ...             ...    ...        ...
# 1121131       P2016  94110      94110
# 1121461       P2016  94110      94110
# 1121462       P2016  94110      94110
# 1121477       P2016  94112      94112
# 1121587       P2016  94110      94110
#
# [5465 rows x 20 columns]

# %%
bernie_2016p[bernie_2016p['zipcode_5'].isin(res_int)]
# Out:
#            cmte_id    cand_id           cand_nm            contbr_nm  \
# 3        C00577130  P60007168  Sanders, Bernard            LEE, ALAN
# 4        C00577130  P60007168  Sanders, Bernard     LEONELLI, ODETTE
# 5        C00577130  P60007168  Sanders, Bernard     LEONELLI, ODETTE
# 6        C00577130  P60007168  Sanders, Bernard       LEOPARD, PATTI
# 8        C00577130  P60007168  Sanders, Bernard         LEPKE, KELLY
# ...            ...        ...               ...                  ...
# 1121696  C00577130  P60007168  Sanders, Bernard       SIMONE, ARLENE
# 1121698  C00577130  P60007168  Sanders, Bernard       SIMONE, ARLENE
# 1121703  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
# 1121704  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
# 1121705  C00577130  P60007168  Sanders, Bernard  ROBINSON, KATHARINE
#
#            contbr_city contbr_st     contbr_zip            contbr_employer  \
# 3            CAMARILLO        CA 930,111,214.00  AT&T GOVERNMENT SOLUTIONS
# 4        REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
# 5        REDONDO BEACH        CA 902,784,310.00   VERICOR ENTERPRISES INC.
# 6                VISTA        CA 920,842,849.00  ONSITE ENERGY CORPORATION
# 8          WESTMINSTER        CA 926,833,846.00                       NONE
# ...                ...       ...            ...                        ...
# 1121696         ENCINO        CA      914361655     SELF EMPLOYED-EMPLOYED
# 1121698         ENCINO        CA      914361655     SELF EMPLOYED-EMPLOYED
# 1121703      FULLERTON        CA      928313414        CITY OF LOS ANGELES
# 1121704      FULLERTON        CA      928313414        CITY OF LOS ANGELES
# 1121705      FULLERTON        CA      928313414        CITY OF LOS ANGELES
#
#             contbr_occupation  contb_receipt_amt contb_receipt_dt  \
# 3           SOFTWARE ENGINEER              40.00       2016-03-04
# 4                  PHARMACIST              35.00       2016-03-05
# 5                  PHARMACIST             100.00       2016-03-06
# 6             PROJECT MANAGER              25.00       2016-03-04
# 8                NOT EMPLOYED              10.00       2016-03-05
# ...                       ...                ...              ...
# 1121696          ENTERTASINER              50.00       2016-04-23
# 1121698          ENTERTASINER             100.00       2016-04-27
# 1121703  MANAGEMENT ASSISTANT              15.00       2016-04-15
# 1121704  MANAGEMENT ASSISTANT              15.00       2016-04-23
# 1121705  MANAGEMENT ASSISTANT              15.00       2016-04-25
#
#         receipt_desc memo_cd                            memo_text form_tp  \
# 3                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 4                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 5                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 6                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 8                NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# ...              ...     ...                                  ...     ...
# 1121696          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121698          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121703          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121704          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
# 1121705          NaN     NaN  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A
#
#          file_num      tran_id election_tp   temp  zipcode_5
# 3         1077404  VPF7BKWA097       P2016  93011      93011
# 4         1077404  VPF7BKX3MB3       P2016  90278      90278
# 5         1077404  VPF7BKYBXV4       P2016  90278      90278
# 6         1077404  VPF7BKW04C1       P2016  92084      92084
# 8         1077404  VPF7BKX3H59       P2016  92683      92683
# ...           ...          ...         ...    ...        ...
# 1121696   1079445  VPF7BP5TFS6       P2016  91436      91436
# 1121698   1079445  VPF7BP86GH6       P2016  91436      91436
# 1121703   1079445  VPF7BNXXDY5       P2016  92831      92831
# 1121704   1079445  VPF7BP64DH7       P2016  92831      92831
# 1121705   1079445  VPF7BP6KBS4       P2016  92831      92831
#
# [407085 rows x 20 columns]

# %%
bernie_2016p[bernie_2016p['temp'].isin(['94110', '94112'])]
# Out:
#            cmte_id    cand_id           cand_nm        contbr_nm  \
# 1238     C00577130  P60007168  Sanders, Bernard     MAY, BRIDGET
# 1385     C00577130  P60007168  Sanders, Bernard        NAIR, ANL
# 1386     C00577130  P60007168  Sanders, Bernard        NAIR, ANL
# 1624     C00577130  P60007168  Sanders, Bernard   KETSCHER, MARK
# 2219     C00577130  P60007168  Sanders, Bernard    HUBBERT, LISA
# ...            ...        ...               ...              ...
# 1121131  C00577130  P60007168  Sanders, Bernard    SCHMITT, PETE
# 1121461  C00577130  P60007168  Sanders, Bernard  SCHWANKE, JAMES
# 1121462  C00577130  P60007168  Sanders, Bernard  SCHWANKE, JAMES
# 1121477  C00577130  P60007168  Sanders, Bernard    SLAVIN, NANCY
# 1121587  C00577130  P60007168  Sanders, Bernard     SEAVEY, FRED
#
#            contbr_city contbr_st     contbr_zip  \
# 1238     SAN FRANCISCO        CA 941,103,924.00
# 1385     SAN FRANCISCO        CA 941,104,625.00
# 1386     SAN FRANCISCO        CA 941,104,625.00
# 1624     SAN FRANCISCO        CA 941,106,056.00
# 2219     SAN FRANCISCO        CA 941,102,370.00
# ...                ...       ...            ...
# 1121131  SAN FRANCISCO        CA      941106025
# 1121461  SAN FRANCISCO        CA      941105215
# 1121462  SAN FRANCISCO        CA      941105215
# 1121477  SAN FRANCISCO        CA      941121052
# 1121587  SAN FRANCISCO        CA      941104633
#
#                               contbr_employer      contbr_occupation  \
# 1238                     THERAVANCE BIOPHARMA     ANALYTICAL CHEMIST
# 1385                                     ASCO  SOFTWARE PROFESSIONAL
# 1386                                     ASCO  SOFTWARE PROFESSIONAL
# 1624                          UNITED AIRLINES                  PULOT
# 2219                                SWIRL INC               PRODUCER
# ...                                       ...                    ...
# 1121131                              JBR, INC         REGION MANAGER
# 1121461                         SELF EMPLOYED              PHYSICIAN
# 1121462                         SELF EMPLOYED              PHYSICIAN
# 1121477                                  NONE           NOT EMPLOYED
# 1121587  NATIONAL UNION OF HEALTHCARE WORKERS             RESEARCHER
#
#          contb_receipt_amt contb_receipt_dt receipt_desc memo_cd  \
# 1238                 27.00       2016-03-05          NaN     NaN
# 1385                100.00       2016-03-06          NaN     NaN
# 1386                 27.00       2016-03-06          NaN     NaN
# 1624                100.00       2016-03-06          NaN     NaN
# 2219                 10.00       2016-03-06          NaN     NaN
# ...                    ...              ...          ...     ...
# 1121131              50.00       2016-04-30          NaN     NaN
# 1121461             100.00       2016-04-01          NaN     NaN
# 1121462              50.00       2016-04-29          NaN     NaN
# 1121477              25.00       2016-04-08          NaN     NaN
# 1121587             200.00       2016-04-30          NaN     NaN
#
#                                    memo_text form_tp  file_num      tran_id  \
# 1238     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKXQ8T4
# 1385     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BM0KJ12
# 1386     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BM0SF05
# 1624     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKZGBA4
# 2219     * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1077404  VPF7BKYBQD2
# ...                                      ...     ...       ...          ...
# 1121131  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BPAQ3P3
# 1121461  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BNDVHR0
# 1121462  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BPA14W0
# 1121477  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BNMZ8S7
# 1121587  * EARMARKED CONTRIBUTION: SEE BELOW   SA17A   1079445  VPF7BPB0540
#
#         election_tp   temp  zipcode_5
# 1238          P2016  94110      94110
# 1385          P2016  94110      94110
# 1386          P2016  94110      94110
# 1624          P2016  94110      94110
# 2219          P2016  94110      94110
# ...             ...    ...        ...
# 1121131       P2016  94110      94110
# 1121461       P2016  94110      94110
# 1121462       P2016  94110      94110
# 1121477       P2016  94112      94112
# 1121587       P2016  94110      94110
#
# [5465 rows x 20 columns]

# %%
bernie_2016p[bernie_2016p['temp'].isin([[sub['zip_code'] for sub in filtered_zips]])]
# Out:
# Empty DataFrame
# Columns: [cmte_id, cand_id, cand_nm, contbr_nm, contbr_city, contbr_st, contbr_zip, contbr_employer, contbr_occupation, contb_receipt_amt, contb_receipt_dt, receipt_desc, memo_cd, memo_text, form_tp, file_num, tran_id, election_tp, temp, zipcode_5]
# Index: []

# %%
temp = bernie_2016p[bernie_2016p['zipcode_5'].apply(lambda x : x == res_int)]
temp
# Out:
# Empty DataFrame
# Columns: [cmte_id, cand_id, cand_nm, contbr_nm, contbr_city, contbr_st, contbr_zip, contbr_employer, contbr_occupation, contb_receipt_amt, contb_receipt_dt, receipt_desc, memo_cd, memo_text, form_tp, file_num, tran_id, election_tp, temp, zipcode_5]
# Index: []

# %%
for i in range(100):
    zip_list = []
    zip_list = zip_list.append(filtered_zips[i]['zip_code'])
    print(zip_list)
#    i += 1
#zip_list[1]
#filtered_zips[1]['zip_code']
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None

# %%
zip_list.append(filtered_zips[1]['zip_code'])
#zip_list
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 zip_list.append(filtered_zips[1]['zip_code'])
#       2 zip_list
#
# AttributeError: 'NoneType' object has no attribute 'append'

# %%
[filtered_zips[i]['zip_code'] for i in filtered_zips]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 [filtered_zips[i]['zip_code'] for i in filtered_zips]
#
# Input In [37], in <listcomp>(.0)
# ----> 1 [filtered_zips[i]['zip_code'] for i in filtered_zips]
#
# TypeError: list indices must be integers or slices, not dict

# %% [markdown]
# ---

# %%
import zipcodes

# extract_zip = zipcodes#.similar_to('923')
# extract_zip

filtered_zips = zipcodes.filter_by(state="CA")
filtered_zips
# Out:
# [{'zip_code': '90001',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Firestone Park', 'Firestone Pk'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9736',
#   'long': '-118.2479'},
#  {'zip_code': '90002',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Watts'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9490',
#   'long': '-118.2460'},
#  {'zip_code': '90003',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Broadway Manchester'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9640',
#   'long': '-118.2737'},
#  {'zip_code': '90004',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Oakwood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0761',
#   'long': '-118.3108'},
#  {'zip_code': '90005',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Sanford'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323', '562', '626', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0584',
#   'long': '-118.3113'},
#  {'zip_code': '90006',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Pico Heights'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0476',
#   'long': '-118.2923'},
#  {'zip_code': '90007',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Dockweiler'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0265',
#   'long': '-118.2828'},
#  {'zip_code': '90008',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Baldwin Hills', 'Leimert Park', 'View Park'],
#   'unacceptable_cities': ['Crenshaw'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0069',
#   'long': '-118.3457'},
#  {'zip_code': '90009',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Los Angeles AFB', 'Los Angls AFB'],
#   'unacceptable_cities': ['Los Angeles International'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2425'},
#  {'zip_code': '90010',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Sanford'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '562', '626', '818', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0633',
#   'long': '-118.3121'},
#  {'zip_code': '90011',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0098',
#   'long': '-118.2586'},
#  {'zip_code': '90012',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Federal'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['818', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0655',
#   'long': '-118.2405'},
#  {'zip_code': '90013',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Federal'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323', '424', '562', '626', '747', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0456',
#   'long': '-118.2416'},
#  {'zip_code': '90014',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '323', '562', '626', '818', '310', '424', '747'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0430',
#   'long': '-118.2523'},
#  {'zip_code': '90015',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424', '562', '626', '818', '213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0405',
#   'long': '-118.2670'},
#  {'zip_code': '90016',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['West Adams'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0290',
#   'long': '-118.3578'},
#  {'zip_code': '90017',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Foy'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '818', '213', '323', '424', '562', '626'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0529',
#   'long': '-118.2649'},
#  {'zip_code': '90018',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Cimarron', 'Dockweiler'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0273',
#   'long': '-118.3177'},
#  {'zip_code': '90019',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Rimpau'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0485',
#   'long': '-118.3395'},
#  {'zip_code': '90020',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Sanford'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323', '562', '626', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0661',
#   'long': '-118.3114'},
#  {'zip_code': '90021',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Market'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0298',
#   'long': '-118.2403'},
#  {'zip_code': '90022',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Commerce', 'E Los Angeles', 'East Los Angeles'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0294',
#   'long': '-118.1513'},
#  {'zip_code': '90023',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Commerce'],
#   'unacceptable_cities': ['Lugo'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0172',
#   'long': '-118.2002'},
#  {'zip_code': '90024',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Village'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '818', '310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0657',
#   'long': '-118.4341'},
#  {'zip_code': '90025',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['W Los Angeles', 'West Los Angeles'],
#   'unacceptable_cities': ['Wla'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '424', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0454',
#   'long': '-118.4436'},
#  {'zip_code': '90026',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Echo Park', 'Edendale', 'Silver Lake'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0761',
#   'long': '-118.2623'},
#  {'zip_code': '90027',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Hollywood', 'Los Feliz'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1280',
#   'long': '-118.2891'},
#  {'zip_code': '90028',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Hollywood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['818', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0996',
#   'long': '-118.3275'},
#  {'zip_code': '90029',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Vermont'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0897',
#   'long': '-118.2926'},
#  {'zip_code': '90030',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90031',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Lincoln Heights', 'Lincoln Hts'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0791',
#   'long': '-118.2181'},
#  {'zip_code': '90032',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['626'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0826',
#   'long': '-118.1773'},
#  {'zip_code': '90033',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Boyle Heights'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0497',
#   'long': '-118.2113'},
#  {'zip_code': '90034',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Palms'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0293',
#   'long': '-118.3994'},
#  {'zip_code': '90035',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Preuss'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0521',
#   'long': '-118.3853'},
#  {'zip_code': '90036',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Farmer Market', 'Miracle Mile', 'Wilshire La Brea'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0704',
#   'long': '-118.3505'},
#  {'zip_code': '90037',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Green'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '323', '310', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0033',
#   'long': '-118.2889'},
#  {'zip_code': '90038',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['W Hollywood', 'West Hollywood'],
#   'unacceptable_cities': ['Hollywood', 'Wilcox'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0892',
#   'long': '-118.3272'},
#  {'zip_code': '90039',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Griffith'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1206',
#   'long': '-118.2551'},
#  {'zip_code': '90040',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Commerce', 'Cty Of Cmmrce'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9941',
#   'long': '-118.1523'},
#  {'zip_code': '90041',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Eagle Rock'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '626'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1341',
#   'long': '-118.2053'},
#  {'zip_code': '90042',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Highland Park'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '626'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1133',
#   'long': '-118.1915'},
#  {'zip_code': '90043',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['View Park', 'Windsor Hills'],
#   'unacceptable_cities': ['La Tijera'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9855',
#   'long': '-118.3380'},
#  {'zip_code': '90044',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['August F Haw', 'Hancock'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9531',
#   'long': '-118.2920'},
#  {'zip_code': '90045',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Westchester'],
#   'unacceptable_cities': ['Bradley International', 'Playa Vista'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9551',
#   'long': '-118.4020'},
#  {'zip_code': '90046',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['W Hollywood', 'West Hollywood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1073',
#   'long': '-118.3689'},
#  {'zip_code': '90047',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Wagner'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9530',
#   'long': '-118.3094'},
#  {'zip_code': '90048',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['W Hollywood', 'West Hollywood'],
#   'unacceptable_cities': ['Bicentennial', 'Briggs'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0710',
#   'long': '-118.3762'},
#  {'zip_code': '90049',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Barrington'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0863',
#   'long': '-118.4883'},
#  {'zip_code': '90050',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90051',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['August F Haw'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90052',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90053',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90054',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90055',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90056',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Baldwin Hills', 'Windsor Hills'],
#   'unacceptable_cities': ['Crenshaw'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9945',
#   'long': '-118.3743'},
#  {'zip_code': '90057',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Flint'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0623',
#   'long': '-118.2762'},
#  {'zip_code': '90058',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Vernon'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0019',
#   'long': '-118.2126'},
#  {'zip_code': '90059',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['August F Haw', 'Greenmead'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9207',
#   'long': '-118.2452'},
#  {'zip_code': '90060',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90061',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['August F Haw', 'South'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '213', '310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9206',
#   'long': '-118.2739'},
#  {'zip_code': '90062',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Westvern'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0037',
#   'long': '-118.3097'},
#  {'zip_code': '90063',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Hazard'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0438',
#   'long': '-118.1875'},
#  {'zip_code': '90064',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Rancho Park'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0371',
#   'long': '-118.4279'},
#  {'zip_code': '90065',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Glassell', 'Glassell Park'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1115',
#   'long': '-118.2286'},
#  {'zip_code': '90066',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Culver Cty', 'Mar Vista'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0002',
#   'long': '-118.4326'},
#  {'zip_code': '90067',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Century City'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0578',
#   'long': '-118.4138'},
#  {'zip_code': '90068',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Hollywood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1299',
#   'long': '-118.3355'},
#  {'zip_code': '90069',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'West Hollywood',
#   'acceptable_cities': ['Los Angeles', 'W Hollywood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0942',
#   'long': '-118.3809'},
#  {'zip_code': '90070',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0578',
#   'long': '-118.2725'},
#  {'zip_code': '90071',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Arco', 'Arco Plaza'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '562', '626', '424', '747', '323', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0525',
#   'long': '-118.2553'},
#  {'zip_code': '90072',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Santa Western'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90073',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Veterans Adm',
#    'Veterans Admin',
#    'Veterans Administration',
#    'Veterans Admn'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0592',
#   'long': '-118.4514'},
#  {'zip_code': '90074',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Bank Of America'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90075',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90076',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90077',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Barrington'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1027',
#   'long': '-118.4525'},
#  {'zip_code': '90078',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Hollywood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90079',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '323', '424', '626', '747', '818'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0529',
#   'long': '-118.2407'},
#  {'zip_code': '90080',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90081',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90082',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90083',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90084',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Wells Fargo'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0617',
#   'long': '-118.4474'},
#  {'zip_code': '90086',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90087',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90088',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Wells Fargo'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90089',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['University Of Southern Ca'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0218',
#   'long': '-118.2883'},
#  {'zip_code': '90090',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Dodgertown',
#   'acceptable_cities': ['Los Angeles'],
#   'unacceptable_cities': ['Los Angeles Dodgers'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0727',
#   'long': '-118.2453'},
#  {'zip_code': '90091',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Commerce', 'Cty Of Cmmrce'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0002',
#   'long': '-118.1535'},
#  {'zip_code': '90093',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0522',
#   'long': '-118.2429'},
#  {'zip_code': '90094',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Playa Vista',
#   'acceptable_cities': ['Los Angeles'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9762',
#   'long': '-118.4171'},
#  {'zip_code': '90095',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Uc Los Angeles'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0710',
#   'long': '-118.4432'},
#  {'zip_code': '90096',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Shared Firm Zip Code'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0765',
#   'long': '-118.2093'},
#  {'zip_code': '90099',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Bar Code Term Annex', 'Los Angeles Brm'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0597',
#   'long': '-118.2489'},
#  {'zip_code': '90101',
#   'zip_code_type': 'STANDARD',
#   'active': False,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Bulk Mail Center', 'La'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.99',
#   'long': '-118.16'},
#  {'zip_code': '90102',
#   'zip_code_type': 'UNIQUE',
#   'active': False,
#   'city': 'Los Angeles',
#   'acceptable_cities': ['Brylane'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.01',
#   'long': '-118.19'},
#  {'zip_code': '90103',
#   'zip_code_type': 'UNIQUE',
#   'active': False,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Rodale Press'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.99',
#   'long': '-118.16'},
#  {'zip_code': '90134',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Goat'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': [],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '0.0000',
#   'long': '0.0000'},
#  {'zip_code': '90189',
#   'zip_code_type': 'UNIQUE',
#   'active': True,
#   'city': 'Los Angeles',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Citibank', 'First Data Remitco'],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0583',
#   'long': '-118.2476'},
#  {'zip_code': '90201',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Bell Gardens',
#   'acceptable_cities': ['Bell', 'Cudahy'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9762',
#   'long': '-118.1676'},
#  {'zip_code': '90202',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Bell',
#   'acceptable_cities': ['Bell Gardens'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9656',
#   'long': '-118.1519'},
#  {'zip_code': '90209',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Beverly Hills',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0738',
#   'long': '-118.3994'},
#  {'zip_code': '90210',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Beverly Hills',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.1031',
#   'long': '-118.4163'},
#  {'zip_code': '90211',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Beverly Hills',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0646',
#   'long': '-118.3814'},
#  {'zip_code': '90212',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Beverly Hills',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323', '424', '310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0611',
#   'long': '-118.4021'},
#  {'zip_code': '90213',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Beverly Hills',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0738',
#   'long': '-118.3994'},
#  {'zip_code': '90220',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Compton',
#   'acceptable_cities': ['Crystal City', 'Rancho Dominguez', 'Rncho Domingz'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '562', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8750',
#   'long': '-118.2408'},
#  {'zip_code': '90221',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Compton',
#   'acceptable_cities': ['E Rncho Dmngz', 'East Rancho Dominguez'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8801',
#   'long': '-118.2013'},
#  {'zip_code': '90222',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Compton',
#   'acceptable_cities': ['Rosewood'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['424', '310', '323', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9137',
#   'long': '-118.2355'},
#  {'zip_code': '90223',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Compton',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8959',
#   'long': '-118.2192'},
#  {'zip_code': '90224',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Compton',
#   'acceptable_cities': ['Rancho Dominguez', 'Rncho Domingz'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8959',
#   'long': '-118.2192'},
#  {'zip_code': '90230',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Culver City',
#   'acceptable_cities': ['Los Angeles'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9954',
#   'long': '-118.3999'},
#  {'zip_code': '90231',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Culver City',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0212',
#   'long': '-118.3956'},
#  {'zip_code': '90232',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Culver City',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0193',
#   'long': '-118.3935'},
#  {'zip_code': '90233',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Culver City',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '34.0212',
#   'long': '-118.3956'},
#  {'zip_code': '90239',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Downey',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9400',
#   'long': '-118.1319'},
#  {'zip_code': '90240',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Downey',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9559',
#   'long': '-118.1189'},
#  {'zip_code': '90241',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Downey',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9390',
#   'long': '-118.1256'},
#  {'zip_code': '90242',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Downey',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9231',
#   'long': '-118.1391'},
#  {'zip_code': '90245',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'El Segundo',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9161',
#   'long': '-118.4041'},
#  {'zip_code': '90247',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Gardena',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323', '424', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8946',
#   'long': '-118.2992'},
#  {'zip_code': '90248',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Gardena',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323', '424', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8814',
#   'long': '-118.2856'},
#  {'zip_code': '90249',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Gardena',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['213', '310', '323', '424', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8997',
#   'long': '-118.3177'},
#  {'zip_code': '90250',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Hawthorne',
#   'acceptable_cities': ['Holly Park', 'Hollyglen'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '323', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9128',
#   'long': '-118.3456'},
#  {'zip_code': '90251',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Hawthorne',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9167',
#   'long': '-118.3514'},
#  {'zip_code': '90254',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Hermosa Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['310', '424'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.8648',
#   'long': '-118.3972'},
#  {'zip_code': '90255',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Huntington Park',
#   'acceptable_cities': ['Huntington Pk', 'Walnut Park'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['323'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.9775',
#   'long': '-118.2130'},
#  {'zip_code': '90260',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Lawndale',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Los Angeles County',
# ...
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6245',
#   'long': '-117.7952'},
#  {'zip_code': '92604',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6903',
#   'long': '-117.7899'},
#  {'zip_code': '92605',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Huntington Beach',
#   'acceptable_cities': ['Huntingtn Bch'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.7036',
#   'long': '-117.9942'},
#  {'zip_code': '92606',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6998',
#   'long': '-117.8169'},
#  {'zip_code': '92607',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Laguna Niguel',
#   'acceptable_cities': ['Laguna Beach'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5425',
#   'long': '-117.7825'},
#  {'zip_code': '92609',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'El Toro',
#   'acceptable_cities': ['Lake Forest'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5955',
#   'long': '-117.7077'},
#  {'zip_code': '92610',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Foothill Ranch',
#   'acceptable_cities': ['El Toro', 'Foothill Rnch', 'Lake Forest'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.7094',
#   'long': '-117.6670'},
#  {'zip_code': '92612',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6615',
#   'long': '-117.8217'},
#  {'zip_code': '92614',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949', '714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6841',
#   'long': '-117.8275'},
#  {'zip_code': '92615',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Huntington Beach',
#   'acceptable_cities': ['Huntingtn Bch'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6606',
#   'long': '-117.9983'},
#  {'zip_code': '92616',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6695',
#   'long': '-117.8222'},
#  {'zip_code': '92617',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6430',
#   'long': '-117.8419'},
#  {'zip_code': '92618',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6852',
#   'long': '-117.7346'},
#  {'zip_code': '92619',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6695',
#   'long': '-117.8222'},
#  {'zip_code': '92620',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.7090',
#   'long': '-117.7590'},
#  {'zip_code': '92623',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Irvine',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6695',
#   'long': '-117.8222'},
#  {'zip_code': '92624',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Capistrano Beach',
#   'acceptable_cities': ['Capo Beach', 'Dana Point'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.4557',
#   'long': '-117.6647'},
#  {'zip_code': '92625',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Corona Del Mar',
#   'acceptable_cities': ['Corona Dl Mar'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5994',
#   'long': '-117.8659'},
#  {'zip_code': '92626',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Costa Mesa',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6791',
#   'long': '-117.9055'},
#  {'zip_code': '92627',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Costa Mesa',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6490',
#   'long': '-117.9178'},
#  {'zip_code': '92628',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Costa Mesa',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6414',
#   'long': '-117.9178'},
#  {'zip_code': '92629',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Dana Point',
#   'acceptable_cities': ['Monarch Bay', 'Monarch Beach'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.4780',
#   'long': '-117.7059'},
#  {'zip_code': '92630',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Lake Forest',
#   'acceptable_cities': ['El Toro'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6443',
#   'long': '-117.6789'},
#  {'zip_code': '92637',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Laguna Woods',
#   'acceptable_cities': ['Laguna Hills'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6071',
#   'long': '-117.7311'},
#  {'zip_code': '92646',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Huntington Beach',
#   'acceptable_cities': ['Huntingtn Bch'],
#   'unacceptable_cities': ['Huntington'],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['657', '714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6649',
#   'long': '-117.9642'},
#  {'zip_code': '92647',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Huntington Beach',
#   'acceptable_cities': ['Huntingtn Bch'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['657', '714', '562'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.7268',
#   'long': '-118.0069'},
#  {'zip_code': '92648',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Huntington Beach',
#   'acceptable_cities': ['Huntingtn Bch'],
#   'unacceptable_cities': ['Beach Center'],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562', '657', '714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6767',
#   'long': '-118.0212'},
#  {'zip_code': '92649',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Huntington Beach',
#   'acceptable_cities': ['Huntingtn Bch'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['562', '714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.7223',
#   'long': '-118.0543'},
#  {'zip_code': '92650',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'East Irvine',
#   'acceptable_cities': ['Irvine'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6758',
#   'long': '-117.7587'},
#  {'zip_code': '92651',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Laguna Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5451',
#   'long': '-117.7761'},
#  {'zip_code': '92652',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Laguna Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': ['Playa'],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5425',
#   'long': '-117.7825'},
#  {'zip_code': '92653',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Laguna Hills',
#   'acceptable_cities': ['Aliso Viejo', 'Laguna Beach', 'Laguna Woods'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714', '949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5940',
#   'long': '-117.7099'},
#  {'zip_code': '92654',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Laguna Hills',
#   'acceptable_cities': ['Laguna Beach', 'Laguna Woods'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5425',
#   'long': '-117.7825'},
#  {'zip_code': '92655',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Midway City',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.7432',
#   'long': '-117.9853'},
#  {'zip_code': '92656',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Aliso Viejo',
#   'acceptable_cities': ['Laguna Beach', 'Laguna Hills'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949', '714'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5736',
#   'long': '-117.7296'},
#  {'zip_code': '92657',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Newport Coast',
#   'acceptable_cities': ['Newport Beach'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.5932',
#   'long': '-117.8312'},
#  {'zip_code': '92658',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Newport Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6187',
#   'long': '-117.9283'},
#  {'zip_code': '92659',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'Newport Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6187',
#   'long': '-117.9283'},
#  {'zip_code': '92660',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Newport Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6380',
#   'long': '-117.8732'},
#  {'zip_code': '92661',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Newport Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6023',
#   'long': '-117.9019'},
#  {'zip_code': '92662',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Newport Beach',
#   'acceptable_cities': ['Balboa', 'Balboa Island'],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6012',
#   'long': '-117.8911'},
#  {'zip_code': '92663',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'Newport Beach',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.6266',
#   'long': '-117.9305'},
#  {'zip_code': '92672',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'San Clemente',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.3929',
#   'long': '-117.5296'},
#  {'zip_code': '92673',
#   'zip_code_type': 'STANDARD',
#   'active': True,
#   'city': 'San Clemente',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.4658',
#   'long': '-117.6187'},
#  {'zip_code': '92674',
#   'zip_code_type': 'PO BOX',
#   'active': True,
#   'city': 'San Clemente',
#   'acceptable_cities': [],
#   'unacceptable_cities': [],
#   'state': 'CA',
#   'county': 'Orange County',
#   'timezone': 'America/Los_Angeles',
#   'area_codes': ['949'],
#   'world_region': 'NA',
#   'country': 'US',
#   'lat': '33.4266',
#   'long': '-117.6112'},
#  ...]

# %%
filtered_zips

res = [sub['zip_code'] for sub in filtered_zips]
len(res)
res
# Out:
# ['90001',
#  '90002',
#  '90003',
#  '90004',
#  '90005',
#  '90006',
#  '90007',
#  '90008',
#  '90009',
#  '90010',
#  '90011',
#  '90012',
#  '90013',
#  '90014',
#  '90015',
#  '90016',
#  '90017',
#  '90018',
#  '90019',
#  '90020',
#  '90021',
#  '90022',
#  '90023',
#  '90024',
#  '90025',
#  '90026',
#  '90027',
#  '90028',
#  '90029',
#  '90030',
#  '90031',
#  '90032',
#  '90033',
#  '90034',
#  '90035',
#  '90036',
#  '90037',
#  '90038',
#  '90039',
#  '90040',
#  '90041',
#  '90042',
#  '90043',
#  '90044',
#  '90045',
#  '90046',
#  '90047',
#  '90048',
#  '90049',
#  '90050',
#  '90051',
#  '90052',
#  '90053',
#  '90054',
#  '90055',
#  '90056',
#  '90057',
#  '90058',
#  '90059',
#  '90060',
#  '90061',
#  '90062',
#  '90063',
#  '90064',
#  '90065',
#  '90066',
#  '90067',
#  '90068',
#  '90069',
#  '90070',
#  '90071',
#  '90072',
#  '90073',
#  '90074',
#  '90075',
#  '90076',
#  '90077',
#  '90078',
#  '90079',
#  '90080',
#  '90081',
#  '90082',
#  '90083',
#  '90084',
#  '90086',
#  '90087',
#  '90088',
#  '90089',
#  '90090',
#  '90091',
#  '90093',
#  '90094',
#  '90095',
#  '90096',
#  '90099',
#  '90101',
#  '90102',
#  '90103',
#  '90134',
#  '90189',
#  '90201',
#  '90202',
#  '90209',
#  '90210',
#  '90211',
#  '90212',
#  '90213',
#  '90220',
#  '90221',
#  '90222',
#  '90223',
#  '90224',
#  '90230',
#  '90231',
#  '90232',
#  '90233',
#  '90239',
#  '90240',
#  '90241',
#  '90242',
#  '90245',
#  '90247',
#  '90248',
#  '90249',
#  '90250',
#  '90251',
#  '90254',
#  '90255',
#  '90260',
#  '90261',
#  '90262',
#  '90263',
#  '90264',
#  '90265',
#  '90266',
#  '90267',
#  '90270',
#  '90272',
#  '90274',
#  '90275',
#  '90277',
#  '90278',
#  '90280',
#  '90290',
#  '90291',
#  '90292',
#  '90293',
#  '90294',
#  '90295',
#  '90296',
#  '90301',
#  '90302',
#  '90303',
#  '90304',
#  '90305',
#  '90306',
#  '90307',
#  '90308',
#  '90309',
#  '90310',
#  '90311',
#  '90312',
#  '90313',
#  '90397',
#  '90398',
#  '90401',
#  '90402',
#  '90403',
#  '90404',
#  '90405',
#  '90406',
#  '90407',
#  '90408',
#  '90409',
#  '90410',
#  '90411',
#  '90501',
#  '90502',
#  '90503',
#  '90504',
#  '90505',
#  '90506',
#  '90507',
#  '90508',
#  '90509',
#  '90510',
#  '90601',
#  '90602',
#  '90603',
#  '90604',
#  '90605',
#  '90606',
#  '90607',
#  '90608',
#  '90609',
#  '90610',
#  '90612',
#  '90620',
#  '90621',
#  '90622',
#  '90623',
#  '90624',
#  '90630',
#  '90631',
#  '90632',
#  '90633',
#  '90637',
#  '90638',
#  '90639',
#  '90640',
#  '90650',
#  '90651',
#  '90652',
#  '90659',
#  '90660',
#  '90661',
#  '90662',
#  '90670',
#  '90671',
#  '90680',
#  '90701',
#  '90702',
#  '90703',
#  '90704',
#  '90706',
#  '90707',
#  '90710',
#  '90711',
#  '90712',
#  '90713',
#  '90714',
#  '90715',
#  '90716',
#  '90717',
#  '90720',
#  '90721',
#  '90723',
#  '90731',
#  '90732',
#  '90733',
#  '90734',
#  '90740',
#  '90742',
#  '90743',
#  '90744',
#  '90745',
#  '90746',
#  '90747',
#  '90748',
#  '90749',
#  '90755',
#  '90801',
#  '90802',
#  '90803',
#  '90804',
#  '90805',
#  '90806',
#  '90807',
#  '90808',
#  '90809',
#  '90810',
#  '90813',
#  '90814',
#  '90815',
#  '90822',
#  '90831',
#  '90832',
#  '90833',
#  '90834',
#  '90835',
#  '90840',
#  '90842',
#  '90844',
#  '90845',
#  '90846',
#  '90847',
#  '90848',
#  '90853',
#  '90888',
#  '90895',
#  '90899',
#  '91001',
#  '91003',
#  '91006',
#  '91007',
#  '91008',
#  '91009',
#  '91010',
#  '91011',
#  '91012',
#  '91016',
#  '91017',
#  '91020',
#  '91021',
#  '91023',
#  '91024',
#  '91025',
#  '91030',
#  '91031',
#  '91040',
#  '91041',
#  '91042',
#  '91043',
#  '91046',
#  '91066',
#  '91077',
#  '91101',
#  '91102',
#  '91103',
#  '91104',
#  '91105',
#  '91106',
#  '91107',
#  '91108',
#  '91109',
#  '91110',
#  '91114',
#  '91115',
#  '91116',
#  '91117',
#  '91118',
#  '91121',
#  '91123',
#  '91124',
#  '91125',
#  '91126',
#  '91129',
#  '91131',
#  '91182',
#  '91184',
#  '91185',
#  '91188',
#  '91189',
#  '91191',
#  '91199',
#  '91201',
#  '91202',
#  '91203',
#  '91204',
#  '91205',
#  '91206',
#  '91207',
#  '91208',
#  '91209',
#  '91210',
#  '91214',
#  '91221',
#  '91222',
#  '91224',
#  '91225',
#  '91226',
#  '91301',
#  '91302',
#  '91303',
#  '91304',
#  '91305',
#  '91306',
#  '91307',
#  '91308',
#  '91309',
#  '91310',
#  '91311',
#  '91313',
#  '91316',
#  '91319',
#  '91320',
#  '91321',
#  '91322',
#  '91324',
#  '91325',
#  '91326',
#  '91327',
#  '91328',
#  '91329',
#  '91330',
#  '91331',
#  '91333',
#  '91334',
#  '91335',
#  '91337',
#  '91340',
#  '91341',
#  '91342',
#  '91343',
#  '91344',
#  '91345',
#  '91346',
#  '91350',
#  '91351',
#  '91352',
#  '91353',
#  '91354',
#  '91355',
#  '91356',
#  '91357',
#  '91358',
#  '91359',
#  '91360',
#  '91361',
#  '91362',
#  '91363',
#  '91364',
#  '91365',
#  '91367',
#  '91371',
#  '91372',
#  '91376',
#  '91377',
#  '91380',
#  '91381',
#  '91382',
#  '91383',
#  '91384',
#  '91385',
#  '91386',
#  '91387',
#  '91388',
#  '91390',
#  '91392',
#  '91393',
#  '91394',
#  '91395',
#  '91396',
#  '91399',
#  '91401',
#  '91402',
#  '91403',
#  '91404',
#  '91405',
#  '91406',
#  '91407',
#  '91408',
#  '91409',
#  '91410',
#  '91411',
#  '91412',
#  '91413',
#  '91416',
#  '91423',
#  '91426',
#  '91436',
#  '91470',
#  '91482',
#  '91495',
#  '91496',
#  '91497',
#  '91499',
#  '91501',
#  '91502',
#  '91503',
#  '91504',
#  '91505',
#  '91506',
#  '91507',
#  '91508',
#  '91510',
#  '91521',
#  '91522',
#  '91523',
#  '91526',
#  '91601',
#  '91602',
#  '91603',
#  '91604',
#  '91605',
#  '91606',
#  '91607',
#  '91608',
#  '91609',
#  '91610',
#  '91611',
#  '91612',
#  '91614',
#  '91615',
#  '91616',
#  '91617',
#  '91618',
#  '91701',
#  '91702',
#  '91706',
#  '91708',
#  '91709',
#  '91710',
#  '91711',
#  '91714',
#  '91715',
#  '91716',
#  '91722',
#  '91723',
#  '91724',
#  '91729',
#  '91730',
#  '91731',
#  '91732',
#  '91733',
#  '91734',
#  '91735',
#  '91737',
#  '91739',
#  '91740',
#  '91741',
#  '91743',
#  '91744',
#  '91745',
#  '91746',
#  '91747',
#  '91748',
#  '91749',
#  '91750',
#  '91752',
#  '91754',
#  '91755',
#  '91756',
#  '91758',
#  '91759',
#  '91761',
#  '91762',
#  '91763',
#  '91764',
#  '91765',
#  '91766',
#  '91767',
#  '91768',
#  '91769',
#  '91770',
#  '91771',
#  '91772',
#  '91773',
#  '91775',
#  '91776',
#  '91778',
#  '91780',
#  '91784',
#  '91785',
#  '91786',
#  '91788',
#  '91789',
#  '91790',
#  '91791',
#  '91792',
#  '91793',
#  '91795',
#  '91797',
#  '91798',
#  '91799',
#  '91801',
#  '91802',
#  '91803',
#  '91804',
#  '91841',
#  '91896',
#  '91899',
#  '91901',
#  '91902',
#  '91903',
#  '91905',
#  '91906',
#  '91908',
#  '91909',
#  '91910',
#  '91911',
#  '91912',
#  '91913',
#  '91914',
#  '91915',
#  '91916',
#  '91917',
#  '91921',
#  '91931',
#  '91932',
#  '91933',
#  '91934',
#  '91935',
#  '91941',
#  '91942',
#  '91943',
#  '91944',
#  '91945',
#  '91946',
#  '91947',
#  '91948',
#  '91950',
#  '91951',
#  '91962',
#  '91963',
#  '91976',
#  '91977',
#  '91978',
#  '91979',
#  '91980',
#  '91987',
#  '91990',
#  '92003',
#  '92004',
#  '92007',
#  '92008',
#  '92009',
#  '92010',
#  '92011',
#  '92013',
#  '92014',
#  '92018',
#  '92019',
#  '92020',
#  '92021',
#  '92022',
#  '92023',
#  '92024',
#  '92025',
#  '92026',
#  '92027',
#  '92028',
#  '92029',
#  '92030',
#  '92033',
#  '92036',
#  '92037',
#  '92038',
#  '92039',
#  '92040',
#  '92046',
#  '92049',
#  '92051',
#  '92052',
#  '92054',
#  '92055',
#  '92056',
#  '92057',
#  '92058',
#  '92059',
#  '92060',
#  '92061',
#  '92064',
#  '92065',
#  '92066',
#  '92067',
#  '92068',
#  '92069',
#  '92070',
#  '92071',
#  '92072',
#  '92074',
#  '92075',
#  '92078',
#  '92079',
#  '92081',
#  '92082',
#  '92083',
#  '92084',
#  '92085',
#  '92086',
#  '92088',
#  '92090',
#  '92091',
#  '92092',
#  '92093',
#  '92096',
#  '92101',
#  '92102',
#  '92103',
#  '92104',
#  '92105',
#  '92106',
#  '92107',
#  '92108',
#  '92109',
#  '92110',
#  '92111',
#  '92112',
#  '92113',
#  '92114',
#  '92115',
#  '92116',
#  '92117',
#  '92118',
#  '92119',
#  '92120',
#  '92121',
#  '92122',
#  '92123',
#  '92124',
#  '92126',
#  '92127',
#  '92128',
#  '92129',
#  '92130',
#  '92131',
#  '92132',
#  '92133',
#  '92134',
#  '92135',
#  '92136',
#  '92137',
#  '92138',
#  '92139',
#  '92140',
#  '92142',
#  '92143',
#  '92145',
#  '92147',
#  '92149',
#  '92150',
#  '92152',
#  '92153',
#  '92154',
#  '92155',
#  '92158',
#  '92159',
#  '92160',
#  '92161',
#  '92162',
#  '92163',
#  '92164',
#  '92165',
#  '92166',
#  '92167',
#  '92168',
#  '92169',
#  '92170',
#  '92171',
#  '92172',
#  '92173',
#  '92174',
#  '92175',
#  '92176',
#  '92177',
#  '92178',
#  '92179',
#  '92182',
#  '92184',
#  '92186',
#  '92187',
#  '92190',
#  '92191',
#  '92192',
#  '92193',
#  '92194',
#  '92195',
#  '92196',
#  '92197',
#  '92198',
#  '92199',
#  '92201',
#  '92202',
#  '92203',
#  '92210',
#  '92211',
#  '92220',
#  '92222',
#  '92223',
#  '92225',
#  '92226',
#  '92227',
#  '92230',
#  '92231',
#  '92232',
#  '92233',
#  '92234',
#  '92235',
#  '92236',
#  '92239',
#  '92240',
#  '92241',
#  '92242',
#  '92243',
#  '92244',
#  '92247',
#  '92248',
#  '92249',
#  '92250',
#  '92251',
#  '92252',
#  '92253',
#  '92254',
#  '92255',
#  '92256',
#  '92257',
#  '92258',
#  '92259',
#  '92260',
#  '92261',
#  '92262',
#  '92263',
#  '92264',
#  '92266',
#  '92267',
#  '92268',
#  '92270',
#  '92273',
#  '92274',
#  '92275',
#  '92276',
#  '92277',
#  '92278',
#  '92280',
#  '92281',
#  '92282',
#  '92283',
#  '92284',
#  '92285',
#  '92286',
#  '92292',
#  '92301',
#  '92304',
#  '92305',
#  '92307',
#  '92308',
#  '92309',
#  '92310',
#  '92311',
#  '92312',
#  '92313',
#  '92314',
#  '92315',
#  '92316',
#  '92317',
#  '92318',
#  '92320',
#  '92321',
#  '92322',
#  '92323',
#  '92324',
#  '92325',
#  '92326',
#  '92327',
#  '92328',
#  '92329',
#  '92331',
#  '92332',
#  '92333',
#  '92334',
#  '92335',
#  '92336',
#  '92337',
#  '92338',
#  '92339',
#  '92340',
#  '92341',
#  '92342',
#  '92344',
#  '92345',
#  '92346',
#  '92347',
#  '92350',
#  '92352',
#  '92354',
#  '92356',
#  '92357',
#  '92358',
#  '92359',
#  '92363',
#  '92364',
#  '92365',
#  '92366',
#  '92368',
#  '92369',
#  '92371',
#  '92372',
#  '92373',
#  '92374',
#  '92375',
#  '92376',
#  '92377',
#  '92378',
#  '92382',
#  '92384',
#  '92385',
#  '92386',
#  '92389',
#  '92391',
#  '92392',
#  '92393',
#  '92394',
#  '92395',
#  '92397',
#  '92398',
#  '92399',
#  '92401',
#  '92402',
#  '92403',
#  '92404',
#  '92405',
#  '92406',
#  '92407',
#  '92408',
#  '92410',
#  '92411',
#  '92412',
#  '92413',
#  '92414',
#  '92415',
#  '92418',
#  '92423',
#  '92424',
#  '92427',
#  '92501',
#  '92502',
#  '92503',
#  '92504',
#  '92505',
#  '92506',
#  '92507',
#  '92508',
#  '92509',
#  '92513',
#  '92514',
#  '92515',
#  '92516',
#  '92517',
#  '92518',
#  '92519',
#  '92521',
#  '92522',
#  '92530',
#  '92531',
#  '92532',
#  '92536',
#  '92539',
#  '92543',
#  '92544',
#  '92545',
#  '92546',
#  '92548',
#  '92549',
#  '92551',
#  '92552',
#  '92553',
#  '92554',
#  '92555',
#  '92556',
#  '92557',
#  '92561',
#  '92562',
#  '92563',
#  '92564',
#  '92567',
#  '92570',
#  '92571',
#  '92572',
#  '92581',
#  '92582',
#  '92583',
#  '92584',
#  '92585',
#  '92586',
#  '92587',
#  '92589',
#  '92590',
#  '92591',
#  '92592',
#  '92593',
#  '92595',
#  '92596',
#  '92599',
#  '92602',
#  '92603',
#  '92604',
#  '92605',
#  '92606',
#  '92607',
#  '92609',
#  '92610',
#  '92612',
#  '92614',
#  '92615',
#  '92616',
#  '92617',
#  '92618',
#  '92619',
#  '92620',
#  '92623',
#  '92624',
#  '92625',
#  '92626',
#  '92627',
#  '92628',
#  '92629',
#  '92630',
#  '92637',
#  '92646',
#  '92647',
#  '92648',
#  '92649',
#  '92650',
#  '92651',
#  '92652',
#  '92653',
#  '92654',
#  '92655',
#  '92656',
#  '92657',
#  '92658',
#  '92659',
#  '92660',
#  '92661',
#  '92662',
#  '92663',
#  '92672',
#  '92673',
#  '92674',
#  ...]

# %%
res_int = [eval(i) for i in res]
res_int
# Out:
# [90001,
#  90002,
#  90003,
#  90004,
#  90005,
#  90006,
#  90007,
#  90008,
#  90009,
#  90010,
#  90011,
#  90012,
#  90013,
#  90014,
#  90015,
#  90016,
#  90017,
#  90018,
#  90019,
#  90020,
#  90021,
#  90022,
#  90023,
#  90024,
#  90025,
#  90026,
#  90027,
#  90028,
#  90029,
#  90030,
#  90031,
#  90032,
#  90033,
#  90034,
#  90035,
#  90036,
#  90037,
#  90038,
#  90039,
#  90040,
#  90041,
#  90042,
#  90043,
#  90044,
#  90045,
#  90046,
#  90047,
#  90048,
#  90049,
#  90050,
#  90051,
#  90052,
#  90053,
#  90054,
#  90055,
#  90056,
#  90057,
#  90058,
#  90059,
#  90060,
#  90061,
#  90062,
#  90063,
#  90064,
#  90065,
#  90066,
#  90067,
#  90068,
#  90069,
#  90070,
#  90071,
#  90072,
#  90073,
#  90074,
#  90075,
#  90076,
#  90077,
#  90078,
#  90079,
#  90080,
#  90081,
#  90082,
#  90083,
#  90084,
#  90086,
#  90087,
#  90088,
#  90089,
#  90090,
#  90091,
#  90093,
#  90094,
#  90095,
#  90096,
#  90099,
#  90101,
#  90102,
#  90103,
#  90134,
#  90189,
#  90201,
#  90202,
#  90209,
#  90210,
#  90211,
#  90212,
#  90213,
#  90220,
#  90221,
#  90222,
#  90223,
#  90224,
#  90230,
#  90231,
#  90232,
#  90233,
#  90239,
#  90240,
#  90241,
#  90242,
#  90245,
#  90247,
#  90248,
#  90249,
#  90250,
#  90251,
#  90254,
#  90255,
#  90260,
#  90261,
#  90262,
#  90263,
#  90264,
#  90265,
#  90266,
#  90267,
#  90270,
#  90272,
#  90274,
#  90275,
#  90277,
#  90278,
#  90280,
#  90290,
#  90291,
#  90292,
#  90293,
#  90294,
#  90295,
#  90296,
#  90301,
#  90302,
#  90303,
#  90304,
#  90305,
#  90306,
#  90307,
#  90308,
#  90309,
#  90310,
#  90311,
#  90312,
#  90313,
#  90397,
#  90398,
#  90401,
#  90402,
#  90403,
#  90404,
#  90405,
#  90406,
#  90407,
#  90408,
#  90409,
#  90410,
#  90411,
#  90501,
#  90502,
#  90503,
#  90504,
#  90505,
#  90506,
#  90507,
#  90508,
#  90509,
#  90510,
#  90601,
#  90602,
#  90603,
#  90604,
#  90605,
#  90606,
#  90607,
#  90608,
#  90609,
#  90610,
#  90612,
#  90620,
#  90621,
#  90622,
#  90623,
#  90624,
#  90630,
#  90631,
#  90632,
#  90633,
#  90637,
#  90638,
#  90639,
#  90640,
#  90650,
#  90651,
#  90652,
#  90659,
#  90660,
#  90661,
#  90662,
#  90670,
#  90671,
#  90680,
#  90701,
#  90702,
#  90703,
#  90704,
#  90706,
#  90707,
#  90710,
#  90711,
#  90712,
#  90713,
#  90714,
#  90715,
#  90716,
#  90717,
#  90720,
#  90721,
#  90723,
#  90731,
#  90732,
#  90733,
#  90734,
#  90740,
#  90742,
#  90743,
#  90744,
#  90745,
#  90746,
#  90747,
#  90748,
#  90749,
#  90755,
#  90801,
#  90802,
#  90803,
#  90804,
#  90805,
#  90806,
#  90807,
#  90808,
#  90809,
#  90810,
#  90813,
#  90814,
#  90815,
#  90822,
#  90831,
#  90832,
#  90833,
#  90834,
#  90835,
#  90840,
#  90842,
#  90844,
#  90845,
#  90846,
#  90847,
#  90848,
#  90853,
#  90888,
#  90895,
#  90899,
#  91001,
#  91003,
#  91006,
#  91007,
#  91008,
#  91009,
#  91010,
#  91011,
#  91012,
#  91016,
#  91017,
#  91020,
#  91021,
#  91023,
#  91024,
#  91025,
#  91030,
#  91031,
#  91040,
#  91041,
#  91042,
#  91043,
#  91046,
#  91066,
#  91077,
#  91101,
#  91102,
#  91103,
#  91104,
#  91105,
#  91106,
#  91107,
#  91108,
#  91109,
#  91110,
#  91114,
#  91115,
#  91116,
#  91117,
#  91118,
#  91121,
#  91123,
#  91124,
#  91125,
#  91126,
#  91129,
#  91131,
#  91182,
#  91184,
#  91185,
#  91188,
#  91189,
#  91191,
#  91199,
#  91201,
#  91202,
#  91203,
#  91204,
#  91205,
#  91206,
#  91207,
#  91208,
#  91209,
#  91210,
#  91214,
#  91221,
#  91222,
#  91224,
#  91225,
#  91226,
#  91301,
#  91302,
#  91303,
#  91304,
#  91305,
#  91306,
#  91307,
#  91308,
#  91309,
#  91310,
#  91311,
#  91313,
#  91316,
#  91319,
#  91320,
#  91321,
#  91322,
#  91324,
#  91325,
#  91326,
#  91327,
#  91328,
#  91329,
#  91330,
#  91331,
#  91333,
#  91334,
#  91335,
#  91337,
#  91340,
#  91341,
#  91342,
#  91343,
#  91344,
#  91345,
#  91346,
#  91350,
#  91351,
#  91352,
#  91353,
#  91354,
#  91355,
#  91356,
#  91357,
#  91358,
#  91359,
#  91360,
#  91361,
#  91362,
#  91363,
#  91364,
#  91365,
#  91367,
#  91371,
#  91372,
#  91376,
#  91377,
#  91380,
#  91381,
#  91382,
#  91383,
#  91384,
#  91385,
#  91386,
#  91387,
#  91388,
#  91390,
#  91392,
#  91393,
#  91394,
#  91395,
#  91396,
#  91399,
#  91401,
#  91402,
#  91403,
#  91404,
#  91405,
#  91406,
#  91407,
#  91408,
#  91409,
#  91410,
#  91411,
#  91412,
#  91413,
#  91416,
#  91423,
#  91426,
#  91436,
#  91470,
#  91482,
#  91495,
#  91496,
#  91497,
#  91499,
#  91501,
#  91502,
#  91503,
#  91504,
#  91505,
#  91506,
#  91507,
#  91508,
#  91510,
#  91521,
#  91522,
#  91523,
#  91526,
#  91601,
#  91602,
#  91603,
#  91604,
#  91605,
#  91606,
#  91607,
#  91608,
#  91609,
#  91610,
#  91611,
#  91612,
#  91614,
#  91615,
#  91616,
#  91617,
#  91618,
#  91701,
#  91702,
#  91706,
#  91708,
#  91709,
#  91710,
#  91711,
#  91714,
#  91715,
#  91716,
#  91722,
#  91723,
#  91724,
#  91729,
#  91730,
#  91731,
#  91732,
#  91733,
#  91734,
#  91735,
#  91737,
#  91739,
#  91740,
#  91741,
#  91743,
#  91744,
#  91745,
#  91746,
#  91747,
#  91748,
#  91749,
#  91750,
#  91752,
#  91754,
#  91755,
#  91756,
#  91758,
#  91759,
#  91761,
#  91762,
#  91763,
#  91764,
#  91765,
#  91766,
#  91767,
#  91768,
#  91769,
#  91770,
#  91771,
#  91772,
#  91773,
#  91775,
#  91776,
#  91778,
#  91780,
#  91784,
#  91785,
#  91786,
#  91788,
#  91789,
#  91790,
#  91791,
#  91792,
#  91793,
#  91795,
#  91797,
#  91798,
#  91799,
#  91801,
#  91802,
#  91803,
#  91804,
#  91841,
#  91896,
#  91899,
#  91901,
#  91902,
#  91903,
#  91905,
#  91906,
#  91908,
#  91909,
#  91910,
#  91911,
#  91912,
#  91913,
#  91914,
#  91915,
#  91916,
#  91917,
#  91921,
#  91931,
#  91932,
#  91933,
#  91934,
#  91935,
#  91941,
#  91942,
#  91943,
#  91944,
#  91945,
#  91946,
#  91947,
#  91948,
#  91950,
#  91951,
#  91962,
#  91963,
#  91976,
#  91977,
#  91978,
#  91979,
#  91980,
#  91987,
#  91990,
#  92003,
#  92004,
#  92007,
#  92008,
#  92009,
#  92010,
#  92011,
#  92013,
#  92014,
#  92018,
#  92019,
#  92020,
#  92021,
#  92022,
#  92023,
#  92024,
#  92025,
#  92026,
#  92027,
#  92028,
#  92029,
#  92030,
#  92033,
#  92036,
#  92037,
#  92038,
#  92039,
#  92040,
#  92046,
#  92049,
#  92051,
#  92052,
#  92054,
#  92055,
#  92056,
#  92057,
#  92058,
#  92059,
#  92060,
#  92061,
#  92064,
#  92065,
#  92066,
#  92067,
#  92068,
#  92069,
#  92070,
#  92071,
#  92072,
#  92074,
#  92075,
#  92078,
#  92079,
#  92081,
#  92082,
#  92083,
#  92084,
#  92085,
#  92086,
#  92088,
#  92090,
#  92091,
#  92092,
#  92093,
#  92096,
#  92101,
#  92102,
#  92103,
#  92104,
#  92105,
#  92106,
#  92107,
#  92108,
#  92109,
#  92110,
#  92111,
#  92112,
#  92113,
#  92114,
#  92115,
#  92116,
#  92117,
#  92118,
#  92119,
#  92120,
#  92121,
#  92122,
#  92123,
#  92124,
#  92126,
#  92127,
#  92128,
#  92129,
#  92130,
#  92131,
#  92132,
#  92133,
#  92134,
#  92135,
#  92136,
#  92137,
#  92138,
#  92139,
#  92140,
#  92142,
#  92143,
#  92145,
#  92147,
#  92149,
#  92150,
#  92152,
#  92153,
#  92154,
#  92155,
#  92158,
#  92159,
#  92160,
#  92161,
#  92162,
#  92163,
#  92164,
#  92165,
#  92166,
#  92167,
#  92168,
#  92169,
#  92170,
#  92171,
#  92172,
#  92173,
#  92174,
#  92175,
#  92176,
#  92177,
#  92178,
#  92179,
#  92182,
#  92184,
#  92186,
#  92187,
#  92190,
#  92191,
#  92192,
#  92193,
#  92194,
#  92195,
#  92196,
#  92197,
#  92198,
#  92199,
#  92201,
#  92202,
#  92203,
#  92210,
#  92211,
#  92220,
#  92222,
#  92223,
#  92225,
#  92226,
#  92227,
#  92230,
#  92231,
#  92232,
#  92233,
#  92234,
#  92235,
#  92236,
#  92239,
#  92240,
#  92241,
#  92242,
#  92243,
#  92244,
#  92247,
#  92248,
#  92249,
#  92250,
#  92251,
#  92252,
#  92253,
#  92254,
#  92255,
#  92256,
#  92257,
#  92258,
#  92259,
#  92260,
#  92261,
#  92262,
#  92263,
#  92264,
#  92266,
#  92267,
#  92268,
#  92270,
#  92273,
#  92274,
#  92275,
#  92276,
#  92277,
#  92278,
#  92280,
#  92281,
#  92282,
#  92283,
#  92284,
#  92285,
#  92286,
#  92292,
#  92301,
#  92304,
#  92305,
#  92307,
#  92308,
#  92309,
#  92310,
#  92311,
#  92312,
#  92313,
#  92314,
#  92315,
#  92316,
#  92317,
#  92318,
#  92320,
#  92321,
#  92322,
#  92323,
#  92324,
#  92325,
#  92326,
#  92327,
#  92328,
#  92329,
#  92331,
#  92332,
#  92333,
#  92334,
#  92335,
#  92336,
#  92337,
#  92338,
#  92339,
#  92340,
#  92341,
#  92342,
#  92344,
#  92345,
#  92346,
#  92347,
#  92350,
#  92352,
#  92354,
#  92356,
#  92357,
#  92358,
#  92359,
#  92363,
#  92364,
#  92365,
#  92366,
#  92368,
#  92369,
#  92371,
#  92372,
#  92373,
#  92374,
#  92375,
#  92376,
#  92377,
#  92378,
#  92382,
#  92384,
#  92385,
#  92386,
#  92389,
#  92391,
#  92392,
#  92393,
#  92394,
#  92395,
#  92397,
#  92398,
#  92399,
#  92401,
#  92402,
#  92403,
#  92404,
#  92405,
#  92406,
#  92407,
#  92408,
#  92410,
#  92411,
#  92412,
#  92413,
#  92414,
#  92415,
#  92418,
#  92423,
#  92424,
#  92427,
#  92501,
#  92502,
#  92503,
#  92504,
#  92505,
#  92506,
#  92507,
#  92508,
#  92509,
#  92513,
#  92514,
#  92515,
#  92516,
#  92517,
#  92518,
#  92519,
#  92521,
#  92522,
#  92530,
#  92531,
#  92532,
#  92536,
#  92539,
#  92543,
#  92544,
#  92545,
#  92546,
#  92548,
#  92549,
#  92551,
#  92552,
#  92553,
#  92554,
#  92555,
#  92556,
#  92557,
#  92561,
#  92562,
#  92563,
#  92564,
#  92567,
#  92570,
#  92571,
#  92572,
#  92581,
#  92582,
#  92583,
#  92584,
#  92585,
#  92586,
#  92587,
#  92589,
#  92590,
#  92591,
#  92592,
#  92593,
#  92595,
#  92596,
#  92599,
#  92602,
#  92603,
#  92604,
#  92605,
#  92606,
#  92607,
#  92609,
#  92610,
#  92612,
#  92614,
#  92615,
#  92616,
#  92617,
#  92618,
#  92619,
#  92620,
#  92623,
#  92624,
#  92625,
#  92626,
#  92627,
#  92628,
#  92629,
#  92630,
#  92637,
#  92646,
#  92647,
#  92648,
#  92649,
#  92650,
#  92651,
#  92652,
#  92653,
#  92654,
#  92655,
#  92656,
#  92657,
#  92658,
#  92659,
#  92660,
#  92661,
#  92662,
#  92663,
#  92672,
#  92673,
#  92674,
#  ...]

# %% [markdown]
# ---

# %%
from uszipcode import SearchEngine
engine = SearchEngine()
zipcodes = engine.by_city_and_state(city="Los Angeles", state="california")
for zipcode in zipcodes:
    print(zipcode.zipcode, zipcode.major_city, zipcode.population, zipcode.state)
# Out:
# 90001 Los Angeles 57110 CA
# 90002 Los Angeles 51223 CA
# 90003 Los Angeles 66266 CA
# 90004 Los Angeles 62180 CA
# 90005 Los Angeles 37681 CA

# %%
from uszipcode import SearchEngine
engine = SearchEngine()
zipcodes = engine.by_state(state="CA")
for zipcode in zipcodes:
    print(zipcode.zipcode)
#zipcodes
# Out:
# 90001
# 90002
# 90003
# 90004
# 90005

# %%
bernie_2016p['a'] = [x[:5] for x in bernie_2016p['contbr_zip'] ]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 1>()
# ----> 1 bernie_2016p['a'] = [x[:5] for x in bernie_2016p['contbr_zip'] ]
#
# Input In [22], in <listcomp>(.0)
# ----> 1 bernie_2016p['a'] = [x[:5] for x in bernie_2016p['contbr_zip'] ]
#
# TypeError: 'float' object is not subscriptable

# %%
#print(bernie_2016p['contbr_zip'][:5])

bernie_2016p['contbr_zip']#.str.extract(r"(\d{5})")

# %% [markdown]
# ---

# %% [markdown]
# **2d.** The receipt amount column has negative donations. After talking with your team, a decision was made that the best course of action is to remove these negative values so that the donation count and amount is more accurate. Print/show the shape of the dataframe after the filtering is complete. (5 points)

# %%
# 2d YOUR CODE HERE

# %% [markdown]
# **2e.** From the dataset drop any columns that won't be used in the analysis. Print/show the shape of the dataframe after the dropping is complete. What columns did you drop and why? (5 points)

# %%
# 2e YOUR CODE HERE

# %% [markdown]
# - **2e answer here:**

# %% [markdown]
# **2f.** List any assumptions that you made up to this point:

# %% [markdown]
# - **2f answer here:**

# %% [markdown]
# ***
# ## 3. Answering the questions (20 points)
#
# Now that the data is cleaned and filterd - let's answer the two questions from your boss!

# %% [markdown]
# **3a.** Which zipcode had the highest count of contributions and the most dollar amount? (10 points)

# %%
# 3a YOUR CODE HERE

# %% [markdown]
# - **3a answer here:**

# %% [markdown]
# **3b.** What day(s) of the month do most people donate? (10 points)

# %%
# 3b YOUR CODE HERE

# %% [markdown]
# - **3b answer here:**

# %% [markdown]
# ## If you have feedback for this homework, please submit it using the link below:
#
# http://goo.gl/forms/74yCiQTf6k
