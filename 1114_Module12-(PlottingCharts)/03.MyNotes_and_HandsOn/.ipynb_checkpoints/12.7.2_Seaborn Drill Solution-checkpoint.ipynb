# %% [markdown]
# # Seaborn - Plotting with Python
#
# ### Python and Plotting
# Plotting data is facilitated using a number of tools - python's own drawing tools and a many libraries & plug-ins. In this drill, we explore a number of plot actions for a basis and then integrate data that you manipulate with numpy and pandas.
#
# ### Helpful Tools
# There are lots of helpful tools and demos in GitHub, some of which have been used in this drill set.  Some most common plotting examples: bar plot, scatter, line plots, histograms, and (others).
#
# ### Why visualize?
# The main points of visualizing data is to communicate to the viewer (a) trends in the data, group membership (and when a member of one group intersects with another), unusual "events" or "interesting events" that warrant futher investigation, and an understanding of both the big picture of the data and the subsets (or clusters, classifications) that collectively tell a compelling story.  Adding interactivity either programmatically moving the data over a timeline or letting the user select details-on-demand really underscores the communicative goal of your cool programming.

# %% [markdown]
# ## Data prep
#
# 1) Import numpy, pandas, matplotlib and seaborn
# 2) Load the file "travelData.csv" - this is a file of world travel data from the The World Bank https://data.worldbank.org/indicator/ST.INT.ARVL.
#
# 3) Do some quick exploration of the data like what are the columns and rows?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
trav = pd.read_csv('travelData.csv')
trav.head()
# Out:
#   Country_Name Code                             Indicator_Name     Ind_Code  \
# 0        Aruba  ABW  International tourism, number of arrivals  ST.INT.ARVL
# 1  Afghanistan  AFG  International tourism, number of arrivals  ST.INT.ARVL
# 2       Angola  AGO  International tourism, number of arrivals  ST.INT.ARVL
# 3      Albania  ALB  International tourism, number of arrivals  ST.INT.ARVL
# 4      Andorra  AND  International tourism, number of arrivals  ST.INT.ARVL
#
#        1995      1996      1997      1998       1999       2000  ...  \
# 0  619000.0  641000.0  650000.0  647000.0   683000.0   721000.0  ...
# 1       NaN       NaN       NaN       NaN        NaN        NaN  ...
# 2    9000.0   21000.0   45000.0   52000.0    45000.0    51000.0  ...
# 3  304000.0  287000.0  119000.0  184000.0   371000.0   317000.0  ...
# 4       NaN       NaN       NaN       NaN  2347000.0  2949000.0  ...
#
#         2007       2008       2009       2010       2011       2012  \
# 0   772000.0   827000.0   813000.0   824000.0   869000.0   904000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   195000.0   294000.0   366000.0   425000.0   481000.0   528000.0
# 3  1062000.0  1247000.0  1711000.0  2191000.0  2469000.0  3156000.0
# 4  2189000.0  2059000.0  1830000.0  1808000.0  2242000.0  2238000.0
#
#         2013       2014       2015       2016
# 0   979000.0  1072000.0  1225000.0  1102000.0
# 1        NaN        NaN        NaN        NaN
# 2   650000.0   595000.0   592000.0   397000.0
# 3  2857000.0  3341000.0  3784000.0  4070000.0
# 4  2328000.0  2363000.0  2663000.0  2831000.0
#
# [5 rows x 26 columns]

# %%
travel = pd.read_csv('travelData.csv')
travel.head()
# Out:
#   Country_Name Code                             Indicator_Name     Ind_Code  \
# 0        Aruba  ABW  International tourism, number of arrivals  ST.INT.ARVL
# 1  Afghanistan  AFG  International tourism, number of arrivals  ST.INT.ARVL
# 2       Angola  AGO  International tourism, number of arrivals  ST.INT.ARVL
# 3      Albania  ALB  International tourism, number of arrivals  ST.INT.ARVL
# 4      Andorra  AND  International tourism, number of arrivals  ST.INT.ARVL
#
#        1995      1996      1997      1998       1999       2000  ...  \
# 0  619000.0  641000.0  650000.0  647000.0   683000.0   721000.0  ...
# 1       NaN       NaN       NaN       NaN        NaN        NaN  ...
# 2    9000.0   21000.0   45000.0   52000.0    45000.0    51000.0  ...
# 3  304000.0  287000.0  119000.0  184000.0   371000.0   317000.0  ...
# 4       NaN       NaN       NaN       NaN  2347000.0  2949000.0  ...
#
#         2007       2008       2009       2010       2011       2012  \
# 0   772000.0   827000.0   813000.0   824000.0   869000.0   904000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   195000.0   294000.0   366000.0   425000.0   481000.0   528000.0
# 3  1062000.0  1247000.0  1711000.0  2191000.0  2469000.0  3156000.0
# 4  2189000.0  2059000.0  1830000.0  1808000.0  2242000.0  2238000.0
#
#         2013       2014       2015       2016
# 0   979000.0  1072000.0  1225000.0  1102000.0
# 1        NaN        NaN        NaN        NaN
# 2   650000.0   595000.0   592000.0   397000.0
# 3  2857000.0  3341000.0  3784000.0  4070000.0
# 4  2328000.0  2363000.0  2663000.0  2831000.0
#
# [5 rows x 26 columns]

# %%
travel['Indicator_Name'].unique()
# Out:
# array(['International tourism, number of arrivals'], dtype=object)

# %%
travel['Ind_Code'].unique()
# Out:
# array(['ST.INT.ARVL'], dtype=object)

# %%
travel.columns
# Out:
# Index(['Country_Name', 'Code', 'Indicator_Name', 'Ind_Code', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
trav.columns
# Out:
# Index(['Country_Name', 'Code', 'Indicator_Name', 'Ind_Code', '1995', '1996',
#        '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005',
#        '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014',
#        '2015', '2016'],
#       dtype='object')

# %%
travel.shape
# Out:
# (220, 26)

# %%
trav.shape
# Out:
# (220, 26)

# %%
trav['Code'].value_counts(dropna=False)
# Out:
# CUB    1
# BRN    1
# SRB    1
# USA    1
# SEN    1
# CAN    1
# DOM    1
# DJI    1
# IRN    1
# MUS    1
# BEL    1
# EST    1
# ETH    1
# TUR    1
# NIC    1
# LKA    1
# GRL    1
# MDA    1
# COM    1
# GIB    1
# CZE    1
# HKG    1
# SOM    1
# SWE    1
# BHR    1
# BLR    1
# TON    1
# ZMB    1
# SWZ    1
# VUT    1
#       ..
# NOR    1
# AFG    1
# MWI    1
# KWT    1
# CYP    1
# PNG    1
# ARG    1
# AZE    1
# CRI    1
# DMA    1
# RUS    1
# HUN    1
# PSE    1
# FJI    1
# MEX    1
# UKR    1
# GEO    1
# BLZ    1
# LVA    1
# LBY    1
# FIN    1
# TCA    1
# CMR    1
# BGR    1
# COL    1
# CPV    1
# SVK    1
# FSM    1
# MAR    1
# GHA    1
# Name: Code, Length: 220, dtype: int64

# %%
travel['Code'].value_counts(dropna = False)
# Out:
# ABW    1
# OMN    1
# NAC    1
# NAM    1
# NCL    1
#       ..
# GNQ    1
# GRC    1
# GRD    1
# GRL    1
# ZWE    1
# Name: Code, Length: 220, dtype: int64

# %% [markdown]
# ### Bar Chart
#
# Use Seaborn to make a bar chart showing the top 10 countries with the most travelers for the year 2016.

# %%
travel_2016 = travel[['Country_Name', '2016']]
travel_2016
# Out:
#      Country_Name        2016
# 0           Aruba   1102000.0
# 1     Afghanistan         NaN
# 2          Angola    397000.0
# 3         Albania   4070000.0
# 4         Andorra   2831000.0
# ..            ...         ...
# 215        Kosovo         NaN
# 216   Yemen, Rep.         NaN
# 217  South Africa  10044000.0
# 218        Zambia    956000.0
# 219      Zimbabwe   2168000.0
#
# [220 rows x 2 columns]

# %%
travel_2016 = travel[['Country_Name', '2016']]
#travel_2016

travel_2016_top10 = travel_2016.sort_values(['2016'], ascending = False)

travel_2016_top10
# Out:
#               Country_Name         2016
# 58               Euro area  364655000.0
# 140          North America   95676000.0
# 65                  France   82570000.0
# 206          United States   75608000.0
# 60                   Spain   75315000.0
# ..                     ...          ...
# 195           Turkmenistan          NaN
# 207             Uzbekistan          NaN
# 211  Virgin Islands (U.S.)          NaN
# 215                 Kosovo          NaN
# 216            Yemen, Rep.          NaN
#
# [220 rows x 2 columns]

# %%
travel_2016 = travel[['Country_Name', '2016']]
#travel_2016

travel_2016_top10 = travel_2016.sort_values(['2016'], ascending = False)

travel_2016_top10.head(10)
# Out:
#        Country_Name         2016
# 58        Euro area  364655000.0
# 140   North America   95676000.0
# 65           France   82570000.0
# 206   United States   75608000.0
# 60            Spain   75315000.0
# 36            China   59270000.0
# 96            Italy   52372000.0
# 69   United Kingdom   35814000.0
# 50          Germany   35555000.0
# 126          Mexico   35079000.0

# %%
# Subsetting to just 2016 /sorting to get the top 10 countries

trav2016 = trav[['Country_Name', '2016']]
bar = trav2016.sort_values(['2016'], ascending = False)
bar.head(10)
# Out:
#        Country_Name         2016
# 58        Euro area  364655000.0
# 140   North America   95676000.0
# 65           France   82570000.0
# 206   United States   75608000.0
# 60            Spain   75315000.0
# 36            China   59270000.0
# 96            Italy   52372000.0
# 69   United Kingdom   35814000.0
# 50          Germany   35555000.0
# 126          Mexico   35079000.0

# %%
# dropping two of the values

# %%
travel_2016_top10.drop([58, 140], inplace = True)

#travel_2016_top10.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 travel_2016_top10.drop([58, 140], inplace = True)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: '[58, 140] not found in axis'

# %%
travel_2016_top10.head(10)
# Out:
#        Country_Name        2016
# 65           France  82570000.0
# 206   United States  75608000.0
# 60            Spain  75315000.0
# 36            China  59270000.0
# 96            Italy  52372000.0
# 69   United Kingdom  35814000.0
# 50          Germany  35555000.0
# 126          Mexico  35079000.0
# 193        Thailand  32530000.0
# 200          Turkey  30289000.0

# %%
# Dropping records #58 & 140 because they are areas not countries
bar.drop([58,140], inplace=True)
bar.head(10)
# Out:
#        Country_Name        2016
# 65           France  82570000.0
# 206   United States  75608000.0
# 60            Spain  75315000.0
# 36            China  59270000.0
# 96            Italy  52372000.0
# 69   United Kingdom  35814000.0
# 50          Germany  35555000.0
# 126          Mexico  35079000.0
# 193        Thailand  32530000.0
# 200          Turkey  30289000.0

# %%
plt.figure(figsize = (12,8))

ax = sns.barplot(x = 'Country_Name', y = '2016', data = travel_2016_top10.head(10))

# %%
plt.figure(figsize = (12,8))

ax = sns.barplot(x = 'Country_Name', y = '2016', data = travel_2016_top10.head(10))

plt.xticks(rotation = 90)
plt.title('My Title')
plt.show()

# %%
plt.figure(figsize=(12,8))
ax = sns.barplot(x='Country_Name', y='2016', data=bar.head(10))
plt.xticks(rotation='vertical')
plt.title('Top 10 Countries by # of travelers in 2016')
plt.show()

# %% [markdown]
# ### Scatterplot
#
# Let's add some more data to our analysis - load the file named 'ruralPop.csv'.
#
# Using both files, plot a scatterplot with the x-axis being the rural pop of the nation and the y-axis being the # of travelers from that nation for the year 2016.

# %%
# Read in the dataset and take a look at it

rur = pd.read_csv('ruralPop.csv')
rur.head()
# Out:
#   Country Name Country Code    Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  
# 1  25165917.0  25877997.0  26530269.0
# 2  10040932.0  10192857.0  10340319.0
# 3   1258985.0   1226200.0   1195854.0
# 4      9156.0      9092.0      9084.0
#
# [5 rows x 61 columns]

# %%
# Subset both datasets for just the columns we need

trav2016 = trav[['Country_Name', 'Code', '2016']]
rur2016 = rur[['Country_Code', '2016']]

# Rename the columns (it easiest to join on a common column) 
# If you don't rename the columns than columns will be renamed on the join with an x or y
# for example 2016 will be renamed to 2016_x which then you'll have to remember if thats the pop or travelers

trav2016.columns = ['Country_Name', 'Code', 'Trav_2016']
rur2016.columns = ['Code', 'Rur_Pop_2016']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [35], in <cell line: 3>()
#       1 # Subset both datasets for just the columns we need
# ----> 3 trav2016 = trav[['Country_Name', 'Code', '2016']]
#       4 rur2016 = rur[['Country_Code', '2016']]
#       6 # Rename the columns (it easiest to join on a common column)
#       7 # If you don't rename the columns than columns will be renamed on the join with an x or y
#       8 # for example 2016 will be renamed to 2016_x which then you'll have to remember if thats the pop or travelers
#
# NameError: name 'trav' is not defined

# %%
rural.columns
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016'],
#       dtype='object')

# %%
travel2 = pd.read_csv('travelData.csv')
travel2.head()

travel2_2016 = travel2[['Country_Name', 'Code', '2016']]
travel2_2016.head()

rural_2016 = rural[['Country Code', '2016']]
#rural_2016.head()
# travel2_2016.head()
# Out:
#   Country_Name Code       2016
# 0        Aruba  ABW  1102000.0
# 1  Afghanistan  AFG        NaN
# 2       Angola  AGO   397000.0
# 3      Albania  ALB  4070000.0
# 4      Andorra  AND  2831000.0

# %%
#rename columns

# %%
travel2 = pd.read_csv('travelData.csv')
travel2.head()

travel2_2016 = travel2[['Country_Name', 'Code', '2016']]
rural_2016 = rural[['Country Code', '2016']]

travel2_2016.columns = ['Country_Name', 'Code', '2016']

rural_2016.columns = ['Code', 'Rur_Pop_2016']

# %%
travel2_2016.head()
# Out:
#   Country_Name Code       2016
# 0        Aruba  ABW  1102000.0
# 1  Afghanistan  AFG        NaN
# 2       Angola  AGO   397000.0
# 3      Albania  ALB  4070000.0
# 4      Andorra  AND  2831000.0

# %%
rural_2016.head()
# Out:
#   Code  Rur_Pop_2016
# 0  ABW       59576.0
# 1  AFG    26530269.0
# 2  AGO    10340319.0
# 3  ALB     1195854.0
# 4  AND        9084.0

# %%
# Merge on the 'Code' field - just taking the common records (inner join)

tot = pd.merge(left=trav2016, right=rur2016, on='Code', how='inner')

# %%
# inner join on Code

# %%
total = pd.merge(left = travel2_2016, right = rural_2016, on = 'Code', how = 'inner')

# %%
total.head()
# Out:
#   Country_Name Code       2016  Rur_Pop_2016
# 0        Aruba  ABW  1102000.0       59576.0
# 2       Angola  AGO   397000.0    10340319.0
# 3      Albania  ALB  4070000.0     1195854.0
# 4      Andorra  AND  2831000.0        9084.0
# 6    Argentina  ARG  5559000.0     3649822.0

# %%
# Nas in the data... 

tot.head()
# Out:
#   Country_Name Code  Trav_2016  Rur_Pop_2016
# 0        Aruba  ABW  1102000.0       59576.0
# 1  Afghanistan  AFG        NaN    26530269.0
# 2       Angola  AGO   397000.0    10340319.0
# 3      Albania  ALB  4070000.0     1195854.0
# 4      Andorra  AND  2831000.0        9084.0

# %%
# Dropping NAs due to not knowing what those could be and it might mess up the analysis
# (could be there was no data reported)

tot.dropna(inplace=True)
tot.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 4>()
#       1 # Dropping NAs due to not knowing what those could be and it might mess up the analysis
#       2 # (could be there was no data reported)
# ----> 4 tot.dropna(inplace=True)
#       5 tot.head()
#
# NameError: name 'tot' is not defined

# %%
# drop the NaN field

# %%
total.dropna(inplace = True)
total.head()
# Out:
#   Country_Name Code       2016  Rur_Pop_2016
# 0        Aruba  ABW  1102000.0       59576.0
# 2       Angola  AGO   397000.0    10340319.0
# 3      Albania  ALB  4070000.0     1195854.0
# 4      Andorra  AND  2831000.0        9084.0
# 6    Argentina  ARG  5559000.0     3649822.0

# %%
plt.figure(figsize = (12,10))

ax = sns.scatterplot(x = 'Rur_Pop_2016', y = '2016', data = total)
plt.title('Rural population by # of Travelers per Country')
plt.show()

# %%
plt.figure(figsize=(12,10))
ax = sns.scatterplot(x='Rur_Pop_2016', y='Trav_2016', data=tot)
plt.title('Rural population by # of Travelers per Country')
plt.show()

# %% [markdown]
# ### Heatmap
#
# Finally, make a heat map with the top 10 countries (found above in the bar chart) on the y-axis and the years 2000-2016 on the x-axis.

# %%
# heat map

# %%
travel_sub = travel.drop(['Code', 'Indicator_Name', 'Ind_Code', '1995', '1996', '1997', '1998', '1999',], axis=1)

travel_sub.head()
# Out:
#   Country_Name       2000       2001       2002       2003       2004  \
# 0        Aruba   721000.0   691000.0   643000.0   642000.0   728000.0
# 1  Afghanistan        NaN        NaN        NaN        NaN        NaN
# 2       Angola    51000.0    67000.0    91000.0   107000.0   194000.0
# 3      Albania   317000.0   354000.0   470000.0   557000.0   645000.0
# 4      Andorra  2949000.0  3516000.0  3387000.0  3138000.0  2791000.0
#
#         2005       2006       2007       2008       2009       2010  \
# 0   733000.0   694000.0   772000.0   827000.0   813000.0   824000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   210000.0   121000.0   195000.0   294000.0   366000.0   425000.0
# 3   748000.0   937000.0  1062000.0  1247000.0  1711000.0  2191000.0
# 4  2418000.0  2227000.0  2189000.0  2059000.0  1830000.0  1808000.0
#
#         2011       2012       2013       2014       2015       2016
# 0   869000.0   904000.0   979000.0  1072000.0  1225000.0  1102000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2   481000.0   528000.0   650000.0   595000.0   592000.0   397000.0
# 3  2469000.0  3156000.0  2857000.0  3341000.0  3784000.0  4070000.0
# 4  2242000.0  2238000.0  2328000.0  2363000.0  2663000.0  2831000.0

# %%
travel.head()
# Out:
#   Country_Name Code                             Indicator_Name     Ind_Code  \
# 0        Aruba  ABW  International tourism, number of arrivals  ST.INT.ARVL
# 1  Afghanistan  AFG  International tourism, number of arrivals  ST.INT.ARVL
# 2       Angola  AGO  International tourism, number of arrivals  ST.INT.ARVL
# 3      Albania  ALB  International tourism, number of arrivals  ST.INT.ARVL
# 4      Andorra  AND  International tourism, number of arrivals  ST.INT.ARVL
#
#        1995      1996      1997      1998       1999       2000  ...  \
# 0  619000.0  641000.0  650000.0  647000.0   683000.0   721000.0  ...
# 1       NaN       NaN       NaN       NaN        NaN        NaN  ...
# 2    9000.0   21000.0   45000.0   52000.0    45000.0    51000.0  ...
# 3  304000.0  287000.0  119000.0  184000.0   371000.0   317000.0  ...
# 4       NaN       NaN       NaN       NaN  2347000.0  2949000.0  ...
#
#         2007       2008       2009       2010       2011       2012  \
# 0   772000.0   827000.0   813000.0   824000.0   869000.0   904000.0
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 
# 50   26875000.0  28374000.0  30411000.0  31545000.0  32999000.0  34970000.0
# 126  23290000.0  23403000.0  23403000.0  24151000.0  29346000.0  32093000.0
# 193  15936000.0  19230000.0  22354000.0  26547000.0  24810000.0  29923000.0
# 200  31364000.0  34654000.0  35698000.0  37795000.0  39811000.0  39478000.0
#
#            2016
# 65   82570000.0
# 206  75608000.0
# 60   75315000.0
# 36   59270000.0
# 96   52372000.0
# 69   35814000.0
# 50   35555000.0
# 126  35079000.0
# 193  32530000.0
# 200  30289000.0

# %%
travel_top10.columns
# Out:
# Index(['2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016'],
#       dtype='object')

# %%
travel_top10.set_index('Country Name', inplace = True)

travel_top10.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [76], in <cell line: 1>()
# ----> 1 travel_top10.set_index('Country Name', inplace = True)
#       3 travel_top10.head()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:5494, in DataFrame.set_index(self, keys, drop, append, inplace, verify_integrity)
#    5491                 missing.append(col)
#    5493 if missing:
# -> 5494     raise KeyError(f"None of {missing} are in the columns")
#    5496 if inplace:
#    5497     frame = self
#
# KeyError: "None of ['Country Name'] are in the columns"

# %%
travel_top10.head()
# Out:
#                      2000        2001        2002        2003        2004  \
# Country_Name
# France         77190000.0  75202000.0  77012000.0  75048000.0  74433000.0
# United States  51238000.0  46927000.0  43581000.0  41218000.0  46086000.0
# Spain          46403000.0  48565000.0  50331000.0  50854000.0  52430000.0
# China          31229000.0  33167000.0  36803000.0  32970000.0  41761000.0
# Italy          41181000.0  39563000.0  39799000.0  39604000.0  37071000.0
#
#                      2005        2006        2007        2008        2009  \
# Country_Name
# France         74988000.0  77916000.0  80853000.0  79218000.0  76764000.0
# United States  49206000.0  50977000.0  56135000.0  58007000.0  55103000.0
# Spain          55914000.0  58004000.0  58666000.0  57192000.0  52178000.0
# China          46809000.0  49913000.0  54720000.0  53049000.0  50875000.0
# Italy          36513000.0  41058000.0  43654000.0  42734000.0  43239000.0
#
#                      2010        2011        2012        2013        2014  \
# Country_Name
# France         76647000.0  80499000.0  81980000.0  83634000.0  83701000.0
# United States  60010000.0  62821000.0  66657000.0  69995000.0  75022000.0
# Spain          52677000.0  56177000.0  57464000.0  60675000.0  64939000.0
# China          55664000.0  57581000.0  57725000.0  55686000.0  55622000.0
# Italy          43626000.0  46119000.0  46360000.0  47704000.0  48576000.0
#
#                      2015        2016
# Country_Name
# France         84452000.0  82570000.0
# United States  77465000.0  75608000.0
# Spain          68175000.0  75315000.0
# China          56886000.0  59270000.0
# Italy          50732000.0  52372000.0

# %%
plt.figure(figsize = (12,10))

ax = sns.heatmap(travel_top10)

plt.title('My Title')
plt.show()

# %%
# Subsetting the travelers df to just the columns we want (dropping the others)
trav_sub = trav.drop(['Code', 'Indicator_Name', 'Ind_Code', '1995', '1996', '1997', '1998', '1999',], axis=1)

# dropping NAs as well as the groups (that aren't countries)
trav_sub.dropna()
trav_sub.drop([58,140], inplace=True)

# Sorting by the top 10 countries
trav10 = trav_sub.sort_values(['2016'], ascending = False).head(10)

# %%
# Making the index the country name to be used as the y-axis

trav10.set_index('Country_Name', inplace=True)

# %%
plt.figure(figsize=(12,10))
ax = sns.heatmap(trav10)
plt.title('Travelers by year per Top 10 Countries')
plt.show()
