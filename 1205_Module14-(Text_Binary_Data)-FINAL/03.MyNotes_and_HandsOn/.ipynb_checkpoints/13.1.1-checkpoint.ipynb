# %% [markdown]
# # 13.1.1

# %% [markdown]
# ![image.png](attachment:8f63c74c-8b0d-4e2b-9b07-cea224cab32c.png)

# %% [markdown]
# ![image.png](attachment:98eeca73-092c-486c-99b3-f18961451391.png)

# %% [markdown]
# ## split, apply, combibe workflow

# %% [markdown]
# ![image.png](attachment:8f16b199-4ea1-472a-9d0f-c3839f7fe6e7.png)

# %%
# similar to map-reduce architecture

### here groups are sent off to different compueters

# %%
# fundamental to parallel computation architectures

# %% [markdown]
# ---

# %% [markdown]
# # Series.groupby

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# tripadvisor

# %% [markdown]
# #### data source

# %% [markdown]
# ![image.png](attachment:66fa686f-6e4e-4ff7-867d-20c53e1df767.png)

# %%
Vegas = pd.read_csv('
