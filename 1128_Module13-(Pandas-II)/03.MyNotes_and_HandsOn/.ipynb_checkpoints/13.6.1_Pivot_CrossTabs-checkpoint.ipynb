# %% [markdown]
# # Pivot Tables and Crosstabs

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import matplotlib.pyplot as plt
# %matplotlib inline


Vegas = pd.read_csv('vegas.csv')
Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()
Vegas.columns
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_57943/1923321273.py:9: FutureWarning: The default value of regex will change from True to False in a future version.
#   Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()
# Index(['user_country', 'nr_reviews', 'nr_hotel_reviews', 'helpful_votes',
#        'score', 'period_of_stay', 'traveler_type', 'pool', 'gym',
#        'tennis_court', 'spa', 'casino', 'free_internet', 'hotel_name',
#        'hotel_stars', 'nr_rooms', 'user_continent', 'member_years',
#        'review_month', 'review_weekday'],
#       dtype='object')

# %% [markdown]
# ![image.png](attachment:fe3e7fe8-b3e9-43f5-a0b2-7807cbab1f4e.png)

# %%
# simple application of GROUPBY and AGG

# %%
# DataFrame.pivot_table()

# %%
# pd.pivot_table()

# %% [markdown]
# ---

# %%
H = pd.read_csv("gnhotels01.csv")

# %%
H
# Out:
#                                            hotel_name  mean_score  \
# 0                                  Bellagio Las Vegas        4.21
# 1                                      Caesars Palace        4.12
# 2              Circus Circus Hotel & Casino Las Vegas        3.21
# 3                            Encore at wynn Las Vegas        4.54
# 4                            Excalibur Hotel & Casino        3.71
# 5              Hilton Grand Vacations at the Flamingo        3.96
# 6             Hilton Grand Vacations on the Boulevard        4.17
# 7                            Marriott's Grand Chateau        4.54
# 8                           Monte Carlo Resort&Casino        3.29
# 9                                     Paris Las Vegas        4.04
# 10                         The Cosmopolitan Las Vegas        4.25
# 11                                       The Cromwell        4.08
# 12                    The Palazzo Resort Hotel Casino        4.38
# 13                       The Venetian Las Vegas Hotel        4.58
# 14            The Westin las Vegas Hotel Casino & Spa        3.92
# 15                 Treasure Island- TI Hotel & Casino        3.96
# 16  Tropicana Las Vegas - A Double Tree by Hilton ...        4.04
# 17                Trump International Hotel Las Vegas        4.38
# 18                  Tuscany Las Vegas Suites & Casino        4.21
# 19                               Wyndham Grand Desert        4.38
# 20                                     Wynn Las Vegas        4.62
#
#     percent_non_usa  gym tennis_court  spa casino free_internet hotel_stars  \
# 0              0.67  YES           NO  YES    YES           YES           5
# 1              0.42  YES           NO  YES    YES           YES           5
# 2              0.58  YES           NO   NO    YES           YES           3
# 3              0.42  YES           NO  YES    YES           YES           5
# 4              0.75  YES           NO  YES    YES           YES           3
# 5              0.50  YES           NO   NO     NO           YES           3
# 6              0.58  YES           NO  YES    YES           YES         3,5
# 7              0.67  YES           NO   NO    YES           YES         3,5
# 8              0.75  YES           NO  YES    YES            NO           4
# 9              0.38  YES           NO  YES    YES           YES           4
# 10             0.62  YES           NO  YES    YES           YES           5
# 11             0.38   NO           NO   NO    YES           YES         4,5
# 12             0.58  YES           NO  YES    YES           YES           5
# 13             0.71  YES           NO  YES    YES           YES           5
# 14             0.29  YES           NO  YES    YES           YES           4
# 15             0.75  YES          YES  YES    YES           YES           4
# 16             0.92  YES          YES  YES    YES           YES           4
# 17             0.54  YES           NO  YES    YES           YES           5
# 18             0.46  YES          YES  YES    YES           YES           3
# 19             0.50  YES          YES   NO     NO           YES         3,5
# 20             0.50  YES          YES  YES    YES           YES           5
#
#     nr_rooms
# 0       3933
# 1       3348
# 2       3773
# 3       2034
# 4       3981
# 5        315
# 6       1228
# 7        732
# 8       3003
# 9       2916
# 10      2959
# 11       188
# 12      3025
# 13      4027
# 14       826
# 15      2884
# 16      1467
# 17      1282
# 18       716
# 19       787
# 20      2700

# %%
# change index

# %%
H = pd.read_csv("gnhotels01.csv", index_col = "hotel_name")

# %%
H.head(5)
# Out:
#                                         mean_score  percent_non_usa  gym  \
# hotel_name
# Bellagio Las Vegas                            4.21             0.67  YES
# Caesars Palace                                4.12             0.42  YES
# Circus Circus Hotel & Casino Las Vegas        3.21             0.58  YES
# Encore at wynn Las Vegas                      4.54             0.42  YES
# Excalibur Hotel & Casino                      3.71             0.75  YES
#
#                                        tennis_court  spa casino free_internet  \
# hotel_name
# Bellagio Las Vegas                               NO  YES    YES           YES
# Caesars Palace                                   NO  YES    YES           YES
# Circus Circus Hotel & Casino Las Vegas           NO   NO    YES           YES
# Encore at wynn Las Vegas                         NO  YES    YES           YES
# Excalibur Hotel & Casino                         NO  YES    YES           YES
#
#                                        hotel_stars  nr_rooms
# hotel_name
# Bellagio Las Vegas                               5      3933
# Caesars Palace                                   5      3348
# Circus Circus Hotel & Casino Las Vegas           3      3773
# Encore at wynn Las Vegas                         5      2034
# Excalibur Hotel & Casino                         3      3981

# %% [markdown]
# ---

# %% [markdown]
# # Create Pivot Table

# %% [markdown]
# ### 3 aspects

# %%
# 1.. which is the mean (aggregation function)

# 2. what is the key for the y axis

# 3. key for the columns

# %%
# WRONG

# H = pd.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_57943/3883088764.py in <module>
# ----> 1 H = pd.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa')
#
# TypeError: pivot_table() missing 1 required positional argument: 'data'

# %%
H.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa')
# Out:
# spa            NO  YES
# tennis_court
# NO           3.95 4.13
# YES          4.38 4.21

# %% [markdown]
# ---

# %% [markdown]
# ## pass in list of keys

# %%
# H.pivot_table(values = 'mean_score', index = ['tennis_court', 'pool'], columns = ['spa', 'hotel_stars'])

# error (as pool is not present)

# %%
H.pivot_table(values = 'mean_score', index = ['tennis_court', 'casino'], columns = ['spa', 'hotel_stars'])
# Out:
# spa                   NO            YES
# hotel_stars            3  3,5  4,5    3  3,5    4    5
# tennis_court casino
# NO           NO     3.96  NaN  NaN  NaN  NaN  NaN  NaN
#              YES    3.21 4.54 4.08 3.71 4.17 3.75 4.35
# YES          NO      NaN 4.38  NaN  NaN  NaN  NaN  NaN
#              YES     NaN  NaN  NaN 4.21  NaN 4.00 4.62

# %% [markdown]
# ---

# %%
H.pivot_table(values = 'mean_score', index = ['tennis_court', 'casino'], 
              columns = ['spa', 'hotel_stars'], margins = True)
# Out:
# spa                   NO            YES                 All
# hotel_stars            3  3,5  4,5    3  3,5    4    5
# tennis_court casino
# NO           NO     3.96  NaN  NaN  NaN  NaN  NaN  NaN 3.96
#              YES    3.21 4.54 4.08 3.71 4.17 3.75 4.35 4.09
# YES          NO      NaN 4.38  NaN  NaN  NaN  NaN  NaN 4.38
#              YES     NaN  NaN  NaN 4.21  NaN 4.00 4.62 4.21
# All                 3.58 4.46 4.08 3.96 4.17 3.85 4.39 4.12

# %%
# added ALL for rows and columns

# %% [markdown]
# # the pivot table user mean as aggregation function by default

# %%
H.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa', aggfunc = min)
# Out:
# spa            NO  YES
# tennis_court
# NO           3.21 3.29
# YES          4.38 3.96

# %%
H.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa', aggfunc = count)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_57943/3557610323.py in <module>
# ----> 1 H.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa', aggfunc = count)
#
# NameError: name 'count' is not defined

# %%
H.pivot_table(values = 'mean_score', index = 'tennis_court', columns = 'spa', aggfunc = 'count')
# Out:
# spa           NO  YES
# tennis_court
# NO             4   12
# YES            1    4

# %% [markdown]
# # <font color = red> A cross tab is a special type of pivot table

# %% [markdown]
# ---

# %% [markdown]
# # you can also get cross tabs directly from pandas

# %%
pd.crosstab(H.tennis_court, H.spa)
# Out:
# spa           NO  YES
# tennis_court
# NO             4   12
# YES            1    4
