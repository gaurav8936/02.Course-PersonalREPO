# %% [markdown]
# # Airline Data Flight Example

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sys

pd.options.display.float_format = '{:,.2f}'.format
# %matplotlib inline

print(sys.version)
print(pd.__version__)
print(np.__version__)
# Out:
# 3.9.13 (main, Aug 25 2022, 18:29:29)
# [Clang 12.0.0 ]
# 1.4.4
# 1.21.5

# %% [markdown]
# ---

# %% [markdown]
# ### get dataframe prepared (with all the datawranging required -- recall the html issue)

# %%
# 1. import the new csv file

df1 = pd.read_csv("fresh_start_airline_gn.csv")

# %%
# 2. check the df

df1.head(5)
# Out:
#    Unnamed: 0        Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0           0  1994-06-05          7 1,542.00        1540 1,819.00
# 1           1  1994-06-06          1 1,549.00        1540 1,831.00
# 2           2  1994-06-07          2 1,540.00        1540 1,803.00
# 3           3  1994-06-08          3 1,541.00        1540 1,808.00
# 4           4  1994-06-09          4 1,541.00        1540 1,835.00
#
#    CRSArrTime UniqueCarrier  FlightNum  TailNum  ...  TaxiIn  TaxiOut  \
# 0        1815            US        236      NaN  ...     NaN      NaN
# 1        1815            US        236      NaN  ...     NaN      NaN
# 2        1815            US        236      NaN  ...     NaN      NaN
# 3        1815            US        236      NaN  ...     NaN      NaN
# 4        1815            US        236      NaN  ...     NaN      NaN
#
#    Cancelled  CancellationCode  Diverted CarrierDelay WeatherDelay  NASDelay  \
# 0          0               NaN         0          NaN          NaN       NaN
# 1          0               NaN         0          NaN          NaN       NaN
# 2          0               NaN         0          NaN          NaN       NaN
# 3          0               NaN         0          NaN          NaN       NaN
# 4          0               NaN         0          NaN          NaN       NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
#
# [5 rows x 28 columns]

# %%
# 3. delete the unnamed columns added 

df = df1.loc[:, ~df1.columns.str.contains('^Unnamed')]

# %%
# 4. check the new df

df.head(5)
# Out:
#          Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  1994-06-05          7 1,542.00        1540 1,819.00        1815
# 1  1994-06-06          1 1,549.00        1540 1,831.00        1815
# 2  1994-06-07          2 1,540.00        1540 1,803.00        1815
# 3  1994-06-08          3 1,541.00        1540 1,808.00        1815
# 4  1994-06-09          4 1,541.00        1540 1,835.00        1815
#
#   UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  ...  TaxiIn  TaxiOut  \
# 0            US        236      NaN             157.00  ...     NaN      NaN
# 1            US        236      NaN             162.00  ...     NaN      NaN
# 2            US        236      NaN             143.00  ...     NaN      NaN
# 3            US        236      NaN             147.00  ...     NaN      NaN
# 4            US        236      NaN             174.00  ...     NaN      NaN
#
#    Cancelled  CancellationCode Diverted CarrierDelay  WeatherDelay  NASDelay  \
# 0          0               NaN        0          NaN           NaN       NaN
# 1          0               NaN        0          NaN           NaN       NaN
# 2          0               NaN        0          NaN           NaN       NaN
# 3          0               NaN        0          NaN           NaN       NaN
# 4          0               NaN        0          NaN           NaN       NaN
#
#    SecurityDelay  LateAircraftDelay
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
#
# [5 rows x 27 columns]

# %% [markdown]
# ---

# %% [markdown]
# # converting numerical to categorical data

# %%
df.FlightNum.describe()
# Out:
# count   426,490.00
# mean        901.69
# std         593.51
# min           1.00
# 25%         407.00
# 50%         792.00
# 75%       1,429.00
# max       3,219.00
# Name: FlightNum, dtype: float64

# %%
# the average flight number data is useless

# it does not matter if it is flight 1 or flight 99

        # those are just categories
        # it could just as well be flight G

# %%
# pandas thinks about this as numerical data, not categorical data

# %%
# sometimes you have relatively continuous data tht should be categorical data
### these should be grouped as bins

##### maybe elapsed time is in this category
# wehre you say, 1-200 is one category

# you could say, 1-100: short hop, 100-200 - medium hop, 200-400: long hop

# %% [markdown]
# ---

# %% [markdown]
# # bins

# %%
# departure and arrival times are in military format

# create them into bins

# %%
# this converts a continuous variable to a categorical one

# %%
# we are looking at actual departure times (not scheduled)

# %%
ranges = [0, 600, 1200, 1800, 2400]

# %%
labels = ['Early Morning', 'Morning', 'Early Afternoon', 'Evening']

# %% [markdown]
# ## cut

# %%
# DepTime: actual
# CRSDEpTime: Scheduled

# %%
df['DepTime2'] = pd.cut(df.DepTime, ranges, labels=labels).astype('category')

# %%
df['ArrTime2'] = pd.cut(df.ArrTime, ranges, labels=labels).astype('category')

# %% [markdown]
# ---

# %% [markdown]
# ## average time delays

# %%
df.groupby(['DepTime2', 'ArrTime2'])[['DepDelay', 'ArrDelay']].mean()
# Out:
#                                  DepDelay  ArrDelay
# DepTime2        ArrTime2
# Early Morning   Early Morning       43.80     42.07
#                 Morning              2.58      2.11
#                 Early Afternoon       NaN       NaN
#                 Evening             64.00     61.33
# Morning         Early Morning         NaN       NaN
#                 Morning              2.37      0.66
#                 Early Afternoon      3.77      4.10
#                 Evening              5.41     12.92
# Early Afternoon Early Morning        8.89     14.45
#                 Morning              4.90      2.48
#                 Early Afternoon      5.17      4.57
#                 Evening              7.63     11.08
# Evening         Early Morning       36.96     42.04
#                 Morning              5.46      7.63
#                 Early Afternoon     29.14     22.50
#                 Evening             13.67     12.76

# %% [markdown]
# ---

# %% [markdown]
# # variation in the delays

# %%
transformations = [np.mean, np.std]

# %%
agg_dict = {'ArrDelay': transformations,  'DepDelay' : transformations}

# %%
df.groupby(['DepTime2', 'ArrTime2']).agg(agg_dict)
# Out:
#                                 ArrDelay       DepDelay
#                                     mean   std     mean   std
# DepTime2        ArrTime2
# Early Morning   Early Morning      42.07 91.24    43.80 91.84
#                 Morning             2.11 18.44     2.58 16.60
#                 Early Afternoon      NaN   NaN      NaN   NaN
#                 Evening            61.33  5.51    64.00  8.89
# Morning         Early Morning        NaN   NaN      NaN   NaN
#                 Morning             0.66 13.45     2.37 10.22
#                 Early Afternoon     4.10 17.17     3.77 12.48
#                 Evening            12.92 24.19     5.41 15.70
# Early Afternoon Early Morning      14.45 42.65     8.89 27.35
#                 Morning             2.48 11.08     4.90  8.72
#                 Early Afternoon     4.57 18.71     5.17 14.86
#                 Evening            11.08 28.07     7.63 19.32
# Evening         Early Morning      42.04 74.14    36.96 65.64
#                 Morning             7.63 17.13     5.46 12.30
#                 Early Afternoon    22.50 30.93    29.14 32.23
#                 Evening            12.76 34.13    13.67 39.55

# %% [markdown]
# ![image.png](attachment:e697056f-b0fc-407c-bfcc-e03c6681bef4.png)

# %% [markdown]
# ---

# %% [markdown]
# # <font color = red> Start Here

# %% [markdown]
# # which flights are worst for delays

# %% [markdown]
# ### rank flights with the worst delay times

# %%
df.head()
# Out:
#          Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  1994-06-05          7 1,542.00        1540 1,819.00        1815
# 1  1994-06-06          1 1,549.00        1540 1,831.00        1815
# 2  1994-06-07          2 1,540.00        1540 1,803.00        1815
# 3  1994-06-08          3 1,541.00        1540 1,808.00        1815
# 4  1994-06-09          4 1,541.00        1540 1,835.00        1815
#
#   UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  ...  Cancelled  \
# 0            US        236      NaN             157.00  ...          0
# 1            US        236      NaN             162.00  ...          0
# 2            US        236      NaN             143.00  ...          0
# 3            US        236      NaN             147.00  ...          0
# 4            US        236      NaN             174.00  ...          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# 0               NaN         0           NaN          NaN      NaN
# 1               NaN         0           NaN          NaN      NaN
# 2               NaN         0           NaN          NaN      NaN
# 3               NaN         0           NaN          NaN      NaN
# 4               NaN         0           NaN          NaN      NaN
#
#    SecurityDelay  LateAircraftDelay         DepTime2  ArrTime2
# 0            NaN                NaN  Early Afternoon   Evening
# 1            NaN                NaN  Early Afternoon   Evening
# 2            NaN                NaN  Early Afternoon   Evening
# 3            NaN                NaN  Early Afternoon   Evening
# 4            NaN                NaN  Early Afternoon   Evening
#
# [5 rows x 29 columns]

# %%
# write a function that takes in a df adn return a df with th eranks

# %%
# create a column wiht total delay time

# %%
# also create a new column that bins the delay time

# %%
df['TotalDelay'] = df.ArrDelay + df.DepDelay

# %% [markdown]
# ### cut for binning

# %%
df['ScheduledDepTime'] = pd.cut(df.CRSDepTime, ranges, labels = labels)

# %%
df.head()
# Out:
#          Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  1994-06-05          7 1,542.00        1540 1,819.00        1815
# 1  1994-06-06          1 1,549.00        1540 1,831.00        1815
# 2  1994-06-07          2 1,540.00        1540 1,803.00        1815
# 3  1994-06-08          3 1,541.00        1540 1,808.00        1815
# 4  1994-06-09          4 1,541.00        1540 1,835.00        1815
#
#   UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  ...  Diverted  \
# 0            US        236      NaN             157.00  ...         0
# 1            US        236      NaN             162.00  ...         0
# 2            US        236      NaN             143.00  ...         0
# 3            US        236      NaN             147.00  ...         0
# 4            US        236      NaN             174.00  ...         0
#
#    CarrierDelay  WeatherDelay  NASDelay SecurityDelay LateAircraftDelay  \
# 0           NaN           NaN       NaN           NaN               NaN
# 1           NaN           NaN       NaN           NaN               NaN
# 2           NaN           NaN       NaN           NaN               NaN
# 3           NaN           NaN       NaN           NaN               NaN
# 4           NaN           NaN       NaN           NaN               NaN
#
#           DepTime2  ArrTime2  TotalDelay  ScheduledDepTime
# 0  Early Afternoon   Evening        6.00   Early Afternoon
# 1  Early Afternoon   Evening       25.00   Early Afternoon
# 2  Early Afternoon   Evening      -12.00   Early Afternoon
# 3  Early Afternoon   Evening       -6.00   Early Afternoon
# 4  Early Afternoon   Evening       21.00   Early Afternoon
#
# [5 rows x 31 columns]

# %% [markdown]
# ---

# %%
# crete a new function for average delay

# %%
def average_delay(dataframe):
    dataframe['AvgFlightDelay'] = dataframe.TotalDelay.mean()
    return dataframe

# %% [markdown]
# ---

# %% [markdown]
# ## approach 1: simple

# %% [markdown]
# ### execute function on the df dataframe

# %%
avg_delayed = df.groupby('FlightNum').apply(average_delay)

# %%
avg_delayed.head()
# Out:
#          Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 0  1994-06-05          7 1,542.00        1540 1,819.00        1815
# 1  1994-06-06          1 1,549.00        1540 1,831.00        1815
# 2  1994-06-07          2 1,540.00        1540 1,803.00        1815
# 3  1994-06-08          3 1,541.00        1540 1,808.00        1815
# 4  1994-06-09          4 1,541.00        1540 1,835.00        1815
#
#   UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  ...  CarrierDelay  \
# 0            US        236      NaN             157.00  ...           NaN
# 1            US        236      NaN             162.00  ...           NaN
# 2            US        236      NaN             143.00  ...           NaN
# 3            US        236      NaN             147.00  ...           NaN
# 4            US        236      NaN             174.00  ...           NaN
#
#    WeatherDelay  NASDelay  SecurityDelay LateAircraftDelay         DepTime2  \
# 0           NaN       NaN            NaN               NaN  Early Afternoon
# 1           NaN       NaN            NaN               NaN  Early Afternoon
# 2           NaN       NaN            NaN               NaN  Early Afternoon
# 3           NaN       NaN            NaN               NaN  Early Afternoon
# 4           NaN       NaN            NaN               NaN  Early Afternoon
#
#    ArrTime2  TotalDelay  ScheduledDepTime  AvgFlightDelay
# 0   Evening        6.00   Early Afternoon           13.61
# 1   Evening       25.00   Early Afternoon           13.61
# 2   Evening      -12.00   Early Afternoon           13.61
# 3   Evening       -6.00   Early Afternoon           13.61
# 4   Evening       21.00   Early Afternoon           13.61
#
# [5 rows x 32 columns]

# %% [markdown]
# ## <font color = red> Sample

# %%
avg_delayed.sample()
# Out:
#              Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 47291  1994-06-03          5 1,947.00        1945 2,014.00        2017
#
#       UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  ...  CarrierDelay  \
# 47291            US       1763      NaN              87.00  ...           NaN
#
#        WeatherDelay  NASDelay  SecurityDelay LateAircraftDelay DepTime2  \
# 47291           NaN       NaN            NaN               NaN  Evening
#
#        ArrTime2  TotalDelay  ScheduledDepTime  AvgFlightDelay
# 47291   Evening       -1.00           Evening            8.24
#
# [1 rows x 32 columns]

# %%
avg_delayed.sample(5)
# Out:
#               Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  CRSArrTime  \
# 270360  1994-06-09          4   859.00         855 1,028.00        1021
# 228266  1994-06-06          1 1,142.00        1140 1,230.00        1227
# 374875  1994-06-12          7 1,318.00        1320 1,458.00        1459
# 15299   1994-06-22          3 2,358.00        2355   557.00         555
# 409430  1994-06-23          4 1,750.00        1740 1,927.00        1917
#
#        UniqueCarrier  FlightNum  TailNum  ActualElapsedTime  ...  \
# 270360            DL       1511      NaN              89.00  ...
# 228266            DL        436      NaN              48.00  ...
# 374875            AA       1979      NaN             160.00  ...
# 15299             US        637      NaN             239.00  ...
# 409430            CO       1150      NaN             157.00  ...
#
#         CarrierDelay  WeatherDelay  NASDelay  SecurityDelay LateAircraftDelay  \
# 270360           NaN           NaN       NaN            NaN               NaN
# 228266           NaN           NaN       NaN            NaN               NaN
# 374875           NaN           NaN       NaN            NaN               NaN
# 15299            NaN           NaN       NaN            NaN               NaN
# 409430           NaN           NaN       NaN            NaN               NaN
#
#                DepTime2         ArrTime2  TotalDelay  ScheduledDepTime  \
# 270360          Morning          Morning       11.00           Morning
# 228266          Morning  Early Afternoon        5.00           Morning
# 374875  Early Afternoon  Early Afternoon       -3.00   Early Afternoon
# 15299           Evening    Early Morning        5.00           Evening
# 409430  Early Afternoon          Evening       20.00   Early Afternoon
#
#         AvgFlightDelay
# 270360            9.79
# 228266           17.59
# 374875           19.08
# 15299            14.36
# 409430           10.54
#
# [5 rows x 32 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## approach 2: more compact

# %%
df2 = df.groupby('FlightNum').agg({'TotalDelay': np.mean})
df2
# Out:
#            TotalDelay
# FlightNum
# 1                6.40
# 2                7.01
# 3                9.38
# 4               17.79
# 5                6.25
# ...               ...
# 3010            36.74
# 3197            13.24
# 3203             3.18
# 3218             5.56
# 3219            16.71
#
# [2582 rows x 1 columns]

# %%
#df2.sorted('TotalDelay')

df2.sort_values(by = ['TotalDelay'], ascending = False)
# Out:
#            TotalDelay
# FlightNum
# 2849           183.33
# 1428           173.78
# 2928           150.50
# 2835           124.33
# 2252           112.23
# ...               ...
# 2314           -15.00
# 2628           -16.25
# 2280           -18.00
# 2282           -18.75
# 2091           -20.97
#
# [2582 rows x 1 columns]

# %% [markdown]
# ![image.png](attachment:7d3ef683-3009-4b6a-a6c8-d5f2678b3dc4.png)

# %%
df.groupby('FlightNum').agg({'TotalDelay': np.mean}).\
            sort_values(by = ['TotalDelay'], ascending = False)
# Out:
#            TotalDelay
# FlightNum
# 2849           183.33
# 1428           173.78
# 2928           150.50
# 2835           124.33
# 2252           112.23
# ...               ...
# 2314           -15.00
# 2628           -16.25
# 2280           -18.00
# 2282           -18.75
# 2091           -20.97
#
# [2582 rows x 1 columns]

# %% [markdown]
# ---

# %% [markdown]
# ## ranking function to cretae a generic way to do this

# %%
def ranking(dataframe, column):
    dataframe.sort_values(column, ascending = False, inplace = True)
    dataframe[column + 'Rank'] = np.arange(len(dataframe))+ 1
    return dataframe

# %% [markdown]
# ---

# %% [markdown]
# # rank flights by aveage delay

# %% [markdown]
# # new df

# %%
avg_delayed_ranked = avg_delayed.groupby\
('ScheduledDepTime').\
apply(lambda x:ranking(x, 'AvgFlightDelay'))

# %%
avg_delayed_ranked.head()
# Out:
#                                Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# ScheduledDepTime
# Early Morning    269530  1994-06-02          4    51.00         110   109.00
#                  269529  1994-06-01          3   115.00         110   134.00
#                  269532  1994-06-04          6   108.00         110   127.00
#                  269533  1994-06-05          7   100.00         110   122.00
#                  269534  1994-06-06          1    58.00         110   113.00
#
#                          CRSArrTime UniqueCarrier  FlightNum  TailNum  \
# ScheduledDepTime
# Early Morning    269530         131            DL       1490      NaN
#                  269529         131            DL       1490      NaN
#                  269532         131            DL       1490      NaN
#                  269533         131            DL       1490      NaN
#                  269534         131            DL       1490      NaN
#
#                          ActualElapsedTime  ...  WeatherDelay  NASDelay  \
# ScheduledDepTime                            ...
# Early Morning    269530              18.00  ...           NaN       NaN
#                  269529              19.00  ...           NaN       NaN
#                  269532              19.00  ...           NaN       NaN
#                  269533              22.00  ...           NaN       NaN
#                  269534              15.00  ...           NaN       NaN
#
#                          SecurityDelay  LateAircraftDelay       DepTime2  \
# ScheduledDepTime
# Early Morning    269530            NaN                NaN  Early Morning
#                  269529            NaN                NaN  Early Morning
#                  269532            NaN                NaN  Early Morning
#                  269533            NaN                NaN  Early Morning
#                  269534            NaN                NaN  Early Morning
#
#                               ArrTime2  TotalDelay  ScheduledDepTime  \
# ScheduledDepTime
# Early Morning    269530  Early Morning      -41.00     Early Morning
#                  269529  Early Morning        8.00     Early Morning
#                  269532  Early Morning       -6.00     Early Morning
#                  269533  Early Morning      -19.00     Early Morning
#                  269534  Early Morning      -30.00     Early Morning
#
#                          AvgFlightDelay  AvgFlightDelayRank
# ScheduledDepTime
# Early Morning    269530           36.88                   1
#                  269529           36.88                   2
#                  269532           36.88                   3
#                  269533           36.88                   4
#                  269534           36.88                   5
#
# [5 rows x 33 columns]

# %%
avg_delayed_ranked[avg_delayed_ranked\
                   .AvgFlightDelayRank == 1]
# Out:
#                                Date  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# ScheduledDepTime
# Early Morning    269530  1994-06-02          4    51.00         110   109.00
# Morning          267020  1994-06-28          2 1,158.00        1151 1,253.00
# Early Afternoon  60742   1994-06-12          7 1,605.00        1600 1,703.00
# Evening          266946  1994-06-09          4 1,953.00        2005 2,022.00
#
#                          CRSArrTime UniqueCarrier  FlightNum  TailNum  \
# ScheduledDepTime
# Early Morning    269530         131            DL       1490      NaN
# Morning          267020        1250            DL       1428      NaN
# Early Afternoon  60742         1659            US       2849      NaN
# Evening          266946        2039            DL       1428      NaN
#
#                          ActualElapsedTime  ...  WeatherDelay  NASDelay  \
# ScheduledDepTime                            ...
# Early Morning    269530              18.00  ...           NaN       NaN
# Morning          267020              55.00  ...           NaN       NaN
# Early Afternoon  60742               58.00  ...           NaN       NaN
# Evening          266946              29.00  ...           NaN       NaN
#
#                          SecurityDelay  LateAircraftDelay         DepTime2  \
# ScheduledDepTime
# Early Morning    269530            NaN                NaN    Early Morning
# Morning          267020            NaN                NaN          Morning
# Early Afternoon  60742             NaN                NaN  Early Afternoon
# Evening          266946            NaN                NaN          Evening
#
#                                 ArrTime2  TotalDelay  ScheduledDepTime  \
# ScheduledDepTime
# Early Morning    269530    Early Morning      -41.00     Early Morning
# Morning          267020  Early Afternoon       10.00           Morning
# Early Afternoon  60742   Early Afternoon        9.00   Early Afternoon
# Evening          266946          Evening    1,411.00           Evening
#
#                          AvgFlightDelay  AvgFlightDelayRank
# ScheduledDepTime
# Early Morning    269530           36.88                   1
# Morning          267020          173.78                   1
# Early Afternoon  60742           183.33                   1
# Evening          266946          173.78                   1
#
# [4 rows x 33 columns]

# %% [markdown]
# #### flight 1428 has the worst in the morning and evening

# %% [markdown]
# ![image.png](attachment:2749b745-7514-4fbb-b090-25625526f696.png)

# %% [markdown]
# ---

# %% [markdown]
# ## <font color = red> This format is cool

# %% [markdown]
# ### <font color = blue> Doing itall in one line -- without intermediate DFs

# %%
df.groupby('FlightNum')\
.agg({'TotalDelay' : np.mean})\
.sort_values('TotalDelay', ascending=False)\
.head()
# Out:
#            TotalDelay
# FlightNum
# 2849           183.33
# 1428           173.78
# 2928           150.50
# 2835           124.33
# 2252           112.23

# %%
df.groupby('ScheduledDepTime')\
.agg({'TotalDelay' : np.mean})\
.sort_values('TotalDelay', ascending=False)\
.head()
# Out:
#                   TotalDelay
# ScheduledDepTime
# Evening                24.29
# Early Afternoon        16.04
# Morning                 5.58
# Early Morning           4.07
