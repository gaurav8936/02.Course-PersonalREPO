# %% [markdown]
# # 12022022_02

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import matplotlib.pyplot as plt
# %matplotlib inline

Vegas = pd.read_csv('../vegas.csv')
Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/778092029.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()

# %% [markdown]
# ---

# %%
Vegas.score.groupby(Vegas.hotel_name).head()
# Out:
# 0      5
# 1      3
# 2      5
# 3      4
# 4      4
#       ..
# 480    4
# 481    3
# 482    4
# 483    3
# 484    5
# Name: score, Length: 105, dtype: int64

# %%
Vegas.shape
# Out:
# (504, 20)

# %%
Vegas.score.groupby([Vegas.hotel_name, Vegas.traveler_type]).min().unstack()
# Out:
# traveler_type                                       Business  Couples  \
# hotel_name
# Bellagio Las Vegas                                      2.00     4.00
# Caesars Palace                                          5.00     1.00
# Circus Circus Hotel & Casino Las Vegas                  3.00     1.00
# Encore at wynn Las Vegas                                1.00     4.00
# Excalibur Hotel & Casino                                3.00     3.00
# Hilton Grand Vacations at the Flamingo                  3.00     2.00
# Hilton Grand Vacations on the Boulevard                 4.00     1.00
# Marriott's Grand Chateau                                3.00     4.00
# Monte Carlo Resort&Casino                               1.00     2.00
# Paris Las Vegas                                         4.00     2.00
# The Cosmopolitan Las Vegas                              1.00     2.00
# The Cromwell                                            3.00     3.00
# ...

# %%
temp = Vegas.score.groupby([Vegas.hotel_name, Vegas.traveler_type]).min().unstack()

# %%
temp
# Out:
# traveler_type                                       Business  Couples  \
# hotel_name
# Bellagio Las Vegas                                      2.00     4.00
# Caesars Palace                                          5.00     1.00
# Circus Circus Hotel & Casino Las Vegas                  3.00     1.00
# Encore at wynn Las Vegas                                1.00     4.00
# Excalibur Hotel & Casino                                3.00     3.00
# Hilton Grand Vacations at the Flamingo                  3.00     2.00
# Hilton Grand Vacations on the Boulevard                 4.00     1.00
# Marriott's Grand Chateau                                3.00     4.00
# Monte Carlo Resort&Casino                               1.00     2.00
# Paris Las Vegas                                         4.00     2.00
# The Cosmopolitan Las Vegas                              1.00     2.00
# The Cromwell                                            3.00     3.00
# ...

# %%
temp = get_group(Vegas.score.groupby([Vegas.hotel_name, Vegas.traveler_type])).head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/1143713654.py in <module>
# ----> 1 temp = get_group(Vegas.score.groupby([Vegas.hotel_name, Vegas.traveler_type])).head(5)
#
# NameError: name 'get_group' is not defined

# %%
tempgrp = Vegas.score.groupby([Vegas.hotel_name, Vegas.traveler_type])

# %%
type(tempgrp)
# Out:
# pandas.core.groupby.generic.SeriesGroupBy

# %%
tempgrp.get_group(Vegas.hotel_name == 'Wynn Las Vegas', Vegas.traveler_type = 'Business'), ().head(5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/1412594590.py in <module>
# ----> 1 tempgrp.get_group(Vegas['hotel_name'] == 'Wynn Las Vegas').head(5)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     743             obj = self._selected_obj
#     744
# --> 745         inds = self._get_index(name)
#     746         if not len(inds):
#     747             raise KeyError(name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _get_index(self, name)
#     671         Safe get index, translate keys for datelike to underlying repr.
#     672         """
# --> 673         return self._get_indices([name])[0]
#     674
#     675     @final
#
# ...

# %%
temp3 = Vegas.score.groupby(Vegas.hotel_name).min()

# %%
temp3
# Out:
# hotel_name
# Bellagio Las Vegas                                     2
# Caesars Palace                                         1
# Circus Circus Hotel & Casino Las Vegas                 1
# Encore at wynn Las Vegas                               1
# Excalibur Hotel & Casino                               2
# Hilton Grand Vacations at the Flamingo                 2
# Hilton Grand Vacations on the Boulevard                1
# Marriott's Grand Chateau                               3
# Monte Carlo Resort&Casino                              1
# Paris Las Vegas                                        2
# The Cosmopolitan Las Vegas                             1
# The Cromwell                                           1
# The Palazzo Resort Hotel Casino                        3
# The Venetian Las Vegas Hotel                           3
# The Westin las Vegas Hotel Casino & Spa                2
# Treasure Island- TI Hotel & Casino                     3
# ...

# %%
temp4 = Vegas.score.groupby(Vegas.hotel_name)

# %%
temp4.mean()
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.21
# Caesars Palace                                        4.12
# Circus Circus Hotel & Casino Las Vegas                3.21
# Encore at wynn Las Vegas                              4.54
# Excalibur Hotel & Casino                              3.71
# Hilton Grand Vacations at the Flamingo                3.96
# Hilton Grand Vacations on the Boulevard               4.17
# Marriott's Grand Chateau                              4.54
# Monte Carlo Resort&Casino                             3.29
# Paris Las Vegas                                       4.04
# The Cosmopolitan Las Vegas                            4.25
# The Cromwell                                          4.08
# The Palazzo Resort Hotel Casino                       4.38
# The Venetian Las Vegas Hotel                          4.58
# The Westin las Vegas Hotel Casino & Spa               3.92
# Treasure Island- TI Hotel & Casino                    3.96
# ...

# %%
temp4.get_group(Vegas.hotel_name[0]).head(5)
# Out:
# 0    5
# 1    3
# 2    5
# 3    4
# 4    4
# Name: score, dtype: int64

# %%
temp4.get_group(Vegas.hotel_name == 'Paris Las Vegas').head(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/3305134674.py in <module>
# ----> 1 temp4.get_group(Vegas.hotel_name == 'Paris Las Vegas').head(5)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in get_group(self, name, obj)
#     743             obj = self._selected_obj
#     744
# --> 745         inds = self._get_index(name)
#     746         if not len(inds):
#     747             raise KeyError(name)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _get_index(self, name)
#     671         Safe get index, translate keys for datelike to underlying repr.
#     672         """
# --> 673         return self._get_indices([name])[0]
#     674
#     675     @final
#
# ...

# %%
Vegas.score.groupby(Vegas.traveler_type)

# %%
Vegas.score.groupby(Vegas.traveler_type, Vegas.pool).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/1124680300.py in <module>
# ----> 1 Vegas.score.groupby(Vegas.traveler_type, Vegas.pool).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1916         if level is None and by is None:
#    1917             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 1918         axis = self._get_axis_number(axis)
#    1919
#    1920         # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     548     def _get_axis_number(cls, axis: Axis) -> int:
#     549         try:
# ...

# %%
by_hotel = Vegas.score.groupby(Vegas.hotel_name).mean()

# %%
type(by_hotel)
# Out:
# pandas.core.series.Series

# %%
by_hotel.get_group(Vegas.hotel_name[0]).head(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/1511028526.py in <module>
# ----> 1 by_hotel.get_group(Vegas.hotel_name[0]).head(5)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'get_group'

# %%
Vegas.groupby(Vegas.hotel_name).head()
# Out:
#     user_country  nr_reviews  nr_hotel_reviews  helpful_votes  score  \
# 0            USA          11                 4             13      5
# 1            USA         119                21             75      3
# 2            USA          36                 9             25      5
# 3             UK          14                 7             14      4
# 4         Canada           5                 5              2      4
# ..           ...         ...               ...            ...    ...
# 480       Canada          20                13             17      4
# 481          USA          15                 3              4      3
# 482        Italy         189                72            129      4
# 483          USA          25                19             27      3
# 484          USA          33                11             12      5
#
#     period_of_stay traveler_type pool  gym tennis_court  spa casino  \
# 0          Dec-Feb       Friends   NO  YES           NO   NO    YES
# ...

# %%
Vegas.score.groupby(Vegas.hotel_name).head()
# Out:
# 0      5
# 1      3
# 2      5
# 3      4
# 4      4
#       ..
# 480    4
# 481    3
# 482    4
# 483    3
# 484    5
# Name: score, Length: 105, dtype: int64

# %%
by_hotel = Vegas.score.groupby(Vegas.hotel_name)

# %%
by_hotel.mean()
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.21
# Caesars Palace                                        4.12
# Circus Circus Hotel & Casino Las Vegas                3.21
# Encore at wynn Las Vegas                              4.54
# Excalibur Hotel & Casino                              3.71
# Hilton Grand Vacations at the Flamingo                3.96
# Hilton Grand Vacations on the Boulevard               4.17
# Marriott's Grand Chateau                              4.54
# Monte Carlo Resort&Casino                             3.29
# Paris Las Vegas                                       4.04
# The Cosmopolitan Las Vegas                            4.25
# The Cromwell                                          4.08
# The Palazzo Resort Hotel Casino                       4.38
# The Venetian Las Vegas Hotel                          4.58
# The Westin las Vegas Hotel Casino & Spa               3.92
# Treasure Island- TI Hotel & Casino                    3.96
# ...

# %% [markdown]
# ---

# %%
by_hotel = Vegas.groupby(Vegas.hotel_name)

# %%
by_hotel = Vegas.groupby('hotel_name')

# %%
by_hotel

# %%
by_hotel.get_group(Vegas.hotel_name[0]).head(5)
# Out:
#   user_country  nr_reviews  nr_hotel_reviews  helpful_votes  score  \
# 0          USA          11                 4             13      5
# 1          USA         119                21             75      3
# 2          USA          36                 9             25      5
# 3           UK          14                 7             14      4
# 4       Canada           5                 5              2      4
#
#   period_of_stay traveler_type pool  gym tennis_court spa casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 1        Dec-Feb      Business   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
#
#   free_internet                              hotel_name hotel_stars  nr_rooms  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas           3      3773
# ...

# %%
by_hotel.mean()
# Out:
#                                                     nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                       27.71
# Caesars Palace                                           38.00
# Circus Circus Hotel & Casino Las Vegas                   29.21
# Encore at wynn Las Vegas                                 57.17
# Excalibur Hotel & Casino                                 45.58
# Hilton Grand Vacations at the Flamingo                   48.42
# Hilton Grand Vacations on the Boulevard                  36.92
# Marriott's Grand Chateau                                 90.04
# Monte Carlo Resort&Casino                                71.83
# Paris Las Vegas                                          51.21
# The Cosmopolitan Las Vegas                               33.79
# The Cromwell                                             71.54
# The Palazzo Resort Hotel Casino                          44.92
# The Venetian Las Vegas Hotel                             32.04
# ...

# %%
by_traveler = Vegas.groupby('traveler_type')

# %%
by_traveler = Vegas.groupby(Vegas.traveler_type)

# %%
type(by_traveler)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
by_traveler.mean()
# Out:
#                nr_reviews  nr_hotel_reviews  helpful_votes  score  nr_rooms  \
# traveler_type
# Business            72.00             23.68          42.27   3.88  1,964.99
# Couples             45.68             14.79          32.10   4.23  2,299.20
# Families            45.11             14.32          26.18   4.02  2,067.17
# Friends             39.66             14.52          29.46   4.26  2,242.13
# Solo                39.17             16.33          29.54   3.92  2,428.96
#
#                member_years
# traveler_type
# Business               4.16
# Couples                4.43
# Families               4.26
# Friends                4.32
# Solo                 -70.54

# %%
Vegas.groupby([Vegas.traveler_type, Vegas.pool])

# %%
Vegas.groupby([Vegas.traveler_type, Vegas.pool]).mean()
# Out:
#                     nr_reviews  nr_hotel_reviews  helpful_votes  score  \
# traveler_type pool
# Business      NO        119.00             21.00          75.00   3.00
#               YES        71.36             23.71          41.82   3.89
# Couples       NO         20.43              6.86          18.00   2.71
#               YES        46.54             15.06          32.58   4.29
# Families      NO         41.62              9.50          20.00   3.38
#               YES        45.38             14.70          26.67   4.07
# Friends       NO         14.43              5.29          11.57   3.43
#               YES        42.01             15.39          31.13   4.33
# Solo          NO          5.00              5.00           2.00   4.00
#               YES        40.65             16.83          30.74   3.91
#
#                     nr_rooms  member_years
# traveler_type pool
# Business      NO    3,773.00          3.00
#               YES   1,940.22          4.18
# ...

# %%
Vegas.score.groupby([Vegas.traveler_type, Vegas.pool]).mean()
# Out:
# traveler_type  pool
# Business       NO     3.00
#                YES    3.89
# Couples        NO     2.71
#                YES    4.29
# Families       NO     3.38
#                YES    4.07
# Friends        NO     3.43
#                YES    4.33
# Solo           NO     4.00
#                YES    3.91
# Name: score, dtype: float64

# %%
Vegas.score.groupby([Vegas.traveler_type, Vegas.pool]).mean().unstack()
# Out:
# pool            NO  YES
# traveler_type
# Business      3.00 3.89
# Couples       2.71 4.29
# Families      3.38 4.07
# Friends       3.43 4.33
# Solo          4.00 3.91

# %%
Vegas.groupby([Vegas.traveler_type, Vegas.pool])['score']

# %%
Vegas.groupby([Vegas.traveler_type, Vegas.pool])['score', 'helpful_votes']
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/2509526336.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Vegas.groupby([Vegas.traveler_type, Vegas.pool])['score', 'helpful_votes']

# %%
Vegas.groupby([Vegas.traveler_type, Vegas.pool])['score', 'helpful_votes'].mean()
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/3868489920.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Vegas.groupby([Vegas.traveler_type, Vegas.pool])['score', 'helpful_votes'].mean()
#                     score  helpful_votes
# traveler_type pool
# Business      NO     3.00          75.00
#               YES    3.89          41.82
# Couples       NO     2.71          18.00
#               YES    4.29          32.58
# Families      NO     3.38          20.00
#               YES    4.07          26.67
# Friends       NO     3.43          11.57
#               YES    4.33          31.13
# Solo          NO     4.00           2.00
#               YES    3.91          30.74

# %%
Vegas[['score', 'helpful_votes']].groupby([Vegas.traveler_type, Vegas.pool]).mean()
# Out:
#                     score  helpful_votes
# traveler_type pool
# Business      NO     3.00          75.00
#               YES    3.89          41.82
# Couples       NO     2.71          18.00
#               YES    4.29          32.58
# Families      NO     3.38          20.00
#               YES    4.07          26.67
# Friends       NO     3.43          11.57
#               YES    4.33          31.13
# Solo          NO     4.00           2.00
#               YES    3.91          30.74

# %%
Vegas[['helpful_votes']].groupby([Vegas.traveler_type, Vegas.pool]).mean()
# Out:
#                     helpful_votes
# traveler_type pool
# Business      NO            75.00
#               YES           41.82
# Couples       NO            18.00
#               YES           32.58
# Families      NO            20.00
#               YES           26.67
# Friends       NO            11.57
#               YES           31.13
# Solo          NO             2.00
#               YES           30.74

# %% [markdown]
# ---

# %%
# most common

# %%
Vegas[['hotel_name', 'score', 'nr_hotel_reviews']].groupby([Vegas.traveler_type, Vegas.pool]).mean()
# Out:
#                     score  nr_hotel_reviews
# traveler_type pool
# Business      NO     3.00             21.00
#               YES    3.89             23.71
# Couples       NO     2.71              6.86
#               YES    4.29             15.06
# Families      NO     3.38              9.50
#               YES    4.07             14.70
# Friends       NO     3.43              5.29
#               YES    4.33             15.39
# Solo          NO     4.00              5.00
#               YES    3.91             16.83

# %% [markdown]
# ---

# %%
Vegas
# Out:
#     user_country  nr_reviews  nr_hotel_reviews  helpful_votes  score  \
# 0            USA          11                 4             13      5
# 1            USA         119                21             75      3
# 2            USA          36                 9             25      5
# 3             UK          14                 7             14      4
# 4         Canada           5                 5              2      4
# ..           ...         ...               ...            ...    ...
# 499           UK          15                 4              8      5
# 500       Canada          50                13             29      4
# 501          USA         154                23             31      4
# 502          USA           9                 6              5      2
# 503          USA          20                19            112      4
#
#     period_of_stay traveler_type pool  gym tennis_court  spa casino  \
# 0          Dec-Feb       Friends   NO  YES           NO   NO    YES
# ...

# %%
Vegas.set_index('hotel_name')
# Out:
#                                         user_country  nr_reviews  \
# hotel_name
# Circus Circus Hotel & Casino Las Vegas           USA          11
# Circus Circus Hotel & Casino Las Vegas           USA         119
# Circus Circus Hotel & Casino Las Vegas           USA          36
# Circus Circus Hotel & Casino Las Vegas            UK          14
# Circus Circus Hotel & Casino Las Vegas        Canada           5
# ...                                              ...         ...
# The Westin las Vegas Hotel Casino & Spa           UK          15
# The Westin las Vegas Hotel Casino & Spa       Canada          50
# The Westin las Vegas Hotel Casino & Spa          USA         154
# The Westin las Vegas Hotel Casino & Spa          USA           9
# The Westin las Vegas Hotel Casino & Spa          USA          20
#
#                                          nr_hotel_reviews  helpful_votes  \
# hotel_name
# Circus Circus Hotel & Casino Las Vegas                  4             13
# ...

# %%
def fun(name):
    if 'Circus' in name or 'Flamingo' in name:
        return 'preferred hotel'
    else:
        return 'non-preferred'

# %%
Vegas.groupby('hotel_name').mean()
# Out:
#                                                     nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                       27.71
# Caesars Palace                                           38.00
# Circus Circus Hotel & Casino Las Vegas                   29.21
# Encore at wynn Las Vegas                                 57.17
# Excalibur Hotel & Casino                                 45.58
# Hilton Grand Vacations at the Flamingo                   48.42
# Hilton Grand Vacations on the Boulevard                  36.92
# Marriott's Grand Chateau                                 90.04
# Monte Carlo Resort&Casino                                71.83
# Paris Las Vegas                                          51.21
# The Cosmopolitan Las Vegas                               33.79
# The Cromwell                                             71.54
# The Palazzo Resort Hotel Casino                          44.92
# The Venetian Las Vegas Hotel                             32.04
# ...

# %%
Vegas.groupby(fun).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_91850/4102238029.py in <module>
# ----> 1 Vegas.groupby(fun).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7719         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7720         # "Union[bool, NoDefault]"; expected "bool"
# -> 7721         return DataFrameGroupBy(
#    7722             obj=self,
#    7723             keys=by,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     880             from pandas.core.groupby.grouper import get_grouper
# ...
