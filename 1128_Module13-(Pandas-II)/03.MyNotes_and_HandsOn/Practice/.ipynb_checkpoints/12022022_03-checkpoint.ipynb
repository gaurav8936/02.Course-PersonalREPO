# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format
import matplotlib.pyplot as plt
# %matplotlib inline

Vegas = pd.read_csv('../vegas.csv')
Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/778092029.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()

# %%
Vegas.columns
# Out:
# Index(['user_country', 'nr_reviews', 'nr_hotel_reviews', 'helpful_votes',
#        'score', 'period_of_stay', 'traveler_type', 'pool', 'gym',
#        'tennis_court', 'spa', 'casino', 'free_internet', 'hotel_name',
#        'hotel_stars', 'nr_rooms', 'user_continent', 'member_years',
#        'review_month', 'review_weekday'],
#       dtype='object')

# %%
Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/3735199667.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   Vegas.columns = Vegas.columns.str.replace('\.*\s+', '_').str.lower()

# %% [markdown]
# ### aggregation

# %%
Vegas.score.groupby(Vegas.hotel_name).count()
# Out:
# hotel_name
# Bellagio Las Vegas                                     24
# Caesars Palace                                         24
# Circus Circus Hotel & Casino Las Vegas                 24
# Encore at wynn Las Vegas                               24
# Excalibur Hotel & Casino                               24
# Hilton Grand Vacations at the Flamingo                 24
# Hilton Grand Vacations on the Boulevard                24
# Marriott's Grand Chateau                               24
# Monte Carlo Resort&Casino                              24
# Paris Las Vegas                                        24
# The Cosmopolitan Las Vegas                             24
# The Cromwell                                           24
# The Palazzo Resort Hotel Casino                        24
# The Venetian Las Vegas Hotel                           24
# The Westin las Vegas Hotel Casino & Spa                24
# Treasure Island- TI Hotel & Casino                     24
# ...

# %%
Vegas.groupby(Vegas.hotel_name).count()
# Out:
#                                                     user_country  nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                            24          24
# Caesars Palace                                                24          24
# Circus Circus Hotel & Casino Las Vegas                        24          24
# Encore at wynn Las Vegas                                      24          24
# Excalibur Hotel & Casino                                      24          24
# Hilton Grand Vacations at the Flamingo                        24          24
# Hilton Grand Vacations on the Boulevard                       24          24
# Marriott's Grand Chateau                                      24          24
# Monte Carlo Resort&Casino                                     24          24
# Paris Las Vegas                                               24          24
# The Cosmopolitan Las Vegas                                    24          24
# ...

# %%
Vegas.score.groupby(Vegas.hotel_name, Vegas.pool).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/3473275737.py in <module>
# ----> 1 Vegas.score.groupby(Vegas.hotel_name, Vegas.pool).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1916         if level is None and by is None:
#    1917             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 1918         axis = self._get_axis_number(axis)
#    1919
#    1920         # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     548     def _get_axis_number(cls, axis: Axis) -> int:
#     549         try:
# ...

# %%
Vegas.score.groupby(Vegas.hotel_name).quantile(0.5)
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.50
# Caesars Palace                                        4.50
# Circus Circus Hotel & Casino Las Vegas                3.00
# Encore at wynn Las Vegas                              5.00
# Excalibur Hotel & Casino                              4.00
# Hilton Grand Vacations at the Flamingo                4.00
# Hilton Grand Vacations on the Boulevard               4.50
# Marriott's Grand Chateau                              5.00
# Monte Carlo Resort&Casino                             3.50
# Paris Las Vegas                                       4.00
# The Cosmopolitan Las Vegas                            5.00
# The Cromwell                                          4.50
# The Palazzo Resort Hotel Casino                       5.00
# The Venetian Las Vegas Hotel                          5.00
# The Westin las Vegas Hotel Casino & Spa               4.00
# Treasure Island- TI Hotel & Casino                    4.00
# ...

# %%
by_hotel = Vegas.groupby(Vegas.hotel_name)

# %%
type(by_hotel)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
by_hotel['score']

# %%
by_hotel['score'].min()
# Out:
# hotel_name
# Bellagio Las Vegas                                     2
# Caesars Palace                                         1
# Circus Circus Hotel & Casino Las Vegas                 1
# Encore at wynn Las Vegas                               1
# Excalibur Hotel & Casino                               2
# Hilton Grand Vacations at the Flamingo                 2
# Hilton Grand Vacations on the Boulevard                1
# Marriott's Grand Chateau                               3
# Monte Carlo Resort&Casino                              1
# Paris Las Vegas                                        2
# The Cosmopolitan Las Vegas                             1
# The Cromwell                                           1
# The Palazzo Resort Hotel Casino                        3
# The Venetian Las Vegas Hotel                           3
# The Westin las Vegas Hotel Casino & Spa                2
# Treasure Island- TI Hotel & Casino                     3
# ...

# %%
by_hotel['score'].quantile(0.5)
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.50
# Caesars Palace                                        4.50
# Circus Circus Hotel & Casino Las Vegas                3.00
# Encore at wynn Las Vegas                              5.00
# Excalibur Hotel & Casino                              4.00
# Hilton Grand Vacations at the Flamingo                4.00
# Hilton Grand Vacations on the Boulevard               4.50
# Marriott's Grand Chateau                              5.00
# Monte Carlo Resort&Casino                             3.50
# Paris Las Vegas                                       4.00
# The Cosmopolitan Las Vegas                            5.00
# The Cromwell                                          4.50
# The Palazzo Resort Hotel Casino                       5.00
# The Venetian Las Vegas Hotel                          5.00
# The Westin las Vegas Hotel Casino & Spa               4.00
# Treasure Island- TI Hotel & Casino                    4.00
# ...

# %%
# write own function

# %%
def minmax(pdseries):
    return np.max(pdseries) - np.min(pdseries)

# %%
by_hotel

# %%
by_hotel.agg(minmax)
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/3530225733.py:1: FutureWarning: ['user_country', 'period_of_stay', 'traveler_type', 'pool', 'gym', 'tennis_court', 'spa', 'casino', 'free_internet', 'hotel_stars', 'user_continent', 'review_month', 'review_weekday'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   by_hotel.agg(minmax)
#                                                     nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                          99
# Caesars Palace                                             157
# Circus Circus Hotel & Casino Las Vegas                     144
# Encore at wynn Las Vegas                                   330
# Excalibur Hotel & Casino                                   287
# Hilton Grand Vacations at the Flamingo                     288
# Hilton Grand Vacations on the Boulevard                    108
# ...

# %% [markdown]
# ---

# %%
Vegas.groupby(Vegas.hotel_name)

# %%
Vegas.groupby(Vegas.hotel_name).mean().head(5)
# Out:
#                                         nr_reviews  nr_hotel_reviews  \
# hotel_name
# Bellagio Las Vegas                           27.71             10.21
# Caesars Palace                               38.00             15.29
# Circus Circus Hotel & Casino Las Vegas       29.21              7.79
# Encore at wynn Las Vegas                     57.17             16.33
# Excalibur Hotel & Casino                     45.58             22.12
#
#                                         helpful_votes  score  nr_rooms  \
# hotel_name
# Bellagio Las Vegas                              24.88   4.21  3,933.00
# Caesars Palace                                  26.38   4.12  3,348.00
# Circus Circus Hotel & Casino Las Vegas          18.50   3.21  3,773.00
# Encore at wynn Las Vegas                        36.75   4.54  2,034.00
# Excalibur Hotel & Casino                        31.75   3.71  3,981.00
#
#                                         member_years
# hotel_name
# ...

# %%
Vegas['member_years'].groupby(Vegas[['hotel_name', 'pool']]).mean()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/3138190125.py in <module>
# ----> 1 Vegas['member_years'].groupby(Vegas[['hotel_name', 'pool']]).mean()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    1920         # error: Argument "squeeze" to "SeriesGroupBy" has incompatible type
#    1921         # "Union[bool, NoDefault]"; expected "bool"
# -> 1922         return SeriesGroupBy(
#    1923             obj=self,
#    1924             keys=by,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
# ...

# %% [markdown]
# ---

# %%
by_hotel = Vegas.groupby(Vegas.hotel_name)

# %%
by_hotel.score.mean()
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.21
# Caesars Palace                                        4.12
# Circus Circus Hotel & Casino Las Vegas                3.21
# Encore at wynn Las Vegas                              4.54
# Excalibur Hotel & Casino                              3.71
# Hilton Grand Vacations at the Flamingo                3.96
# Hilton Grand Vacations on the Boulevard               4.17
# Marriott's Grand Chateau                              4.54
# Monte Carlo Resort&Casino                             3.29
# Paris Las Vegas                                       4.04
# The Cosmopolitan Las Vegas                            4.25
# The Cromwell                                          4.08
# The Palazzo Resort Hotel Casino                       4.38
# The Venetian Las Vegas Hotel                          4.58
# The Westin las Vegas Hotel Casino & Spa               3.92
# Treasure Island- TI Hotel & Casino                    3.96
# ...

# %%
by_hotel.nr_reviews.agg(minmax).sort_values(ascending = False)
# Out:
# hotel_name
# Trump International Hotel Las Vegas                    774
# Tuscany Las Vegas Suites & Casino                      607
# Monte Carlo Resort&Casino                              575
# Wyndham Grand Desert                                   409
# Marriott's Grand Chateau                               366
# Encore at wynn Las Vegas                               330
# The Cromwell                                           318
# Hilton Grand Vacations at the Flamingo                 288
# Excalibur Hotel & Casino                               287
# The Palazzo Resort Hotel Casino                        248
# The Westin las Vegas Hotel Casino & Spa                180
# Wynn Las Vegas                                         162
# Caesars Palace                                         157
# Circus Circus Hotel & Casino Las Vegas                 144
# Paris Las Vegas                                        133
# Tropicana Las Vegas - A Double Tree by Hilton Hotel    125
# ...

# %% [markdown]
# ---

# %%
by_hotel

# %%
type(by_hotel)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
by_hotel.nr_hotel_reviews.mean()
# Out:
# hotel_name
# Bellagio Las Vegas                                    10.21
# Caesars Palace                                        15.29
# Circus Circus Hotel & Casino Las Vegas                 7.79
# Encore at wynn Las Vegas                              16.33
# Excalibur Hotel & Casino                              22.12
# Hilton Grand Vacations at the Flamingo                23.04
# Hilton Grand Vacations on the Boulevard               15.54
# Marriott's Grand Chateau                              30.42
# Monte Carlo Resort&Casino                             17.46
# Paris Las Vegas                                       11.46
# The Cosmopolitan Las Vegas                            10.12
# The Cromwell                                          20.96
# The Palazzo Resort Hotel Casino                       15.33
# The Venetian Las Vegas Hotel                          12.96
# The Westin las Vegas Hotel Casino & Spa               18.08
# ...

# %%
by_hotel['score'].agg(minmax)
# Out:
# hotel_name
# Bellagio Las Vegas                                     3
# Caesars Palace                                         4
# Circus Circus Hotel & Casino Las Vegas                 4
# Encore at wynn Las Vegas                               4
# Excalibur Hotel & Casino                               3
# Hilton Grand Vacations at the Flamingo                 3
# Hilton Grand Vacations on the Boulevard                4
# Marriott's Grand Chateau                               2
# Monte Carlo Resort&Casino                              4
# Paris Las Vegas                                        3
# The Cosmopolitan Las Vegas                             4
# The Cromwell                                           4
# The Palazzo Resort Hotel Casino                        2
# The Venetian Las Vegas Hotel                           2
# The Westin las Vegas Hotel Casino & Spa                3
# Treasure Island- TI Hotel & Casino                     2
# ...

# %%
by_hotel['score'].agg('mean', minmax)
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.21
# Caesars Palace                                        4.12
# Circus Circus Hotel & Casino Las Vegas                3.21
# Encore at wynn Las Vegas                              4.54
# Excalibur Hotel & Casino                              3.71
# Hilton Grand Vacations at the Flamingo                3.96
# Hilton Grand Vacations on the Boulevard               4.17
# Marriott's Grand Chateau                              4.54
# Monte Carlo Resort&Casino                             3.29
# Paris Las Vegas                                       4.04
# The Cosmopolitan Las Vegas                            4.25
# The Cromwell                                          4.08
# The Palazzo Resort Hotel Casino                       4.38
# The Venetian Las Vegas Hotel                          4.58
# The Westin las Vegas Hotel Casino & Spa               3.92
# Treasure Island- TI Hotel & Casino                    3.96
# ...

# %%
by_hotel['score'].agg('mean', minmax)
# Out:
# hotel_name
# Bellagio Las Vegas                                    4.21
# Caesars Palace                                        4.12
# Circus Circus Hotel & Casino Las Vegas                3.21
# Encore at wynn Las Vegas                              4.54
# Excalibur Hotel & Casino                              3.71
# Hilton Grand Vacations at the Flamingo                3.96
# Hilton Grand Vacations on the Boulevard               4.17
# Marriott's Grand Chateau                              4.54
# Monte Carlo Resort&Casino                             3.29
# Paris Las Vegas                                       4.04
# The Cosmopolitan Las Vegas                            4.25
# The Cromwell                                          4.08
# The Palazzo Resort Hotel Casino                       4.38
# The Venetian Las Vegas Hotel                          4.58
# The Westin las Vegas Hotel Casino & Spa               3.92
# Treasure Island- TI Hotel & Casino                    3.96
# ...

# %%
by_hotel['score'].agg(['mean', minmax, lambda x : x.mean() > 4])
# Out:
#                                                     mean  minmax  <lambda_0>
# hotel_name
# Bellagio Las Vegas                                  4.21       3        True
# Caesars Palace                                      4.12       4        True
# Circus Circus Hotel & Casino Las Vegas              3.21       4       False
# Encore at wynn Las Vegas                            4.54       4        True
# Excalibur Hotel & Casino                            3.71       3       False
# Hilton Grand Vacations at the Flamingo              3.96       3       False
# Hilton Grand Vacations on the Boulevard             4.17       4        True
# Marriott's Grand Chateau                            4.54       2        True
# Monte Carlo Resort&Casino                           3.29       4       False
# Paris Las Vegas                                     4.04       3        True
# The Cosmopolitan Las Vegas                          4.25       4        True
# ...

# %%
by_hotel['score'].agg(['mean', minmax, ('4+score', lambda x : x.mean() > 4)])
# Out:
#                                                     mean  \
# hotel_name
# Bellagio Las Vegas                                  4.21
# Caesars Palace                                      4.12
# Circus Circus Hotel & Casino Las Vegas              3.21
# Encore at wynn Las Vegas                            4.54
# Excalibur Hotel & Casino                            3.71
# Hilton Grand Vacations at the Flamingo              3.96
# Hilton Grand Vacations on the Boulevard             4.17
# Marriott's Grand Chateau                            4.54
# Monte Carlo Resort&Casino                           3.29
# Paris Las Vegas                                     4.04
# The Cosmopolitan Las Vegas                          4.25
# The Cromwell                                        4.08
# The Palazzo Resort Hotel Casino                     4.38
# The Venetian Las Vegas Hotel                        4.58
# The Westin las Vegas Hotel Casino & Spa             3.92
# ...

# %%
by_hotel['score'].agg(['mean', ('minmax', minmax), ('4+score', lambda x : x.mean() > 4)])
# Out:
#                                                     mean  minmax  4+score
# hotel_name
# Bellagio Las Vegas                                  4.21       3     True
# Caesars Palace                                      4.12       4     True
# Circus Circus Hotel & Casino Las Vegas              3.21       4    False
# Encore at wynn Las Vegas                            4.54       4     True
# Excalibur Hotel & Casino                            3.71       3    False
# Hilton Grand Vacations at the Flamingo              3.96       3    False
# Hilton Grand Vacations on the Boulevard             4.17       4     True
# Marriott's Grand Chateau                            4.54       2     True
# Monte Carlo Resort&Casino                           3.29       4    False
# Paris Las Vegas                                     4.04       3     True
# The Cosmopolitan Las Vegas                          4.25       4     True
# ...

# %%
by_hotel = Vegas.groupby(Vegas.hotel_name)

# %%
by_hotel.mean()
# Out:
#                                                     nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                       27.71
# Caesars Palace                                           38.00
# Circus Circus Hotel & Casino Las Vegas                   29.21
# Encore at wynn Las Vegas                                 57.17
# Excalibur Hotel & Casino                                 45.58
# Hilton Grand Vacations at the Flamingo                   48.42
# Hilton Grand Vacations on the Boulevard                  36.92
# Marriott's Grand Chateau                                 90.04
# Monte Carlo Resort&Casino                                71.83
# Paris Las Vegas                                          51.21
# The Cosmopolitan Las Vegas                               33.79
# The Cromwell                                             71.54
# The Palazzo Resort Hotel Casino                          44.92
# The Venetian Las Vegas Hotel                             32.04
# ...

# %%
by_hotel.agg('mean')
# Out:
#                                                     nr_reviews  \
# hotel_name
# Bellagio Las Vegas                                       27.71
# Caesars Palace                                           38.00
# Circus Circus Hotel & Casino Las Vegas                   29.21
# Encore at wynn Las Vegas                                 57.17
# Excalibur Hotel & Casino                                 45.58
# Hilton Grand Vacations at the Flamingo                   48.42
# Hilton Grand Vacations on the Boulevard                  36.92
# Marriott's Grand Chateau                                 90.04
# Monte Carlo Resort&Casino                                71.83
# Paris Las Vegas                                          51.21
# The Cosmopolitan Las Vegas                               33.79
# The Cromwell                                             71.54
# The Palazzo Resort Hotel Casino                          44.92
# The Venetian Las Vegas Hotel                             32.04
# ...

# %%
by_hotel.agg(['mean', minmax])
# Out:
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/1888959684.py:1: FutureWarning: ['user_country', 'period_of_stay', 'traveler_type', 'pool', 'gym', 'tennis_court', 'spa', 'casino', 'free_internet', 'hotel_stars', 'user_continent', 'review_month', 'review_weekday'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   by_hotel.agg(['mean', minmax])
#                                                    nr_reviews         \
#                                                          mean minmax
# hotel_name
# Bellagio Las Vegas                                      27.71     99
# Caesars Palace                                          38.00    157
# Circus Circus Hotel & Casino Las Vegas                  29.21    144
# Encore at wynn Las Vegas                                57.17    330
# Excalibur Hotel & Casino                                45.58    287
# ...

# %%
by_hotel[['score', 'member_years']].agg(['mean', minmax])
# Out:
#                                                    score        member_years  \
#                                                     mean minmax         mean
# hotel_name
# Bellagio Las Vegas                                  4.21      3         3.42
# Caesars Palace                                      4.12      4         4.75
# Circus Circus Hotel & Casino Las Vegas              3.21      4         3.83
# Encore at wynn Las Vegas                            4.54      4         4.75
# Excalibur Hotel & Casino                            3.71      3         4.50
# Hilton Grand Vacations at the Flamingo              3.96      3         3.96
# Hilton Grand Vacations on the Boulevard             4.17      4         4.79
# Marriott's Grand Chateau                            4.54      2         4.38
# Monte Carlo Resort&Casino                           3.29      4         3.58
# Paris Las Vegas                                     4.04      3         3.62
# ...

# %%
func_dict = {'score': 'mean', 'user_country': lambda x : (x != 'USA').mean()}

# %%
by_hotel.agg(func_dict)
# Out:
#                                                     score  user_country
# hotel_name
# Bellagio Las Vegas                                   4.21          0.67
# Caesars Palace                                       4.12          0.42
# Circus Circus Hotel & Casino Las Vegas               3.21          0.58
# Encore at wynn Las Vegas                             4.54          0.42
# Excalibur Hotel & Casino                             3.71          0.75
# Hilton Grand Vacations at the Flamingo               3.96          0.50
# Hilton Grand Vacations on the Boulevard              4.17          0.58
# Marriott's Grand Chateau                             4.54          0.67
# Monte Carlo Resort&Casino                            3.29          0.75
# Paris Las Vegas                                      4.04          0.38
# The Cosmopolitan Las Vegas                           4.25          0.62
# The Cromwell                                         4.08          0.38
# ...

# %%
new_df = by_hotel.agg(func_dict)

# %%
new_df
# Out:
#                                                     score  user_country
# hotel_name
# Bellagio Las Vegas                                   4.21          0.67
# Caesars Palace                                       4.12          0.42
# Circus Circus Hotel & Casino Las Vegas               3.21          0.58
# Encore at wynn Las Vegas                             4.54          0.42
# Excalibur Hotel & Casino                             3.71          0.75
# Hilton Grand Vacations at the Flamingo               3.96          0.50
# Hilton Grand Vacations on the Boulevard              4.17          0.58
# Marriott's Grand Chateau                             4.54          0.67
# Monte Carlo Resort&Casino                            3.29          0.75
# Paris Las Vegas                                      4.04          0.38
# The Cosmopolitan Las Vegas                           4.25          0.62
# The Cromwell                                         4.08          0.38
# ...

# %%
by_hotel.sample(5)
# Out:
#     user_country  nr_reviews  nr_hotel_reviews  helpful_votes  score  \
# 454        India           4                 4              1      4
# 444          USA          28                 5             23      5
# 441           UK          15                 6             17      5
# 448      Ireland          13                 3              2      5
# 432    Australia          16                 6              3      4
# ..           ...         ...               ...            ...    ...
# 211           UK           8                 4             16      5
# 202          USA          73                27            365      5
# 194       Canada           7                 5             20      4
# 206       Canada          67                46             99      5
# 192          USA         164                48             82      5
#
#     period_of_stay traveler_type pool  gym tennis_court  spa casino  \
# 454        Dec-Feb      Business  YES  YES           NO  YES    YES
# ...

# %%
type(by_hotel)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas').head()
# Out:
#   user_country  nr_reviews  nr_hotel_reviews  helpful_votes  score  \
# 0          USA          11                 4             13      5
# 1          USA         119                21             75      3
# 2          USA          36                 9             25      5
# 3           UK          14                 7             14      4
# 4       Canada           5                 5              2      4
#
#   period_of_stay traveler_type pool  gym tennis_court spa casino  \
# 0        Dec-Feb       Friends   NO  YES           NO  NO    YES
# 1        Dec-Feb      Business   NO  YES           NO  NO    YES
# 2        Mar-May      Families   NO  YES           NO  NO    YES
# 3        Mar-May       Friends   NO  YES           NO  NO    YES
# 4        Mar-May          Solo   NO  YES           NO  NO    YES
#
#   free_internet                              hotel_name hotel_stars  nr_rooms  \
# 0           YES  Circus Circus Hotel & Casino Las Vegas           3      3773
# ...

# %%
by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['pool']
# Out:
# 0     NO
# 1     NO
# 2     NO
# 3     NO
# 4     NO
# 5     NO
# 6     NO
# 7     NO
# 8     NO
# 9     NO
# 10    NO
# 11    NO
# 12    NO
# 13    NO
# 14    NO
# 15    NO
# 16    NO
# 17    NO
# 18    NO
# 19    NO
# 20    NO
# 21    NO
# 22    NO
# 23    NO
# Name: pool, dtype: object

# %%
by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['pool']
# Out:
# 0     NO
# 1     NO
# 2     NO
# 3     NO
# 4     NO
# 5     NO
# 6     NO
# 7     NO
# 8     NO
# 9     NO
# 10    NO
# 11    NO
# 12    NO
# 13    NO
# 14    NO
# 15    NO
# 16    NO
# 17    NO
# 18    NO
# 19    NO
# 20    NO
# 21    NO
# 22    NO
# 23    NO
# Name: pool, dtype: object

# %%
by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['pool'].first()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/xj/j51mz36s00z2vnfq7wp23hxm0000gn/T/ipykernel_94095/21201579.py in <module>
# ----> 1 by_hotel.get_group('Circus Circus Hotel & Casino Las Vegas')['pool'].first()
#
# TypeError: first() missing 1 required positional argument: 'offset'

# %%
by_hotel['pool'].first()
# Out:
# hotel_name
# Bellagio Las Vegas                                     YES
# Caesars Palace                                         YES
# Circus Circus Hotel & Casino Las Vegas                  NO
# Encore at wynn Las Vegas                               YES
# Excalibur Hotel & Casino                               YES
# Hilton Grand Vacations at the Flamingo                 YES
# Hilton Grand Vacations on the Boulevard                YES
# Marriott's Grand Chateau                               YES
# Monte Carlo Resort&Casino                              YES
# Paris Las Vegas                                        YES
# The Cosmopolitan Las Vegas                             YES
# The Cromwell                                           YES
# The Palazzo Resort Hotel Casino                        YES
# The Venetian Las Vegas Hotel                           YES
# The Westin las Vegas Hotel Casino & Spa                YES
# Treasure Island- TI Hotel & Casino                     YES
# ...

# %% [markdown]
# ---

# %%
def is_unique(gpseries):
    return len(gpseries.unique()) == 1

# %%
by_hotel['pool'].agg(is_unique)
# Out:
# hotel_name
# Bellagio Las Vegas                                     True
# Caesars Palace                                         True
# Circus Circus Hotel & Casino Las Vegas                 True
# Encore at wynn Las Vegas                               True
# Excalibur Hotel & Casino                               True
# Hilton Grand Vacations at the Flamingo                 True
# Hilton Grand Vacations on the Boulevard                True
# Marriott's Grand Chateau                               True
# Monte Carlo Resort&Casino                              True
# Paris Las Vegas                                        True
# The Cosmopolitan Las Vegas                             True
# The Cromwell                                           True
# The Palazzo Resort Hotel Casino                        True
# The Venetian Las Vegas Hotel                           True
# The Westin las Vegas Hotel Casino & Spa                True
# ...

# %%
by_hotel['pool'].agg(is_unique).all()
# Out:
# True

# %%
func_dict = {'score': 'mean',
            'user_country': lambda x : (x != 'USA').mean(),
             'gym' : 'first',
             'tennis_court': 'first',
             'spa' : 'first',
             'casino' : 'first',
             'free_internet': 'first',
             'hotel_stars': 'first',
             'nr_rooms' : 'first'
            }

# %%
hotel_df = by_hotel.agg(func_dict)

# %%
hotel_df
# Out:
#                                                     score  user_country  gym  \
# hotel_name
# Bellagio Las Vegas                                   4.21          0.67  YES
# Caesars Palace                                       4.12          0.42  YES
# Circus Circus Hotel & Casino Las Vegas               3.21          0.58  YES
# Encore at wynn Las Vegas                             4.54          0.42  YES
# Excalibur Hotel & Casino                             3.71          0.75  YES
# Hilton Grand Vacations at the Flamingo               3.96          0.50  YES
# Hilton Grand Vacations on the Boulevard              4.17          0.58  YES
# Marriott's Grand Chateau                             4.54          0.67  YES
# Monte Carlo Resort&Casino                            3.29          0.75  YES
# Paris Las Vegas                                      4.04          0.38  YES
# The Cosmopolitan Las Vegas                           4.25          0.62  YES
# ...

# %%
hotel_df.columns = ['mean_score', 'percent_non_usa'] + list(temp3.columns[2:])

# %%
hotel_df
# Out:
#                                                     mean_score  \
# hotel_name
# Bellagio Las Vegas                                        4.21
# Caesars Palace                                            4.12
# Circus Circus Hotel & Casino Las Vegas                    3.21
# Encore at wynn Las Vegas                                  4.54
# Excalibur Hotel & Casino                                  3.71
# Hilton Grand Vacations at the Flamingo                    3.96
# Hilton Grand Vacations on the Boulevard                   4.17
# Marriott's Grand Chateau                                  4.54
# Monte Carlo Resort&Casino                                 3.29
# Paris Las Vegas                                           4.04
# The Cosmopolitan Las Vegas                                4.25
# The Cromwell                                              4.08
# The Palazzo Resort Hotel Casino                           4.38
# The Venetian Las Vegas Hotel                              4.58
# ...

# %%
hotel_df.to_csv('gnhotels01.csv')
