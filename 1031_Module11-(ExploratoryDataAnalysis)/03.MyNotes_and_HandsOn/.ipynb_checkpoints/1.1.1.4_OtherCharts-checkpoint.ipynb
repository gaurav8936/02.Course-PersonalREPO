# %% [markdown]
# # Other Charts

# %% [markdown]
# ## Scatter Plot

# %% [markdown]
# ![image.png](attachment:c65952fe-3370-4ed7-abb9-9b0d1a3af92b.png)

# %% [markdown]
# ## 6-Plot

# %% [markdown]
# ![image.png](attachment:60f9f77c-dae3-478e-b6a6-f69335c62fc1.png)

# %% [markdown]
# ![image.png](attachment:29e137d1-1f57-487e-8448-6b53c9e60d96.png)
