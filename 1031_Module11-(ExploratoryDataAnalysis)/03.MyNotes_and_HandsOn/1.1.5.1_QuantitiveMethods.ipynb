# %% [markdown]
# # Quantative

# %% [markdown]
# ![image.png](attachment:79ef1fad-d74c-4ece-825c-6466bfea482a.png)

# %% [markdown]
# ## Hypothesis Tests

# %% [markdown]
# ![image.png](attachment:6fcaf63d-e2eb-4024-906d-b7f1bd3b4a93.png)

# %% [markdown]
# ## Analysis of Variances

# %% [markdown]
# ![image.png](attachment:594f3dad-4f78-4a3a-9904-d0f8128eeddf.png)

# %% [markdown]
# ## Point Estimates and Confidence Intervals

# %% [markdown]
# ![image.png](attachment:13ce1db2-384f-4fbb-b795-19a432c60924.png)

# %% [markdown]
# ## Least Squares Regression

# %% [markdown]
# ![image.png](attachment:f35acd6c-b4c3-43d8-a19d-3cd90844626c.png)
