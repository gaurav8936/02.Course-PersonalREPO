# %% [markdown]
# # The Role of Graphics

# %% [markdown]
# ![image.png](attachment:e62ca559-e90b-413d-a782-88837a9bbf93.png)

# %% [markdown]
# ![image.png](attachment:04d33455-2a97-4008-a7e9-eecbd46e5390.png)

# %% [markdown]
# ![image.png](attachment:704f6a28-ec06-4a36-a8ab-1171bb877e5e.png)

# %% [markdown]
# ![image.png](attachment:13be61cc-a8dd-4220-b3f1-e5ff43df8854.png)
