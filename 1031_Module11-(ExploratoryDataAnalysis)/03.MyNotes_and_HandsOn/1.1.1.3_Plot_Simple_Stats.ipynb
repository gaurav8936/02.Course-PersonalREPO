# %% [markdown]
# # Plot Simple Statistics

# %% [markdown]
# ## Mean Plot

# %% [markdown]
# ![image.png](attachment:ae5e5aa9-914c-441c-bed2-e3b34f0b40bd.png)

# %% [markdown]
# ![image.png](attachment:f1e0eafa-ba06-47eb-a1e1-479a5da65851.png)

# %% [markdown]
# ## Standard Deviation Plot

# %% [markdown]
# ![image.png](attachment:1906c1af-6ff6-4048-b72d-20e7b82191e2.png)

# %% [markdown]
# ![image.png](attachment:fd6b37d4-f656-4a3a-b734-e86aa675eeba.png)

# %% [markdown]
# ## Box Plot

# %% [markdown]
# ![image.png](attachment:98c1eb28-171a-49d2-9b50-745f6995cf0b.png)

# %% [markdown]
# ![image.png](attachment:75982aef-a244-4b03-8e24-00052fceea3c.png)
