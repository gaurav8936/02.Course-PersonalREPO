# %% [markdown]
# # EDA Graphics Example

# %% [markdown]
# ![image.png](attachment:2bae1130-0841-4402-8a1a-2db37f014a28.png)

# %% [markdown]
# ![image.png](attachment:51325e69-c706-4b08-a4f3-f3b0d8d45f4f.png)

# %% [markdown]
# ![image.png](attachment:97b4be33-3c88-4bf8-a6b3-fd453c0f02c3.png)

# %% [markdown]
# ![image.png](attachment:faa8e235-b33e-43a5-9472-76036104e77a.png)

# %% [markdown]
#     To illustrate the loss of information that results when the graphics insight step is skipped, consider the following three data sets

# %% [markdown]
# ![image.png](attachment:051060eb-720d-46c9-b91a-8e8a9dd4bb5e.png)

# %% [markdown]
#      One might naively assume that the two data sets are "equivalent" since that is what the statistics tell us; but what do the statistics not tell us?

# %% [markdown]
# ![image.png](attachment:7eb40670-c17b-455f-94af-fb598a116f05.png)

# %% [markdown]
#      implies that in some quantitative sense, all four of the data sets are "equivalent".
#
#      In fact, the four data sets are far from "equivalent" and a scatter plot of each data set, which would be step 1 of any EDA approach, would tell us that immediately.

# %% [markdown]
# ![image.png](attachment:55596973-fb2c-4292-ae56-22f152b160ea.png)

# %% [markdown]
# ![image.png](attachment:cf91c4b7-86a2-4c50-b9a7-9ca45d953dd1.png)

# %% [markdown]
# ![image.png](attachment:af9f616a-b46d-42b0-85d9-303dedc47a70.png)
