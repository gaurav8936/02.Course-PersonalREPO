# %% [markdown]
# # General Problem Categories - Problem Classification

# %% [markdown]
# # <font color = blue> Univariate and Control

# %% [markdown]
# ![image.png](attachment:95c8f6c6-50d9-4371-b1ac-8f818397b2ca.png)

# %% [markdown]
# # <font color = red> Univariate

# %% [markdown]
#     UNIVARIATE
#     Data:
#         A single column of numbers, Y.
#     Model:
#         y = constant + error
#     Output:
#         1. A number (the estimated constant in the model).
#         2. An estimate of uncertainty for the constant.
#         3. An estimate of the distribution for the error.
#     Techniques:
#         4-Plot
#         Probability Plot
#         PPCC Plot

# %% [markdown]
# #### 4-Plot

# %% [markdown]
# ![image.png](attachment:86f248b0-a39a-4cf6-a571-19d9269ebedd.png)

# %% [markdown]
# ![image.png](attachment:1ff7db85-9122-4412-a8ed-291561b25347.png)

# %% [markdown]
# #### Probability Plot

# %% [markdown]
# ![image.png](attachment:b1c11ead-990a-4b10-8fe3-96dc77ae609b.png)

# %% [markdown]
# #### PPCC Plot

# %% [markdown]
# ![image.png](attachment:dda3334b-f5a0-4c68-a67c-8c805ab7a1b9.png)

# %% [markdown]
# ![image.png](attachment:3b5ad528-c1b1-4e04-8b63-82454ba53f63.png)

# %% [markdown]
# # <font color = red>  Control

# %% [markdown]
#     CONTROL
#     Data:
#         A single column of numbers, Y.
#     Model:
#         y = constant + error
#     Output:
#         A "yes" or "no" to the question "Is the system out of control?".
#     Techniques:
#         Control Charts

# %% [markdown]
# ![image.png](attachment:66d7313d-d79d-444b-a5e9-e0f44c320703.png)

# %% [markdown]
# ---
