# %% [markdown]
# # Variables

# %% [markdown]
# ![image.png](attachment:56aeabfc-daeb-49fb-9b6e-8b57b4b4eb96.png)

# %% [markdown]
# ![image.png](attachment:30fb1ab5-7eff-4aa1-bc20-be822669fbb2.png)

# %% [markdown]
# ![image.png](attachment:76a5ed33-65cc-41ea-b9e0-01c10bc40f84.png)

# %% [markdown]
# ## Python evaluates the RIGHT HAND SIDE FIRST

# %%
# then the value of 1 is assigned to the variable a

# %% [markdown]
# ![image.png](attachment:d3c6bfb4-e6f5-4322-9007-e21dcd9d2587.png)

# %%
# a -= 1 is the same as a = a-1

# %% [markdown]
# ![image.png](attachment:312c9d66-0de5-40bb-87c9-3304d9bc35cd.png)

# %% [markdown]
# ## This is integer divide //

# %% [markdown]
# #### same as b = b // 5

# %% [markdown]
# ![image.png](attachment:9d27c3ef-db70-4bd2-8b11-61d50f4c17d9.png)

# %% [markdown]
# ![image.png](attachment:c407baed-c76b-4bbf-bf82-f9dbb3839d1d.png)

# %% [markdown]
# # Dynamic Typing

# %%
# variable can refer to one type of object -- then another

# %% [markdown]
# ![image.png](attachment:002868bf-a5ed-43a1-929a-aea37168063e.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:cd62fe9e-1279-42cf-9aeb-649d399cddcf.png)

# %%
# two ways to identify objects
## memory location
## variables

# %% [markdown]
# ![image.png](attachment:1228c139-9914-41c2-8039-bf4d76f7c05c.png)

# %% [markdown]
# ![image.png](attachment:5e9a5a09-2d05-4ad2-bcdd-9a73fe3b283b.png)

# %% [markdown]
# ![image.png](attachment:56b13e48-11f9-46be-8d27-dbe1a15195a7.png)

# %%
.
