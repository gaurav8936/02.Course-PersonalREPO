# %% [markdown]
# # Representing Numbers

# %% [markdown]
# ![image.png](attachment:e96974ee-e6d4-4cda-8394-719e107a51e7.png)

# %% [markdown]
# ![image.png](attachment:fc1dc531-d0bc-4460-8041-e4597fdc9ce4.png)

# %%
# in python you cannot store an infinite number of digits

# %%
# float generally stores 16 decimal places

# %%
# after 16 decimals -- rounding

# %%
1/10
# Out:
# 0.1

# %%
# you actually have a rounding error

# %% [markdown]
# ![image.png](attachment:8b586152-36f6-452e-bdbb-bc6c19c84b72.png)

# %%
# at a low level, everything is encoded as bits, 0s and 1s

# %%
# normally we work in base 10

# %%
# binary uses powers of 2 instead of powers of 10

# %% [markdown]
# ![image.png](attachment:d1e97028-c844-4200-98ec-39cc3f120979.png)

# %% [markdown]
# ![image.png](attachment:559723b2-f60c-4c9f-85f7-fa365d8c3fcf.png)

# %%
# 21/2 is stored as 10.01 (ie 2*1 + 0*1 + 0*1/2 + 1*1/4)

# %% [markdown]
# ![image.png](attachment:83ef0d37-3521-445a-9d71-db1c879187c5.png)

# %% [markdown]
# ![image.png](attachment:4c3b25c6-b3b4-4950-af5d-5fd2e2f8d61c.png)

# %% [markdown]
# ![image.png](attachment:597667fe-c74a-472a-8c19-30983667f6dc.png)

# %%
# this actually works perfectly in the case of 3.5

# %% [markdown]
# # Rounding Errors

# %% [markdown]
# ![image.png](attachment:7379884e-0fdf-46a4-bffc-569d6697aa8c.png)

# %%
# this is a non terminating decimal

# %%
# you cannot store this in a computer without a rounding error

# %%
# they might not be equal to each other even though we are expecting them to be

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:26f7777e-8ab7-4cd9-804d-69bb02b88dc7.png)

# %% [markdown]
# ![image.png](attachment:25a8188f-5412-4866-b4d1-5313988ba025.png)

# %% [markdown]
# ## when 2 integers are divided, it will ALWAYS be a float

# %% [markdown]
# ![image.png](attachment:ac9c9cd0-ae67-4795-b189-f7a94b143ace.png)

# %% [markdown]
# ## Integer Division

# %% [markdown]
# ### 14 // 5

# %% [markdown]
# ![image.png](attachment:9be02cb2-e683-450b-8ed4-9b4303fcd35a.png)

# %% [markdown]
# # Quotient (//) DOUBLE DIVIDER -- Remainder (%) MOD

# %% [markdown]
# ![image.png](attachment:893d5519-783e-49a7-8088-73aa7d81fd99.png)

# %%
5 * 2 + 4
# Out:
# 14

# %% [markdown]
# ![image.png](attachment:49feb5ad-9ae5-4686-901f-d6c26cb10a24.png)

# %% [markdown]
# # Use the == to check EQUALITY

# %% [markdown]
# ## the = is used for variable assignment

# %% [markdown]
# ---

# %% [markdown]
# # A float is only an approximation of a real number

# %%
0.1 + 0.1 + 0.3 == .3
# Out:
# False

# %%
# 0.1 in base 2 is a non termination float

# %%
0.1 + 0.1 + 0.1
# Out:
# 0.30000000000000004
