# %% [markdown]
# # Object and Types

# %% [markdown]
# ![image.png](attachment:31b9a2fa-9cc2-47f2-a546-a26fa78b3987.png)

# %% [markdown]
# ![image.png](attachment:05d0572b-47bd-43ac-836e-a98d4e73f43f.png)

# %%
# an object is just a container of data

# %% [markdown]
# ![image.png](attachment:11f3a2bd-6ca6-4fbf-96ce-6a0072fa389b.png)

# %% [markdown]
# ![image.png](attachment:7663d2f8-8a3c-4923-8e40-b5e12b8d5a11.png)

# %% [markdown]
# ![image.png](attachment:f80dcd0d-a541-4629-b2b9-63d04bd5951e.png)

# %% [markdown]
# ![image.png](attachment:bb6176d4-6c04-446d-9a9a-f27a03d028ce.png)

# %% [markdown]
# ![image.png](attachment:dc3063c0-65eb-4174-ac94-6c6901c21121.png)

# %%
# bool

# %%
# int

# %%
# str

# %%
# float

# %% [markdown]
# ![image.png](attachment:35841d29-35c3-4d02-b381-96084cd6e6bd.png)

# %% [markdown]
# ![image.png](attachment:e50f3392-590a-4161-8bb6-f8f6b7cc03c8.png)

# %% [markdown]
# ![image.png](attachment:eee39dd2-628b-4629-9e79-dbaa44e32ef2.png)

# %% [markdown]
# ### Constructor

# %% [markdown]
# ![image.png](attachment:29ab5922-8eda-4caf-84c5-ba7fb541ebae.png)

# %% [markdown]
# ![image.png](attachment:c825478b-bec7-4696-87e7-229abadf0e0a.png)

# %% [markdown]
# ![image.png](attachment:56b39c6f-ac9c-40f1-8fd7-853a45c714ea.png)

# %% [markdown]
# #### However the constructors do not work in all cases

# %% [markdown]
# ![image.png](attachment:dead17cd-38a7-4293-8e13-58774659bca2.png)

# %% [markdown]
# invalid literal for int

# %% [markdown]
# #### there can be workarounds by using nested constructors

# %% [markdown]
# ![image.png](attachment:8829dd4e-1742-4724-a747-079364533ae3.png)

# %% [markdown]
# The first conversino is from string to float -- and then from float to int

# %% [markdown]
# ## this is called Typecasting

# %% [markdown]
# #### Constructors are not just for typecasting (as above), but for other use cases as well

# %% [markdown]
# # Exercises

# %% [markdown]
# ![image.png](attachment:image.png)
