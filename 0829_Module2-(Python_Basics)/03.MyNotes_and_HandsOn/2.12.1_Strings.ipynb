# %% [markdown]
# # Strings

# %% [markdown]
# ![image.png](attachment:e0b36ef1-94c6-4828-9827-83d4dc2bc2cb.png)

# %%
# triple quotes

# %% [markdown]
# ![image.png](attachment:e469250f-1988-4e08-833c-3a4550b36cbc.png)

# %% [markdown]
# ## Note the symbol for escape --- \

# %% [markdown]
# ![image.png](attachment:37739b36-d008-4d4a-8526-e0fa35e8e69a.png)

# %% [markdown]
# ![image.png](attachment:ff891afc-6693-4856-8f7c-5bbae005131e.png)

# %% [markdown]
# ## Special Characters in Strings

# %%
x = "To be or not to be\nThat is a question"
print(x)
# Out:
# To be or not to be
# That is a question

# %%
# note the \n which is a special character

# %%
x = "to be or note to be \t that is the question"
print(x)
# Out:
# to be or note to be 	 that is the question

# %%
# this is a tab

# %%
x = "Shakespeare said: \"To be or note to be\""

print(x)
# Out:
# Shakespeare said: "To be or note to be"

# %%
# note the escapate for managing quotations as well

# %%
x = "I just wanted to use a backslash \\ in this example"
print(x)
# Out:
# I just wanted to use a backslash \ in this example

# %%
# the first backslash is escaping the second backslash

# %% [markdown]
# ---

# %%
a = "The "
b = "best class"
a + b
# Out:
# 'The best class'

# %%
# the plus sign is concatanation

# %% [markdown]
# ### duplication

# %%
a*4
# Out:
# 'The The The The '

# %% [markdown]
# ***

# %% [markdown]
# ## String Index

# %%
s = "Absolute"

print(s[0])
# Out:
# A

# %%
print(s[1])
# Out:
# b

# %%
print(s[-1])
# Out:
# e

# %% [markdown]
# ---

# %% [markdown]
# # Slicing

# %%
print(s[1:4])
# Out:
# bso

# %%
s[1:-1]
# Out:
# 'bsolut'

# %%
# the above is from the second character to the last but one character

# %%
# STEP SIZE

# %%
s[0:6:2]
# Out:
# 'Asl'

# %%
# the step size jumps a character in between

# %%
s[1:]
# Out:
# 'bsolute'

# %%
s[:1]
# Out:
# 'A'

# %%
s[:-1]
# Out:
# 'Absolut'

# %% [markdown]
# ### reversing a string

# %%
s[::-1]
# Out:
# 'etulosbA'

# %%
# this has a negative step size

# %%
s[:]
# Out:
# 'Absolute'

# %%
s[:3]
# Out:
# 'Abs'

# %%
s[1:]
# Out:
# 'bsolute'

# %%
s[3:]
# Out:
# 'olute'

# %%
s[:-1]
# Out:
# 'Absolut'

# %% [markdown]
# ## Change Case

# %%
s.upper()
# Out:
# 'ABSOLUTE'

# %%
s.lower()
# Out:
# 'absolute'

# %%
s.title()
# Out:
# 'Absolute'

# %% [markdown]
# ## User Input

# %%
name = input("Please enter your name")
# Out:
# Please enter your name Ziba

# %%
name[::-1]
# Out:
# 'abiZ'

# %% [markdown]
# ### Whatever that is collected as input will be a STRING

# %%
num = input("please enter a number")
# Out:
# please enter a number 8

# %%
type(num)
# Out:
# str

# %% [markdown]
# ***

# %% [markdown]
# # Formatting Strings

# %%
name = "Rob"
money = 10.343

# %%
# string concatantion method

str_con = ("My name is " + name and "I have " + str(money) + " in my wallet")

print(str_con)
# Out:
# I have 10.343 in my wallet

# %% [markdown]
# ## f-String

# %%
f_str = f"My name is {name} and I have {money} in my wallet"

print(f_str)
# Out:
# My name is Rob and I have 10.343 in my wallet

# %% [markdown]
# #### this solves a big issue with spacing and conciseness

# %% [markdown]
# ## Format a float

# %%
str_con = ("My name is " + name and "I have " + str(round(money, 2)) + " in my wallet")
           
print(str_con)
# Out:
# I have 10.34 in my wallet

# %% [markdown]
# ---

# %%
f_str = f"My name is {name} and I have {money:.2} in my wallet"

print(f_str)
# Out:
# My name is Rob and I have 1e+01 in my wallet

# %% [markdown]
# ![image.png](attachment:e0514918-aa7d-4b48-930b-f22590b17ff6.png)

# %%
# note this gives the output in scientific notation (e)

# %%
f_str = f"My name is {name} and I have {money:.2f} in my wallet"

print(f_str)
# Out:
# My name is Rob and I have 10.34 in my wallet

# %% [markdown]
# ## Field Width

# %%
price = 12

print(f"""Price: {price:10.2f}

taxes: {price*0.10:10.2f}

Total: {price+price*0.10:10.2f}

""")
# Out:
# Price:      12.00
#
# taxes:       1.20
#
# Total:      13.20

# %%
# # the 0.10 is the 10%, the enxt 10 is fro 10 decimal places and
