# %% [markdown]
# # Python Intro - 08282022

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 0

while x > 10:
    x += 1
    x = x-10
    print(x)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# high level languages

# R

# PERL

# Visual Basic

# Ruby

# Javascript

# Go

# Python

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# slightly higher level language -- Assembly language

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# c writes in machine code

# Java writes in object code

# %%
# python is technically not a 100% interpreted language

# %% [markdown]
# ### Python is complied into BYTE CODE in the background (this is an extra step)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# .POI file -- for python files

# %%
# jupyter notebook adn jupyter lab

# %%
# Jupyter Lab is actually a newer interface

# %% [markdown]
# ---

# %%
# combination of both programming and communication

# %%
7+7
# Out:
# 14

# %% [markdown]
# *hello*
