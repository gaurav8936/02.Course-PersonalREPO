# %% [markdown]
# # Receiving Arguments from the Command Line

# %% [markdown]
# ![image.png](attachment:1df4d9dc-43a1-44e6-ab8a-a5b2579dcbdb.png)

# %% [markdown]
# ![image.png](attachment:cce01907-eb2b-4775-8172-018a58781cd0.png)

# %% [markdown]
# ## arguments are passsed as a list

# %%
# first element of the list is the file itself

# %% [markdown]
# ![image.png](attachment:925d28bb-06a4-44f8-8cf6-5b4d6c705c5b.png)

# %% [markdown]
# ![image.png](attachment:ce9ed7a0-9252-4f91-9510-9ed61de37e87.png)

# %% [markdown]
# ![image.png](attachment:86e448c3-2e71-4dc3-ac41-61d0e4bda259.png)

# %% [markdown]
# ![image.png](attachment:a44893e6-1e7b-4cb2-a5c6-d8544021669c.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:4ddb8fc6-d00a-4e06-848a-dd4ca6510c9e.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:4577fb77-71fd-483a-b4bd-912fc18aa7f8.png)

# %% [markdown]
# ![image.png](attachment:5f1c5499-5ea8-413f-91db-6cff5e511727.png)

# %% [markdown]
# ---

# %% [markdown]
# ## Error when not having the required number of arguments

# %% [markdown]
# ![image.png](attachment:e9dfdf23-8214-4114-9387-ab874bdced6c.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:f8eb8c5b-be5e-41d7-9192-57f0fdbf28b9.png)
