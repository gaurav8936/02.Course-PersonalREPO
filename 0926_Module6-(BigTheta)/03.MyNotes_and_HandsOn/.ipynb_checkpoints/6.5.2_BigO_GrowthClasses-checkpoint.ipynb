# %% [markdown]
# # Big O Growth Classes

# %% [markdown]
# ![image.png](attachment:8026f8c2-fe0f-4656-80d7-cfd7434f5553.png)

# %%
# theta(c**n)

# %%
#theta(1) is the fastest

# %%
# theta(constant**n) -- these are the longest

# %%
# theta(c**n)

# theta(c**3)

# theta(c**2)

# theta(n log n)

# theta(n)

# theta(logn)

# theta(1)

# %% [markdown]
# ![image.png](attachment:b643febd-6295-4956-b151-44cab6c69cf6.png)

# %%
# for a datascientist, we should see this as a continium

# %% [markdown]
# ![image.png](attachment:c2728777-f8f9-4e2e-b956-5702abff936f.png)

# %%
# theta(n **3)

# a billion rows of data ** 3 is impractal

# %%
# theta (log n) is great for any online tasks

# %% [markdown]
# ![image.png](attachment:6a288038-58d3-4489-b640-06afc7f109c5.png)

# %% [markdown]
# # adding a log does not change the growth rate much

# %%
# the exponential growth rate is the only exception

# %%
# these are cases of theta (c ** n)

# %%
# theta(c**n) ---> Exponential

# theta(c**3) ---> Cubic

# theta(c**2) ---> Quadratic

# theta(n log n) ---> N Log N

# theta(n) ---> Linear

# theta(logn) ---> Logarithmic

# theta(1) ---> Constant
