# %% [markdown]
# ![image.png](attachment:b7fc5291-9e1a-4fd1-8254-be15074c8a97.png)

# %% [markdown]
# ![image.png](attachment:dc3ca6c2-4291-4e0f-a7f0-b84ca9da705e.png)

# %%
# input size (number of rows of data) typically determines the number of steps

# %% [markdown]
# ![image.png](attachment:17aaca0b-49f7-43fb-958f-4a9c72d4b915.png)

# %%
# field of study called Big-O

# %%
# simply growth rate functions

# %%
# Big-O
# Big Omega
# Big Theta

# %% [markdown]
# ![image.png](attachment:a063a90b-bd5a-4f5d-a3ea-aeb35b584aff.png)

# %%
# we will focus on Big-Theta

# %% [markdown]
# ![image.png](attachment:d6ab52e5-79c9-44ca-ac19-78de44142fe4.png)

# %%
# delete lower order terms

# %% [markdown]
# ![image.png](attachment:a96718c5-8dfa-451d-b4fb-ff2f4a574fba.png)

# %% [markdown]
# ![image.png](attachment:d0611216-9e5a-49d7-b289-23ed64a088df.png)

# %% [markdown]
# ![image.png](attachment:bb362906-2144-42d9-914a-5d1be57a30ac.png)

# %%
# 2n**2 dominates the other terms

# %%
# we can safely ignore the other terms

# %% [markdown]
# ![image.png](attachment:fc1dac54-ae72-413d-ab01-09184ff7d545.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:ac9b2a14-efa3-4bef-83b9-935978667338.png)

# %%
# there are techniques to rewrite the algorigthm that does not use 2

# %% [markdown]
# ![image.png](attachment:dc5e7439-dd1d-4dfd-af65-e3f4839ceed8.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:2973e903-c485-4b29-9b2d-f9ad4690162a.png)

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:575df2a0-a2e5-442b-9145-a6e3499cdc10.png)

# %%
# log 1 = 0

# %% [markdown]
# ![image.png](attachment:06edb082-ba6c-4731-8c29-dc20533de326.png)

# %% [markdown]
# ![image.png](attachment:4181ece7-25e9-4675-a995-aa2da03d6452.png)

# %%
# log of 10 base 10 is 1

# %%
# log base 10 of 1000 is 3

# %% [markdown]
# ![image.png](attachment:47bdd284-8a16-47ee-9d80-3e0340cc0bd7.png)

# %%
# log base 10 does not really add much

# %%
# logs tend to grow very slowly

# %% [markdown]
# ![image.png](attachment:dd2e7ad7-de7c-4cce-9129-edb68f836647.png)

# %%
# logn is somewhere between n and 1

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:2dd7735f-cd48-4653-9ba0-82c676676ad0.png)

# %%
# while log base 10 is most common, we will see log base 2 in our problems as well

# %%
# all logs are exactly the same

# %% [markdown]
# ---

# %% [markdown]
# ![image.png](attachment:e5e131c9-fbee-4be5-ba00-47d96d32ca76.png)

# %%
# the first one will always take longer

# %%
#2nlog(base10)n + 100n = nlogn
