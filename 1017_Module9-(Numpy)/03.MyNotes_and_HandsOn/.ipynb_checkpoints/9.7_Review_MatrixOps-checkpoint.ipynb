# %% [markdown]
# # Review of Matrix Operations

# %% [markdown]
# ![image.png](attachment:f52c690a-3487-4e3f-945a-b7ab331fba46.png)

# %% [markdown]
# ![image.png](attachment:a67de92d-6771-4d01-9648-2a6a7d779709.png)

# %% [markdown]
# ![image.png](attachment:c8bbaf1e-954d-47ad-9b43-ef2baa6c344d.png)

# %% [markdown]
# ![image.png](attachment:41493d71-6eb9-4689-844c-1a43ea46a6d5.png)

# %% [markdown]
# ![image.png](attachment:501d2768-7720-4faf-9fe8-723c98a7844b.png)

# %% [markdown]
# ![image.png](attachment:ad5f65a4-b412-45aa-b72b-17c1479c811a.png)

# %%
# look at the inner dimensions

# they have to equal each other

# %% [markdown]
# ![image.png](attachment:5173af3d-1bc9-4283-bad6-0cf71a4c2d3b.png)

# %%
# B X A will not be allowed

# %% [markdown]
# ![image.png](attachment:a04b094c-5550-4ebd-9748-dd67a8e2d427.png)

# %% [markdown]
# ![image.png](attachment:cb8f7f32-24c9-4110-95d4-863d2c9b1562.png)

# %% [markdown]
# ![image.png](attachment:eec0e764-c45f-4ca2-a94d-728d991cb43d.png)

# %% [markdown]
# ![image.png](attachment:a8164d47-fadb-413e-9965-412f5fbfa0d9.png)

# %% [markdown]
# ![image.png](attachment:885774b9-e091-4b7e-988d-2f8d77470730.png)

# %% [markdown]
# ![image.png](attachment:5bc27c0f-ce82-4564-bbfb-c63e39c07067.png)

# %% [markdown]
# ![image.png](attachment:f505b268-99d6-4aa7-b7d0-a51ae75213b1.png)
