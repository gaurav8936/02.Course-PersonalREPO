# %% [markdown]
# # Linear Model in Matrix Form

# %%
# applications of matrices in data science

# %% [markdown]
# ![image.png](attachment:3eac0834-0d73-460d-be83-3f9f498ab07b.png)

# %%
# y1 = subject 1
# y2 = subject 2

# %% [markdown]
# ---

# %%
# row vector with Xs

# column vector with Ys

# %% [markdown]
# ![image.png](attachment:e9a62a3b-942e-494d-b593-6c0cbed3c66b.png)

# %% [markdown]
# ![image.png](attachment:dfb1db31-499a-440d-8b44-d3630e08e5f3.png)

# %% [markdown]
# ![image.png](attachment:76b94577-c630-4a03-81ed-feb3044033f7.png)

# %% [markdown]
# ![image.png](attachment:6b0a485c-c3ee-4fb2-9f55-7816ce6cede5.png)

# %% [markdown]
# ![image.png](attachment:7b710fec-e18f-4f21-bffb-12bf7e67e2b9.png)

# %%
# the middle X is called the DESIGN MATRIX
